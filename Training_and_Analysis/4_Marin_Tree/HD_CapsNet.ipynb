# %% [markdown]
# ***
# <font size="6"><center><b> HD-CapsNet: A Hierarchical Deep Capsule Network for Image Classification </b></center></font>
# ***

# %% [markdown]
# **Changing Model Architecture**
# - **(Mod-3.1)** 32D>16D>8D (Coarse>Medium>FINE) use skip connections between Secondary Capsules $Concatenate([P_{caps}, S_{coarse}])$ > input for $S_{medium}$ and $Concatenate([P_{caps}, S_{medium}])$ > input for $S_{fine}$
# - With $L_{Cons}$

# %% [markdown]
# # Files and Libraries

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras import regularizers, optimizers
from tensorflow.keras import backend as K

import tensorflow_docs as tfdocs
import tensorflow_docs.plots

# Supporting Libraries:
    #Mathplot lib for ploting graphs
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
    # numpy and pandas
import numpy as np
import pandas as pd
    #system
import os
import sys
import csv
    #import other libraries
import math
import random
from datetime import datetime
from treelib import Tree
    # ML model, Dataset and evalution metrics
sys.path.append('../../') ### adding system parth for src folder
from src import datasets # load datasets
from src import MixUp # load datasets
from src import MixUp_add_loss # load datasets
from src import metrics # load hierarchcial metrics
from src import sysenv # load hierarchcial metrics
from src import models # load machine learning models

    ## Tensorflow_docs
import tensorflow_docs as tfdocs
import tensorflow_docs.plots

    # Auto reload local libraries if updated
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # System information & GPU growth

# %%
systeminfo = sysenv.systeminfo()
print(systeminfo)
# Out:
# • Computer Name = posix
# • Working Directory = /home/knoor/Downloads/RunningOnServer/HD-CapsNet_MTree/Training_and_Analysis/7_Marin_Tree
# • Python Version = 3.9.16 (main, Mar  8 2023, 14:00:05)
# [GCC 11.2.0]
# • TensorFlow Version = 2.8.4
# • Keras Version = 2.8.0
# • Current Environment = Not Using Anaconda

# %%
gpus = "0,1,2,3,4,5,6,7" ## Selecting Available gpus (Multi-GPUS)
gpus = "1" ## Selecting Available gpus (Single GPU)
gpugrowth = sysenv.gpugrowth(gpus = gpus) ## Limiting GPUS from OS environment
gpugrowth.memory_growth() #GPU memory growth
# Out:
# Following GPUS are selected =  1
# Done: GPU PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# 1 Physical GPUs, 1 Logical GPUs
# 2023-04-13 11:20:08.167341: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-13 11:20:08.996056: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 20608 MB memory:  -> device: 0, name: Tesla V100-PCIE-32GB, pci bus id: 0000:86:00.0, compute capability: 7.0

# %% [markdown]
# # Parameters

# %%
train_params = {"n_epochs" : 100,
                "batch_size": 64,
                "lr": 0.001, # Initial learning rate
                "lr_decay": 0.95, # Learning rate decay
                "decay_exe": 9, #learning rate decay execution epoch after
               }
model_params = {"optimizer": tf.keras.optimizers.Adam(train_params['lr']),
                "loss_function": models.MarginLoss(),
               }

# %% [markdown]
# # log directory

# %%
directory = sysenv.log_dir('7_Marine_Tree/HD_CapsNet/Mod_3_3')
# Out:
# FOLDER CREATED =  ../../logs/7_Marine_Tree/HD_CapsNet/Mod_3_3

# %% [markdown]
# # Import Dataset : Marine Tree Dataset

# %%
dataset = datasets.get_Marine_dataset(output_level='level_depth_3', # 'level_depth_3', 'level_depth_4', 'level_depth_5
#                                       dataset_path ='D:\Datasets\Marine_tree', ## Path to the dataset directory
                                      dataset_path ='/home/knoor/Downloads/RunningOnServer/H-CapsNet_Revision/Dataset/Marine_tree', ## Path to the dataset directory
                                      image_size=(64,64),
                                      batch_size=train_params['batch_size'],
                                      subtype='Combined',
                                      data_normalizing ='normalize',
                                      class_encoding = 'One_Hot_Encoder',
                                      data_augmantation = 'mixup'
                                     )

# %%
for x,y in dataset.train_dataset.take(1):
    for i in range(len(x)):
        print('Example = ', i)
        plt.imshow(x[i])
        plt.show()
        print('Coarse =', {k:v for k,v in enumerate(y[0][i].numpy()) if v != 0}) # coarse lables
        print('Medium =', {k:v for k,v in enumerate(y[1][i].numpy()) if v != 0}) # medium lables
        print('Fine   =', {k:v for k,v in enumerate(y[2][i].numpy()) if v != 0}) # fine lables
# Out:
# 2023-04-13 11:20:27.577694: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:390] Filling up shuffle buffer (this may take a while): 5447 of 6400
# 2023-04-13 11:20:28.952515: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:415] Shuffle buffer filled.
# Example =  0
# Coarse = {0: 1.0}
# Medium = {7: 1.0}
# Fine   = {1: 0.8873789, 33: 0.112621106}
# Example =  1
# Coarse = {0: 1.0}
# Medium = {7: 1.0}
# Fine   = {4: 1.0}
# Example =  2
# Coarse = {0: 1.0}
# Medium = {7: 1.0}
# Fine   = {4: 0.961441, 10: 0.038559016}
# Example =  3
# Coarse = {0: 1.0}
# Medium = {0: 0.026788414, 7: 0.9732116}
# Fine   = {31: 0.026788414, 33: 0.9732116}
# Example =  4
# Coarse = {0: 1.0}
# Medium = {7: 1.0}
# Fine   = {7: 0.99147654, 33: 0.008523486}
# Example =  5
# Coarse = {0: 1.0}
# Medium = {7: 1.0}
# Fine   = {0: 0.054237306, 4: 0.9457627}
# Example =  6
# Coarse = {0: 0.9069765, 1: 0.09302348}
# Medium = {7: 0.9069765, 9: 0.09302348}
# Fine   = {0: 0.9069765, 14: 0.09302348}
# Example =  7
# Coarse = {0: 1.0}
# Medium = {7: 1.0}
# Fine   = {4: 0.9130494, 33: 0.0869506}
# Example =  8
# Coarse = {0: 1.0}
# Medium = {7: 1.0}
# Fine   = {4: 0.9999125, 33: 8.749962e-05}
# Example =  9
# Coarse = {0: 0.8153901, 1: 0.18460989}
# Medium = {7: 0.8153901, 9: 0.18460989}
# Fine   = {15: 0.18460989, 33: 0.8153901}
# Example =  10
# Coarse = {0: 1.0}
# Medium = {7: 1.0}
# Fine   = {33: 1.0}
# Example =  11
# Coarse = {0: 1.0}
# Medium = {7: 1.0}
# Fine   = {7: 1.1840479e-05, 33: 0.99998814}
# Example =  12
# Coarse = {0: 1.0}
# Medium = {7: 1.0}
# Fine   = {0: 0.16657579, 7: 0.8334242}
# Example =  13
# Coarse = {0: 1.0}
# Medium = {7: 1.0}
# Fine   = {7: 0.15007144, 33: 0.84992856}
# Example =  14
# Coarse = {1: 1.0}
# Medium = {9: 1.0}
# Fine   = {15: 1.0}
# Example =  15
# Coarse = {0: 1.0}
# Medium = {7: 1.0}
# Fine   = {33: 1.0}
# Example =  16
# Coarse = {0: 0.10131511, 1: 0.89868486}
# Medium = {1: 0.10131511, 9: 0.89868486}
# Fine   = {15: 0.89868486, 32: 0.10131511}
# Example =  17
# Coarse = {0: 1.0}
# Medium = {7: 1.0}
# Fine   = {7: 1.257658e-05, 33: 0.9999874}
# Example =  18
# Coarse = {0: 0.9991129, 1: 0.00088709104}
# Medium = {1: 0.9991129, 9: 0.00088709104}
# Fine   = {14: 0.00088709104, 32: 0.9991129}
# Example =  19
# Coarse = {0: 1.0}
# Medium = {1: 0.95582896, 7: 0.044171035}
# Fine   = {32: 0.95582896, 33: 0.044171035}
# Example =  20
# Coarse = {0: 1.0}
# Medium = {7: 1.0}
# Fine   = {1: 0.9733088, 10: 0.026691217}
# Example =  21
# Coarse = {0: 1.0}
# Medium = {7: 1.0}
# Fine   = {33: 0.95731765, 34: 0.042682357}
# Example =  22
# Coarse = {0: 1.0}
# Medium = {1: 0.97670215, 7: 0.023297846}
# Fine   = {10: 0.023297846, 32: 0.97670215}
# Example =  23
# Coarse = {0: 1.0}
# Medium = {7: 1.0}
# Fine   = {0: 0.6368975, 7: 0.3631025}
# Example =  24
# Coarse = {0: 1.0}
# Medium = {7: 1.0}
# Fine   = {7: 1.0}
# Example =  25
# Coarse = {0: 1.0}
# Medium = {7: 1.0}
# Fine   = {4: 0.8206328, 33: 0.17936718}
# Example =  26
# Coarse = {0: 1.0}
# Medium = {7: 1.0}
# Fine   = {33: 1.0}
# Example =  27
# Coarse = {0: 1.0}
# Medium = {7: 1.0}
# Fine   = {10: 0.98896796, 33: 0.011032038}
# Example =  28
# Coarse = {0: 1.0}
# Medium = {0: 1.0}
# Fine   = {28: 0.21967185, 30: 0.78032815}
# Example =  29
# Coarse = {0: 0.57430494, 1: 0.42569506}
# Medium = {7: 0.57430494, 9: 0.42569506}
# Fine   = {8: 0.57430494, 11: 0.42569506}
# Example =  30
# Coarse = {0: 1.0}
# Medium = {1: 0.6801064, 7: 0.31989363}
# Fine   = {10: 0.31989363, 32: 0.6801064}
# Example =  31
# Coarse = {0: 1.0}
# Medium = {7: 1.0}
# Fine   = {33: 1.0}
# Example =  32
# Coarse = {0: 0.15119998, 1: 0.8488}
# Medium = {7: 0.15119998, 9: 0.8488}
# Fine   = {15: 0.8488, 33: 0.15119998}
# Example =  33
# Coarse = {0: 1.0}
# Medium = {7: 1.0}
# Fine   = {7: 0.23543155, 33: 0.76456845}
# Example =  34
# Coarse = {0: 1.0}
# Medium = {7: 1.0}
# Fine   = {0: 2.3841858e-07, 33: 0.99999976}
# Example =  35
# Coarse = {0: 0.00023370377, 1: 0.9997663}
# Medium = {6: 0.00023370377, 9: 0.9997663}
# Fine   = {15: 0.9997663, 25: 0.00023370377}
# Example =  36
# Coarse = {0: 1.0}
# Medium = {7: 0.0030918717, 8: 0.9969081}
# Fine   = {23: 0.9969081, 36: 0.0030918717}
# Example =  37
# Coarse = {0: 1.0}
# Medium = {7: 1.0}
# Fine   = {10: 0.18389939, 33: 0.8161006}
# Example =  38
# Coarse = {0: 1.0}
# Medium = {3: 0.9998738, 7: 0.00012618303}
# Fine   = {26: 0.9998738, 33: 0.00012618303}
# Example =  39
# Coarse = {0: 1.0}
# Medium = {7: 1.0}
# Fine   = {10: 0.73975706, 33: 0.26024294}
# Example =  40
# Coarse = {0: 1.0}
# Medium = {7: 1.0}
# Fine   = {33: 0.92892, 36: 0.07108002}
# Example =  41
# Coarse = {0: 1.0}
# Medium = {7: 1.0}
# Fine   = {33: 0.9548776, 36: 0.045122404}
# Example =  42
# Coarse = {0: 1.0}
# Medium = {7: 1.0}
# Fine   = {0: 0.99998444, 33: 1.5556812e-05}
# Example =  43
# Coarse = {0: 1.0}
# Medium = {7: 1.0}
# Fine   = {7: 0.98876494, 33: 0.011235086}
# Example =  44
# Coarse = {0: 1.0}
# Medium = {7: 1.0}
# Fine   = {33: 6.562025e-10, 34: 1.0}
# Example =  45
# Coarse = {0: 1.0}
# Medium = {7: 1.0}
# Fine   = {0: 7.8082085e-06, 10: 0.9999922}
# Example =  46
# Coarse = {0: 1.0}
# Medium = {7: 1.0}
# Fine   = {33: 1.0}
# Example =  47
# Coarse = {0: 1.0}
# Medium = {0: 0.9723138, 7: 0.027686173}
# Fine   = {28: 0.9723138, 33: 0.027686173}
# Example =  48
# Coarse = {0: 0.47955358, 1: 0.5204464}
# Medium = {7: 0.47955358, 9: 0.5204464}
# Fine   = {10: 0.47955358, 14: 0.5204464}
# Example =  49
# Coarse = {0: 1.0}
# Medium = {7: 1.0}
# Fine   = {0: 0.0077190995, 2: 0.9922809}
# Example =  50
# Coarse = {0: 1.0}
# Medium = {7: 1.0}
# Fine   = {7: 6.221463e-05, 33: 0.9999378}
# Example =  51
# Coarse = {0: 0.46520254, 1: 0.53479743}
# Medium = {1: 0.46520254, 9: 0.53479743}
# Fine   = {15: 0.53479743, 32: 0.46520254}
# Example =  52
# Coarse = {0: 1.0}
# Medium = {7: 1.0}
# Fine   = {10: 0.036582053, 33: 0.96341795}
# Example =  53
# Coarse = {0: 1.0}
# Medium = {7: 1.0}
# Fine   = {1: 0.85307276, 10: 0.14692724}
# Example =  54
# Coarse = {0: 1.0}
# Medium = {7: 1.0}
# Fine   = {4: 0.050712705, 10: 0.9492873}
# Example =  55
# Coarse = {0: 1.0}
# Medium = {6: 0.999566, 7: 0.00043398142}
# Fine   = {25: 0.999566, 33: 0.00043398142}
# Example =  56
# Coarse = {0: 1.0}
# Medium = {0: 0.05020356, 1: 0.94979644}
# Fine   = {28: 0.05020356, 32: 0.94979644}
# Example =  57
# Coarse = {0: 0.0037142038, 1: 0.9962858}
# Medium = {7: 0.0037142038, 9: 0.9962858}
# Fine   = {15: 0.9962858, 33: 0.0037142038}
# Example =  58
# Coarse = {0: 1.0}
# Medium = {1: 0.030551255, 7: 0.96944875}
# Fine   = {21: 0.030551255, 33: 0.96944875}
# Example =  59
# Coarse = {0: 0.5664652, 1: 0.4335348}
# Medium = {7: 0.5664652, 9: 0.4335348}
# Fine   = {15: 0.4335348, 33: 0.5664652}
# Example =  60
# Coarse = {0: 1.0}
# Medium = {7: 1.0}
# Fine   = {0: 9.853791e-06, 33: 0.99999017}
# Example =  61
# Coarse = {0: 1.0}
# Medium = {7: 1.0}
# Fine   = {0: 0.97072816, 7: 0.029271824}
# Example =  62
# Coarse = {0: 1.0}
# Medium = {0: 0.004262036, 7: 0.99573797}
# Fine   = {31: 0.004262036, 33: 0.99573797}
# Example =  63
# Coarse = {0: 1.0}
# Medium = {1: 0.92608505, 7: 0.073914945}
# Fine   = {32: 0.92608505, 33: 0.073914945}

# %%
for x,y in dataset.train_dataset.take(1):
    image_shape = x.shape[1:]
    coarse_label_shape = y[0].shape[1:]
    medium_label_shape = y[1].shape[1:]
    fine_label_shape = y[2].shape[1:]

# %% [markdown]
# ## Learning Rate Decay Scheduler

# %%
def scheduler(epoch):
    learning_rate_init = train_params["lr"]
    
    if epoch > train_params["decay_exe"]:
        learning_rate_init = train_params["lr"] * (train_params["lr_decay"] ** (epoch-9))
        
    tf.summary.scalar('learning rate', data=learning_rate_init, step=epoch)
        
    return learning_rate_init

# %% [markdown]
# # Model Architecture

# %% [markdown]
# ## Loss Function

# %%
coarse_class, medium_class, fine_class = dataset.num_classes

## For Dynamic LossWeights
initial_lw = models.initial_lw({"coarse": coarse_class,
                                 "medium": medium_class,
                                 "fine": fine_class})

lossweight = {'coarse_lw' : K.variable(value = initial_lw['coarse'], dtype="float32", name="coarse_lw"),
             'medium_lw' : K.variable(value = initial_lw['medium'], dtype="float32", name="medium_lw"),
             'fine_lw' : K.variable(value = initial_lw['fine'], dtype="float32", name="fine_lw"),
              'decoder_lw' : 0.0
             }

# %%
Matrix_coarse_to_medium_OneHot = dataset.Matrix_coarse_to_medium_OneHot
Matrix_medium_to_fine_OneHot = dataset.Matrix_medium_to_fine_OneHot

# %%
def margin_loss(y_true, y_proba):
    
    present_error_raw = tf.square(tf.maximum(0., 0.9 - y_proba), name="present_error_raw")
    absent_error_raw = tf.square(tf.maximum(0., y_proba - 0.1), name="absent_error_raw")
    L = tf.add(y_true * present_error_raw, 0.5 * (1.0 - y_true) * absent_error_raw,name="L")
    total_marginloss = tf.reduce_sum(L, axis=1, name="margin_loss")

    return total_marginloss


def consistency_check(y_pred_ancestor,y_pred_current,lookup_matrix,num_class_current):
    pred_max_ancestor = tf.argmax(y_pred_ancestor,axis=1)
    pred_max_current = tf.argmax(y_pred_current,axis=1)
    
    consistant_check = tf.gather(lookup_matrix, indices=pred_max_ancestor)*tf.one_hot(pred_max_current,num_class_current)
    
    return tf.reduce_sum(consistant_check,1)

def get_consistency(y_true_ancestor, y_pred, lookup_matrix):
    '''
    Get consistency based on 2 levels
    Provide ture levels for the level above, predictions for the current level and a look up metrix
    '''
    y_prob = tf.math.divide(y_pred,tf.reshape(tf.reduce_sum(y_pred,-1),(-1,1),name='reshape'),name='Probability')
    
    index_for_predictions = tf.cast(tf.math.argmax(y_true_ancestor,axis=1),dtype= 'int32')
    consistent_fine = tf.gather(lookup_matrix, indices=index_for_predictions) * y_prob
    Consistency_sum_array = tf.reduce_sum(consistent_fine, axis =1)
    
    return tf.abs(1-Consistency_sum_array)

def CustomLoss(y_true_c, y_true_m, y_true_f, y_pred_c, y_pred_m, y_pred_f, LW_C, LW_M, LW_F,
               number_of_classes_m, number_of_classes_f, C_Weight=0.2):
    
    con_m = consistency_check(y_pred_c,y_pred_m,Matrix_coarse_to_medium_OneHot,num_class_current=number_of_classes_m)
    con_m_not = tf.abs(con_m-1)
    
    con_f = consistency_check(y_pred_m,y_pred_f,Matrix_medium_to_fine_OneHot,num_class_current=number_of_classes_f)
    con_f_not = tf.abs(con_f-1)
    
    con_sum_m = get_consistency(y_true_c,y_pred_m,Matrix_coarse_to_medium_OneHot)
    con_sum_f = get_consistency(y_true_m,y_pred_f,Matrix_medium_to_fine_OneHot)
    
    medium_lvl_cosistency = con_sum_m * con_m_not
    fine_lvl_cosistency = con_sum_f * con_f_not    
   
    ML_c = margin_loss(y_true_c, y_pred_c)*LW_C
    ML_m = LW_M*((1-C_Weight)*(margin_loss(y_true_m, y_pred_m))+C_Weight*(medium_lvl_cosistency))
    ML_f = LW_F*((1-C_Weight)*(margin_loss(y_true_f, y_pred_f))+C_Weight*(fine_lvl_cosistency))
    
    batch_loss = ML_c + ML_m+ ML_f

    return tf.reduce_mean(batch_loss)

# %% [markdown]
# ## Architecture

# %%
def get_compiled_model():
    
    ## Calling the HD-CapsNet Model
    model = models.HD_CapsNet_Mod_3_3(input_shape     = image_shape, 
                                      input_shape_yc  = coarse_label_shape,
                                      input_shape_ym  = medium_label_shape,
                                      input_shape_yf  = fine_label_shape, 
                                      no_coarse_class = coarse_class, 
                                      no_medium_class = medium_class, 
                                      no_fine_class   = fine_class,
                                      PCap_n_dims     = 8, 
                                      SCap_f_dims     = 16, 
                                      SCap_m_dims     = 32, 
                                      SCap_c_dims     = 64)
    
    ## Saving Model Architecture
    keras.utils.plot_model(model, to_file = directory+"/Architecture.png", show_shapes=True)
    
    ## Add Loss for Model
    model.add_loss(CustomLoss(y_true_c            = model.inputs[1], 
                              y_true_m            = model.inputs[2], 
                              y_true_f            = model.inputs[3], 
                              y_pred_c            = model.output[0], 
                              y_pred_m            = model.output[1], 
                              y_pred_f            = model.output[2], 
                              LW_C                = lossweight['coarse_lw'], 
                              LW_M                = lossweight['medium_lw'], 
                              LW_F                = lossweight['fine_lw'],
                              number_of_classes_m = medium_class, 
                              number_of_classes_f = fine_class, 
                              C_Weight            =0.2)
                  )
    
    ## Compile Model
    model.compile(optimizer='adam',                  
                  metrics={'prediction_fine': 'accuracy',
                           'prediction_medium': 'accuracy',
                           'prediction_coarse': 'accuracy'}
                 )
    return model

# %% [markdown]
# ## Compile Model

# %%
model = get_compiled_model()
# Out:
# WARNING:tensorflow:The following Variables were used in a Lambda layer's call (tf.math.multiply_9), but are not present in its tracked objects:   <tf.Variable 'coarse_lw:0' shape=() dtype=float32>. This is a strong indication that the Lambda layer should be rewritten as a subclassed Layer.

# %% [raw]
# strategy = models.multi_gpu_select('windows')
#
# print("Number of devices: {}".format(strategy.num_replicas_in_sync))
#
# with strategy.scope():
#     # Everything that creates variables should be under the strategy scope.
#     # In general this is only model construction & `compile()`.
#     model = get_compiled_model()

# %%
model.summary()
# keras.utils.plot_model(model, to_file = directory+"/Architecture.png", show_shapes=True)
# Out:
# Model: "HD-CapsNet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Input_Image (InputLayer)       [(None, 64, 64, 3)]  0           []
#
#  block1_conv1 (Conv2D)          (None, 64, 64, 64)   1792        ['Input_Image[0][0]']
#
#  batch_normalization (BatchNorm  (None, 64, 64, 64)  256         ['block1_conv1[0][0]']
#  alization)
#
#  block1_conv2 (Conv2D)          (None, 64, 64, 64)   36928       ['batch_normalization[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 64, 64, 64)  256         ['block1_conv2[0][0]']
#  rmalization)
#
#  block1_pool (MaxPooling2D)     (None, 32, 32, 64)   0           ['batch_normalization_1[0][0]']
#
#  block2_conv1 (Conv2D)          (None, 32, 32, 128)  73856       ['block1_pool[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 32, 32, 128)  512        ['block2_conv1[0][0]']
#  rmalization)
#
#  block2_conv2 (Conv2D)          (None, 32, 32, 128)  147584      ['batch_normalization_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 32, 32, 128)  512        ['block2_conv2[0][0]']
#  rmalization)
#
#  block2_pool (MaxPooling2D)     (None, 16, 16, 128)  0           ['batch_normalization_3[0][0]']
#
#  block3_conv1 (Conv2D)          (None, 16, 16, 256)  295168      ['block2_pool[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 16, 16, 256)  1024       ['block3_conv1[0][0]']
#  rmalization)
#
#  block3_conv2 (Conv2D)          (None, 16, 16, 256)  590080      ['batch_normalization_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 16, 16, 256)  1024       ['block3_conv2[0][0]']
#  rmalization)
#
#  block3_pool (MaxPooling2D)     (None, 8, 8, 256)    0           ['batch_normalization_5[0][0]']
#
#  block4_conv1 (Conv2D)          (None, 8, 8, 512)    1180160     ['block3_pool[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 8, 8, 512)   2048        ['block4_conv1[0][0]']
#  rmalization)
#
#  block4_conv2 (Conv2D)          (None, 8, 8, 512)    2359808     ['batch_normalization_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 8, 8, 512)   2048        ['block4_conv2[0][0]']
#  rmalization)
#
#  block4_pool (MaxPooling2D)     (None, 4, 4, 512)    0           ['batch_normalization_7[0][0]']
#
#  reshape_layer (Reshape)        (None, 1024, 8)      0           ['block4_pool[0][0]']
#
#  p_caps (Lambda)                (None, 1024, 8)      0           ['reshape_layer[0][0]']
#
#  s_caps_coarse (SecondaryCapsul  (None, 2, 64)       1048576     ['p_caps[0][0]']
#  e)
#
#  primary_skip_m (Reshape)       (None, 128, 64)      0           ['p_caps[0][0]']
#
#  skip_connection_m (Concatenate  (None, 130, 64)     0           ['primary_skip_m[0][0]',
#  )                                                                's_caps_coarse[0][0]']
#
#  s_caps_medium (SecondaryCapsul  (None, 10, 32)      2662400     ['skip_connection_m[0][0]']
#  e)
#
#  primary_skip_f (Reshape)       (None, 256, 32)      0           ['p_caps[0][0]']
#
#  skip_connection_f (Concatenate  (None, 266, 32)     0           ['primary_skip_f[0][0]',
#  )                                                                's_caps_medium[0][0]']
#
#  s_caps_fine (SecondaryCapsule)  (None, 38, 16)      5175296     ['skip_connection_f[0][0]']
#
#  input_yc (InputLayer)          [(None, 2)]          0           []
#
#  input_ym (InputLayer)          [(None, 10)]         0           []
#
#  input_yf (InputLayer)          [(None, 38)]         0           []
#
#  prediction_coarse (LengthLayer  (None, 2)           0           ['s_caps_coarse[0][0]']
#  )
#
#  prediction_medium (LengthLayer  (None, 10)          0           ['s_caps_medium[0][0]']
#  )
#
#  prediction_fine (LengthLayer)  (None, 38)           0           ['s_caps_fine[0][0]']
#
#  tf.math.argmax_4 (TFOpLambda)  (None,)              0           ['input_yc[0][0]']
#
#  tf.math.reduce_sum_2 (TFOpLamb  (None,)             0           ['prediction_medium[0][0]']
#  da)
#
#  tf.cast (TFOpLambda)           (None,)              0           ['tf.math.argmax_4[0][0]']
#
#  tf.reshape (TFOpLambda)        (None, 1)            0           ['tf.math.reduce_sum_2[0][0]']
#
#  tf.math.argmax (TFOpLambda)    (None,)              0           ['prediction_coarse[0][0]']
#
#  tf.math.argmax_1 (TFOpLambda)  (None,)              0           ['prediction_medium[0][0]']
#
#  tf.math.argmax_5 (TFOpLambda)  (None,)              0           ['input_ym[0][0]']
#
#  tf.math.reduce_sum_4 (TFOpLamb  (None,)             0           ['prediction_fine[0][0]']
#  da)
#
#  tf.math.subtract_7 (TFOpLambda  (None, 10)          0           ['prediction_medium[0][0]']
#  )
#
#  tf.math.subtract_8 (TFOpLambda  (None, 10)          0           ['prediction_medium[0][0]']
#  )
#
#  tf.compat.v1.gather_2 (TFOpLam  (None, 10)          0           ['tf.cast[0][0]']
#  bda)
#
#  tf.math.divide (TFOpLambda)    (None, 10)           0           ['prediction_medium[0][0]',
#                                                                   'tf.reshape[0][0]']
#
#  tf.compat.v1.gather (TFOpLambd  (None, 10)          0           ['tf.math.argmax[0][0]']
#  a)
#
#  tf.one_hot (TFOpLambda)        (None, 10)           0           ['tf.math.argmax_1[0][0]']
#
#  tf.cast_1 (TFOpLambda)         (None,)              0           ['tf.math.argmax_5[0][0]']
#
#  tf.reshape_1 (TFOpLambda)      (None, 1)            0           ['tf.math.reduce_sum_4[0][0]']
#
#  tf.math.argmax_2 (TFOpLambda)  (None,)              0           ['prediction_medium[0][0]']
#
#  tf.math.argmax_3 (TFOpLambda)  (None,)              0           ['prediction_fine[0][0]']
#
#  tf.math.maximum_2 (TFOpLambda)  (None, 10)          0           ['tf.math.subtract_7[0][0]']
#
#  tf.math.subtract_9 (TFOpLambda  (None, 10)          0           ['input_ym[0][0]']
#  )
#
#  tf.math.maximum_3 (TFOpLambda)  (None, 10)          0           ['tf.math.subtract_8[0][0]']
#
#  tf.math.multiply_2 (TFOpLambda  (None, 10)          0           ['tf.compat.v1.gather_2[0][0]',
#  )                                                                'tf.math.divide[0][0]']
#
#  tf.math.multiply (TFOpLambda)  (None, 10)           0           ['tf.compat.v1.gather[0][0]',
#                                                                   'tf.one_hot[0][0]']
#
#  tf.math.subtract_10 (TFOpLambd  (None, 38)          0           ['prediction_fine[0][0]']
#  a)
#
#  tf.math.subtract_11 (TFOpLambd  (None, 38)          0           ['prediction_fine[0][0]']
#  a)
#
#  tf.compat.v1.gather_3 (TFOpLam  (None, 38)          0           ['tf.cast_1[0][0]']
#  bda)
#
#  tf.math.divide_1 (TFOpLambda)  (None, 38)           0           ['prediction_fine[0][0]',
#                                                                   'tf.reshape_1[0][0]']
#
#  tf.compat.v1.gather_1 (TFOpLam  (None, 38)          0           ['tf.math.argmax_2[0][0]']
#  bda)
#
#  tf.one_hot_1 (TFOpLambda)      (None, 38)           0           ['tf.math.argmax_3[0][0]']
#
#  tf.math.subtract_4 (TFOpLambda  (None, 2)           0           ['prediction_coarse[0][0]']
#  )
#
#  tf.math.subtract_5 (TFOpLambda  (None, 2)           0           ['prediction_coarse[0][0]']
#  )
#
#  tf.math.square_2 (TFOpLambda)  (None, 10)           0           ['tf.math.maximum_2[0][0]']
#
#  tf.math.multiply_11 (TFOpLambd  (None, 10)          0           ['tf.math.subtract_9[0][0]']
#  a)
#
#  tf.math.square_3 (TFOpLambda)  (None, 10)           0           ['tf.math.maximum_3[0][0]']
#
#  tf.math.reduce_sum_3 (TFOpLamb  (None,)             0           ['tf.math.multiply_2[0][0]']
#  da)
#
#  tf.math.reduce_sum (TFOpLambda  (None,)             0           ['tf.math.multiply[0][0]']
#  )
#
#  tf.math.maximum_4 (TFOpLambda)  (None, 38)          0           ['tf.math.subtract_10[0][0]']
#
#  tf.math.subtract_12 (TFOpLambd  (None, 38)          0           ['input_yf[0][0]']
#  a)
#
#  tf.math.maximum_5 (TFOpLambda)  (None, 38)          0           ['tf.math.subtract_11[0][0]']
#
#  tf.math.multiply_3 (TFOpLambda  (None, 38)          0           ['tf.compat.v1.gather_3[0][0]',
#  )                                                                'tf.math.divide_1[0][0]']
#
#  tf.math.multiply_1 (TFOpLambda  (None, 38)          0           ['tf.compat.v1.gather_1[0][0]',
#  )                                                                'tf.one_hot_1[0][0]']
#
#  tf.math.maximum (TFOpLambda)   (None, 2)            0           ['tf.math.subtract_4[0][0]']
#
#  tf.math.subtract_6 (TFOpLambda  (None, 2)           0           ['input_yc[0][0]']
#  )
#
#  tf.math.maximum_1 (TFOpLambda)  (None, 2)           0           ['tf.math.subtract_5[0][0]']
#
#  tf.math.multiply_10 (TFOpLambd  (None, 10)          0           ['input_ym[0][0]',
#  a)                                                               'tf.math.square_2[0][0]']
#
#  tf.math.multiply_12 (TFOpLambd  (None, 10)          0           ['tf.math.multiply_11[0][0]',
#  a)                                                               'tf.math.square_3[0][0]']
#
#  tf.math.subtract_2 (TFOpLambda  (None,)             0           ['tf.math.reduce_sum_3[0][0]']
#  )
#
#  tf.math.subtract (TFOpLambda)  (None,)              0           ['tf.math.reduce_sum[0][0]']
#
#  tf.math.square_4 (TFOpLambda)  (None, 38)           0           ['tf.math.maximum_4[0][0]']
#
#  tf.math.multiply_17 (TFOpLambd  (None, 38)          0           ['tf.math.subtract_12[0][0]']
#  a)
#
#  tf.math.square_5 (TFOpLambda)  (None, 38)           0           ['tf.math.maximum_5[0][0]']
#
#  tf.math.reduce_sum_5 (TFOpLamb  (None,)             0           ['tf.math.multiply_3[0][0]']
#  da)
#
#  tf.math.reduce_sum_1 (TFOpLamb  (None,)             0           ['tf.math.multiply_1[0][0]']
#  da)
#
#  tf.math.square (TFOpLambda)    (None, 2)            0           ['tf.math.maximum[0][0]']
#
#  tf.math.multiply_7 (TFOpLambda  (None, 2)           0           ['tf.math.subtract_6[0][0]']
#  )
#
#  tf.math.square_1 (TFOpLambda)  (None, 2)            0           ['tf.math.maximum_1[0][0]']
#
#  tf.math.add_1 (TFOpLambda)     (None, 10)           0           ['tf.math.multiply_10[0][0]',
#                                                                   'tf.math.multiply_12[0][0]']
#
#  tf.math.abs_2 (TFOpLambda)     (None,)              0           ['tf.math.subtract_2[0][0]']
#
#  tf.math.abs (TFOpLambda)       (None,)              0           ['tf.math.subtract[0][0]']
#
#  tf.math.multiply_16 (TFOpLambd  (None, 38)          0           ['input_yf[0][0]',
#  a)                                                               'tf.math.square_4[0][0]']
#
#  tf.math.multiply_18 (TFOpLambd  (None, 38)          0           ['tf.math.multiply_17[0][0]',
#  a)                                                               'tf.math.square_5[0][0]']
#
#  tf.math.subtract_3 (TFOpLambda  (None,)             0           ['tf.math.reduce_sum_5[0][0]']
#  )
#
#  tf.math.subtract_1 (TFOpLambda  (None,)             0           ['tf.math.reduce_sum_1[0][0]']
#  )
#
#  tf.math.multiply_6 (TFOpLambda  (None, 2)           0           ['input_yc[0][0]',
#  )                                                                'tf.math.square[0][0]']
#
#  tf.math.multiply_8 (TFOpLambda  (None, 2)           0           ['tf.math.multiply_7[0][0]',
#  )                                                                'tf.math.square_1[0][0]']
#
#  tf.math.reduce_sum_7 (TFOpLamb  (None,)             0           ['tf.math.add_1[0][0]']
#  da)
#
#  tf.math.multiply_4 (TFOpLambda  (None,)             0           ['tf.math.abs_2[0][0]',
#  )                                                                'tf.math.abs[0][0]']
#
#  tf.math.add_2 (TFOpLambda)     (None, 38)           0           ['tf.math.multiply_16[0][0]',
#                                                                   'tf.math.multiply_18[0][0]']
#
#  tf.math.abs_3 (TFOpLambda)     (None,)              0           ['tf.math.subtract_3[0][0]']
#
#  tf.math.abs_1 (TFOpLambda)     (None,)              0           ['tf.math.subtract_1[0][0]']
#
#  tf.math.add (TFOpLambda)       (None, 2)            0           ['tf.math.multiply_6[0][0]',
#                                                                   'tf.math.multiply_8[0][0]']
#
#  tf.math.multiply_13 (TFOpLambd  (None,)             0           ['tf.math.reduce_sum_7[0][0]']
#  a)
#
#  tf.math.multiply_14 (TFOpLambd  (None,)             0           ['tf.math.multiply_4[0][0]']
#  a)
#
#  tf.math.reduce_sum_8 (TFOpLamb  (None,)             0           ['tf.math.add_2[0][0]']
#  da)
#
#  tf.math.multiply_5 (TFOpLambda  (None,)             0           ['tf.math.abs_3[0][0]',
#  )                                                                'tf.math.abs_1[0][0]']
#
#  tf.math.reduce_sum_6 (TFOpLamb  (None,)             0           ['tf.math.add[0][0]']
#  da)
#
#  tf.__operators__.add (TFOpLamb  (None,)             0           ['tf.math.multiply_13[0][0]',
#  da)                                                              'tf.math.multiply_14[0][0]']
#
#  tf.math.multiply_19 (TFOpLambd  (None,)             0           ['tf.math.reduce_sum_8[0][0]']
#  a)
#
#  tf.math.multiply_20 (TFOpLambd  (None,)             0           ['tf.math.multiply_5[0][0]']
#  a)
#
#  tf.math.multiply_9 (TFOpLambda  (None,)             0           ['tf.math.reduce_sum_6[0][0]']
#  )
#
#  tf.math.multiply_15 (TFOpLambd  (None,)             0           ['tf.__operators__.add[0][0]']
#  a)
#
#  tf.__operators__.add_1 (TFOpLa  (None,)             0           ['tf.math.multiply_19[0][0]',
#  mbda)                                                            'tf.math.multiply_20[0][0]']
#
#  tf.__operators__.add_2 (TFOpLa  (None,)             0           ['tf.math.multiply_9[0][0]',
#  mbda)                                                            'tf.math.multiply_15[0][0]']
#
#  tf.math.multiply_21 (TFOpLambd  (None,)             0           ['tf.__operators__.add_1[0][0]']
#  a)
#
#  tf.__operators__.add_3 (TFOpLa  (None,)             0           ['tf.__operators__.add_2[0][0]',
#  mbda)                                                            'tf.math.multiply_21[0][0]']
#
#  tf.math.reduce_mean (TFOpLambd  ()                  0           ['tf.__operators__.add_3[0][0]']
#  a)
#
#  add_loss (AddLoss)             ()                   0           ['tf.math.reduce_mean[0][0]']
#
# ==================================================================================================
# Total params: 13,579,328
# Trainable params: 13,575,488
# Non-trainable params: 3,840
# __________________________________________________________________________________________________

# %% [markdown]
# ## Training Pipeline Alignment

# %%
#### Matching the pipeling with model inputs
def pipeline_multi_input_output(image, label):
    label_0 = label[0]
    label_1 = label[1]
    label_2 = label[2]
    return (image, label_0, label_1, label_2), (label_0, label_1, label_2)

training_dataset_match = dataset.train_dataset.map(pipeline_multi_input_output) ## Mixup dataset
val_dataset_match = dataset.val_dataset.map(pipeline_multi_input_output) ## Val Dataset

# %% [markdown]
# ## Callback

# %%
tb = keras.callbacks.TensorBoard(directory+'./tb_logs'+ datetime.now().strftime("%Y%m%d-%H%M%S"))
log = keras.callbacks.CSVLogger(directory+'/log.csv', append=True)

checkpoint = keras.callbacks.ModelCheckpoint(directory+'/epoch-best.h5',
                                             monitor='val_prediction_fine_accuracy',
                                             save_best_only=True, 
                                             save_weights_only=True, 
                                             verbose=1)

change_lw = models.LossWeightsModifier(lossweight = lossweight,
                                       initial_lw = initial_lw,
                                       directory = directory)

lr_decay = keras.callbacks.LearningRateScheduler(scheduler)

# %% [markdown]
# ## Model Training

# %%
model_save_dir = str(directory+'/trained_model.h5')
try:
    model.load_weights(model_save_dir)
except:
    history = model.fit(training_dataset_match,
                        epochs = train_params["n_epochs"],
                        validation_data = val_dataset_match,
                        callbacks = [tb,log,change_lw,lr_decay,checkpoint],
                        verbose=1)
    
    model.save_weights(model_save_dir)
# Out:
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring... Layer tf.math.multiply_9 was passed non-JSON-serializable arguments. Arguments had types: {'y': <class 'tensorflow.python.ops.resource_variable_ops.ResourceVariable'>, 'name': <class 'NoneType'>}. They cannot be serialized out when saving the model.
# Epoch 1/100
# 2023-04-13 11:21:39.801976: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8100
# 2023-04-13 11:21:46.155809: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-04-13 11:21:46.306859: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] RESOURCE_EXHAUSTED: /tmp/tempfile-luthin-7c88ddac-203387-5f92d8c4dcae4; No space left on device
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
#    6/1848 [..............................] - ETA: 2:13 - loss: 0.7942 - prediction_coarse_accuracy: 0.6719 - prediction_medium_accuracy: 0.4401 - prediction_fine_accuracy: 0.2500WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0373s vs `on_train_batch_end` time: 0.0875s). Check your callbacks.
# 1848/1848 [==============================] - ETA: 0s - loss: 0.1776 - prediction_coarse_accuracy: 0.8567 - prediction_medium_accuracy: 0.7047 - prediction_fine_accuracy: 0.3678
#   • Coarse Accuracy = 85.67% | Val_Accuracy = 85.77% | LossWeight = 0.26
#   • Medium Accuracy = 70.47% | Val_Accuracy = 71.34% | LossWeight = 0.45
#   • Fine   Accuracy = 36.78% | Val_Accuracy = 38.25% | LossWeight = 0.29
#
# Epoch 1: val_prediction_fine_accuracy improved from -inf to 0.38253, saving model to ../../logs/7_Marine_Tree/HD_CapsNet/Mod_3_3/epoch-best.h5
# 1848/1848 [==============================] - 410s 202ms/step - loss: 0.1776 - prediction_coarse_accuracy: 0.8567 - prediction_medium_accuracy: 0.7047 - prediction_fine_accuracy: 0.3678 - val_loss: 0.1702 - val_prediction_coarse_accuracy: 0.8577 - val_prediction_medium_accuracy: 0.7134 - val_prediction_fine_accuracy: 0.3825 - lr: 0.0010
# Epoch 2/100
# 2023-04-13 11:28:54.947986: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:390] Filling up shuffle buffer (this may take a while): 3344 of 6400
# 2023-04-13 11:28:59.655674: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:415] Shuffle buffer filled.
# 1848/1848 [==============================] - ETA: 0s - loss: 0.1404 - prediction_coarse_accuracy: 0.8593 - prediction_medium_accuracy: 0.7105 - prediction_fine_accuracy: 0.3929
#   • Coarse Accuracy = 85.93% | Val_Accuracy = 85.84% | LossWeight = 0.26
#   • Medium Accuracy = 71.05% | Val_Accuracy = 70.77% | LossWeight = 0.45
#   • Fine   Accuracy = 39.29% | Val_Accuracy = 38.60% | LossWeight = 0.28
#
# Epoch 2: val_prediction_fine_accuracy improved from 0.38253 to 0.38600, saving model to ../../logs/7_Marine_Tree/HD_CapsNet/Mod_3_3/epoch-best.h5
# 1848/1848 [==============================] - 509s 265ms/step - loss: 0.1404 - prediction_coarse_accuracy: 0.8593 - prediction_medium_accuracy: 0.7105 - prediction_fine_accuracy: 0.3929 - val_loss: 0.1479 - val_prediction_coarse_accuracy: 0.8584 - val_prediction_medium_accuracy: 0.7077 - val_prediction_fine_accuracy: 0.3860 - lr: 0.0010
# Epoch 3/100
# 2023-04-13 11:37:24.505278: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:390] Filling up shuffle buffer (this may take a while): 6195 of 6400
# 2023-04-13 11:37:25.052639: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:415] Shuffle buffer filled.
# 1848/1848 [==============================] - ETA: 0s - loss: 0.1357 - prediction_coarse_accuracy: 0.8641 - prediction_medium_accuracy: 0.7189 - prediction_fine_accuracy: 0.4100
#   • Coarse Accuracy = 86.41% | Val_Accuracy = 86.45% | LossWeight = 0.26
#   • Medium Accuracy = 71.89% | Val_Accuracy = 71.84% | LossWeight = 0.45
#   • Fine   Accuracy = 41.00% | Val_Accuracy = 40.80% | LossWeight = 0.28
#
# Epoch 3: val_prediction_fine_accuracy improved from 0.38600 to 0.40801, saving model to ../../logs/7_Marine_Tree/HD_CapsNet/Mod_3_3/epoch-best.h5
# 1848/1848 [==============================] - 421s 219ms/step - loss: 0.1357 - prediction_coarse_accuracy: 0.8641 - prediction_medium_accuracy: 0.7189 - prediction_fine_accuracy: 0.4100 - val_loss: 0.1335 - val_prediction_coarse_accuracy: 0.8645 - val_prediction_medium_accuracy: 0.7184 - val_prediction_fine_accuracy: 0.4080 - lr: 0.0010
# Epoch 4/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.1297 - prediction_coarse_accuracy: 0.8702 - prediction_medium_accuracy: 0.7289 - prediction_fine_accuracy: 0.4353
#   • Coarse Accuracy = 87.02% | Val_Accuracy = 87.59% | LossWeight = 0.26
#   • Medium Accuracy = 72.89% | Val_Accuracy = 73.32% | LossWeight = 0.45
#   • Fine   Accuracy = 43.53% | Val_Accuracy = 44.27% | LossWeight = 0.28
#
# Epoch 4: val_prediction_fine_accuracy improved from 0.40801 to 0.44267, saving model to ../../logs/7_Marine_Tree/HD_CapsNet/Mod_3_3/epoch-best.h5
# 1848/1848 [==============================] - 484s 257ms/step - loss: 0.1297 - prediction_coarse_accuracy: 0.8702 - prediction_medium_accuracy: 0.7289 - prediction_fine_accuracy: 0.4353 - val_loss: 0.1267 - val_prediction_coarse_accuracy: 0.8759 - val_prediction_medium_accuracy: 0.7332 - val_prediction_fine_accuracy: 0.4427 - lr: 0.0010
# Epoch 5/100
# 2023-04-13 11:52:29.661114: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:390] Filling up shuffle buffer (this may take a while): 3443 of 6400
# 2023-04-13 11:52:37.802849: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:415] Shuffle buffer filled.
# 1848/1848 [==============================] - ETA: 0s - loss: 0.1238 - prediction_coarse_accuracy: 0.8777 - prediction_medium_accuracy: 0.7416 - prediction_fine_accuracy: 0.4555
#   • Coarse Accuracy = 87.77% | Val_Accuracy = 87.62% | LossWeight = 0.26
#   • Medium Accuracy = 74.16% | Val_Accuracy = 74.25% | LossWeight = 0.45
#   • Fine   Accuracy = 45.55% | Val_Accuracy = 46.87% | LossWeight = 0.29
#
# Epoch 5: val_prediction_fine_accuracy improved from 0.44267 to 0.46866, saving model to ../../logs/7_Marine_Tree/HD_CapsNet/Mod_3_3/epoch-best.h5
# 1848/1848 [==============================] - 275s 137ms/step - loss: 0.1238 - prediction_coarse_accuracy: 0.8777 - prediction_medium_accuracy: 0.7416 - prediction_fine_accuracy: 0.4555 - val_loss: 0.1206 - val_prediction_coarse_accuracy: 0.8762 - val_prediction_medium_accuracy: 0.7425 - val_prediction_fine_accuracy: 0.4687 - lr: 0.0010
# Epoch 6/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.1191 - prediction_coarse_accuracy: 0.8818 - prediction_medium_accuracy: 0.7535 - prediction_fine_accuracy: 0.4730
#   • Coarse Accuracy = 88.18% | Val_Accuracy = 88.27% | LossWeight = 0.26
#   • Medium Accuracy = 75.35% | Val_Accuracy = 74.68% | LossWeight = 0.45
#   • Fine   Accuracy = 47.30% | Val_Accuracy = 48.50% | LossWeight = 0.29
#
# Epoch 6: val_prediction_fine_accuracy improved from 0.46866 to 0.48496, saving model to ../../logs/7_Marine_Tree/HD_CapsNet/Mod_3_3/epoch-best.h5
# 1848/1848 [==============================] - 158s 82ms/step - loss: 0.1191 - prediction_coarse_accuracy: 0.8818 - prediction_medium_accuracy: 0.7535 - prediction_fine_accuracy: 0.4730 - val_loss: 0.1184 - val_prediction_coarse_accuracy: 0.8827 - val_prediction_medium_accuracy: 0.7468 - val_prediction_fine_accuracy: 0.4850 - lr: 0.0010
# Epoch 7/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.1153 - prediction_coarse_accuracy: 0.8860 - prediction_medium_accuracy: 0.7645 - prediction_fine_accuracy: 0.4874
#   • Coarse Accuracy = 88.60% | Val_Accuracy = 87.82% | LossWeight = 0.26
#   • Medium Accuracy = 76.45% | Val_Accuracy = 75.27% | LossWeight = 0.45
#   • Fine   Accuracy = 48.74% | Val_Accuracy = 48.03% | LossWeight = 0.29
#
# Epoch 7: val_prediction_fine_accuracy did not improve from 0.48496
# 1848/1848 [==============================] - 160s 83ms/step - loss: 0.1153 - prediction_coarse_accuracy: 0.8860 - prediction_medium_accuracy: 0.7645 - prediction_fine_accuracy: 0.4874 - val_loss: 0.1159 - val_prediction_coarse_accuracy: 0.8782 - val_prediction_medium_accuracy: 0.7527 - val_prediction_fine_accuracy: 0.4803 - lr: 0.0010
# Epoch 8/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.1120 - prediction_coarse_accuracy: 0.8919 - prediction_medium_accuracy: 0.7733 - prediction_fine_accuracy: 0.5011
#   • Coarse Accuracy = 89.19% | Val_Accuracy = 89.40% | LossWeight = 0.26
#   • Medium Accuracy = 77.33% | Val_Accuracy = 77.74% | LossWeight = 0.45
#   • Fine   Accuracy = 50.11% | Val_Accuracy = 50.99% | LossWeight = 0.30
#
# Epoch 8: val_prediction_fine_accuracy improved from 0.48496 to 0.50989, saving model to ../../logs/7_Marine_Tree/HD_CapsNet/Mod_3_3/epoch-best.h5
# 1848/1848 [==============================] - 343s 180ms/step - loss: 0.1120 - prediction_coarse_accuracy: 0.8919 - prediction_medium_accuracy: 0.7733 - prediction_fine_accuracy: 0.5011 - val_loss: 0.1069 - val_prediction_coarse_accuracy: 0.8940 - val_prediction_medium_accuracy: 0.7774 - val_prediction_fine_accuracy: 0.5099 - lr: 0.0010
# Epoch 9/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.1082 - prediction_coarse_accuracy: 0.8956 - prediction_medium_accuracy: 0.7831 - prediction_fine_accuracy: 0.5146
#   • Coarse Accuracy = 89.56% | Val_Accuracy = 89.46% | LossWeight = 0.26
#   • Medium Accuracy = 78.31% | Val_Accuracy = 78.30% | LossWeight = 0.44
#   • Fine   Accuracy = 51.46% | Val_Accuracy = 52.68% | LossWeight = 0.30
#
# Epoch 9: val_prediction_fine_accuracy improved from 0.50989 to 0.52676, saving model to ../../logs/7_Marine_Tree/HD_CapsNet/Mod_3_3/epoch-best.h5
# 1848/1848 [==============================] - 361s 189ms/step - loss: 0.1082 - prediction_coarse_accuracy: 0.8956 - prediction_medium_accuracy: 0.7831 - prediction_fine_accuracy: 0.5146 - val_loss: 0.1028 - val_prediction_coarse_accuracy: 0.8946 - val_prediction_medium_accuracy: 0.7830 - val_prediction_fine_accuracy: 0.5268 - lr: 0.0010
# Epoch 10/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.1055 - prediction_coarse_accuracy: 0.8994 - prediction_medium_accuracy: 0.7916 - prediction_fine_accuracy: 0.5267
#   • Coarse Accuracy = 89.94% | Val_Accuracy = 89.42% | LossWeight = 0.26
#   • Medium Accuracy = 79.16% | Val_Accuracy = 77.83% | LossWeight = 0.44
#   • Fine   Accuracy = 52.67% | Val_Accuracy = 51.45% | LossWeight = 0.30
#
# Epoch 10: val_prediction_fine_accuracy did not improve from 0.52676
# 1848/1848 [==============================] - 158s 81ms/step - loss: 0.1055 - prediction_coarse_accuracy: 0.8994 - prediction_medium_accuracy: 0.7916 - prediction_fine_accuracy: 0.5267 - val_loss: 0.1057 - val_prediction_coarse_accuracy: 0.8942 - val_prediction_medium_accuracy: 0.7783 - val_prediction_fine_accuracy: 0.5145 - lr: 0.0010
# Epoch 11/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.1026 - prediction_coarse_accuracy: 0.9043 - prediction_medium_accuracy: 0.7988 - prediction_fine_accuracy: 0.5380
#   • Coarse Accuracy = 90.43% | Val_Accuracy = 89.11% | LossWeight = 0.25
#   • Medium Accuracy = 79.88% | Val_Accuracy = 78.02% | LossWeight = 0.44
#   • Fine   Accuracy = 53.80% | Val_Accuracy = 53.14% | LossWeight = 0.30
#
# Epoch 11: val_prediction_fine_accuracy improved from 0.52676 to 0.53141, saving model to ../../logs/7_Marine_Tree/HD_CapsNet/Mod_3_3/epoch-best.h5
# 1848/1848 [==============================] - 158s 82ms/step - loss: 0.1026 - prediction_coarse_accuracy: 0.9043 - prediction_medium_accuracy: 0.7988 - prediction_fine_accuracy: 0.5380 - val_loss: 0.1048 - val_prediction_coarse_accuracy: 0.8911 - val_prediction_medium_accuracy: 0.7802 - val_prediction_fine_accuracy: 0.5314 - lr: 9.5000e-04
# Epoch 12/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0987 - prediction_coarse_accuracy: 0.9100 - prediction_medium_accuracy: 0.8104 - prediction_fine_accuracy: 0.5523
#   • Coarse Accuracy = 91.00% | Val_Accuracy = 88.58% | LossWeight = 0.25
#   • Medium Accuracy = 81.04% | Val_Accuracy = 77.46% | LossWeight = 0.44
#   • Fine   Accuracy = 55.23% | Val_Accuracy = 53.26% | LossWeight = 0.31
#
# Epoch 12: val_prediction_fine_accuracy improved from 0.53141 to 0.53259, saving model to ../../logs/7_Marine_Tree/HD_CapsNet/Mod_3_3/epoch-best.h5
# 1848/1848 [==============================] - 234s 123ms/step - loss: 0.0987 - prediction_coarse_accuracy: 0.9100 - prediction_medium_accuracy: 0.8104 - prediction_fine_accuracy: 0.5523 - val_loss: 0.1065 - val_prediction_coarse_accuracy: 0.8858 - val_prediction_medium_accuracy: 0.7746 - val_prediction_fine_accuracy: 0.5326 - lr: 9.0250e-04
# Epoch 13/100
# 2023-04-13 12:23:46.304107: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:390] Filling up shuffle buffer (this may take a while): 2768 of 6400
# 2023-04-13 12:23:56.334413: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:390] Filling up shuffle buffer (this may take a while): 5301 of 6400
# 2023-04-13 12:23:59.336279: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:415] Shuffle buffer filled.
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0948 - prediction_coarse_accuracy: 0.9169 - prediction_medium_accuracy: 0.8216 - prediction_fine_accuracy: 0.5641
#   • Coarse Accuracy = 91.69% | Val_Accuracy = 90.21% | LossWeight = 0.24
#   • Medium Accuracy = 82.16% | Val_Accuracy = 78.76% | LossWeight = 0.44
#   • Fine   Accuracy = 56.41% | Val_Accuracy = 54.79% | LossWeight = 0.32
#
# Epoch 13: val_prediction_fine_accuracy improved from 0.53259 to 0.54790, saving model to ../../logs/7_Marine_Tree/HD_CapsNet/Mod_3_3/epoch-best.h5
# 1848/1848 [==============================] - 436s 220ms/step - loss: 0.0948 - prediction_coarse_accuracy: 0.9169 - prediction_medium_accuracy: 0.8216 - prediction_fine_accuracy: 0.5641 - val_loss: 0.1007 - val_prediction_coarse_accuracy: 0.9021 - val_prediction_medium_accuracy: 0.7876 - val_prediction_fine_accuracy: 0.5479 - lr: 8.5737e-04
# Epoch 14/100
# 2023-04-13 12:31:02.860137: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:390] Filling up shuffle buffer (this may take a while): 2708 of 6400
# 2023-04-13 12:31:12.835393: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:390] Filling up shuffle buffer (this may take a while): 5592 of 6400
# 2023-04-13 12:31:15.101999: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:415] Shuffle buffer filled.
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0907 - prediction_coarse_accuracy: 0.9237 - prediction_medium_accuracy: 0.8333 - prediction_fine_accuracy: 0.5742
#   • Coarse Accuracy = 92.37% | Val_Accuracy = 89.29% | LossWeight = 0.24
#   • Medium Accuracy = 83.33% | Val_Accuracy = 78.64% | LossWeight = 0.43
#   • Fine   Accuracy = 57.42% | Val_Accuracy = 55.04% | LossWeight = 0.33
#
# Epoch 14: val_prediction_fine_accuracy improved from 0.54790 to 0.55044, saving model to ../../logs/7_Marine_Tree/HD_CapsNet/Mod_3_3/epoch-best.h5
# 1848/1848 [==============================] - 262s 127ms/step - loss: 0.0907 - prediction_coarse_accuracy: 0.9237 - prediction_medium_accuracy: 0.8333 - prediction_fine_accuracy: 0.5742 - val_loss: 0.0990 - val_prediction_coarse_accuracy: 0.8929 - val_prediction_medium_accuracy: 0.7864 - val_prediction_fine_accuracy: 0.5504 - lr: 8.1451e-04
# Epoch 15/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0861 - prediction_coarse_accuracy: 0.9329 - prediction_medium_accuracy: 0.8466 - prediction_fine_accuracy: 0.5881
#   • Coarse Accuracy = 93.29% | Val_Accuracy = 90.23% | LossWeight = 0.23
#   • Medium Accuracy = 84.66% | Val_Accuracy = 78.60% | LossWeight = 0.43
#   • Fine   Accuracy = 58.81% | Val_Accuracy = 54.78% | LossWeight = 0.35
#
# Epoch 15: val_prediction_fine_accuracy did not improve from 0.55044
# 1848/1848 [==============================] - 222s 115ms/step - loss: 0.0861 - prediction_coarse_accuracy: 0.9329 - prediction_medium_accuracy: 0.8466 - prediction_fine_accuracy: 0.5881 - val_loss: 0.0988 - val_prediction_coarse_accuracy: 0.9023 - val_prediction_medium_accuracy: 0.7860 - val_prediction_fine_accuracy: 0.5478 - lr: 7.7378e-04
# Epoch 16/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0819 - prediction_coarse_accuracy: 0.9393 - prediction_medium_accuracy: 0.8563 - prediction_fine_accuracy: 0.5964
#   • Coarse Accuracy = 93.93% | Val_Accuracy = 89.91% | LossWeight = 0.22
#   • Medium Accuracy = 85.63% | Val_Accuracy = 79.13% | LossWeight = 0.43
#   • Fine   Accuracy = 59.64% | Val_Accuracy = 56.76% | LossWeight = 0.36
#
# Epoch 16: val_prediction_fine_accuracy improved from 0.55044 to 0.56756, saving model to ../../logs/7_Marine_Tree/HD_CapsNet/Mod_3_3/epoch-best.h5
# 1848/1848 [==============================] - 199s 99ms/step - loss: 0.0819 - prediction_coarse_accuracy: 0.9393 - prediction_medium_accuracy: 0.8563 - prediction_fine_accuracy: 0.5964 - val_loss: 0.0980 - val_prediction_coarse_accuracy: 0.8991 - val_prediction_medium_accuracy: 0.7913 - val_prediction_fine_accuracy: 0.5676 - lr: 7.3509e-04
# Epoch 17/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0781 - prediction_coarse_accuracy: 0.9455 - prediction_medium_accuracy: 0.8674 - prediction_fine_accuracy: 0.6068
#   • Coarse Accuracy = 94.55% | Val_Accuracy = 89.86% | LossWeight = 0.21
#   • Medium Accuracy = 86.74% | Val_Accuracy = 78.89% | LossWeight = 0.42
#   • Fine   Accuracy = 60.68% | Val_Accuracy = 56.15% | LossWeight = 0.37
#
# Epoch 17: val_prediction_fine_accuracy did not improve from 0.56756
# 1848/1848 [==============================] - 185s 95ms/step - loss: 0.0781 - prediction_coarse_accuracy: 0.9455 - prediction_medium_accuracy: 0.8674 - prediction_fine_accuracy: 0.6068 - val_loss: 0.0966 - val_prediction_coarse_accuracy: 0.8986 - val_prediction_medium_accuracy: 0.7889 - val_prediction_fine_accuracy: 0.5615 - lr: 6.9834e-04
# Epoch 18/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0734 - prediction_coarse_accuracy: 0.9534 - prediction_medium_accuracy: 0.8811 - prediction_fine_accuracy: 0.6193
#   • Coarse Accuracy = 95.34% | Val_Accuracy = 89.72% | LossWeight = 0.19
#   • Medium Accuracy = 88.11% | Val_Accuracy = 79.00% | LossWeight = 0.41
#   • Fine   Accuracy = 61.93% | Val_Accuracy = 55.96% | LossWeight = 0.40
#
# Epoch 18: val_prediction_fine_accuracy did not improve from 0.56756
# 1848/1848 [==============================] - 271s 139ms/step - loss: 0.0734 - prediction_coarse_accuracy: 0.9534 - prediction_medium_accuracy: 0.8811 - prediction_fine_accuracy: 0.6193 - val_loss: 0.0971 - val_prediction_coarse_accuracy: 0.8972 - val_prediction_medium_accuracy: 0.7900 - val_prediction_fine_accuracy: 0.5596 - lr: 6.6342e-04
# Epoch 19/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0702 - prediction_coarse_accuracy: 0.9577 - prediction_medium_accuracy: 0.8892 - prediction_fine_accuracy: 0.6257
#   • Coarse Accuracy = 95.77% | Val_Accuracy = 89.73% | LossWeight = 0.19
#   • Medium Accuracy = 88.92% | Val_Accuracy = 78.38% | LossWeight = 0.40
#   • Fine   Accuracy = 62.57% | Val_Accuracy = 56.68% | LossWeight = 0.41
#
# Epoch 19: val_prediction_fine_accuracy did not improve from 0.56756
# 1848/1848 [==============================] - 426s 226ms/step - loss: 0.0702 - prediction_coarse_accuracy: 0.9577 - prediction_medium_accuracy: 0.8892 - prediction_fine_accuracy: 0.6257 - val_loss: 0.0990 - val_prediction_coarse_accuracy: 0.8973 - val_prediction_medium_accuracy: 0.7838 - val_prediction_fine_accuracy: 0.5668 - lr: 6.3025e-04
# Epoch 20/100
# 2023-04-13 12:57:25.082947: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:390] Filling up shuffle buffer (this may take a while): 3069 of 6400
# 2023-04-13 12:57:32.225928: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:415] Shuffle buffer filled.
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0673 - prediction_coarse_accuracy: 0.9604 - prediction_medium_accuracy: 0.8970 - prediction_fine_accuracy: 0.6366
#   • Coarse Accuracy = 96.04% | Val_Accuracy = 89.55% | LossWeight = 0.18
#   • Medium Accuracy = 89.70% | Val_Accuracy = 78.75% | LossWeight = 0.40
#   • Fine   Accuracy = 63.66% | Val_Accuracy = 56.40% | LossWeight = 0.42
#
# Epoch 20: val_prediction_fine_accuracy did not improve from 0.56756
# 1848/1848 [==============================] - 501s 258ms/step - loss: 0.0673 - prediction_coarse_accuracy: 0.9604 - prediction_medium_accuracy: 0.8970 - prediction_fine_accuracy: 0.6366 - val_loss: 0.0970 - val_prediction_coarse_accuracy: 0.8955 - val_prediction_medium_accuracy: 0.7875 - val_prediction_fine_accuracy: 0.5640 - lr: 5.9874e-04
# Epoch 21/100
# 2023-04-13 13:05:46.518409: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:390] Filling up shuffle buffer (this may take a while): 2616 of 6400
# 2023-04-13 13:05:56.478198: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:390] Filling up shuffle buffer (this may take a while): 5270 of 6400
# 2023-04-13 13:06:00.582387: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:415] Shuffle buffer filled.
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0645 - prediction_coarse_accuracy: 0.9639 - prediction_medium_accuracy: 0.9055 - prediction_fine_accuracy: 0.6445
#   • Coarse Accuracy = 96.39% | Val_Accuracy = 88.89% | LossWeight = 0.18
#   • Medium Accuracy = 90.55% | Val_Accuracy = 77.82% | LossWeight = 0.39
#   • Fine   Accuracy = 64.45% | Val_Accuracy = 55.75% | LossWeight = 0.44
#
# Epoch 21: val_prediction_fine_accuracy did not improve from 0.56756
# 1848/1848 [==============================] - 530s 271ms/step - loss: 0.0645 - prediction_coarse_accuracy: 0.9639 - prediction_medium_accuracy: 0.9055 - prediction_fine_accuracy: 0.6445 - val_loss: 0.1002 - val_prediction_coarse_accuracy: 0.8889 - val_prediction_medium_accuracy: 0.7782 - val_prediction_fine_accuracy: 0.5575 - lr: 5.6880e-04
# Epoch 22/100
# 2023-04-13 13:15:08.599083: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:390] Filling up shuffle buffer (this may take a while): 2958 of 6400
# 2023-04-13 13:15:18.613882: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:390] Filling up shuffle buffer (this may take a while): 6113 of 6400
# 2023-04-13 13:15:19.281293: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:415] Shuffle buffer filled.
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0624 - prediction_coarse_accuracy: 0.9664 - prediction_medium_accuracy: 0.9119 - prediction_fine_accuracy: 0.6523
#   • Coarse Accuracy = 96.64% | Val_Accuracy = 89.27% | LossWeight = 0.17
#   • Medium Accuracy = 91.19% | Val_Accuracy = 77.43% | LossWeight = 0.38
#   • Fine   Accuracy = 65.23% | Val_Accuracy = 56.13% | LossWeight = 0.45
#
# Epoch 22: val_prediction_fine_accuracy did not improve from 0.56756
# 1848/1848 [==============================] - 641s 333ms/step - loss: 0.0624 - prediction_coarse_accuracy: 0.9664 - prediction_medium_accuracy: 0.9119 - prediction_fine_accuracy: 0.6523 - val_loss: 0.1004 - val_prediction_coarse_accuracy: 0.8927 - val_prediction_medium_accuracy: 0.7743 - val_prediction_fine_accuracy: 0.5613 - lr: 5.4036e-04
# Epoch 23/100
# 2023-04-13 13:25:50.189467: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:390] Filling up shuffle buffer (this may take a while): 2838 of 6400
# 2023-04-13 13:26:00.226096: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:390] Filling up shuffle buffer (this may take a while): 5704 of 6400
# 2023-04-13 13:26:02.497891: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:415] Shuffle buffer filled.
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0601 - prediction_coarse_accuracy: 0.9688 - prediction_medium_accuracy: 0.9183 - prediction_fine_accuracy: 0.6585
#   • Coarse Accuracy = 96.88% | Val_Accuracy = 89.46% | LossWeight = 0.17
#   • Medium Accuracy = 91.83% | Val_Accuracy = 78.27% | LossWeight = 0.37
#   • Fine   Accuracy = 65.85% | Val_Accuracy = 56.17% | LossWeight = 0.46
#
# Epoch 23: val_prediction_fine_accuracy did not improve from 0.56756
# 1848/1848 [==============================] - 321s 159ms/step - loss: 0.0601 - prediction_coarse_accuracy: 0.9688 - prediction_medium_accuracy: 0.9183 - prediction_fine_accuracy: 0.6585 - val_loss: 0.0982 - val_prediction_coarse_accuracy: 0.8946 - val_prediction_medium_accuracy: 0.7827 - val_prediction_fine_accuracy: 0.5617 - lr: 5.1334e-04
# Epoch 24/100
# 2023-04-13 13:31:12.314711: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:390] Filling up shuffle buffer (this may take a while): 4326 of 6400
# 2023-04-13 13:31:16.985405: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:415] Shuffle buffer filled.
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0585 - prediction_coarse_accuracy: 0.9698 - prediction_medium_accuracy: 0.9221 - prediction_fine_accuracy: 0.6631
#   • Coarse Accuracy = 96.98% | Val_Accuracy = 89.76% | LossWeight = 0.17
#   • Medium Accuracy = 92.21% | Val_Accuracy = 78.97% | LossWeight = 0.36
#   • Fine   Accuracy = 66.31% | Val_Accuracy = 57.12% | LossWeight = 0.47
#
# Epoch 24: val_prediction_fine_accuracy improved from 0.56756 to 0.57115, saving model to ../../logs/7_Marine_Tree/HD_CapsNet/Mod_3_3/epoch-best.h5
# 1848/1848 [==============================] - 294s 148ms/step - loss: 0.0585 - prediction_coarse_accuracy: 0.9698 - prediction_medium_accuracy: 0.9221 - prediction_fine_accuracy: 0.6631 - val_loss: 0.0956 - val_prediction_coarse_accuracy: 0.8976 - val_prediction_medium_accuracy: 0.7897 - val_prediction_fine_accuracy: 0.5712 - lr: 4.8767e-04
# Epoch 25/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0568 - prediction_coarse_accuracy: 0.9715 - prediction_medium_accuracy: 0.9272 - prediction_fine_accuracy: 0.6712
#   • Coarse Accuracy = 97.15% | Val_Accuracy = 89.40% | LossWeight = 0.17
#   • Medium Accuracy = 92.72% | Val_Accuracy = 78.25% | LossWeight = 0.35
#   • Fine   Accuracy = 67.12% | Val_Accuracy = 56.76% | LossWeight = 0.48
#
# Epoch 25: val_prediction_fine_accuracy did not improve from 0.57115
# 1848/1848 [==============================] - 277s 142ms/step - loss: 0.0568 - prediction_coarse_accuracy: 0.9715 - prediction_medium_accuracy: 0.9272 - prediction_fine_accuracy: 0.6712 - val_loss: 0.0980 - val_prediction_coarse_accuracy: 0.8940 - val_prediction_medium_accuracy: 0.7825 - val_prediction_fine_accuracy: 0.5676 - lr: 4.6329e-04
# Epoch 26/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0545 - prediction_coarse_accuracy: 0.9731 - prediction_medium_accuracy: 0.9325 - prediction_fine_accuracy: 0.6819
#   • Coarse Accuracy = 97.31% | Val_Accuracy = 89.69% | LossWeight = 0.17
#   • Medium Accuracy = 93.25% | Val_Accuracy = 77.94% | LossWeight = 0.35
#   • Fine   Accuracy = 68.19% | Val_Accuracy = 57.02% | LossWeight = 0.49
#
# Epoch 27: val_prediction_fine_accuracy did not improve from 0.57115
# 1848/1848 [==============================] - 243s 124ms/step - loss: 0.0545 - prediction_coarse_accuracy: 0.9731 - prediction_medium_accuracy: 0.9325 - prediction_fine_accuracy: 0.6819 - val_loss: 0.0991 - val_prediction_coarse_accuracy: 0.8969 - val_prediction_medium_accuracy: 0.7794 - val_prediction_fine_accuracy: 0.5702 - lr: 4.1812e-04
# Epoch 28/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0531 - prediction_coarse_accuracy: 0.9744 - prediction_medium_accuracy: 0.9371 - prediction_fine_accuracy: 0.6882
#   • Coarse Accuracy = 97.44% | Val_Accuracy = 89.58% | LossWeight = 0.16
#   • Medium Accuracy = 93.71% | Val_Accuracy = 78.43% | LossWeight = 0.34
#   • Fine   Accuracy = 68.82% | Val_Accuracy = 56.68% | LossWeight = 0.50
#
# Epoch 28: val_prediction_fine_accuracy did not improve from 0.57115
# 1848/1848 [==============================] - 266s 137ms/step - loss: 0.0531 - prediction_coarse_accuracy: 0.9744 - prediction_medium_accuracy: 0.9371 - prediction_fine_accuracy: 0.6882 - val_loss: 0.0970 - val_prediction_coarse_accuracy: 0.8958 - val_prediction_medium_accuracy: 0.7843 - val_prediction_fine_accuracy: 0.5668 - lr: 3.9721e-04
# Epoch 29/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0522 - prediction_coarse_accuracy: 0.9741 - prediction_medium_accuracy: 0.9391 - prediction_fine_accuracy: 0.6937
#   • Coarse Accuracy = 97.41% | Val_Accuracy = 89.67% | LossWeight = 0.17
#   • Medium Accuracy = 93.91% | Val_Accuracy = 78.04% | LossWeight = 0.33
#   • Fine   Accuracy = 69.37% | Val_Accuracy = 57.02% | LossWeight = 0.50
#
# Epoch 29: val_prediction_fine_accuracy did not improve from 0.57115
# 1848/1848 [==============================] - 249s 131ms/step - loss: 0.0522 - prediction_coarse_accuracy: 0.9741 - prediction_medium_accuracy: 0.9391 - prediction_fine_accuracy: 0.6937 - val_loss: 0.0982 - val_prediction_coarse_accuracy: 0.8967 - val_prediction_medium_accuracy: 0.7804 - val_prediction_fine_accuracy: 0.5702 - lr: 3.7735e-04
# Epoch 30/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0514 - prediction_coarse_accuracy: 0.9755 - prediction_medium_accuracy: 0.9420 - prediction_fine_accuracy: 0.6990
#   • Coarse Accuracy = 97.55% | Val_Accuracy = 89.60% | LossWeight = 0.17
#   • Medium Accuracy = 94.20% | Val_Accuracy = 77.59% | LossWeight = 0.33
#   • Fine   Accuracy = 69.90% | Val_Accuracy = 57.00% | LossWeight = 0.51
#
# Epoch 30: val_prediction_fine_accuracy did not improve from 0.57115
# 1848/1848 [==============================] - 265s 136ms/step - loss: 0.0514 - prediction_coarse_accuracy: 0.9755 - prediction_medium_accuracy: 0.9420 - prediction_fine_accuracy: 0.6990 - val_loss: 0.1005 - val_prediction_coarse_accuracy: 0.8960 - val_prediction_medium_accuracy: 0.7759 - val_prediction_fine_accuracy: 0.5700 - lr: 3.5849e-04
# Epoch 31/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0501 - prediction_coarse_accuracy: 0.9757 - prediction_medium_accuracy: 0.9443 - prediction_fine_accuracy: 0.7048
#   • Coarse Accuracy = 97.57% | Val_Accuracy = 89.87% | LossWeight = 0.17
#   • Medium Accuracy = 94.43% | Val_Accuracy = 78.10% | LossWeight = 0.32
#   • Fine   Accuracy = 70.48% | Val_Accuracy = 56.90% | LossWeight = 0.51
#
# Epoch 31: val_prediction_fine_accuracy did not improve from 0.57115
# 1848/1848 [==============================] - 263s 135ms/step - loss: 0.0501 - prediction_coarse_accuracy: 0.9757 - prediction_medium_accuracy: 0.9443 - prediction_fine_accuracy: 0.7048 - val_loss: 0.0990 - val_prediction_coarse_accuracy: 0.8987 - val_prediction_medium_accuracy: 0.7810 - val_prediction_fine_accuracy: 0.5690 - lr: 3.4056e-04
# Epoch 32/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0498 - prediction_coarse_accuracy: 0.9768 - prediction_medium_accuracy: 0.9459 - prediction_fine_accuracy: 0.7082
#   • Coarse Accuracy = 97.68% | Val_Accuracy = 89.88% | LossWeight = 0.16
#   • Medium Accuracy = 94.59% | Val_Accuracy = 78.83% | LossWeight = 0.32
#   • Fine   Accuracy = 70.82% | Val_Accuracy = 57.57% | LossWeight = 0.52
#
# Epoch 32: val_prediction_fine_accuracy improved from 0.57115 to 0.57568, saving model to ../../logs/7_Marine_Tree/HD_CapsNet/Mod_3_3/epoch-best.h5
# 1848/1848 [==============================] - 270s 139ms/step - loss: 0.0498 - prediction_coarse_accuracy: 0.9768 - prediction_medium_accuracy: 0.9459 - prediction_fine_accuracy: 0.7082 - val_loss: 0.0973 - val_prediction_coarse_accuracy: 0.8988 - val_prediction_medium_accuracy: 0.7883 - val_prediction_fine_accuracy: 0.5757 - lr: 3.2353e-04
# Epoch 33/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0489 - prediction_coarse_accuracy: 0.9768 - prediction_medium_accuracy: 0.9464 - prediction_fine_accuracy: 0.7143
#   • Coarse Accuracy = 97.68% | Val_Accuracy = 89.77% | LossWeight = 0.17
#   • Medium Accuracy = 94.64% | Val_Accuracy = 78.35% | LossWeight = 0.32
#   • Fine   Accuracy = 71.43% | Val_Accuracy = 57.50% | LossWeight = 0.51
#
# Epoch 33: val_prediction_fine_accuracy did not improve from 0.57568
# 1848/1848 [==============================] - 264s 136ms/step - loss: 0.0489 - prediction_coarse_accuracy: 0.9768 - prediction_medium_accuracy: 0.9464 - prediction_fine_accuracy: 0.7143 - val_loss: 0.0974 - val_prediction_coarse_accuracy: 0.8977 - val_prediction_medium_accuracy: 0.7835 - val_prediction_fine_accuracy: 0.5750 - lr: 3.0736e-04
# Epoch 34/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0485 - prediction_coarse_accuracy: 0.9770 - prediction_medium_accuracy: 0.9484 - prediction_fine_accuracy: 0.7202
#   • Coarse Accuracy = 97.70% | Val_Accuracy = 89.84% | LossWeight = 0.17
#   • Medium Accuracy = 94.84% | Val_Accuracy = 78.70% | LossWeight = 0.32
#   • Fine   Accuracy = 72.02% | Val_Accuracy = 57.33% | LossWeight = 0.51
#
# Epoch 34: val_prediction_fine_accuracy did not improve from 0.57568
# 1848/1848 [==============================] - 264s 136ms/step - loss: 0.0485 - prediction_coarse_accuracy: 0.9770 - prediction_medium_accuracy: 0.9484 - prediction_fine_accuracy: 0.7202 - val_loss: 0.0970 - val_prediction_coarse_accuracy: 0.8984 - val_prediction_medium_accuracy: 0.7870 - val_prediction_fine_accuracy: 0.5733 - lr: 2.9199e-04
# Epoch 35/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0479 - prediction_coarse_accuracy: 0.9771 - prediction_medium_accuracy: 0.9487 - prediction_fine_accuracy: 0.7251
#   • Coarse Accuracy = 97.71% | Val_Accuracy = 89.95% | LossWeight = 0.17
#   • Medium Accuracy = 94.87% | Val_Accuracy = 78.61% | LossWeight = 0.32
#   • Fine   Accuracy = 72.51% | Val_Accuracy = 57.34% | LossWeight = 0.51
#
# Epoch 35: val_prediction_fine_accuracy did not improve from 0.57568
# 1848/1848 [==============================] - 253s 129ms/step - loss: 0.0479 - prediction_coarse_accuracy: 0.9771 - prediction_medium_accuracy: 0.9487 - prediction_fine_accuracy: 0.7251 - val_loss: 0.0971 - val_prediction_coarse_accuracy: 0.8995 - val_prediction_medium_accuracy: 0.7861 - val_prediction_fine_accuracy: 0.5734 - lr: 2.7739e-04
# Epoch 36/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0471 - prediction_coarse_accuracy: 0.9775 - prediction_medium_accuracy: 0.9514 - prediction_fine_accuracy: 0.7297
#   • Coarse Accuracy = 97.75% | Val_Accuracy = 89.90% | LossWeight = 0.17
#   • Medium Accuracy = 95.14% | Val_Accuracy = 78.54% | LossWeight = 0.31
#   • Fine   Accuracy = 72.97% | Val_Accuracy = 56.71% | LossWeight = 0.52
#
# Epoch 36: val_prediction_fine_accuracy did not improve from 0.57568
# 1848/1848 [==============================] - 272s 142ms/step - loss: 0.0471 - prediction_coarse_accuracy: 0.9775 - prediction_medium_accuracy: 0.9514 - prediction_fine_accuracy: 0.7297 - val_loss: 0.0986 - val_prediction_coarse_accuracy: 0.8990 - val_prediction_medium_accuracy: 0.7854 - val_prediction_fine_accuracy: 0.5671 - lr: 2.6352e-04
# Epoch 37/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0466 - prediction_coarse_accuracy: 0.9775 - prediction_medium_accuracy: 0.9518 - prediction_fine_accuracy: 0.7353
#   • Coarse Accuracy = 97.75% | Val_Accuracy = 89.99% | LossWeight = 0.17
#   • Medium Accuracy = 95.18% | Val_Accuracy = 78.83% | LossWeight = 0.31
#   • Fine   Accuracy = 73.53% | Val_Accuracy = 57.13% | LossWeight = 0.51
#
# Epoch 37: val_prediction_fine_accuracy did not improve from 0.57568
# 1848/1848 [==============================] - 275s 143ms/step - loss: 0.0466 - prediction_coarse_accuracy: 0.9775 - prediction_medium_accuracy: 0.9518 - prediction_fine_accuracy: 0.7353 - val_loss: 0.0975 - val_prediction_coarse_accuracy: 0.8999 - val_prediction_medium_accuracy: 0.7883 - val_prediction_fine_accuracy: 0.5713 - lr: 2.5034e-04
# Epoch 38/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0462 - prediction_coarse_accuracy: 0.9779 - prediction_medium_accuracy: 0.9532 - prediction_fine_accuracy: 0.7414
#   • Coarse Accuracy = 97.79% | Val_Accuracy = 89.92% | LossWeight = 0.18
#   • Medium Accuracy = 95.32% | Val_Accuracy = 78.47% | LossWeight = 0.31
#   • Fine   Accuracy = 74.14% | Val_Accuracy = 57.17% | LossWeight = 0.51
#
# Epoch 38: val_prediction_fine_accuracy did not improve from 0.57568
# 1848/1848 [==============================] - 272s 143ms/step - loss: 0.0462 - prediction_coarse_accuracy: 0.9779 - prediction_medium_accuracy: 0.9532 - prediction_fine_accuracy: 0.7414 - val_loss: 0.0988 - val_prediction_coarse_accuracy: 0.8992 - val_prediction_medium_accuracy: 0.7847 - val_prediction_fine_accuracy: 0.5717 - lr: 2.3783e-04
# Epoch 39/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0460 - prediction_coarse_accuracy: 0.9779 - prediction_medium_accuracy: 0.9526 - prediction_fine_accuracy: 0.7443
#   • Coarse Accuracy = 97.79% | Val_Accuracy = 89.76% | LossWeight = 0.18
#   • Medium Accuracy = 95.26% | Val_Accuracy = 78.41% | LossWeight = 0.31
#   • Fine   Accuracy = 74.43% | Val_Accuracy = 56.81% | LossWeight = 0.51
#
# Epoch 39: val_prediction_fine_accuracy did not improve from 0.57568
# 1848/1848 [==============================] - 337s 175ms/step - loss: 0.0460 - prediction_coarse_accuracy: 0.9779 - prediction_medium_accuracy: 0.9526 - prediction_fine_accuracy: 0.7443 - val_loss: 0.0996 - val_prediction_coarse_accuracy: 0.8976 - val_prediction_medium_accuracy: 0.7841 - val_prediction_fine_accuracy: 0.5681 - lr: 2.2594e-04
# Epoch 40/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0454 - prediction_coarse_accuracy: 0.9780 - prediction_medium_accuracy: 0.9542 - prediction_fine_accuracy: 0.7485
#   • Coarse Accuracy = 97.80% | Val_Accuracy = 89.76% | LossWeight = 0.18
#   • Medium Accuracy = 95.42% | Val_Accuracy = 78.58% | LossWeight = 0.31
#   • Fine   Accuracy = 74.85% | Val_Accuracy = 57.22% | LossWeight = 0.51
#
# Epoch 40: val_prediction_fine_accuracy did not improve from 0.57568
# 1848/1848 [==============================] - 227s 115ms/step - loss: 0.0454 - prediction_coarse_accuracy: 0.9780 - prediction_medium_accuracy: 0.9542 - prediction_fine_accuracy: 0.7485 - val_loss: 0.0994 - val_prediction_coarse_accuracy: 0.8976 - val_prediction_medium_accuracy: 0.7858 - val_prediction_fine_accuracy: 0.5722 - lr: 2.1464e-04
# Epoch 41/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0451 - prediction_coarse_accuracy: 0.9782 - prediction_medium_accuracy: 0.9541 - prediction_fine_accuracy: 0.7524
#   • Coarse Accuracy = 97.82% | Val_Accuracy = 89.71% | LossWeight = 0.18
#   • Medium Accuracy = 95.41% | Val_Accuracy = 78.30% | LossWeight = 0.31
#   • Fine   Accuracy = 75.24% | Val_Accuracy = 56.89% | LossWeight = 0.51
#
# Epoch 41: val_prediction_fine_accuracy did not improve from 0.57568
# 1848/1848 [==============================] - 264s 136ms/step - loss: 0.0451 - prediction_coarse_accuracy: 0.9782 - prediction_medium_accuracy: 0.9541 - prediction_fine_accuracy: 0.7524 - val_loss: 0.0995 - val_prediction_coarse_accuracy: 0.8971 - val_prediction_medium_accuracy: 0.7830 - val_prediction_fine_accuracy: 0.5689 - lr: 2.0391e-04
# Epoch 42/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0446 - prediction_coarse_accuracy: 0.9785 - prediction_medium_accuracy: 0.9553 - prediction_fine_accuracy: 0.7582
#   • Coarse Accuracy = 97.85% | Val_Accuracy = 89.89% | LossWeight = 0.18
#   • Medium Accuracy = 95.53% | Val_Accuracy = 78.23% | LossWeight = 0.31
#   • Fine   Accuracy = 75.82% | Val_Accuracy = 56.90% | LossWeight = 0.51
#
# Epoch 42: val_prediction_fine_accuracy did not improve from 0.57568
# 1848/1848 [==============================] - 268s 138ms/step - loss: 0.0446 - prediction_coarse_accuracy: 0.9785 - prediction_medium_accuracy: 0.9553 - prediction_fine_accuracy: 0.7582 - val_loss: 0.0997 - val_prediction_coarse_accuracy: 0.8989 - val_prediction_medium_accuracy: 0.7823 - val_prediction_fine_accuracy: 0.5690 - lr: 1.9371e-04
# Epoch 43/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0443 - prediction_coarse_accuracy: 0.9782 - prediction_medium_accuracy: 0.9549 - prediction_fine_accuracy: 0.7610
#   • Coarse Accuracy = 97.82% | Val_Accuracy = 90.00% | LossWeight = 0.18
#   • Medium Accuracy = 95.49% | Val_Accuracy = 78.66% | LossWeight = 0.32
#   • Fine   Accuracy = 76.10% | Val_Accuracy = 56.97% | LossWeight = 0.50
#
# Epoch 43: val_prediction_fine_accuracy did not improve from 0.57568
# 1848/1848 [==============================] - 268s 138ms/step - loss: 0.0443 - prediction_coarse_accuracy: 0.9782 - prediction_medium_accuracy: 0.9549 - prediction_fine_accuracy: 0.7610 - val_loss: 0.0991 - val_prediction_coarse_accuracy: 0.9000 - val_prediction_medium_accuracy: 0.7866 - val_prediction_fine_accuracy: 0.5697 - lr: 1.8403e-04
# Epoch 44/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0438 - prediction_coarse_accuracy: 0.9791 - prediction_medium_accuracy: 0.9566 - prediction_fine_accuracy: 0.7663
#   • Coarse Accuracy = 97.91% | Val_Accuracy = 89.75% | LossWeight = 0.18
#   • Medium Accuracy = 95.66% | Val_Accuracy = 78.44% | LossWeight = 0.31
#   • Fine   Accuracy = 76.63% | Val_Accuracy = 56.89% | LossWeight = 0.51
#
# Epoch 44: val_prediction_fine_accuracy did not improve from 0.57568
# 1848/1848 [==============================] - 264s 136ms/step - loss: 0.0438 - prediction_coarse_accuracy: 0.9791 - prediction_medium_accuracy: 0.9566 - prediction_fine_accuracy: 0.7663 - val_loss: 0.0991 - val_prediction_coarse_accuracy: 0.8975 - val_prediction_medium_accuracy: 0.7844 - val_prediction_fine_accuracy: 0.5689 - lr: 1.7482e-04
# Epoch 45/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0434 - prediction_coarse_accuracy: 0.9789 - prediction_medium_accuracy: 0.9568 - prediction_fine_accuracy: 0.7708
#   • Coarse Accuracy = 97.89% | Val_Accuracy = 89.81% | LossWeight = 0.18
#   • Medium Accuracy = 95.68% | Val_Accuracy = 78.38% | LossWeight = 0.31
#   • Fine   Accuracy = 77.08% | Val_Accuracy = 56.71% | LossWeight = 0.50
#
# Epoch 45: val_prediction_fine_accuracy did not improve from 0.57568
# 1848/1848 [==============================] - 266s 137ms/step - loss: 0.0434 - prediction_coarse_accuracy: 0.9789 - prediction_medium_accuracy: 0.9568 - prediction_fine_accuracy: 0.7708 - val_loss: 0.0996 - val_prediction_coarse_accuracy: 0.8981 - val_prediction_medium_accuracy: 0.7838 - val_prediction_fine_accuracy: 0.5671 - lr: 1.6608e-04
# Epoch 46/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0432 - prediction_coarse_accuracy: 0.9788 - prediction_medium_accuracy: 0.9570 - prediction_fine_accuracy: 0.7757
#   • Coarse Accuracy = 97.88% | Val_Accuracy = 89.99% | LossWeight = 0.19
#   • Medium Accuracy = 95.70% | Val_Accuracy = 78.66% | LossWeight = 0.32
#   • Fine   Accuracy = 77.57% | Val_Accuracy = 57.00% | LossWeight = 0.50
#
# Epoch 46: val_prediction_fine_accuracy did not improve from 0.57568
# 1848/1848 [==============================] - 266s 137ms/step - loss: 0.0432 - prediction_coarse_accuracy: 0.9788 - prediction_medium_accuracy: 0.9570 - prediction_fine_accuracy: 0.7757 - val_loss: 0.0995 - val_prediction_coarse_accuracy: 0.8999 - val_prediction_medium_accuracy: 0.7866 - val_prediction_fine_accuracy: 0.5700 - lr: 1.5778e-04
# Epoch 47/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0430 - prediction_coarse_accuracy: 0.9792 - prediction_medium_accuracy: 0.9582 - prediction_fine_accuracy: 0.7773
#   • Coarse Accuracy = 97.92% | Val_Accuracy = 89.72% | LossWeight = 0.19
#   • Medium Accuracy = 95.82% | Val_Accuracy = 78.19% | LossWeight = 0.31
#   • Fine   Accuracy = 77.73% | Val_Accuracy = 56.58% | LossWeight = 0.50
#
# Epoch 47: val_prediction_fine_accuracy did not improve from 0.57568
# 1848/1848 [==============================] - 265s 136ms/step - loss: 0.0430 - prediction_coarse_accuracy: 0.9792 - prediction_medium_accuracy: 0.9582 - prediction_fine_accuracy: 0.7773 - val_loss: 0.1003 - val_prediction_coarse_accuracy: 0.8972 - val_prediction_medium_accuracy: 0.7819 - val_prediction_fine_accuracy: 0.5658 - lr: 1.4989e-04
# Epoch 48/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0427 - prediction_coarse_accuracy: 0.9795 - prediction_medium_accuracy: 0.9576 - prediction_fine_accuracy: 0.7806
#   • Coarse Accuracy = 97.95% | Val_Accuracy = 89.87% | LossWeight = 0.18
#   • Medium Accuracy = 95.76% | Val_Accuracy = 78.02% | LossWeight = 0.32
#   • Fine   Accuracy = 78.06% | Val_Accuracy = 56.26% | LossWeight = 0.50
#
# Epoch 48: val_prediction_fine_accuracy did not improve from 0.57568
# 1848/1848 [==============================] - 266s 137ms/step - loss: 0.0427 - prediction_coarse_accuracy: 0.9795 - prediction_medium_accuracy: 0.9576 - prediction_fine_accuracy: 0.7806 - val_loss: 0.1014 - val_prediction_coarse_accuracy: 0.8987 - val_prediction_medium_accuracy: 0.7802 - val_prediction_fine_accuracy: 0.5626 - lr: 1.4240e-04
# Epoch 49/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0427 - prediction_coarse_accuracy: 0.9786 - prediction_medium_accuracy: 0.9575 - prediction_fine_accuracy: 0.7847
#   • Coarse Accuracy = 97.86% | Val_Accuracy = 89.77% | LossWeight = 0.19
#   • Medium Accuracy = 95.75% | Val_Accuracy = 78.53% | LossWeight = 0.32
#   • Fine   Accuracy = 78.47% | Val_Accuracy = 56.57% | LossWeight = 0.49
#
# Epoch 49: val_prediction_fine_accuracy did not improve from 0.57568
# 1848/1848 [==============================] - 322s 168ms/step - loss: 0.0427 - prediction_coarse_accuracy: 0.9786 - prediction_medium_accuracy: 0.9575 - prediction_fine_accuracy: 0.7847 - val_loss: 0.0998 - val_prediction_coarse_accuracy: 0.8977 - val_prediction_medium_accuracy: 0.7853 - val_prediction_fine_accuracy: 0.5657 - lr: 1.3528e-04
# Epoch 50/100
# 2023-04-13 15:33:27.442927: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:390] Filling up shuffle buffer (this may take a while): 3058 of 6400
# 2023-04-13 15:33:37.488953: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:390] Filling up shuffle buffer (this may take a while): 6009 of 6400
# 2023-04-13 15:33:38.179649: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:415] Shuffle buffer filled.
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0424 - prediction_coarse_accuracy: 0.9794 - prediction_medium_accuracy: 0.9581 - prediction_fine_accuracy: 0.7887
#   • Coarse Accuracy = 97.94% | Val_Accuracy = 89.75% | LossWeight = 0.19
#   • Medium Accuracy = 95.81% | Val_Accuracy = 78.28% | LossWeight = 0.32
#   • Fine   Accuracy = 78.87% | Val_Accuracy = 56.25% | LossWeight = 0.49
#
# Epoch 50: val_prediction_fine_accuracy did not improve from 0.57568
# 1848/1848 [==============================] - 307s 153ms/step - loss: 0.0424 - prediction_coarse_accuracy: 0.9794 - prediction_medium_accuracy: 0.9581 - prediction_fine_accuracy: 0.7887 - val_loss: 0.1020 - val_prediction_coarse_accuracy: 0.8975 - val_prediction_medium_accuracy: 0.7828 - val_prediction_fine_accuracy: 0.5625 - lr: 1.2851e-04
# Epoch 51/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0418 - prediction_coarse_accuracy: 0.9792 - prediction_medium_accuracy: 0.9588 - prediction_fine_accuracy: 0.7924
#   • Coarse Accuracy = 97.92% | Val_Accuracy = 89.53% | LossWeight = 0.19
#   • Medium Accuracy = 95.88% | Val_Accuracy = 78.25% | LossWeight = 0.32
#   • Fine   Accuracy = 79.24% | Val_Accuracy = 56.46% | LossWeight = 0.48
#
# Epoch 51: val_prediction_fine_accuracy did not improve from 0.57568
# 1848/1848 [==============================] - 277s 142ms/step - loss: 0.0418 - prediction_coarse_accuracy: 0.9792 - prediction_medium_accuracy: 0.9588 - prediction_fine_accuracy: 0.7924 - val_loss: 0.1010 - val_prediction_coarse_accuracy: 0.8953 - val_prediction_medium_accuracy: 0.7825 - val_prediction_fine_accuracy: 0.5646 - lr: 1.2209e-04
# Epoch 52/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0417 - prediction_coarse_accuracy: 0.9795 - prediction_medium_accuracy: 0.9587 - prediction_fine_accuracy: 0.7972
#   • Coarse Accuracy = 97.95% | Val_Accuracy = 89.66% | LossWeight = 0.19
#   • Medium Accuracy = 95.87% | Val_Accuracy = 78.44% | LossWeight = 0.33
#   • Fine   Accuracy = 79.72% | Val_Accuracy = 56.66% | LossWeight = 0.48
#
# Epoch 52: val_prediction_fine_accuracy did not improve from 0.57568
# ...
# 1848/1848 [==============================] - 267s 137ms/step - loss: 0.0388 - prediction_coarse_accuracy: 0.9800 - prediction_medium_accuracy: 0.9618 - prediction_fine_accuracy: 0.8396 - val_loss: 0.1031 - val_prediction_coarse_accuracy: 0.8976 - val_prediction_medium_accuracy: 0.7855 - val_prediction_fine_accuracy: 0.5606 - lr: 2.6205e-05
# Epoch 82/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0387 - prediction_coarse_accuracy: 0.9796 - prediction_medium_accuracy: 0.9618 - prediction_fine_accuracy: 0.8412
#   • Coarse Accuracy = 97.96% | Val_Accuracy = 89.79% | LossWeight = 0.22
#   • Medium Accuracy = 96.18% | Val_Accuracy = 78.55% | LossWeight = 0.35
#   • Fine   Accuracy = 84.12% | Val_Accuracy = 56.01% | LossWeight = 0.43
#
# Epoch 82: val_prediction_fine_accuracy did not improve from 0.57568
# 1848/1848 [==============================] - 266s 137ms/step - loss: 0.0387 - prediction_coarse_accuracy: 0.9796 - prediction_medium_accuracy: 0.9618 - prediction_fine_accuracy: 0.8412 - val_loss: 0.1026 - val_prediction_coarse_accuracy: 0.8979 - val_prediction_medium_accuracy: 0.7855 - val_prediction_fine_accuracy: 0.5601 - lr: 2.4894e-05
# Epoch 83/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0387 - prediction_coarse_accuracy: 0.9803 - prediction_medium_accuracy: 0.9627 - prediction_fine_accuracy: 0.8416
#   • Coarse Accuracy = 98.03% | Val_Accuracy = 89.79% | LossWeight = 0.22
#   • Medium Accuracy = 96.27% | Val_Accuracy = 78.71% | LossWeight = 0.34
#   • Fine   Accuracy = 84.16% | Val_Accuracy = 55.93% | LossWeight = 0.44
#
# Epoch 83: val_prediction_fine_accuracy did not improve from 0.57568
# 1848/1848 [==============================] - 264s 136ms/step - loss: 0.0387 - prediction_coarse_accuracy: 0.9803 - prediction_medium_accuracy: 0.9627 - prediction_fine_accuracy: 0.8416 - val_loss: 0.1032 - val_prediction_coarse_accuracy: 0.8979 - val_prediction_medium_accuracy: 0.7871 - val_prediction_fine_accuracy: 0.5593 - lr: 2.3650e-05
# Epoch 84/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0390 - prediction_coarse_accuracy: 0.9793 - prediction_medium_accuracy: 0.9612 - prediction_fine_accuracy: 0.8415
#   • Coarse Accuracy = 97.93% | Val_Accuracy = 89.81% | LossWeight = 0.22
#   • Medium Accuracy = 96.12% | Val_Accuracy = 78.64% | LossWeight = 0.35
#   • Fine   Accuracy = 84.15% | Val_Accuracy = 56.04% | LossWeight = 0.43
#
# Epoch 84: val_prediction_fine_accuracy did not improve from 0.57568
# 1848/1848 [==============================] - 271s 140ms/step - loss: 0.0390 - prediction_coarse_accuracy: 0.9793 - prediction_medium_accuracy: 0.9612 - prediction_fine_accuracy: 0.8415 - val_loss: 0.1027 - val_prediction_coarse_accuracy: 0.8981 - val_prediction_medium_accuracy: 0.7864 - val_prediction_fine_accuracy: 0.5604 - lr: 2.2467e-05
# Epoch 85/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0384 - prediction_coarse_accuracy: 0.9801 - prediction_medium_accuracy: 0.9633 - prediction_fine_accuracy: 0.8431
#   • Coarse Accuracy = 98.01% | Val_Accuracy = 89.74% | LossWeight = 0.22
#   • Medium Accuracy = 96.33% | Val_Accuracy = 78.65% | LossWeight = 0.34
#   • Fine   Accuracy = 84.31% | Val_Accuracy = 56.01% | LossWeight = 0.44
#
# Epoch 85: val_prediction_fine_accuracy did not improve from 0.57568
# 1848/1848 [==============================] - 264s 136ms/step - loss: 0.0384 - prediction_coarse_accuracy: 0.9801 - prediction_medium_accuracy: 0.9633 - prediction_fine_accuracy: 0.8431 - val_loss: 0.1031 - val_prediction_coarse_accuracy: 0.8974 - val_prediction_medium_accuracy: 0.7865 - val_prediction_fine_accuracy: 0.5601 - lr: 2.1344e-05
# Epoch 86/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0389 - prediction_coarse_accuracy: 0.9799 - prediction_medium_accuracy: 0.9615 - prediction_fine_accuracy: 0.8431
#   • Coarse Accuracy = 97.99% | Val_Accuracy = 89.79% | LossWeight = 0.22
#   • Medium Accuracy = 96.15% | Val_Accuracy = 78.61% | LossWeight = 0.35
#   • Fine   Accuracy = 84.31% | Val_Accuracy = 55.98% | LossWeight = 0.43
#
# Epoch 86: val_prediction_fine_accuracy did not improve from 0.57568
# 1848/1848 [==============================] - 269s 139ms/step - loss: 0.0389 - prediction_coarse_accuracy: 0.9799 - prediction_medium_accuracy: 0.9615 - prediction_fine_accuracy: 0.8431 - val_loss: 0.1033 - val_prediction_coarse_accuracy: 0.8979 - val_prediction_medium_accuracy: 0.7861 - val_prediction_fine_accuracy: 0.5598 - lr: 2.0277e-05
# Epoch 87/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0388 - prediction_coarse_accuracy: 0.9797 - prediction_medium_accuracy: 0.9612 - prediction_fine_accuracy: 0.8419
#   • Coarse Accuracy = 97.97% | Val_Accuracy = 89.87% | LossWeight = 0.22
#   • Medium Accuracy = 96.12% | Val_Accuracy = 78.77% | LossWeight = 0.35
#   • Fine   Accuracy = 84.19% | Val_Accuracy = 55.93% | LossWeight = 0.43
#
# Epoch 87: val_prediction_fine_accuracy did not improve from 0.57568
# 1848/1848 [==============================] - 369s 192ms/step - loss: 0.0388 - prediction_coarse_accuracy: 0.9797 - prediction_medium_accuracy: 0.9612 - prediction_fine_accuracy: 0.8419 - val_loss: 0.1031 - val_prediction_coarse_accuracy: 0.8987 - val_prediction_medium_accuracy: 0.7877 - val_prediction_fine_accuracy: 0.5593 - lr: 1.9263e-05
# Epoch 88/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0387 - prediction_coarse_accuracy: 0.9798 - prediction_medium_accuracy: 0.9622 - prediction_fine_accuracy: 0.8436
#   • Coarse Accuracy = 97.98% | Val_Accuracy = 89.87% | LossWeight = 0.22
#   • Medium Accuracy = 96.22% | Val_Accuracy = 78.53% | LossWeight = 0.35
#   • Fine   Accuracy = 84.36% | Val_Accuracy = 56.10% | LossWeight = 0.43
#
# Epoch 88: val_prediction_fine_accuracy did not improve from 0.57568
# 1848/1848 [==============================] - 267s 137ms/step - loss: 0.0387 - prediction_coarse_accuracy: 0.9798 - prediction_medium_accuracy: 0.9622 - prediction_fine_accuracy: 0.8436 - val_loss: 0.1031 - val_prediction_coarse_accuracy: 0.8987 - val_prediction_medium_accuracy: 0.7853 - val_prediction_fine_accuracy: 0.5610 - lr: 1.8300e-05
# Epoch 89/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0386 - prediction_coarse_accuracy: 0.9805 - prediction_medium_accuracy: 0.9613 - prediction_fine_accuracy: 0.8440
#   • Coarse Accuracy = 98.05% | Val_Accuracy = 89.84% | LossWeight = 0.21
#   • Medium Accuracy = 96.13% | Val_Accuracy = 78.54% | LossWeight = 0.36
#   • Fine   Accuracy = 84.40% | Val_Accuracy = 55.96% | LossWeight = 0.43
#
# Epoch 89: val_prediction_fine_accuracy did not improve from 0.57568
# 1848/1848 [==============================] - 255s 131ms/step - loss: 0.0386 - prediction_coarse_accuracy: 0.9805 - prediction_medium_accuracy: 0.9613 - prediction_fine_accuracy: 0.8440 - val_loss: 0.1033 - val_prediction_coarse_accuracy: 0.8984 - val_prediction_medium_accuracy: 0.7854 - val_prediction_fine_accuracy: 0.5596 - lr: 1.7385e-05
# Epoch 90/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0384 - prediction_coarse_accuracy: 0.9802 - prediction_medium_accuracy: 0.9621 - prediction_fine_accuracy: 0.8439
#   • Coarse Accuracy = 98.02% | Val_Accuracy = 89.82% | LossWeight = 0.22
#   • Medium Accuracy = 96.21% | Val_Accuracy = 78.77% | LossWeight = 0.35
#   • Fine   Accuracy = 84.39% | Val_Accuracy = 56.10% | LossWeight = 0.43
#
# Epoch 90: val_prediction_fine_accuracy did not improve from 0.57568
# 1848/1848 [==============================] - 269s 138ms/step - loss: 0.0384 - prediction_coarse_accuracy: 0.9802 - prediction_medium_accuracy: 0.9621 - prediction_fine_accuracy: 0.8439 - val_loss: 0.1026 - val_prediction_coarse_accuracy: 0.8982 - val_prediction_medium_accuracy: 0.7877 - val_prediction_fine_accuracy: 0.5610 - lr: 1.6515e-05
# Epoch 91/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0387 - prediction_coarse_accuracy: 0.9803 - prediction_medium_accuracy: 0.9617 - prediction_fine_accuracy: 0.8436
#   • Coarse Accuracy = 98.03% | Val_Accuracy = 89.88% | LossWeight = 0.22
#   • Medium Accuracy = 96.17% | Val_Accuracy = 78.72% | LossWeight = 0.35
#   • Fine   Accuracy = 84.36% | Val_Accuracy = 56.04% | LossWeight = 0.43
#
# Epoch 91: val_prediction_fine_accuracy did not improve from 0.57568
# 1848/1848 [==============================] - 275s 143ms/step - loss: 0.0387 - prediction_coarse_accuracy: 0.9803 - prediction_medium_accuracy: 0.9617 - prediction_fine_accuracy: 0.8436 - val_loss: 0.1027 - val_prediction_coarse_accuracy: 0.8988 - val_prediction_medium_accuracy: 0.7872 - val_prediction_fine_accuracy: 0.5604 - lr: 1.5690e-05
# Epoch 92/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0383 - prediction_coarse_accuracy: 0.9805 - prediction_medium_accuracy: 0.9622 - prediction_fine_accuracy: 0.8463
#   • Coarse Accuracy = 98.05% | Val_Accuracy = 89.81% | LossWeight = 0.22
#   • Medium Accuracy = 96.22% | Val_Accuracy = 78.65% | LossWeight = 0.35
#   • Fine   Accuracy = 84.63% | Val_Accuracy = 55.92% | LossWeight = 0.43
#
# Epoch 92: val_prediction_fine_accuracy did not improve from 0.57568
# 1848/1848 [==============================] - 273s 143ms/step - loss: 0.0383 - prediction_coarse_accuracy: 0.9805 - prediction_medium_accuracy: 0.9622 - prediction_fine_accuracy: 0.8463 - val_loss: 0.1029 - val_prediction_coarse_accuracy: 0.8981 - val_prediction_medium_accuracy: 0.7865 - val_prediction_fine_accuracy: 0.5592 - lr: 1.4905e-05
# Epoch 93/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0380 - prediction_coarse_accuracy: 0.9811 - prediction_medium_accuracy: 0.9632 - prediction_fine_accuracy: 0.8466
#   • Coarse Accuracy = 98.11% | Val_Accuracy = 89.93% | LossWeight = 0.21
#   • Medium Accuracy = 96.32% | Val_Accuracy = 78.61% | LossWeight = 0.35
#   • Fine   Accuracy = 84.66% | Val_Accuracy = 56.08% | LossWeight = 0.44
#
# Epoch 93: val_prediction_fine_accuracy did not improve from 0.57568
# 1848/1848 [==============================] - 276s 143ms/step - loss: 0.0380 - prediction_coarse_accuracy: 0.9811 - prediction_medium_accuracy: 0.9632 - prediction_fine_accuracy: 0.8466 - val_loss: 0.1029 - val_prediction_coarse_accuracy: 0.8993 - val_prediction_medium_accuracy: 0.7861 - val_prediction_fine_accuracy: 0.5608 - lr: 1.4160e-05
# Epoch 94/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0384 - prediction_coarse_accuracy: 0.9803 - prediction_medium_accuracy: 0.9622 - prediction_fine_accuracy: 0.8442
#   • Coarse Accuracy = 98.03% | Val_Accuracy = 89.81% | LossWeight = 0.22
#   • Medium Accuracy = 96.22% | Val_Accuracy = 78.52% | LossWeight = 0.35
#   • Fine   Accuracy = 84.42% | Val_Accuracy = 55.88% | LossWeight = 0.43
#
# Epoch 94: val_prediction_fine_accuracy did not improve from 0.57568
# 1848/1848 [==============================] - 270s 139ms/step - loss: 0.0384 - prediction_coarse_accuracy: 0.9803 - prediction_medium_accuracy: 0.9622 - prediction_fine_accuracy: 0.8442 - val_loss: 0.1028 - val_prediction_coarse_accuracy: 0.8981 - val_prediction_medium_accuracy: 0.7852 - val_prediction_fine_accuracy: 0.5588 - lr: 1.3452e-05
# Epoch 95/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0384 - prediction_coarse_accuracy: 0.9798 - prediction_medium_accuracy: 0.9614 - prediction_fine_accuracy: 0.8465
#   • Coarse Accuracy = 97.98% | Val_Accuracy = 89.81% | LossWeight = 0.22
#   • Medium Accuracy = 96.14% | Val_Accuracy = 78.69% | LossWeight = 0.35
#   • Fine   Accuracy = 84.65% | Val_Accuracy = 56.03% | LossWeight = 0.42
#
# Epoch 95: val_prediction_fine_accuracy did not improve from 0.57568
# 1848/1848 [==============================] - 266s 138ms/step - loss: 0.0384 - prediction_coarse_accuracy: 0.9798 - prediction_medium_accuracy: 0.9614 - prediction_fine_accuracy: 0.8465 - val_loss: 0.1029 - val_prediction_coarse_accuracy: 0.8981 - val_prediction_medium_accuracy: 0.7869 - val_prediction_fine_accuracy: 0.5603 - lr: 1.2779e-05
# Epoch 96/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0385 - prediction_coarse_accuracy: 0.9803 - prediction_medium_accuracy: 0.9621 - prediction_fine_accuracy: 0.8478
#   • Coarse Accuracy = 98.03% | Val_Accuracy = 89.86% | LossWeight = 0.22
#   • Medium Accuracy = 96.21% | Val_Accuracy = 78.60% | LossWeight = 0.35
#   • Fine   Accuracy = 84.78% | Val_Accuracy = 56.10% | LossWeight = 0.43
#
# Epoch 96: val_prediction_fine_accuracy did not improve from 0.57568
# 1848/1848 [==============================] - 270s 139ms/step - loss: 0.0385 - prediction_coarse_accuracy: 0.9803 - prediction_medium_accuracy: 0.9621 - prediction_fine_accuracy: 0.8478 - val_loss: 0.1033 - val_prediction_coarse_accuracy: 0.8986 - val_prediction_medium_accuracy: 0.7860 - val_prediction_fine_accuracy: 0.5610 - lr: 1.2140e-05
# Epoch 97/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0385 - prediction_coarse_accuracy: 0.9798 - prediction_medium_accuracy: 0.9607 - prediction_fine_accuracy: 0.8458
#   • Coarse Accuracy = 97.98% | Val_Accuracy = 89.84% | LossWeight = 0.22
#   • Medium Accuracy = 96.07% | Val_Accuracy = 78.66% | LossWeight = 0.36
#   • Fine   Accuracy = 84.58% | Val_Accuracy = 55.97% | LossWeight = 0.42
#
# Epoch 97: val_prediction_fine_accuracy did not improve from 0.57568
# 1848/1848 [==============================] - 247s 126ms/step - loss: 0.0385 - prediction_coarse_accuracy: 0.9798 - prediction_medium_accuracy: 0.9607 - prediction_fine_accuracy: 0.8458 - val_loss: 0.1028 - val_prediction_coarse_accuracy: 0.8984 - val_prediction_medium_accuracy: 0.7866 - val_prediction_fine_accuracy: 0.5597 - lr: 1.1533e-05
# Epoch 98/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0382 - prediction_coarse_accuracy: 0.9801 - prediction_medium_accuracy: 0.9628 - prediction_fine_accuracy: 0.8473
#   • Coarse Accuracy = 98.01% | Val_Accuracy = 89.83% | LossWeight = 0.22
#   • Medium Accuracy = 96.28% | Val_Accuracy = 78.64% | LossWeight = 0.35
#   • Fine   Accuracy = 84.73% | Val_Accuracy = 55.88% | LossWeight = 0.43
#
# Epoch 98: val_prediction_fine_accuracy did not improve from 0.57568
# 1848/1848 [==============================] - 269s 138ms/step - loss: 0.0382 - prediction_coarse_accuracy: 0.9801 - prediction_medium_accuracy: 0.9628 - prediction_fine_accuracy: 0.8473 - val_loss: 0.1030 - val_prediction_coarse_accuracy: 0.8983 - val_prediction_medium_accuracy: 0.7864 - val_prediction_fine_accuracy: 0.5588 - lr: 1.0957e-05
# Epoch 99/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0382 - prediction_coarse_accuracy: 0.9808 - prediction_medium_accuracy: 0.9622 - prediction_fine_accuracy: 0.8478
#   • Coarse Accuracy = 98.08% | Val_Accuracy = 89.84% | LossWeight = 0.22
#   • Medium Accuracy = 96.22% | Val_Accuracy = 78.60% | LossWeight = 0.36
#   • Fine   Accuracy = 84.78% | Val_Accuracy = 55.97% | LossWeight = 0.43
#
# Epoch 99: val_prediction_fine_accuracy did not improve from 0.57568
# 1848/1848 [==============================] - 351s 183ms/step - loss: 0.0382 - prediction_coarse_accuracy: 0.9808 - prediction_medium_accuracy: 0.9622 - prediction_fine_accuracy: 0.8478 - val_loss: 0.1032 - val_prediction_coarse_accuracy: 0.8984 - val_prediction_medium_accuracy: 0.7860 - val_prediction_fine_accuracy: 0.5597 - lr: 1.0409e-05
# Epoch 100/100
# 1848/1848 [==============================] - ETA: 0s - loss: 0.0383 - prediction_coarse_accuracy: 0.9804 - prediction_medium_accuracy: 0.9617 - prediction_fine_accuracy: 0.8479
#   • Coarse Accuracy = 98.04% | Val_Accuracy = 89.84% | LossWeight = 0.22
#   • Medium Accuracy = 96.17% | Val_Accuracy = 78.65% | LossWeight = 0.36
#   • Fine   Accuracy = 84.79% | Val_Accuracy = 55.94% | LossWeight = 0.42
#
# Epoch 100: val_prediction_fine_accuracy did not improve from 0.57568
# 1848/1848 [==============================] - 271s 139ms/step - loss: 0.0383 - prediction_coarse_accuracy: 0.9804 - prediction_medium_accuracy: 0.9617 - prediction_fine_accuracy: 0.8479 - val_loss: 0.1027 - val_prediction_coarse_accuracy: 0.8984 - val_prediction_medium_accuracy: 0.7865 - val_prediction_fine_accuracy: 0.5594 - lr: 9.8884e-06

# %%
try:
    history_dict = history.history

    plotter = tfdocs.plots.HistoryPlotter()
    plotter.plot({"Coarse": history}, metric = "prediction_coarse_accuracy")
    plotter.plot({"Medium": history}, metric = "prediction_medium_accuracy")
    plotter.plot({"Fine": history}, metric = "prediction_fine_accuracy")
    plt.title("Model Accuracy")
    plt.ylim([0,1])
except:
    print('Trained model weights loaded')

# %%
try:
    plotter = tfdocs.plots.HistoryPlotter()
    plotter.plot({"loss": history}, metric = "loss")
    plt.title("Model Loss")
    plt.ylim([0,1])
except:
    print('Trained model weights loaded')

# %% [markdown]
# ## Model Analysis

# %%
final_model = keras.Model(model.inputs[:1], model.output)
final_model.load_weights(directory+'/epoch-best.h5')

lossfn = models.MarginLoss()
final_model.compile(optimizer='adam', 
                    loss={'prediction_fine' : lossfn,
                          'prediction_medium' : lossfn,
                          'prediction_coarse' : lossfn},

                    loss_weights={'prediction_fine' : lossweight['fine_lw'],
                                  'prediction_medium' : lossweight['medium_lw'],
                                  'prediction_coarse' : lossweight['coarse_lw']},

                    metrics={'prediction_fine': 'accuracy',
                             'prediction_medium': 'accuracy',
                             'prediction_coarse': 'accuracy'
                            }
                   )

# %% [raw]
# image = []
# ds_labels0=[]
# ds_labels1=[]
# ds_labels2=[]
#
# for images, labels in val_dataset.unbatch():
#     image.append(images[0].numpy()) # or labels.numpy().argmax() for int labels
#     ds_labels0.append(images[1].numpy()) # or labels.numpy().argmax() for int labels
#     ds_labels1.append(images[2].numpy()) # or labels.numpy().argmax() for int labels
#     ds_labels2.append(images[3].numpy()) # or labels.numpy().argmax() for int labels

# %%
results = final_model.evaluate(dataset.test_dataset)
for n in range(len(results)):
    print(str(n+1)+'.',final_model.metrics_names[n], '==>', results[n])
# model_predictions = final_model.predict(dataset.test_dataset)
# Out:
# 419/419 [==============================] - 264s 624ms/step - loss: 0.2124 - prediction_coarse_loss: 0.0744 - prediction_medium_loss: 0.1692 - prediction_fine_loss: 0.3199 - prediction_coarse_accuracy: 0.8988 - prediction_medium_accuracy: 0.7860 - prediction_fine_accuracy: 0.5715
# 1. loss ==> 0.21237286925315857
# 2. prediction_coarse_loss ==> 0.07444676011800766
# 3. prediction_medium_loss ==> 0.1691640168428421
# 4. prediction_fine_loss ==> 0.31985634565353394
# 5. prediction_coarse_accuracy ==> 0.8987610936164856
# 6. prediction_medium_accuracy ==> 0.7859914898872375
# 7. prediction_fine_accuracy ==> 0.5715351700782776

# %%
def predict_from_pipeline(model, dataset):
    y_pred_c = []
    y_pred_m = []
    y_pred_f = []
    
    y_true_c = []
    y_true_m = []
    y_true_f = []
    for x, y in dataset:
        batch_pred = model.predict(x)
        
        y_true_c.extend(y[0].numpy().tolist())
        y_true_m.extend(y[1].numpy().tolist())
        y_true_f.extend(y[2].numpy().tolist())
        
        y_pred_c.extend(batch_pred[0].tolist())
        y_pred_m.extend(batch_pred[1].tolist())
        y_pred_f.extend(batch_pred[2].tolist())
        
    return np.array(y_true_c), np.array(y_true_m), np.array(y_true_f), np.array(y_pred_c), np.array(y_pred_m), np.array(y_pred_f)

# %%
y_true_c, y_true_m, y_true_f, y_pred_c, y_pred_m, y_pred_f = predict_from_pipeline(final_model, dataset.test_dataset)

# %%
metrics.lvl_wise_metric([y_true_c, y_true_m, y_true_f],
                        [y_pred_c, y_pred_m, y_pred_f])
# Out:
#   • Confusion_Matrix
#
#   • COARSE LEVEL
# [[22425   655]
#  [ 2058  1660]]
#
#   • MEDIUM LEVEL
# [[   79    77     0     0     0     6     5   506     0    70]
#  [   44  1148     0     0     0     3     5  1001     0   124]
#  [    3     0     0     0     0     0     0    20     0     1]
#  [    2     3     0    27     0     3     0    76     0     8]
#  [    2     2     0     0     0     0     0    44     0     1]
#  [    7    21     0     2     0     5     0    99     0    10]
#  [    1     2     0     0     0     0   451   230     0    11]
#  [  141   379     0     4     0    11   157 17530     0   740]
#  [    0     1     0     0     0     1     0    16     0     1]
#  [   37   154     0     2     0     6    23  1673     0  1823]]
#
#   • FINE LEVEL
# [[590  28   4 ...   0  22   5]
#  [ 45 254  11 ...   0   2   2]
#  [ 41  58  79 ...   0   3   1]
#  ...
#  [  7  10   1 ...   0   6   0]
#  [104  31   7 ...   0  81   1]
#  [  3   2   0 ...   0   0 233]]
#
#   • Classification Report
#
#
#   • COARSE LEVEL
#               precision    recall  f1-score   support
#
#            0    0.91594   0.97162   0.94296     23080
#            1    0.71706   0.44648   0.55031      3718
#
#     accuracy                        0.89876     26798
#    macro avg    0.81650   0.70905   0.74663     26798
# weighted avg    0.88835   0.89876   0.88848     26798
#
#
#   • MEDIUM LEVEL
# /home/knoor/.conda/envs/tf28_luthin/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/knoor/.conda/envs/tf28_luthin/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/knoor/.conda/envs/tf28_luthin/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0    0.25000   0.10633   0.14920       743
#            1    0.64242   0.49376   0.55837      2325
#            2    0.00000   0.00000   0.00000        24
#            3    0.77143   0.22689   0.35065       119
#            4    0.00000   0.00000   0.00000        49
#            5    0.14286   0.03472   0.05587       144
#            6    0.70359   0.64892   0.67515       695
#            7    0.82708   0.92448   0.87307     18962
#            8    0.00000   0.00000   0.00000        19
#            9    0.65364   0.49032   0.56032      3718
#
#     accuracy                        0.78599     26798
#    macro avg    0.39910   0.29254   0.32226     26798
# weighted avg    0.76103   0.78599   0.76747     26798
#
#
#   • FINE LEVEL
#               precision    recall  f1-score   support
#
#            0    0.32507   0.35976   0.34153      1640
#            1    0.42617   0.47925   0.45115       530
#            2    0.57246   0.25159   0.34956       314
#            3    0.21875   0.06604   0.10145       106
#            4    0.43562   0.53304   0.47943      1574
#            5    0.00000   0.00000   0.00000       244
#            6    0.18367   0.03114   0.05325       289
#            7    0.32014   0.38399   0.34917      1474
#            8    0.00000   0.00000   0.00000        96
#            9    0.00000   0.00000   0.00000        30
#           10    0.42615   0.57984   0.49126      3294
#           11    0.39111   0.20561   0.26953       428
#           12    0.33333   0.00943   0.01835       106
#           13    0.00000   0.00000   0.00000        31
#           14    0.21026   0.07130   0.10649       575
#           15    0.61261   0.62385   0.61818      1962
#           16    0.61538   0.27586   0.38095        29
#           17    0.02000   0.01739   0.01860       115
#           18    0.00000   0.00000   0.00000        49
#           19    0.00000   0.00000   0.00000         5
#           20    0.00000   0.00000   0.00000        19
#           21    0.50000   0.03659   0.06818        82
#           22    0.20000   0.02586   0.04580       116
#           23    0.00000   0.00000   0.00000        19
#           24    0.50000   0.10000   0.16667        20
#           25    0.62533   0.70963   0.66482       675
#           26    0.67347   0.27731   0.39286       119
#           27    0.69231   0.25714   0.37500        70
#           28    0.15741   0.09641   0.11958       529
#           29    0.00000   0.00000   0.00000        52
#           30    0.00000   0.00000   0.00000         8
#           31    0.28571   0.06494   0.10582       154
#           32    0.55939   0.58386   0.57136      2057
#           33    0.81832   0.88993   0.85263      8513
#           34    0.61538   0.04651   0.08649       172
#           35    0.00000   0.00000   0.00000        64
#           36    0.30566   0.13023   0.18264       622
#           37    0.43148   0.37825   0.40311       616
#
#     accuracy                        0.57154     26798
#    macro avg    0.30145   0.19697   0.21221     26798
# weighted avg    0.54306   0.57154   0.54680     26798
# /home/knoor/.conda/envs/tf28_luthin/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/knoor/.conda/envs/tf28_luthin/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/knoor/.conda/envs/tf28_luthin/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
h_measurements,consistency,exact_match = metrics.hmeasurements([y_true_c, y_true_m, y_true_f],
                                                               [y_pred_c, y_pred_m, y_pred_f],
                                                               dataset.get_tree())
print('\nHierarchical Precision =',h_measurements[0],
      '\nHierarchical Recall =', h_measurements[1],
      '\nHierarchical F1-Score =',h_measurements[2],
      '\nConsistency = ', consistency,
      '\nExact Match = ', exact_match,
     )
# Out:
# Hierarchical Precision = 0.7501946662686269
# Hierarchical Recall = 0.760442321566286
# Hierarchical F1-Score = 0.7543682186659274
# Consistency =  0.9447346816926636
# Exact Match =  0.5559370102246436
