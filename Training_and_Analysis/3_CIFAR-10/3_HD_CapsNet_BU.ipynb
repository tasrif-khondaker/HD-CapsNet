# %% [markdown]
# ***
# <font size="6"><center><b> HD-CapsNet: A Hierarchical Deep Capsule Network for Image Classification </b></center></font>
# ***

# %% [markdown]
# **Changing Model Architecture**
# - Applying bottom-up approach. (Fine-to-Coarse)
# - Changing the Secondary Capsule Dimension:
#     - 16D>12D>8D (Fine>Medium>Coarse)
#     - Use Hinge Loss (MarginLoss) for each level + Consistency Loss.

# %% [markdown]
# # Files and Libraries

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras import regularizers, optimizers
from tensorflow.keras import backend as K

import tensorflow_docs as tfdocs
import tensorflow_docs.plots

# Supporting Libraries:
    #Mathplot lib for ploting graphs
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
    # numpy and pandas
import numpy as np
import pandas as pd
    #system
import os
import sys
import csv
    #import other libraries
import math
import random
from datetime import datetime
from treelib import Tree
    # ML model, Dataset and evalution metrics
sys.path.append('../../') ### adding system parth for src folder
from src import datasets # load datasets
from src import MixUp_add_loss # load datasets
from src import metrics # load hierarchcial metrics
from src import sysenv # load hierarchcial metrics
from src import models # load machine learning models

    ## Tensorflow_docs
import tensorflow_docs as tfdocs
import tensorflow_docs.plots

    # Auto reload local libraries if updated
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # System information & GPU growth

# %%
systeminfo = sysenv.systeminfo()
print(systeminfo)
# Out:
# • Computer Name = SARUMAN
# • Working Directory = D:\knoor\Deep Learning with Python\RunningOnServer\HD-CapsNet_MOD\Training_and_Analysis\3_CIFAR-10
# • Python Version = 3.8.12 (default, Oct 12 2021, 03:01:40) [MSC v.1916 64 bit (AMD64)]
# • TensorFlow Version = 2.8.0
# • Keras Version = 2.8.0
# • Current Environment = Anaconda Environment Name : D:\knoor\AnacondaEnvironment\py38tf28

# %%
gpus = "0,1,2,3,4,5,6,7" ## Selecting Available gpus (Multi-GPUS)
gpus = "0" ## Selecting Available gpus (Single GPU)
gpugrowth = sysenv.gpugrowth(gpus = gpus) ## Limiting GPUS from OS environment
gpugrowth.memory_growth() #GPU memory growth
# Out:
# Following GPUS are selected =  0
# Done: GPU PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# 1 Physical GPUs, 1 Logical GPUs

# %% [markdown]
# ## log directory

# %%
directory = sysenv.log_dir('MOD_1/3_CIFAR_10/HD_CapsNet/BU_W_C_loss')
# Out:
# FOLDER CREATED =  ../../logs/MOD_1/3_CIFAR_10/HD_CapsNet/BU_W_C_loss

# %% [markdown]
# # Import Dataset : CIFAR-10

# %%
dataset = datasets.CIFAR10(version = 'ALL') # importing CIFAR10 Dataset
# dataset = datasets.CIFAR10(version = 'reduce') # importing CIFAR10 Dataset
# Out:
# CIFAR-10 dataset: Training have 50,000 samples and testing have 10,000 samples

# %% [markdown]
# # Parameters

# %%
train_params = {"n_epochs" : 100,
                "batch_size": 64,
                "lr": 0.001, # Initial learning rate
                "lr_decay": 0.95, # Learning rate decay
                "decay_exe": 9, #learning rate decay execution epoch after
               }
model_params = {"optimizer": tf.keras.optimizers.Adam(train_params['lr']),
                "loss_function": models.MarginLoss(),
               }

# %% [markdown]
# ## Learning Rate Decay Scheduler

# %%
def scheduler(epoch):
    learning_rate_init = train_params["lr"]
    
    if epoch > train_params["decay_exe"]:
        learning_rate_init = train_params["lr"] * (train_params["lr_decay"] ** (epoch-9))
        
    tf.summary.scalar('learning rate', data=learning_rate_init, step=epoch)
        
    return learning_rate_init

# %% [markdown]
# # Bottom up Approach

# %% [markdown]
# ## Loss Function

# %%
number_of_classes_c = len(np.unique(np.argmax(dataset['y_train_coarse'], axis=1)))
number_of_classes_m = len(np.unique(np.argmax(dataset['y_train_medium'], axis=1)))
number_of_classes_f = len(np.unique(np.argmax(dataset['y_train_fine'], axis=1)))

## For Dynamic LossWeights
initial_lw = models.initial_lw({"coarse": number_of_classes_c,
                                "medium": number_of_classes_m,
                                "fine": number_of_classes_f})

lossweight = {'coarse_lw' : K.variable(value = initial_lw['coarse'], dtype="float32", name="coarse_lw"),
             'medium_lw' : K.variable(value = initial_lw['medium'], dtype="float32", name="medium_lw"),
             'fine_lw' : K.variable(value = initial_lw['fine'], dtype="float32", name="fine_lw"),
              'decoder_lw' : 0.0
             }

# %%
coarse_to_medium_array = np.zeros(shape=[number_of_classes_c,number_of_classes_m], dtype=np.int32)
medium_to_fine_array = np.zeros(shape=[number_of_classes_m,number_of_classes_f], dtype=np.int32)

c_id = np.argmax(dataset['y_train_coarse'],1)

m_id = np.argmax(dataset['y_train_medium'],1)

f_id = np.argmax(dataset['y_train_fine'],1)

for x in range(len(dataset['y_test_medium'])):
    coarse_to_medium_array[c_id[x]][m_id[x]] = 1
    
for x in range(len(dataset['y_test_fine'])):
    medium_to_fine_array[m_id[x]][f_id[x]] = 1

Matrix_coarse_to_medium_OneHot = tf.constant(coarse_to_medium_array, dtype=tf.float32)
Matrix_medium_to_fine_OneHot = tf.constant(medium_to_fine_array, dtype=tf.float32)

# %%
def margin_loss(y_true, y_proba):
    
    present_error_raw = tf.square(tf.maximum(0., 0.9 - y_proba), name="present_error_raw")
    absent_error_raw = tf.square(tf.maximum(0., y_proba - 0.1), name="absent_error_raw")
    L = tf.add(y_true * present_error_raw, 0.5 * (1.0 - y_true) * absent_error_raw,name="L")
    total_marginloss = tf.reduce_sum(L, axis=1, name="margin_loss")

    return total_marginloss


def consistency_check(y_pred_ancestor,y_pred_current,lookup_matrix,num_class_current):
    pred_max_ancestor = tf.argmax(y_pred_ancestor,axis=1)
    pred_max_current = tf.argmax(y_pred_current,axis=1)
    
    consistant_check = tf.gather(lookup_matrix, indices=pred_max_ancestor)*tf.one_hot(pred_max_current,num_class_current)
    
    return tf.reduce_sum(consistant_check,1)

def get_consistency(y_true_ancestor, y_pred, lookup_matrix):
    '''
    Get consistency based on 2 levels
    Provide ture levels for the level above, predictions for the current level and a look up metrix
    '''
    y_prob = tf.math.divide(y_pred,tf.reshape(tf.reduce_sum(y_pred,-1),(-1,1),name='reshape'),name='Probability')
    
    index_for_predictions = tf.cast(tf.math.argmax(y_true_ancestor,axis=1),dtype= 'int32')
    consistent_fine = tf.gather(lookup_matrix, indices=index_for_predictions) * y_prob
    Consistency_sum_array = tf.reduce_sum(consistent_fine, axis =1)
    
    return tf.abs(1-Consistency_sum_array)

def CustomLoss(y_true_c, y_true_m, y_true_f, y_pred_c, y_pred_m, y_pred_f, LW_C, LW_M, LW_F,tree: Tree,C_Weight=0.2):
    
    con_m = consistency_check(y_pred_c,y_pred_m,Matrix_coarse_to_medium_OneHot,num_class_current=7)
    con_m_not = tf.abs(con_m-1)
    
    con_f = consistency_check(y_pred_m,y_pred_f,Matrix_medium_to_fine_OneHot,num_class_current=10)
    con_f_not = tf.abs(con_f-1)
    
    con_sum_m = get_consistency(y_true_c,y_pred_m,Matrix_coarse_to_medium_OneHot)
    con_sum_f = get_consistency(y_true_m,y_pred_f,Matrix_medium_to_fine_OneHot)
    
    medium_lvl_cosistency = con_sum_m * con_m_not
    fine_lvl_cosistency = con_sum_f * con_f_not    
   
    ML_c = margin_loss(y_true_c, y_pred_c)*LW_C
    ML_m = LW_M*((1-C_Weight)*(margin_loss(y_true_m, y_pred_m))+C_Weight*(medium_lvl_cosistency))
    ML_f = LW_F*((1-C_Weight)*(margin_loss(y_true_f, y_pred_f))+C_Weight*(fine_lvl_cosistency))
    
    batch_loss = ML_c + ML_m+ ML_f

    return tf.reduce_mean(batch_loss)

# %% [markdown]
# ## Model Architecture

# %%
def get_compiled_model():
    input_shape = dataset['x_train'].shape[1:]

    input_shape_yc = dataset['y_train_coarse'].shape[1:]
    input_shape_ym = dataset['y_train_medium'].shape[1:]
    input_shape_yf = dataset['y_train_fine'].shape[1:]

    no_coarse_class = 2
    no_medium_class = 7
    no_fine_class = 10

    PCap_n_dims = 8

    SCap_f_dims = 16
    SCap_m_dims = 12
    SCap_c_dims = 8


    # Input image
    x_input = keras.layers.Input(shape=input_shape, name="Input_Image")

    # Input True Labels
    y_c = keras.layers.Input(shape=input_shape_yc, name='input_yc')
    y_m = keras.layers.Input(shape=input_shape_ym, name='input_ym')
    y_f = keras.layers.Input(shape=input_shape_yf, name='input_yf')

    #--- block 1 ---
    x = keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv1')(x_input)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv2')(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.MaxPooling2D((2, 2), strides=(2, 2), name='block1_pool')(x)

    #--- block 2 ---
    x = keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv1')(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv2')(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.MaxPooling2D((2, 2), strides=(2, 2), name='block2_pool')(x)

    #--- block 3 ---
    x = keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv1')(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv2')(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.MaxPooling2D((2, 2), strides=(2, 2), name='block3_pool')(x)

    #--- block 4 ---
    x = keras.layers.Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv1')(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv2')(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.MaxPooling2D((2, 2), strides=(2, 2), name='block4_pool')(x)


    # Layer 3: Reshape to 8D primary capsules 
    # input [batch_size, 6, 6, 512], output [batch_size, 2304, 8]
    reshapec = keras.layers.Reshape((256, PCap_n_dims), name="reshape_layer")(x)
    p_caps = keras.layers.Lambda(models.squash, name='p_caps')(reshapec)

    ## Layer Secondary Capsule: For fine level
    s_caps_f = models.SecondaryCapsule(n_caps=no_fine_class, n_dims=SCap_f_dims, 
                        name="s_caps_fine")(p_caps)

    ## Layer Secondary Capsule: For medium level
    s_caps_m = models.SecondaryCapsule(n_caps=no_medium_class, n_dims=SCap_m_dims, 
                        name="s_caps_medium")(s_caps_f)

    ## Layer Secondary Capsule: For coarse level
    s_caps_c = models.SecondaryCapsule(n_caps=no_coarse_class, n_dims=SCap_c_dims, 
                        name="s_caps_coarse")(s_caps_m)

    pred_c = models.LengthLayer(name='prediction_coarse')(s_caps_c)

    pred_m = models.LengthLayer(name='prediction_medium')(s_caps_m)

    pred_f = models.LengthLayer(name='prediction_fine')(s_caps_f)

    model = keras.Model(inputs= [x_input, y_c, y_m, y_f],
                        outputs= [pred_c, pred_m, pred_f],
                        name='HD-CapsNet')

    model.add_loss(CustomLoss(y_c, y_m, y_f, pred_c, pred_m, pred_f, 
                              lossweight['coarse_lw'], lossweight['medium_lw'], lossweight['fine_lw'],
                              dataset['tree']))

    model.compile(optimizer='adam',                  
                  metrics={'prediction_fine': 'accuracy',
                           'prediction_medium': 'accuracy',
                           'prediction_coarse': 'accuracy'
                          }
    )
    return model

# %%
model = get_compiled_model()
# Out:
# WARNING:tensorflow:The following Variables were used in a Lambda layer's call (tf.math.multiply_9), but are not present in its tracked objects:   <tf.Variable 'coarse_lw:0' shape=() dtype=float32>. This is a strong indication that the Lambda layer should be rewritten as a subclassed Layer.

# %% [raw]
# strategy = multi_gpu_select('windows')
#
# print("Number of devices: {}".format(strategy.num_replicas_in_sync))
#
# with strategy.scope():
#     # Everything that creates variables should be under the strategy scope.
#     # In general this is only model construction & `compile()`.
#     model = get_compiled_model()

# %%
model.summary()
# keras.utils.plot_model(model, to_file = directory+"/Architecture.png", show_shapes=True)
# Out:
# Model: "HD-CapsNet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Input_Image (InputLayer)       [(None, 32, 32, 3)]  0           []
#
#  block1_conv1 (Conv2D)          (None, 32, 32, 64)   1792        ['Input_Image[0][0]']
#
#  batch_normalization (BatchNorm  (None, 32, 32, 64)  256         ['block1_conv1[0][0]']
#  alization)
#
#  block1_conv2 (Conv2D)          (None, 32, 32, 64)   36928       ['batch_normalization[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 32, 32, 64)  256         ['block1_conv2[0][0]']
#  rmalization)
#
#  block1_pool (MaxPooling2D)     (None, 16, 16, 64)   0           ['batch_normalization_1[0][0]']
#
#  block2_conv1 (Conv2D)          (None, 16, 16, 128)  73856       ['block1_pool[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 16, 16, 128)  512        ['block2_conv1[0][0]']
#  rmalization)
#
#  block2_conv2 (Conv2D)          (None, 16, 16, 128)  147584      ['batch_normalization_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 16, 16, 128)  512        ['block2_conv2[0][0]']
#  rmalization)
#
#  block2_pool (MaxPooling2D)     (None, 8, 8, 128)    0           ['batch_normalization_3[0][0]']
#
#  block3_conv1 (Conv2D)          (None, 8, 8, 256)    295168      ['block2_pool[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 8, 8, 256)   1024        ['block3_conv1[0][0]']
#  rmalization)
#
#  block3_conv2 (Conv2D)          (None, 8, 8, 256)    590080      ['batch_normalization_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 8, 8, 256)   1024        ['block3_conv2[0][0]']
#  rmalization)
#
#  block3_pool (MaxPooling2D)     (None, 4, 4, 256)    0           ['batch_normalization_5[0][0]']
#
#  block4_conv1 (Conv2D)          (None, 4, 4, 512)    1180160     ['block3_pool[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 4, 4, 512)   2048        ['block4_conv1[0][0]']
#  rmalization)
#
#  block4_conv2 (Conv2D)          (None, 4, 4, 512)    2359808     ['batch_normalization_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 4, 4, 512)   2048        ['block4_conv2[0][0]']
#  rmalization)
#
#  block4_pool (MaxPooling2D)     (None, 2, 2, 512)    0           ['batch_normalization_7[0][0]']
#
#  reshape_layer (Reshape)        (None, 256, 8)       0           ['block4_pool[0][0]']
#
#  p_caps (Lambda)                (None, 256, 8)       0           ['reshape_layer[0][0]']
#
#  s_caps_fine (SecondaryCapsule)  (None, 10, 16)      327680      ['p_caps[0][0]']
#
#  s_caps_medium (SecondaryCapsul  (None, 7, 12)       13440       ['s_caps_fine[0][0]']
#  e)
#
#  s_caps_coarse (SecondaryCapsul  (None, 2, 8)        1344        ['s_caps_medium[0][0]']
#  e)
#
#  input_yc (InputLayer)          [(None, 2)]          0           []
#
#  input_ym (InputLayer)          [(None, 7)]          0           []
#
#  input_yf (InputLayer)          [(None, 10)]         0           []
#
#  prediction_coarse (LengthLayer  (None, 2)           0           ['s_caps_coarse[0][0]']
#  )
#
#  prediction_medium (LengthLayer  (None, 7)           0           ['s_caps_medium[0][0]']
#  )
#
#  prediction_fine (LengthLayer)  (None, 10)           0           ['s_caps_fine[0][0]']
#
#  tf.math.argmax_4 (TFOpLambda)  (None,)              0           ['input_yc[0][0]']
#
#  tf.math.reduce_sum_2 (TFOpLamb  (None,)             0           ['prediction_medium[0][0]']
#  da)
#
#  tf.cast (TFOpLambda)           (None,)              0           ['tf.math.argmax_4[0][0]']
#
#  tf.reshape (TFOpLambda)        (None, 1)            0           ['tf.math.reduce_sum_2[0][0]']
#
#  tf.math.argmax (TFOpLambda)    (None,)              0           ['prediction_coarse[0][0]']
#
#  tf.math.argmax_1 (TFOpLambda)  (None,)              0           ['prediction_medium[0][0]']
#
#  tf.math.argmax_5 (TFOpLambda)  (None,)              0           ['input_ym[0][0]']
#
#  tf.math.reduce_sum_4 (TFOpLamb  (None,)             0           ['prediction_fine[0][0]']
#  da)
#
#  tf.math.subtract_7 (TFOpLambda  (None, 7)           0           ['prediction_medium[0][0]']
#  )
#
#  tf.math.subtract_8 (TFOpLambda  (None, 7)           0           ['prediction_medium[0][0]']
#  )
#
#  tf.compat.v1.gather_2 (TFOpLam  (None, 7)           0           ['tf.cast[0][0]']
#  bda)
#
#  tf.math.divide (TFOpLambda)    (None, 7)            0           ['prediction_medium[0][0]',
#                                                                   'tf.reshape[0][0]']
#
#  tf.compat.v1.gather (TFOpLambd  (None, 7)           0           ['tf.math.argmax[0][0]']
#  a)
#
#  tf.one_hot (TFOpLambda)        (None, 7)            0           ['tf.math.argmax_1[0][0]']
#
#  tf.cast_1 (TFOpLambda)         (None,)              0           ['tf.math.argmax_5[0][0]']
#
#  tf.reshape_1 (TFOpLambda)      (None, 1)            0           ['tf.math.reduce_sum_4[0][0]']
#
#  tf.math.argmax_2 (TFOpLambda)  (None,)              0           ['prediction_medium[0][0]']
#
#  tf.math.argmax_3 (TFOpLambda)  (None,)              0           ['prediction_fine[0][0]']
#
#  tf.math.maximum_2 (TFOpLambda)  (None, 7)           0           ['tf.math.subtract_7[0][0]']
#
#  tf.math.subtract_9 (TFOpLambda  (None, 7)           0           ['input_ym[0][0]']
#  )
#
#  tf.math.maximum_3 (TFOpLambda)  (None, 7)           0           ['tf.math.subtract_8[0][0]']
#
#  tf.math.multiply_2 (TFOpLambda  (None, 7)           0           ['tf.compat.v1.gather_2[0][0]',
#  )                                                                'tf.math.divide[0][0]']
#
#  tf.math.multiply (TFOpLambda)  (None, 7)            0           ['tf.compat.v1.gather[0][0]',
#                                                                   'tf.one_hot[0][0]']
#
#  tf.math.subtract_10 (TFOpLambd  (None, 10)          0           ['prediction_fine[0][0]']
#  a)
#
#  tf.math.subtract_11 (TFOpLambd  (None, 10)          0           ['prediction_fine[0][0]']
#  a)
#
#  tf.compat.v1.gather_3 (TFOpLam  (None, 10)          0           ['tf.cast_1[0][0]']
#  bda)
#
#  tf.math.divide_1 (TFOpLambda)  (None, 10)           0           ['prediction_fine[0][0]',
#                                                                   'tf.reshape_1[0][0]']
#
#  tf.compat.v1.gather_1 (TFOpLam  (None, 10)          0           ['tf.math.argmax_2[0][0]']
#  bda)
#
#  tf.one_hot_1 (TFOpLambda)      (None, 10)           0           ['tf.math.argmax_3[0][0]']
#
#  tf.math.subtract_4 (TFOpLambda  (None, 2)           0           ['prediction_coarse[0][0]']
#  )
#
#  tf.math.subtract_5 (TFOpLambda  (None, 2)           0           ['prediction_coarse[0][0]']
#  )
#
#  tf.math.square_2 (TFOpLambda)  (None, 7)            0           ['tf.math.maximum_2[0][0]']
#
#  tf.math.multiply_11 (TFOpLambd  (None, 7)           0           ['tf.math.subtract_9[0][0]']
#  a)
#
#  tf.math.square_3 (TFOpLambda)  (None, 7)            0           ['tf.math.maximum_3[0][0]']
#
#  tf.math.reduce_sum_3 (TFOpLamb  (None,)             0           ['tf.math.multiply_2[0][0]']
#  da)
#
#  tf.math.reduce_sum (TFOpLambda  (None,)             0           ['tf.math.multiply[0][0]']
#  )
#
#  tf.math.maximum_4 (TFOpLambda)  (None, 10)          0           ['tf.math.subtract_10[0][0]']
#
#  tf.math.subtract_12 (TFOpLambd  (None, 10)          0           ['input_yf[0][0]']
#  a)
#
#  tf.math.maximum_5 (TFOpLambda)  (None, 10)          0           ['tf.math.subtract_11[0][0]']
#
#  tf.math.multiply_3 (TFOpLambda  (None, 10)          0           ['tf.compat.v1.gather_3[0][0]',
#  )                                                                'tf.math.divide_1[0][0]']
#
#  tf.math.multiply_1 (TFOpLambda  (None, 10)          0           ['tf.compat.v1.gather_1[0][0]',
#  )                                                                'tf.one_hot_1[0][0]']
#
#  tf.math.maximum (TFOpLambda)   (None, 2)            0           ['tf.math.subtract_4[0][0]']
#
#  tf.math.subtract_6 (TFOpLambda  (None, 2)           0           ['input_yc[0][0]']
#  )
#
#  tf.math.maximum_1 (TFOpLambda)  (None, 2)           0           ['tf.math.subtract_5[0][0]']
#
#  tf.math.multiply_10 (TFOpLambd  (None, 7)           0           ['input_ym[0][0]',
#  a)                                                               'tf.math.square_2[0][0]']
#
#  tf.math.multiply_12 (TFOpLambd  (None, 7)           0           ['tf.math.multiply_11[0][0]',
#  a)                                                               'tf.math.square_3[0][0]']
#
#  tf.math.subtract_2 (TFOpLambda  (None,)             0           ['tf.math.reduce_sum_3[0][0]']
#  )
#
#  tf.math.subtract (TFOpLambda)  (None,)              0           ['tf.math.reduce_sum[0][0]']
#
#  tf.math.square_4 (TFOpLambda)  (None, 10)           0           ['tf.math.maximum_4[0][0]']
#
#  tf.math.multiply_17 (TFOpLambd  (None, 10)          0           ['tf.math.subtract_12[0][0]']
#  a)
#
#  tf.math.square_5 (TFOpLambda)  (None, 10)           0           ['tf.math.maximum_5[0][0]']
#
#  tf.math.reduce_sum_5 (TFOpLamb  (None,)             0           ['tf.math.multiply_3[0][0]']
#  da)
#
#  tf.math.reduce_sum_1 (TFOpLamb  (None,)             0           ['tf.math.multiply_1[0][0]']
#  da)
#
#  tf.math.square (TFOpLambda)    (None, 2)            0           ['tf.math.maximum[0][0]']
#
#  tf.math.multiply_7 (TFOpLambda  (None, 2)           0           ['tf.math.subtract_6[0][0]']
#  )
#
#  tf.math.square_1 (TFOpLambda)  (None, 2)            0           ['tf.math.maximum_1[0][0]']
#
#  tf.math.add_1 (TFOpLambda)     (None, 7)            0           ['tf.math.multiply_10[0][0]',
#                                                                   'tf.math.multiply_12[0][0]']
#
#  tf.math.abs_2 (TFOpLambda)     (None,)              0           ['tf.math.subtract_2[0][0]']
#
#  tf.math.abs (TFOpLambda)       (None,)              0           ['tf.math.subtract[0][0]']
#
#  tf.math.multiply_16 (TFOpLambd  (None, 10)          0           ['input_yf[0][0]',
#  a)                                                               'tf.math.square_4[0][0]']
#
#  tf.math.multiply_18 (TFOpLambd  (None, 10)          0           ['tf.math.multiply_17[0][0]',
#  a)                                                               'tf.math.square_5[0][0]']
#
#  tf.math.subtract_3 (TFOpLambda  (None,)             0           ['tf.math.reduce_sum_5[0][0]']
#  )
#
#  tf.math.subtract_1 (TFOpLambda  (None,)             0           ['tf.math.reduce_sum_1[0][0]']
#  )
#
#  tf.math.multiply_6 (TFOpLambda  (None, 2)           0           ['input_yc[0][0]',
#  )                                                                'tf.math.square[0][0]']
#
#  tf.math.multiply_8 (TFOpLambda  (None, 2)           0           ['tf.math.multiply_7[0][0]',
#  )                                                                'tf.math.square_1[0][0]']
#
#  tf.math.reduce_sum_7 (TFOpLamb  (None,)             0           ['tf.math.add_1[0][0]']
#  da)
#
#  tf.math.multiply_4 (TFOpLambda  (None,)             0           ['tf.math.abs_2[0][0]',
#  )                                                                'tf.math.abs[0][0]']
#
#  tf.math.add_2 (TFOpLambda)     (None, 10)           0           ['tf.math.multiply_16[0][0]',
#                                                                   'tf.math.multiply_18[0][0]']
#
#  tf.math.abs_3 (TFOpLambda)     (None,)              0           ['tf.math.subtract_3[0][0]']
#
#  tf.math.abs_1 (TFOpLambda)     (None,)              0           ['tf.math.subtract_1[0][0]']
#
#  tf.math.add (TFOpLambda)       (None, 2)            0           ['tf.math.multiply_6[0][0]',
#                                                                   'tf.math.multiply_8[0][0]']
#
#  tf.math.multiply_13 (TFOpLambd  (None,)             0           ['tf.math.reduce_sum_7[0][0]']
#  a)
#
#  tf.math.multiply_14 (TFOpLambd  (None,)             0           ['tf.math.multiply_4[0][0]']
#  a)
#
#  tf.math.reduce_sum_8 (TFOpLamb  (None,)             0           ['tf.math.add_2[0][0]']
#  da)
#
#  tf.math.multiply_5 (TFOpLambda  (None,)             0           ['tf.math.abs_3[0][0]',
#  )                                                                'tf.math.abs_1[0][0]']
#
#  tf.math.reduce_sum_6 (TFOpLamb  (None,)             0           ['tf.math.add[0][0]']
#  da)
#
#  tf.__operators__.add (TFOpLamb  (None,)             0           ['tf.math.multiply_13[0][0]',
#  da)                                                              'tf.math.multiply_14[0][0]']
#
#  tf.math.multiply_19 (TFOpLambd  (None,)             0           ['tf.math.reduce_sum_8[0][0]']
#  a)
#
#  tf.math.multiply_20 (TFOpLambd  (None,)             0           ['tf.math.multiply_5[0][0]']
#  a)
#
#  tf.math.multiply_9 (TFOpLambda  (None,)             0           ['tf.math.reduce_sum_6[0][0]']
#  )
#
#  tf.math.multiply_15 (TFOpLambd  (None,)             0           ['tf.__operators__.add[0][0]']
#  a)
#
#  tf.__operators__.add_1 (TFOpLa  (None,)             0           ['tf.math.multiply_19[0][0]',
#  mbda)                                                            'tf.math.multiply_20[0][0]']
#
#  tf.__operators__.add_2 (TFOpLa  (None,)             0           ['tf.math.multiply_9[0][0]',
#  mbda)                                                            'tf.math.multiply_15[0][0]']
#
#  tf.math.multiply_21 (TFOpLambd  (None,)             0           ['tf.__operators__.add_1[0][0]']
#  a)
#
#  tf.__operators__.add_3 (TFOpLa  (None,)             0           ['tf.__operators__.add_2[0][0]',
#  mbda)                                                            'tf.math.multiply_21[0][0]']
#
#  tf.math.reduce_mean (TFOpLambd  ()                  0           ['tf.__operators__.add_3[0][0]']
#  a)
#
#  add_loss (AddLoss)             ()                   0           ['tf.math.reduce_mean[0][0]']
#
# ==================================================================================================
# Total params: 5,035,520
# Trainable params: 5,031,680
# Non-trainable params: 3,840
# __________________________________________________________________________________________________

# %% [markdown]
# ## Data Augmentation

# %%
datagen = ImageDataGenerator(width_shift_range=0.1,
                            height_shift_range=0.1)

training_generator = MixUp_add_loss.MixupGenerator_3level(dataset['x_train'],
                                                 dataset['y_train_coarse'], 
                                                 dataset['y_train_medium'],
                                                 dataset['y_train_fine'],
                                                 batch_size=train_params["batch_size"],
                                                 alpha=0.2, 
                                                 datagen=datagen
                                                )()

# %% [markdown]
# ## Callback

# %%
tb = keras.callbacks.TensorBoard(directory+'./tb_logs'+ datetime.now().strftime("%Y%m%d-%H%M%S"))
log = keras.callbacks.CSVLogger(directory+'/log.csv', append=True)

checkpoint = keras.callbacks.ModelCheckpoint(
    directory+'/epoch-best.h5', 
    monitor='val_prediction_fine_accuracy',
    save_best_only=True, save_weights_only=True, verbose=1)
change_lw = models.LossWeightsModifier(lossweight = lossweight,
                               initial_lw = initial_lw,
                               directory = directory)
lr_decay = keras.callbacks.LearningRateScheduler(scheduler)

# %% [markdown]
# ## Model Training

# %%
model_save_dir = str(directory+'/trained_model.h5')
try:
    model.load_weights(model_save_dir)
except:
    history = model.fit(training_generator,
                        steps_per_epoch = int(dataset['x_train'].shape[0] / train_params["batch_size"]),
                        epochs = train_params["n_epochs"],
                        validation_data = ([dataset['x_test'],
                                            dataset['y_test_coarse'],dataset['y_test_medium'],dataset['y_test_fine']],
                                           [dataset['y_test_coarse'],dataset['y_test_medium'],dataset['y_test_fine']]),
                        callbacks = [tb,log,change_lw,lr_decay,checkpoint],
                        verbose=1)
    model.save_weights(model_save_dir)
# Out:
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring... Layer tf.math.multiply_9 was passed non-JSON-serializable arguments. Arguments had types: {'y': <class 'tensorflow.python.ops.resource_variable_ops.ResourceVariable'>, 'name': <class 'NoneType'>}. They cannot be serialized out when saving the model.
# Epoch 1/100
# 781/781 [==============================] - ETA: 0s - loss: 0.2622 - prediction_coarse_accuracy: 0.8431 - prediction_medium_accuracy: 0.5555 - prediction_fine_accuracy: 0.4716
#   • Coarse Accuracy = 84.31% | Val_Accuracy = 93.54% | LossWeight = 0.21
#   • Medium Accuracy = 55.55% | Val_Accuracy = 71.48% | LossWeight = 0.42
#   • Fine   Accuracy = 47.16% | Val_Accuracy = 61.35% | LossWeight = 0.37
#
# Epoch 1: val_prediction_fine_accuracy improved from -inf to 0.61350, saving model to ../../logs/MOD_1/3_CIFAR_10/HD_CapsNet/BU_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 57s 63ms/step - loss: 0.2622 - prediction_coarse_accuracy: 0.8431 - prediction_medium_accuracy: 0.5555 - prediction_fine_accuracy: 0.4716 - val_loss: 0.1267 - val_prediction_coarse_accuracy: 0.9354 - val_prediction_medium_accuracy: 0.7148 - val_prediction_fine_accuracy: 0.6135 - lr: 0.0010
# Epoch 2/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1235 - prediction_coarse_accuracy: 0.9285 - prediction_medium_accuracy: 0.7463 - prediction_fine_accuracy: 0.6650
#   • Coarse Accuracy = 92.85% | Val_Accuracy = 93.29% | LossWeight = 0.17
#   • Medium Accuracy = 74.63% | Val_Accuracy = 77.05% | LossWeight = 0.42
#   • Fine   Accuracy = 66.50% | Val_Accuracy = 71.13% | LossWeight = 0.41
#
# Epoch 2: val_prediction_fine_accuracy improved from 0.61350 to 0.71130, saving model to ../../logs/MOD_1/3_CIFAR_10/HD_CapsNet/BU_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 47s 60ms/step - loss: 0.1235 - prediction_coarse_accuracy: 0.9285 - prediction_medium_accuracy: 0.7463 - prediction_fine_accuracy: 0.6650 - val_loss: 0.0930 - val_prediction_coarse_accuracy: 0.9329 - val_prediction_medium_accuracy: 0.7705 - val_prediction_fine_accuracy: 0.7113 - lr: 0.0010
# Epoch 3/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1011 - prediction_coarse_accuracy: 0.9440 - prediction_medium_accuracy: 0.8022 - prediction_fine_accuracy: 0.7391
#   • Coarse Accuracy = 94.40% | Val_Accuracy = 96.13% | LossWeight = 0.17
#   • Medium Accuracy = 80.22% | Val_Accuracy = 83.52% | LossWeight = 0.42
#   • Fine   Accuracy = 73.91% | Val_Accuracy = 78.38% | LossWeight = 0.41
#
# Epoch 3: val_prediction_fine_accuracy improved from 0.71130 to 0.78380, saving model to ../../logs/MOD_1/3_CIFAR_10/HD_CapsNet/BU_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 47s 61ms/step - loss: 0.1011 - prediction_coarse_accuracy: 0.9440 - prediction_medium_accuracy: 0.8022 - prediction_fine_accuracy: 0.7391 - val_loss: 0.0657 - val_prediction_coarse_accuracy: 0.9613 - val_prediction_medium_accuracy: 0.8352 - val_prediction_fine_accuracy: 0.7838 - lr: 0.0010
# Epoch 4/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0902 - prediction_coarse_accuracy: 0.9534 - prediction_medium_accuracy: 0.8384 - prediction_fine_accuracy: 0.7809
#   • Coarse Accuracy = 95.34% | Val_Accuracy = 97.07% | LossWeight = 0.17
#   • Medium Accuracy = 83.84% | Val_Accuracy = 85.89% | LossWeight = 0.41
#   • Fine   Accuracy = 78.09% | Val_Accuracy = 80.90% | LossWeight = 0.42
#
# Epoch 4: val_prediction_fine_accuracy improved from 0.78380 to 0.80900, saving model to ../../logs/MOD_1/3_CIFAR_10/HD_CapsNet/BU_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 48s 61ms/step - loss: 0.0902 - prediction_coarse_accuracy: 0.9534 - prediction_medium_accuracy: 0.8384 - prediction_fine_accuracy: 0.7809 - val_loss: 0.0560 - val_prediction_coarse_accuracy: 0.9707 - val_prediction_medium_accuracy: 0.8589 - val_prediction_fine_accuracy: 0.8090 - lr: 0.0010
# Epoch 5/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0851 - prediction_coarse_accuracy: 0.9568 - prediction_medium_accuracy: 0.8546 - prediction_fine_accuracy: 0.8023
#   • Coarse Accuracy = 95.68% | Val_Accuracy = 97.21% | LossWeight = 0.17
#   • Medium Accuracy = 85.46% | Val_Accuracy = 87.50% | LossWeight = 0.41
#   • Fine   Accuracy = 80.23% | Val_Accuracy = 82.85% | LossWeight = 0.42
#
# Epoch 5: val_prediction_fine_accuracy improved from 0.80900 to 0.82850, saving model to ../../logs/MOD_1/3_CIFAR_10/HD_CapsNet/BU_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 48s 61ms/step - loss: 0.0851 - prediction_coarse_accuracy: 0.9568 - prediction_medium_accuracy: 0.8546 - prediction_fine_accuracy: 0.8023 - val_loss: 0.0512 - val_prediction_coarse_accuracy: 0.9721 - val_prediction_medium_accuracy: 0.8750 - val_prediction_fine_accuracy: 0.8285 - lr: 0.0010
# Epoch 6/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0781 - prediction_coarse_accuracy: 0.9630 - prediction_medium_accuracy: 0.8716 - prediction_fine_accuracy: 0.8271
#   • Coarse Accuracy = 96.30% | Val_Accuracy = 97.65% | LossWeight = 0.17
#   • Medium Accuracy = 87.16% | Val_Accuracy = 87.68% | LossWeight = 0.41
#   • Fine   Accuracy = 82.71% | Val_Accuracy = 82.99% | LossWeight = 0.42
#
# Epoch 6: val_prediction_fine_accuracy improved from 0.82850 to 0.82990, saving model to ../../logs/MOD_1/3_CIFAR_10/HD_CapsNet/BU_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 47s 61ms/step - loss: 0.0781 - prediction_coarse_accuracy: 0.9630 - prediction_medium_accuracy: 0.8716 - prediction_fine_accuracy: 0.8271 - val_loss: 0.0504 - val_prediction_coarse_accuracy: 0.9765 - val_prediction_medium_accuracy: 0.8768 - val_prediction_fine_accuracy: 0.8299 - lr: 0.0010
# Epoch 7/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0731 - prediction_coarse_accuracy: 0.9664 - prediction_medium_accuracy: 0.8874 - prediction_fine_accuracy: 0.8441
#   • Coarse Accuracy = 96.64% | Val_Accuracy = 97.54% | LossWeight = 0.17
#   • Medium Accuracy = 88.74% | Val_Accuracy = 88.37% | LossWeight = 0.41
#   • Fine   Accuracy = 84.41% | Val_Accuracy = 84.02% | LossWeight = 0.42
#
# Epoch 7: val_prediction_fine_accuracy improved from 0.82990 to 0.84020, saving model to ../../logs/MOD_1/3_CIFAR_10/HD_CapsNet/BU_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 47s 61ms/step - loss: 0.0731 - prediction_coarse_accuracy: 0.9664 - prediction_medium_accuracy: 0.8874 - prediction_fine_accuracy: 0.8441 - val_loss: 0.0482 - val_prediction_coarse_accuracy: 0.9754 - val_prediction_medium_accuracy: 0.8837 - val_prediction_fine_accuracy: 0.8402 - lr: 0.0010
# Epoch 8/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0709 - prediction_coarse_accuracy: 0.9672 - prediction_medium_accuracy: 0.8956 - prediction_fine_accuracy: 0.8550
#   • Coarse Accuracy = 96.72% | Val_Accuracy = 96.86% | LossWeight = 0.18
#   • Medium Accuracy = 89.56% | Val_Accuracy = 88.22% | LossWeight = 0.40
#   • Fine   Accuracy = 85.50% | Val_Accuracy = 84.47% | LossWeight = 0.42
#
# Epoch 8: val_prediction_fine_accuracy improved from 0.84020 to 0.84470, saving model to ../../logs/MOD_1/3_CIFAR_10/HD_CapsNet/BU_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 47s 61ms/step - loss: 0.0709 - prediction_coarse_accuracy: 0.9672 - prediction_medium_accuracy: 0.8956 - prediction_fine_accuracy: 0.8550 - val_loss: 0.0473 - val_prediction_coarse_accuracy: 0.9686 - val_prediction_medium_accuracy: 0.8822 - val_prediction_fine_accuracy: 0.8447 - lr: 0.0010
# Epoch 9/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0674 - prediction_coarse_accuracy: 0.9711 - prediction_medium_accuracy: 0.9064 - prediction_fine_accuracy: 0.8698
#   • Coarse Accuracy = 97.11% | Val_Accuracy = 97.01% | LossWeight = 0.18
#   • Medium Accuracy = 90.64% | Val_Accuracy = 88.62% | LossWeight = 0.40
#   • Fine   Accuracy = 86.98% | Val_Accuracy = 84.41% | LossWeight = 0.42
#
# Epoch 9: val_prediction_fine_accuracy did not improve from 0.84470
# 781/781 [==============================] - 47s 60ms/step - loss: 0.0674 - prediction_coarse_accuracy: 0.9711 - prediction_medium_accuracy: 0.9064 - prediction_fine_accuracy: 0.8698 - val_loss: 0.0472 - val_prediction_coarse_accuracy: 0.9701 - val_prediction_medium_accuracy: 0.8862 - val_prediction_fine_accuracy: 0.8441 - lr: 0.0010
# Epoch 10/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0653 - prediction_coarse_accuracy: 0.9702 - prediction_medium_accuracy: 0.9097 - prediction_fine_accuracy: 0.8756
#   • Coarse Accuracy = 97.02% | Val_Accuracy = 97.44% | LossWeight = 0.19
#   • Medium Accuracy = 90.97% | Val_Accuracy = 89.64% | LossWeight = 0.40
#   • Fine   Accuracy = 87.56% | Val_Accuracy = 86.07% | LossWeight = 0.41
#
# Epoch 10: val_prediction_fine_accuracy improved from 0.84470 to 0.86070, saving model to ../../logs/MOD_1/3_CIFAR_10/HD_CapsNet/BU_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 47s 61ms/step - loss: 0.0653 - prediction_coarse_accuracy: 0.9702 - prediction_medium_accuracy: 0.9097 - prediction_fine_accuracy: 0.8756 - val_loss: 0.0430 - val_prediction_coarse_accuracy: 0.9744 - val_prediction_medium_accuracy: 0.8964 - val_prediction_fine_accuracy: 0.8607 - lr: 0.0010
# Epoch 11/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0622 - prediction_coarse_accuracy: 0.9750 - prediction_medium_accuracy: 0.9200 - prediction_fine_accuracy: 0.8886
#   • Coarse Accuracy = 97.50% | Val_Accuracy = 97.53% | LossWeight = 0.18
#   • Medium Accuracy = 92.00% | Val_Accuracy = 89.62% | LossWeight = 0.40
#   • Fine   Accuracy = 88.86% | Val_Accuracy = 85.20% | LossWeight = 0.42
#
# Epoch 11: val_prediction_fine_accuracy did not improve from 0.86070
# 781/781 [==============================] - 47s 60ms/step - loss: 0.0622 - prediction_coarse_accuracy: 0.9750 - prediction_medium_accuracy: 0.9200 - prediction_fine_accuracy: 0.8886 - val_loss: 0.0443 - val_prediction_coarse_accuracy: 0.9753 - val_prediction_medium_accuracy: 0.8962 - val_prediction_fine_accuracy: 0.8520 - lr: 9.5000e-04
# Epoch 12/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0600 - prediction_coarse_accuracy: 0.9750 - prediction_medium_accuracy: 0.9250 - prediction_fine_accuracy: 0.8944
#   • Coarse Accuracy = 97.50% | Val_Accuracy = 97.96% | LossWeight = 0.19
#   • Medium Accuracy = 92.50% | Val_Accuracy = 89.93% | LossWeight = 0.40
#   • Fine   Accuracy = 89.44% | Val_Accuracy = 86.19% | LossWeight = 0.42
#
# Epoch 12: val_prediction_fine_accuracy improved from 0.86070 to 0.86190, saving model to ../../logs/MOD_1/3_CIFAR_10/HD_CapsNet/BU_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 47s 61ms/step - loss: 0.0600 - prediction_coarse_accuracy: 0.9750 - prediction_medium_accuracy: 0.9250 - prediction_fine_accuracy: 0.8944 - val_loss: 0.0415 - val_prediction_coarse_accuracy: 0.9796 - val_prediction_medium_accuracy: 0.8993 - val_prediction_fine_accuracy: 0.8619 - lr: 9.0250e-04
# Epoch 13/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0584 - prediction_coarse_accuracy: 0.9758 - prediction_medium_accuracy: 0.9313 - prediction_fine_accuracy: 0.9042
#   • Coarse Accuracy = 97.58% | Val_Accuracy = 97.70% | LossWeight = 0.20
#   • Medium Accuracy = 93.13% | Val_Accuracy = 89.67% | LossWeight = 0.39
#   • Fine   Accuracy = 90.42% | Val_Accuracy = 86.12% | LossWeight = 0.41
#
# Epoch 13: val_prediction_fine_accuracy did not improve from 0.86190
# 781/781 [==============================] - 47s 60ms/step - loss: 0.0584 - prediction_coarse_accuracy: 0.9758 - prediction_medium_accuracy: 0.9313 - prediction_fine_accuracy: 0.9042 - val_loss: 0.0417 - val_prediction_coarse_accuracy: 0.9770 - val_prediction_medium_accuracy: 0.8967 - val_prediction_fine_accuracy: 0.8612 - lr: 8.5737e-04
# Epoch 14/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0567 - prediction_coarse_accuracy: 0.9784 - prediction_medium_accuracy: 0.9361 - prediction_fine_accuracy: 0.9105
#   • Coarse Accuracy = 97.84% | Val_Accuracy = 97.95% | LossWeight = 0.19
#   • Medium Accuracy = 93.61% | Val_Accuracy = 90.87% | LossWeight = 0.40
#   • Fine   Accuracy = 91.05% | Val_Accuracy = 87.71% | LossWeight = 0.42
#
# Epoch 14: val_prediction_fine_accuracy improved from 0.86190 to 0.87710, saving model to ../../logs/MOD_1/3_CIFAR_10/HD_CapsNet/BU_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 47s 61ms/step - loss: 0.0567 - prediction_coarse_accuracy: 0.9784 - prediction_medium_accuracy: 0.9361 - prediction_fine_accuracy: 0.9105 - val_loss: 0.0381 - val_prediction_coarse_accuracy: 0.9795 - val_prediction_medium_accuracy: 0.9087 - val_prediction_fine_accuracy: 0.8771 - lr: 8.1451e-04
# Epoch 15/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0552 - prediction_coarse_accuracy: 0.9793 - prediction_medium_accuracy: 0.9396 - prediction_fine_accuracy: 0.9157
#   • Coarse Accuracy = 97.93% | Val_Accuracy = 98.21% | LossWeight = 0.19
#   • Medium Accuracy = 93.96% | Val_Accuracy = 91.17% | LossWeight = 0.39
#   • Fine   Accuracy = 91.57% | Val_Accuracy = 87.53% | LossWeight = 0.41
#
# Epoch 15: val_prediction_fine_accuracy did not improve from 0.87710
# 781/781 [==============================] - 50s 64ms/step - loss: 0.0552 - prediction_coarse_accuracy: 0.9793 - prediction_medium_accuracy: 0.9396 - prediction_fine_accuracy: 0.9157 - val_loss: 0.0374 - val_prediction_coarse_accuracy: 0.9821 - val_prediction_medium_accuracy: 0.9117 - val_prediction_fine_accuracy: 0.8753 - lr: 7.7378e-04
# Epoch 16/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0541 - prediction_coarse_accuracy: 0.9788 - prediction_medium_accuracy: 0.9416 - prediction_fine_accuracy: 0.9205
#   • Coarse Accuracy = 97.88% | Val_Accuracy = 98.03% | LossWeight = 0.20
#   • Medium Accuracy = 94.16% | Val_Accuracy = 90.70% | LossWeight = 0.39
#   • Fine   Accuracy = 92.05% | Val_Accuracy = 87.28% | LossWeight = 0.40
#
# Epoch 16: val_prediction_fine_accuracy did not improve from 0.87710
# 781/781 [==============================] - 47s 61ms/step - loss: 0.0541 - prediction_coarse_accuracy: 0.9788 - prediction_medium_accuracy: 0.9416 - prediction_fine_accuracy: 0.9205 - val_loss: 0.0384 - val_prediction_coarse_accuracy: 0.9803 - val_prediction_medium_accuracy: 0.9070 - val_prediction_fine_accuracy: 0.8728 - lr: 7.3509e-04
# Epoch 17/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0536 - prediction_coarse_accuracy: 0.9812 - prediction_medium_accuracy: 0.9452 - prediction_fine_accuracy: 0.9233
#   • Coarse Accuracy = 98.12% | Val_Accuracy = 98.19% | LossWeight = 0.19
#   • Medium Accuracy = 94.52% | Val_Accuracy = 91.40% | LossWeight = 0.39
#   • Fine   Accuracy = 92.33% | Val_Accuracy = 88.00% | LossWeight = 0.41
#
# Epoch 17: val_prediction_fine_accuracy improved from 0.87710 to 0.88000, saving model to ../../logs/MOD_1/3_CIFAR_10/HD_CapsNet/BU_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 48s 61ms/step - loss: 0.0536 - prediction_coarse_accuracy: 0.9812 - prediction_medium_accuracy: 0.9452 - prediction_fine_accuracy: 0.9233 - val_loss: 0.0368 - val_prediction_coarse_accuracy: 0.9819 - val_prediction_medium_accuracy: 0.9140 - val_prediction_fine_accuracy: 0.8800 - lr: 6.9834e-04
# Epoch 18/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0524 - prediction_coarse_accuracy: 0.9807 - prediction_medium_accuracy: 0.9454 - prediction_fine_accuracy: 0.9278
#   • Coarse Accuracy = 98.07% | Val_Accuracy = 98.14% | LossWeight = 0.20
#   • Medium Accuracy = 94.54% | Val_Accuracy = 91.34% | LossWeight = 0.40
#   • Fine   Accuracy = 92.78% | Val_Accuracy = 87.98% | LossWeight = 0.40
#
# Epoch 18: val_prediction_fine_accuracy did not improve from 0.88000
# 781/781 [==============================] - 47s 61ms/step - loss: 0.0524 - prediction_coarse_accuracy: 0.9807 - prediction_medium_accuracy: 0.9454 - prediction_fine_accuracy: 0.9278 - val_loss: 0.0364 - val_prediction_coarse_accuracy: 0.9814 - val_prediction_medium_accuracy: 0.9134 - val_prediction_fine_accuracy: 0.8798 - lr: 6.6342e-04
# Epoch 19/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0518 - prediction_coarse_accuracy: 0.9807 - prediction_medium_accuracy: 0.9499 - prediction_fine_accuracy: 0.9316
#   • Coarse Accuracy = 98.07% | Val_Accuracy = 98.33% | LossWeight = 0.21
#   • Medium Accuracy = 94.99% | Val_Accuracy = 92.33% | LossWeight = 0.39
#   • Fine   Accuracy = 93.16% | Val_Accuracy = 88.98% | LossWeight = 0.40
#
# Epoch 19: val_prediction_fine_accuracy improved from 0.88000 to 0.88980, saving model to ../../logs/MOD_1/3_CIFAR_10/HD_CapsNet/BU_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 48s 61ms/step - loss: 0.0518 - prediction_coarse_accuracy: 0.9807 - prediction_medium_accuracy: 0.9499 - prediction_fine_accuracy: 0.9316 - val_loss: 0.0339 - val_prediction_coarse_accuracy: 0.9833 - val_prediction_medium_accuracy: 0.9233 - val_prediction_fine_accuracy: 0.8898 - lr: 6.3025e-04
# Epoch 20/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0516 - prediction_coarse_accuracy: 0.9815 - prediction_medium_accuracy: 0.9516 - prediction_fine_accuracy: 0.9349
#   • Coarse Accuracy = 98.15% | Val_Accuracy = 98.28% | LossWeight = 0.21
#   • Medium Accuracy = 95.16% | Val_Accuracy = 91.89% | LossWeight = 0.39
#   • Fine   Accuracy = 93.49% | Val_Accuracy = 88.82% | LossWeight = 0.40
#
# Epoch 20: val_prediction_fine_accuracy did not improve from 0.88980
# 781/781 [==============================] - 48s 61ms/step - loss: 0.0516 - prediction_coarse_accuracy: 0.9815 - prediction_medium_accuracy: 0.9516 - prediction_fine_accuracy: 0.9349 - val_loss: 0.0350 - val_prediction_coarse_accuracy: 0.9828 - val_prediction_medium_accuracy: 0.9189 - val_prediction_fine_accuracy: 0.8882 - lr: 5.9874e-04
# Epoch 21/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0512 - prediction_coarse_accuracy: 0.9811 - prediction_medium_accuracy: 0.9535 - prediction_fine_accuracy: 0.9369
#   • Coarse Accuracy = 98.11% | Val_Accuracy = 98.21% | LossWeight = 0.22
#   • Medium Accuracy = 95.35% | Val_Accuracy = 91.71% | LossWeight = 0.39
#   • Fine   Accuracy = 93.69% | Val_Accuracy = 88.70% | LossWeight = 0.39
#
# Epoch 21: val_prediction_fine_accuracy did not improve from 0.88980
# 781/781 [==============================] - 48s 61ms/step - loss: 0.0512 - prediction_coarse_accuracy: 0.9811 - prediction_medium_accuracy: 0.9535 - prediction_fine_accuracy: 0.9369 - val_loss: 0.0352 - val_prediction_coarse_accuracy: 0.9821 - val_prediction_medium_accuracy: 0.9171 - val_prediction_fine_accuracy: 0.8870 - lr: 5.6880e-04
# Epoch 22/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0503 - prediction_coarse_accuracy: 0.9813 - prediction_medium_accuracy: 0.9538 - prediction_fine_accuracy: 0.9386
#   • Coarse Accuracy = 98.13% | Val_Accuracy = 98.31% | LossWeight = 0.22
#   • Medium Accuracy = 95.38% | Val_Accuracy = 92.24% | LossWeight = 0.39
#   • Fine   Accuracy = 93.86% | Val_Accuracy = 88.86% | LossWeight = 0.39
#
# Epoch 22: val_prediction_fine_accuracy did not improve from 0.88980
# 781/781 [==============================] - 47s 60ms/step - loss: 0.0503 - prediction_coarse_accuracy: 0.9813 - prediction_medium_accuracy: 0.9538 - prediction_fine_accuracy: 0.9386 - val_loss: 0.0340 - val_prediction_coarse_accuracy: 0.9831 - val_prediction_medium_accuracy: 0.9224 - val_prediction_fine_accuracy: 0.8886 - lr: 5.4036e-04
# Epoch 23/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0497 - prediction_coarse_accuracy: 0.9822 - prediction_medium_accuracy: 0.9568 - prediction_fine_accuracy: 0.9437
#   • Coarse Accuracy = 98.22% | Val_Accuracy = 98.27% | LossWeight = 0.23
#   • Medium Accuracy = 95.68% | Val_Accuracy = 92.26% | LossWeight = 0.39
#   • Fine   Accuracy = 94.37% | Val_Accuracy = 89.01% | LossWeight = 0.38
#
# Epoch 23: val_prediction_fine_accuracy improved from 0.88980 to 0.89010, saving model to ../../logs/MOD_1/3_CIFAR_10/HD_CapsNet/BU_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 48s 61ms/step - loss: 0.0497 - prediction_coarse_accuracy: 0.9822 - prediction_medium_accuracy: 0.9568 - prediction_fine_accuracy: 0.9437 - val_loss: 0.0334 - val_prediction_coarse_accuracy: 0.9827 - val_prediction_medium_accuracy: 0.9226 - val_prediction_fine_accuracy: 0.8901 - lr: 5.1334e-04
# Epoch 24/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0491 - prediction_coarse_accuracy: 0.9824 - prediction_medium_accuracy: 0.9570 - prediction_fine_accuracy: 0.9443
#   • Coarse Accuracy = 98.24% | Val_Accuracy = 98.25% | LossWeight = 0.23
#   • Medium Accuracy = 95.70% | Val_Accuracy = 92.27% | LossWeight = 0.39
#   • Fine   Accuracy = 94.43% | Val_Accuracy = 88.92% | LossWeight = 0.38
#
# Epoch 24: val_prediction_fine_accuracy did not improve from 0.89010
# 781/781 [==============================] - 47s 60ms/step - loss: 0.0491 - prediction_coarse_accuracy: 0.9824 - prediction_medium_accuracy: 0.9570 - prediction_fine_accuracy: 0.9443 - val_loss: 0.0335 - val_prediction_coarse_accuracy: 0.9825 - val_prediction_medium_accuracy: 0.9227 - val_prediction_fine_accuracy: 0.8892 - lr: 4.8767e-04
# Epoch 25/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0490 - prediction_coarse_accuracy: 0.9824 - prediction_medium_accuracy: 0.9586 - prediction_fine_accuracy: 0.9473
#   • Coarse Accuracy = 98.24% | Val_Accuracy = 98.23% | LossWeight = 0.24
#   • Medium Accuracy = 95.86% | Val_Accuracy = 92.64% | LossWeight = 0.39
#   • Fine   Accuracy = 94.73% | Val_Accuracy = 89.45% | LossWeight = 0.37
#
# Epoch 25: val_prediction_fine_accuracy improved from 0.89010 to 0.89450, saving model to ../../logs/MOD_1/3_CIFAR_10/HD_CapsNet/BU_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 47s 61ms/step - loss: 0.0490 - prediction_coarse_accuracy: 0.9824 - prediction_medium_accuracy: 0.9586 - prediction_fine_accuracy: 0.9473 - val_loss: 0.0331 - val_prediction_coarse_accuracy: 0.9823 - val_prediction_medium_accuracy: 0.9264 - val_prediction_fine_accuracy: 0.8945 - lr: 4.6329e-04
# Epoch 26/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0490 - prediction_coarse_accuracy: 0.9832 - prediction_medium_accuracy: 0.9596 - prediction_fine_accuracy: 0.9473
#   • Coarse Accuracy = 98.32% | Val_Accuracy = 98.29% | LossWeight = 0.23
#   • Medium Accuracy = 95.96% | Val_Accuracy = 92.67% | LossWeight = 0.39
#   • Fine   Accuracy = 94.73% | Val_Accuracy = 89.51% | LossWeight = 0.38
#
# Epoch 26: val_prediction_fine_accuracy improved from 0.89450 to 0.89510, saving model to ../../logs/MOD_1/3_CIFAR_10/HD_CapsNet/BU_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 47s 61ms/step - loss: 0.0490 - prediction_coarse_accuracy: 0.9832 - prediction_medium_accuracy: 0.9596 - prediction_fine_accuracy: 0.9473 - val_loss: 0.0328 - val_prediction_coarse_accuracy: 0.9829 - val_prediction_medium_accuracy: 0.9267 - val_prediction_fine_accuracy: 0.8951 - lr: 4.4013e-04
# Epoch 27/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0481 - prediction_coarse_accuracy: 0.9829 - prediction_medium_accuracy: 0.9611 - prediction_fine_accuracy: 0.9496
#   • Coarse Accuracy = 98.29% | Val_Accuracy = 98.44% | LossWeight = 0.24
#   • Medium Accuracy = 96.11% | Val_Accuracy = 92.94% | LossWeight = 0.39
#   • Fine   Accuracy = 94.96% | Val_Accuracy = 89.79% | LossWeight = 0.37
#
# Epoch 27: val_prediction_fine_accuracy improved from 0.89510 to 0.89790, saving model to ../../logs/MOD_1/3_CIFAR_10/HD_CapsNet/BU_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 47s 61ms/step - loss: 0.0481 - prediction_coarse_accuracy: 0.9829 - prediction_medium_accuracy: 0.9611 - prediction_fine_accuracy: 0.9496 - val_loss: 0.0315 - val_prediction_coarse_accuracy: 0.9844 - val_prediction_medium_accuracy: 0.9294 - val_prediction_fine_accuracy: 0.8979 - lr: 4.1812e-04
# Epoch 28/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0481 - prediction_coarse_accuracy: 0.9828 - prediction_medium_accuracy: 0.9605 - prediction_fine_accuracy: 0.9499
#   • Coarse Accuracy = 98.28% | Val_Accuracy = 98.47% | LossWeight = 0.24
#   • Medium Accuracy = 96.05% | Val_Accuracy = 93.06% | LossWeight = 0.39
#   • Fine   Accuracy = 94.99% | Val_Accuracy = 90.07% | LossWeight = 0.37
#
# Epoch 28: val_prediction_fine_accuracy improved from 0.89790 to 0.90070, saving model to ../../logs/MOD_1/3_CIFAR_10/HD_CapsNet/BU_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 47s 61ms/step - loss: 0.0481 - prediction_coarse_accuracy: 0.9828 - prediction_medium_accuracy: 0.9605 - prediction_fine_accuracy: 0.9499 - val_loss: 0.0310 - val_prediction_coarse_accuracy: 0.9847 - val_prediction_medium_accuracy: 0.9306 - val_prediction_fine_accuracy: 0.9007 - lr: 3.9721e-04
# Epoch 29/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0481 - prediction_coarse_accuracy: 0.9831 - prediction_medium_accuracy: 0.9606 - prediction_fine_accuracy: 0.9509
#   • Coarse Accuracy = 98.31% | Val_Accuracy = 98.49% | LossWeight = 0.24
#   • Medium Accuracy = 96.06% | Val_Accuracy = 92.96% | LossWeight = 0.39
#   • Fine   Accuracy = 95.09% | Val_Accuracy = 90.04% | LossWeight = 0.37
#
# Epoch 29: val_prediction_fine_accuracy did not improve from 0.90070
# 781/781 [==============================] - 47s 60ms/step - loss: 0.0481 - prediction_coarse_accuracy: 0.9831 - prediction_medium_accuracy: 0.9606 - prediction_fine_accuracy: 0.9509 - val_loss: 0.0309 - val_prediction_coarse_accuracy: 0.9849 - val_prediction_medium_accuracy: 0.9296 - val_prediction_fine_accuracy: 0.9004 - lr: 3.7735e-04
# Epoch 30/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0480 - prediction_coarse_accuracy: 0.9828 - prediction_medium_accuracy: 0.9597 - prediction_fine_accuracy: 0.9501
#   • Coarse Accuracy = 98.28% | Val_Accuracy = 98.45% | LossWeight = 0.24
#   • Medium Accuracy = 95.97% | Val_Accuracy = 92.86% | LossWeight = 0.39
#   • Fine   Accuracy = 95.01% | Val_Accuracy = 89.88% | LossWeight = 0.37
#
# Epoch 30: val_prediction_fine_accuracy did not improve from 0.90070
# 781/781 [==============================] - 47s 60ms/step - loss: 0.0480 - prediction_coarse_accuracy: 0.9828 - prediction_medium_accuracy: 0.9597 - prediction_fine_accuracy: 0.9501 - val_loss: 0.0312 - val_prediction_coarse_accuracy: 0.9845 - val_prediction_medium_accuracy: 0.9286 - val_prediction_fine_accuracy: 0.8988 - lr: 3.5849e-04
# Epoch 31/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0477 - prediction_coarse_accuracy: 0.9833 - prediction_medium_accuracy: 0.9607 - prediction_fine_accuracy: 0.9521
#   • Coarse Accuracy = 98.33% | Val_Accuracy = 98.38% | LossWeight = 0.24
#   • Medium Accuracy = 96.07% | Val_Accuracy = 92.99% | LossWeight = 0.40
#   • Fine   Accuracy = 95.21% | Val_Accuracy = 90.20% | LossWeight = 0.36
#
# Epoch 31: val_prediction_fine_accuracy improved from 0.90070 to 0.90200, saving model to ../../logs/MOD_1/3_CIFAR_10/HD_CapsNet/BU_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 47s 61ms/step - loss: 0.0477 - prediction_coarse_accuracy: 0.9833 - prediction_medium_accuracy: 0.9607 - prediction_fine_accuracy: 0.9521 - val_loss: 0.0305 - val_prediction_coarse_accuracy: 0.9838 - val_prediction_medium_accuracy: 0.9299 - val_prediction_fine_accuracy: 0.9020 - lr: 3.4056e-04
# Epoch 32/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0470 - prediction_coarse_accuracy: 0.9831 - prediction_medium_accuracy: 0.9623 - prediction_fine_accuracy: 0.9542
#   • Coarse Accuracy = 98.31% | Val_Accuracy = 98.43% | LossWeight = 0.25
#   • Medium Accuracy = 96.23% | Val_Accuracy = 92.93% | LossWeight = 0.39
#   • Fine   Accuracy = 95.42% | Val_Accuracy = 90.15% | LossWeight = 0.36
#
# Epoch 32: val_prediction_fine_accuracy did not improve from 0.90200
# 781/781 [==============================] - 47s 61ms/step - loss: 0.0470 - prediction_coarse_accuracy: 0.9831 - prediction_medium_accuracy: 0.9623 - prediction_fine_accuracy: 0.9542 - val_loss: 0.0304 - val_prediction_coarse_accuracy: 0.9843 - val_prediction_medium_accuracy: 0.9293 - val_prediction_fine_accuracy: 0.9015 - lr: 3.2353e-04
# Epoch 33/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0481 - prediction_coarse_accuracy: 0.9829 - prediction_medium_accuracy: 0.9602 - prediction_fine_accuracy: 0.9517
#   • Coarse Accuracy = 98.29% | Val_Accuracy = 98.56% | LossWeight = 0.24
#   • Medium Accuracy = 96.02% | Val_Accuracy = 93.41% | LossWeight = 0.40
#   • Fine   Accuracy = 95.17% | Val_Accuracy = 90.50% | LossWeight = 0.36
#
# Epoch 33: val_prediction_fine_accuracy improved from 0.90200 to 0.90500, saving model to ../../logs/MOD_1/3_CIFAR_10/HD_CapsNet/BU_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 47s 61ms/step - loss: 0.0481 - prediction_coarse_accuracy: 0.9829 - prediction_medium_accuracy: 0.9602 - prediction_fine_accuracy: 0.9517 - val_loss: 0.0307 - val_prediction_coarse_accuracy: 0.9856 - val_prediction_medium_accuracy: 0.9341 - val_prediction_fine_accuracy: 0.9050 - lr: 3.0736e-04
# Epoch 34/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0468 - prediction_coarse_accuracy: 0.9843 - prediction_medium_accuracy: 0.9637 - prediction_fine_accuracy: 0.9566
#   • Coarse Accuracy = 98.43% | Val_Accuracy = 98.48% | LossWeight = 0.24
#   • Medium Accuracy = 96.37% | Val_Accuracy = 93.16% | LossWeight = 0.40
#   • Fine   Accuracy = 95.66% | Val_Accuracy = 90.26% | LossWeight = 0.36
#
# Epoch 34: val_prediction_fine_accuracy did not improve from 0.90500
# 781/781 [==============================] - 47s 60ms/step - loss: 0.0468 - prediction_coarse_accuracy: 0.9843 - prediction_medium_accuracy: 0.9637 - prediction_fine_accuracy: 0.9566 - val_loss: 0.0308 - val_prediction_coarse_accuracy: 0.9848 - val_prediction_medium_accuracy: 0.9316 - val_prediction_fine_accuracy: 0.9026 - lr: 2.9199e-04
# Epoch 35/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0472 - prediction_coarse_accuracy: 0.9835 - prediction_medium_accuracy: 0.9631 - prediction_fine_accuracy: 0.9553
#   • Coarse Accuracy = 98.35% | Val_Accuracy = 98.49% | LossWeight = 0.25
#   • Medium Accuracy = 96.31% | Val_Accuracy = 93.26% | LossWeight = 0.39
#   • Fine   Accuracy = 95.53% | Val_Accuracy = 90.35% | LossWeight = 0.36
#
# Epoch 35: val_prediction_fine_accuracy did not improve from 0.90500
# 781/781 [==============================] - 47s 61ms/step - loss: 0.0472 - prediction_coarse_accuracy: 0.9835 - prediction_medium_accuracy: 0.9631 - prediction_fine_accuracy: 0.9553 - val_loss: 0.0295 - val_prediction_coarse_accuracy: 0.9849 - val_prediction_medium_accuracy: 0.9326 - val_prediction_fine_accuracy: 0.9035 - lr: 2.7739e-04
# Epoch 36/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0472 - prediction_coarse_accuracy: 0.9833 - prediction_medium_accuracy: 0.9623 - prediction_fine_accuracy: 0.9544
#   • Coarse Accuracy = 98.33% | Val_Accuracy = 98.55% | LossWeight = 0.25
#   • Medium Accuracy = 96.23% | Val_Accuracy = 93.15% | LossWeight = 0.39
#   • Fine   Accuracy = 95.44% | Val_Accuracy = 90.24% | LossWeight = 0.36
#
# Epoch 36: val_prediction_fine_accuracy did not improve from 0.90500
# 781/781 [==============================] - 47s 61ms/step - loss: 0.0472 - prediction_coarse_accuracy: 0.9833 - prediction_medium_accuracy: 0.9623 - prediction_fine_accuracy: 0.9544 - val_loss: 0.0300 - val_prediction_coarse_accuracy: 0.9855 - val_prediction_medium_accuracy: 0.9315 - val_prediction_fine_accuracy: 0.9024 - lr: 2.6352e-04
# Epoch 37/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0469 - prediction_coarse_accuracy: 0.9839 - prediction_medium_accuracy: 0.9636 - prediction_fine_accuracy: 0.9567
#   • Coarse Accuracy = 98.39% | Val_Accuracy = 98.68% | LossWeight = 0.25
#   • Medium Accuracy = 96.36% | Val_Accuracy = 93.00% | LossWeight = 0.40
#   • Fine   Accuracy = 95.67% | Val_Accuracy = 89.99% | LossWeight = 0.35
#
# Epoch 37: val_prediction_fine_accuracy did not improve from 0.90500
# 781/781 [==============================] - 47s 60ms/step - loss: 0.0469 - prediction_coarse_accuracy: 0.9839 - prediction_medium_accuracy: 0.9636 - prediction_fine_accuracy: 0.9567 - val_loss: 0.0303 - val_prediction_coarse_accuracy: 0.9868 - val_prediction_medium_accuracy: 0.9300 - val_prediction_fine_accuracy: 0.8999 - lr: 2.5034e-04
# Epoch 38/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0465 - prediction_coarse_accuracy: 0.9848 - prediction_medium_accuracy: 0.9643 - prediction_fine_accuracy: 0.9578
#   • Coarse Accuracy = 98.48% | Val_Accuracy = 98.59% | LossWeight = 0.24
#   • Medium Accuracy = 96.43% | Val_Accuracy = 93.38% | LossWeight = 0.40
#   • Fine   Accuracy = 95.78% | Val_Accuracy = 90.47% | LossWeight = 0.36
#
# Epoch 38: val_prediction_fine_accuracy did not improve from 0.90500
# 781/781 [==============================] - 47s 60ms/step - loss: 0.0465 - prediction_coarse_accuracy: 0.9848 - prediction_medium_accuracy: 0.9643 - prediction_fine_accuracy: 0.9578 - val_loss: 0.0295 - val_prediction_coarse_accuracy: 0.9859 - val_prediction_medium_accuracy: 0.9338 - val_prediction_fine_accuracy: 0.9047 - lr: 2.3783e-04
# Epoch 39/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0463 - prediction_coarse_accuracy: 0.9841 - prediction_medium_accuracy: 0.9639 - prediction_fine_accuracy: 0.9574
#   • Coarse Accuracy = 98.41% | Val_Accuracy = 98.55% | LossWeight = 0.25
#   • Medium Accuracy = 96.39% | Val_Accuracy = 93.40% | LossWeight = 0.40
#   • Fine   Accuracy = 95.74% | Val_Accuracy = 90.62% | LossWeight = 0.35
#
# Epoch 39: val_prediction_fine_accuracy improved from 0.90500 to 0.90620, saving model to ../../logs/MOD_1/3_CIFAR_10/HD_CapsNet/BU_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 47s 60ms/step - loss: 0.0463 - prediction_coarse_accuracy: 0.9841 - prediction_medium_accuracy: 0.9639 - prediction_fine_accuracy: 0.9574 - val_loss: 0.0292 - val_prediction_coarse_accuracy: 0.9855 - val_prediction_medium_accuracy: 0.9340 - val_prediction_fine_accuracy: 0.9062 - lr: 2.2594e-04
# Epoch 40/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0459 - prediction_coarse_accuracy: 0.9849 - prediction_medium_accuracy: 0.9645 - prediction_fine_accuracy: 0.9581
#   • Coarse Accuracy = 98.49% | Val_Accuracy = 98.65% | LossWeight = 0.24
#   • Medium Accuracy = 96.45% | Val_Accuracy = 93.71% | LossWeight = 0.40
#   • Fine   Accuracy = 95.81% | Val_Accuracy = 90.98% | LossWeight = 0.36
#
# Epoch 40: val_prediction_fine_accuracy improved from 0.90620 to 0.90980, saving model to ../../logs/MOD_1/3_CIFAR_10/HD_CapsNet/BU_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 47s 61ms/step - loss: 0.0459 - prediction_coarse_accuracy: 0.9849 - prediction_medium_accuracy: 0.9645 - prediction_fine_accuracy: 0.9581 - val_loss: 0.0286 - val_prediction_coarse_accuracy: 0.9865 - val_prediction_medium_accuracy: 0.9371 - val_prediction_fine_accuracy: 0.9098 - lr: 2.1464e-04
# Epoch 41/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0467 - prediction_coarse_accuracy: 0.9839 - prediction_medium_accuracy: 0.9642 - prediction_fine_accuracy: 0.9578
#   • Coarse Accuracy = 98.39% | Val_Accuracy = 98.62% | LossWeight = 0.25
#   • Medium Accuracy = 96.42% | Val_Accuracy = 93.58% | LossWeight = 0.40
#   • Fine   Accuracy = 95.78% | Val_Accuracy = 90.80% | LossWeight = 0.35
#
# Epoch 41: val_prediction_fine_accuracy did not improve from 0.90980
# 781/781 [==============================] - 47s 61ms/step - loss: 0.0467 - prediction_coarse_accuracy: 0.9839 - prediction_medium_accuracy: 0.9642 - prediction_fine_accuracy: 0.9578 - val_loss: 0.0288 - val_prediction_coarse_accuracy: 0.9862 - val_prediction_medium_accuracy: 0.9358 - val_prediction_fine_accuracy: 0.9080 - lr: 2.0391e-04
# Epoch 42/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0464 - prediction_coarse_accuracy: 0.9843 - prediction_medium_accuracy: 0.9641 - prediction_fine_accuracy: 0.9574
#   • Coarse Accuracy = 98.43% | Val_Accuracy = 98.49% | LossWeight = 0.25
#   • Medium Accuracy = 96.41% | Val_Accuracy = 93.41% | LossWeight = 0.40
#   • Fine   Accuracy = 95.74% | Val_Accuracy = 90.72% | LossWeight = 0.35
#
# Epoch 42: val_prediction_fine_accuracy did not improve from 0.90980
# 781/781 [==============================] - 47s 60ms/step - loss: 0.0464 - prediction_coarse_accuracy: 0.9843 - prediction_medium_accuracy: 0.9641 - prediction_fine_accuracy: 0.9574 - val_loss: 0.0295 - val_prediction_coarse_accuracy: 0.9849 - val_prediction_medium_accuracy: 0.9341 - val_prediction_fine_accuracy: 0.9072 - lr: 1.9371e-04
# Epoch 43/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0459 - prediction_coarse_accuracy: 0.9843 - prediction_medium_accuracy: 0.9650 - prediction_fine_accuracy: 0.9587
#   • Coarse Accuracy = 98.43% | Val_Accuracy = 98.68% | LossWeight = 0.25
#   • Medium Accuracy = 96.50% | Val_Accuracy = 93.37% | LossWeight = 0.40
#   • Fine   Accuracy = 95.87% | Val_Accuracy = 90.73% | LossWeight = 0.35
#
# Epoch 43: val_prediction_fine_accuracy did not improve from 0.90980
# 781/781 [==============================] - 47s 60ms/step - loss: 0.0459 - prediction_coarse_accuracy: 0.9843 - prediction_medium_accuracy: 0.9650 - prediction_fine_accuracy: 0.9587 - val_loss: 0.0291 - val_prediction_coarse_accuracy: 0.9868 - val_prediction_medium_accuracy: 0.9337 - val_prediction_fine_accuracy: 0.9073 - lr: 1.8403e-04
# Epoch 44/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0458 - prediction_coarse_accuracy: 0.9845 - prediction_medium_accuracy: 0.9647 - prediction_fine_accuracy: 0.9587
#   • Coarse Accuracy = 98.45% | Val_Accuracy = 98.48% | LossWeight = 0.25
#   • Medium Accuracy = 96.47% | Val_Accuracy = 93.30% | LossWeight = 0.40
#   • Fine   Accuracy = 95.87% | Val_Accuracy = 90.40% | LossWeight = 0.35
#
# Epoch 44: val_prediction_fine_accuracy did not improve from 0.90980
# 781/781 [==============================] - 47s 61ms/step - loss: 0.0458 - prediction_coarse_accuracy: 0.9845 - prediction_medium_accuracy: 0.9647 - prediction_fine_accuracy: 0.9587 - val_loss: 0.0297 - val_prediction_coarse_accuracy: 0.9848 - val_prediction_medium_accuracy: 0.9330 - val_prediction_fine_accuracy: 0.9040 - lr: 1.7482e-04
# Epoch 45/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0456 - prediction_coarse_accuracy: 0.9845 - prediction_medium_accuracy: 0.9662 - prediction_fine_accuracy: 0.9590
#   • Coarse Accuracy = 98.45% | Val_Accuracy = 98.60% | LossWeight = 0.25
#   • Medium Accuracy = 96.62% | Val_Accuracy = 93.38% | LossWeight = 0.39
#   • Fine   Accuracy = 95.90% | Val_Accuracy = 90.53% | LossWeight = 0.36
#
# Epoch 45: val_prediction_fine_accuracy did not improve from 0.90980
# 781/781 [==============================] - 47s 60ms/step - loss: 0.0456 - prediction_coarse_accuracy: 0.9845 - prediction_medium_accuracy: 0.9662 - prediction_fine_accuracy: 0.9590 - val_loss: 0.0290 - val_prediction_coarse_accuracy: 0.9860 - val_prediction_medium_accuracy: 0.9338 - val_prediction_fine_accuracy: 0.9053 - lr: 1.6608e-04
# Epoch 46/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0458 - prediction_coarse_accuracy: 0.9837 - prediction_medium_accuracy: 0.9660 - prediction_fine_accuracy: 0.9600
#   • Coarse Accuracy = 98.37% | Val_Accuracy = 98.55% | LossWeight = 0.27
#   • Medium Accuracy = 96.60% | Val_Accuracy = 93.38% | LossWeight = 0.39
#   • Fine   Accuracy = 96.00% | Val_Accuracy = 90.67% | LossWeight = 0.34
#
# Epoch 46: val_prediction_fine_accuracy did not improve from 0.90980
# 781/781 [==============================] - 47s 60ms/step - loss: 0.0458 - prediction_coarse_accuracy: 0.9837 - prediction_medium_accuracy: 0.9660 - prediction_fine_accuracy: 0.9600 - val_loss: 0.0290 - val_prediction_coarse_accuracy: 0.9855 - val_prediction_medium_accuracy: 0.9338 - val_prediction_fine_accuracy: 0.9067 - lr: 1.5778e-04
# Epoch 47/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0462 - prediction_coarse_accuracy: 0.9846 - prediction_medium_accuracy: 0.9653 - prediction_fine_accuracy: 0.9595
#   • Coarse Accuracy = 98.46% | Val_Accuracy = 98.69% | LossWeight = 0.25
#   • Medium Accuracy = 96.53% | Val_Accuracy = 93.49% | LossWeight = 0.40
#   • Fine   Accuracy = 95.95% | Val_Accuracy = 90.83% | LossWeight = 0.35
#
# Epoch 47: val_prediction_fine_accuracy did not improve from 0.90980
# 781/781 [==============================] - 47s 60ms/step - loss: 0.0462 - prediction_coarse_accuracy: 0.9846 - prediction_medium_accuracy: 0.9653 - prediction_fine_accuracy: 0.9595 - val_loss: 0.0287 - val_prediction_coarse_accuracy: 0.9869 - val_prediction_medium_accuracy: 0.9349 - val_prediction_fine_accuracy: 0.9083 - lr: 1.4989e-04
# Epoch 48/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0457 - prediction_coarse_accuracy: 0.9844 - prediction_medium_accuracy: 0.9669 - prediction_fine_accuracy: 0.9604
#   • Coarse Accuracy = 98.44% | Val_Accuracy = 98.73% | LossWeight = 0.26
#   • Medium Accuracy = 96.69% | Val_Accuracy = 93.70% | LossWeight = 0.39
#   • Fine   Accuracy = 96.04% | Val_Accuracy = 90.82% | LossWeight = 0.35
#
# Epoch 48: val_prediction_fine_accuracy did not improve from 0.90980
# 781/781 [==============================] - 47s 60ms/step - loss: 0.0457 - prediction_coarse_accuracy: 0.9844 - prediction_medium_accuracy: 0.9669 - prediction_fine_accuracy: 0.9604 - val_loss: 0.0284 - val_prediction_coarse_accuracy: 0.9873 - val_prediction_medium_accuracy: 0.9370 - val_prediction_fine_accuracy: 0.9082 - lr: 1.4240e-04
# Epoch 49/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0459 - prediction_coarse_accuracy: 0.9838 - prediction_medium_accuracy: 0.9663 - prediction_fine_accuracy: 0.9609
#   • Coarse Accuracy = 98.38% | Val_Accuracy = 98.71% | LossWeight = 0.27
#   • Medium Accuracy = 96.63% | Val_Accuracy = 93.77% | LossWeight = 0.39
#   • Fine   Accuracy = 96.09% | Val_Accuracy = 90.91% | LossWeight = 0.34
#
# Epoch 49: val_prediction_fine_accuracy did not improve from 0.90980
# 781/781 [==============================] - 47s 60ms/step - loss: 0.0459 - prediction_coarse_accuracy: 0.9838 - prediction_medium_accuracy: 0.9663 - prediction_fine_accuracy: 0.9609 - val_loss: 0.0281 - val_prediction_coarse_accuracy: 0.9871 - val_prediction_medium_accuracy: 0.9377 - val_prediction_fine_accuracy: 0.9091 - lr: 1.3528e-04
# Epoch 50/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0463 - prediction_coarse_accuracy: 0.9845 - prediction_medium_accuracy: 0.9659 - prediction_fine_accuracy: 0.9600
#   • Coarse Accuracy = 98.45% | Val_Accuracy = 98.67% | LossWeight = 0.26
#   • Medium Accuracy = 96.59% | Val_Accuracy = 93.67% | LossWeight = 0.40
#   • Fine   Accuracy = 96.00% | Val_Accuracy = 91.10% | LossWeight = 0.35
#
# Epoch 50: val_prediction_fine_accuracy improved from 0.90980 to 0.91100, saving model to ../../logs/MOD_1/3_CIFAR_10/HD_CapsNet/BU_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 47s 61ms/step - loss: 0.0463 - prediction_coarse_accuracy: 0.9845 - prediction_medium_accuracy: 0.9659 - prediction_fine_accuracy: 0.9600 - val_loss: 0.0282 - val_prediction_coarse_accuracy: 0.9867 - val_prediction_medium_accuracy: 0.9367 - val_prediction_fine_accuracy: 0.9110 - lr: 1.2851e-04
# Epoch 51/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0455 - prediction_coarse_accuracy: 0.9851 - prediction_medium_accuracy: 0.9662 - prediction_fine_accuracy: 0.9610
#   • Coarse Accuracy = 98.51% | Val_Accuracy = 98.74% | LossWeight = 0.25
#   • Medium Accuracy = 96.62% | Val_Accuracy = 93.95% | LossWeight = 0.40
#   • Fine   Accuracy = 96.10% | Val_Accuracy = 91.14% | LossWeight = 0.35
#
# Epoch 51: val_prediction_fine_accuracy improved from 0.91100 to 0.91140, saving model to ../../logs/MOD_1/3_CIFAR_10/HD_CapsNet/BU_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 47s 60ms/step - loss: 0.0455 - prediction_coarse_accuracy: 0.9851 - prediction_medium_accuracy: 0.9662 - prediction_fine_accuracy: 0.9610 - val_loss: 0.0276 - val_prediction_coarse_accuracy: 0.9874 - val_prediction_medium_accuracy: 0.9395 - val_prediction_fine_accuracy: 0.9114 - lr: 1.2209e-04
# Epoch 52/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0456 - prediction_coarse_accuracy: 0.9840 - prediction_medium_accuracy: 0.9666 - prediction_fine_accuracy: 0.9608
#   • Coarse Accuracy = 98.40% | Val_Accuracy = 98.61% | LossWeight = 0.26
#   • Medium Accuracy = 96.66% | Val_Accuracy = 93.66% | LossWeight = 0.39
#   • Fine   Accuracy = 96.08% | Val_Accuracy = 91.18% | LossWeight = 0.34
#
# Epoch 52: val_prediction_fine_accuracy improved from 0.91140 to 0.91180, saving model to ../../logs/MOD_1/3_CIFAR_10/HD_CapsNet/BU_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 47s 61ms/step - loss: 0.0456 - prediction_coarse_accuracy: 0.9840 - prediction_medium_accuracy: 0.9666 - prediction_fine_accuracy: 0.9608 - val_loss: 0.0282 - val_prediction_coarse_accuracy: 0.9861 - val_prediction_medium_accuracy: 0.9366 - val_prediction_fine_accuracy: 0.9118 - lr: 1.1598e-04
# Epoch 53/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0458 - prediction_coarse_accuracy: 0.9843 - prediction_medium_accuracy: 0.9659 - prediction_fine_accuracy: 0.9602
#   • Coarse Accuracy = 98.43% | Val_Accuracy = 98.69% | LossWeight = 0.26
#   • Medium Accuracy = 96.59% | Val_Accuracy = 93.78% | LossWeight = 0.39
#   • Fine   Accuracy = 96.02% | Val_Accuracy = 91.02% | LossWeight = 0.35
#
# Epoch 53: val_prediction_fine_accuracy did not improve from 0.91180
# 781/781 [==============================] - 47s 60ms/step - loss: 0.0458 - prediction_coarse_accuracy: 0.9843 - prediction_medium_accuracy: 0.9659 - prediction_fine_accuracy: 0.9602 - val_loss: 0.0277 - val_prediction_coarse_accuracy: 0.9869 - val_prediction_medium_accuracy: 0.9378 - val_prediction_fine_accuracy: 0.9102 - lr: 1.1018e-04
# Epoch 54/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0456 - prediction_coarse_accuracy: 0.9841 - prediction_medium_accuracy: 0.9657 - prediction_fine_accuracy: 0.9600
#   • Coarse Accuracy = 98.41% | Val_Accuracy = 98.64% | LossWeight = 0.26
#   • Medium Accuracy = 96.57% | Val_Accuracy = 93.77% | LossWeight = 0.40
#   • Fine   Accuracy = 96.00% | Val_Accuracy = 91.14% | LossWeight = 0.35
#
# Epoch 54: val_prediction_fine_accuracy did not improve from 0.91180
# 781/781 [==============================] - 47s 60ms/step - loss: 0.0456 - prediction_coarse_accuracy: 0.9841 - prediction_medium_accuracy: 0.9657 - prediction_fine_accuracy: 0.9600 - val_loss: 0.0279 - val_prediction_coarse_accuracy: 0.9864 - val_prediction_medium_accuracy: 0.9377 - val_prediction_fine_accuracy: 0.9114 - lr: 1.0467e-04
# Epoch 55/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0454 - prediction_coarse_accuracy: 0.9845 - prediction_medium_accuracy: 0.9663 - prediction_fine_accuracy: 0.9608
#   • Coarse Accuracy = 98.45% | Val_Accuracy = 98.66% | LossWeight = 0.26
#   • Medium Accuracy = 96.63% | Val_Accuracy = 93.81% | LossWeight = 0.40
#   • Fine   Accuracy = 96.08% | Val_Accuracy = 91.18% | LossWeight = 0.35
#
# Epoch 55: val_prediction_fine_accuracy did not improve from 0.91180
# 781/781 [==============================] - 48s 61ms/step - loss: 0.0454 - prediction_coarse_accuracy: 0.9845 - prediction_medium_accuracy: 0.9663 - prediction_fine_accuracy: 0.9608 - val_loss: 0.0276 - val_prediction_coarse_accuracy: 0.9866 - val_prediction_medium_accuracy: 0.9381 - val_prediction_fine_accuracy: 0.9118 - lr: 9.9440e-05
# Epoch 56/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0455 - prediction_coarse_accuracy: 0.9851 - prediction_medium_accuracy: 0.9670 - prediction_fine_accuracy: 0.9619
#   • Coarse Accuracy = 98.51% | Val_Accuracy = 98.65% | LossWeight = 0.26
#   • Medium Accuracy = 96.70% | Val_Accuracy = 93.75% | LossWeight = 0.40
#   • Fine   Accuracy = 96.19% | Val_Accuracy = 91.18% | LossWeight = 0.35
#
# Epoch 56: val_prediction_fine_accuracy did not improve from 0.91180
# ...
# 781/781 [==============================] - 49s 63ms/step - loss: 0.0446 - prediction_coarse_accuracy: 0.9847 - prediction_medium_accuracy: 0.9674 - prediction_fine_accuracy: 0.9630 - val_loss: 0.0268 - val_prediction_coarse_accuracy: 0.9867 - val_prediction_medium_accuracy: 0.9391 - val_prediction_fine_accuracy: 0.9132 - lr: 2.6205e-05
# Epoch 82/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0451 - prediction_coarse_accuracy: 0.9836 - prediction_medium_accuracy: 0.9665 - prediction_fine_accuracy: 0.9621
#   • Coarse Accuracy = 98.36% | Val_Accuracy = 98.68% | LossWeight = 0.27
#   • Medium Accuracy = 96.65% | Val_Accuracy = 93.86% | LossWeight = 0.39
#   • Fine   Accuracy = 96.21% | Val_Accuracy = 91.29% | LossWeight = 0.33
#
# Epoch 82: val_prediction_fine_accuracy did not improve from 0.91320
# 781/781 [==============================] - 49s 63ms/step - loss: 0.0451 - prediction_coarse_accuracy: 0.9836 - prediction_medium_accuracy: 0.9665 - prediction_fine_accuracy: 0.9621 - val_loss: 0.0270 - val_prediction_coarse_accuracy: 0.9868 - val_prediction_medium_accuracy: 0.9386 - val_prediction_fine_accuracy: 0.9129 - lr: 2.4894e-05
# Epoch 83/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0455 - prediction_coarse_accuracy: 0.9851 - prediction_medium_accuracy: 0.9676 - prediction_fine_accuracy: 0.9619
#   • Coarse Accuracy = 98.51% | Val_Accuracy = 98.65% | LossWeight = 0.26
#   • Medium Accuracy = 96.76% | Val_Accuracy = 93.83% | LossWeight = 0.39
#   • Fine   Accuracy = 96.19% | Val_Accuracy = 91.22% | LossWeight = 0.35
#
# Epoch 83: val_prediction_fine_accuracy did not improve from 0.91320
# 781/781 [==============================] - 49s 63ms/step - loss: 0.0455 - prediction_coarse_accuracy: 0.9851 - prediction_medium_accuracy: 0.9676 - prediction_fine_accuracy: 0.9619 - val_loss: 0.0271 - val_prediction_coarse_accuracy: 0.9865 - val_prediction_medium_accuracy: 0.9383 - val_prediction_fine_accuracy: 0.9122 - lr: 2.3650e-05
# Epoch 84/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0453 - prediction_coarse_accuracy: 0.9843 - prediction_medium_accuracy: 0.9665 - prediction_fine_accuracy: 0.9614
#   • Coarse Accuracy = 98.43% | Val_Accuracy = 98.70% | LossWeight = 0.26
#   • Medium Accuracy = 96.65% | Val_Accuracy = 93.85% | LossWeight = 0.40
#   • Fine   Accuracy = 96.14% | Val_Accuracy = 91.25% | LossWeight = 0.34
#
# Epoch 84: val_prediction_fine_accuracy did not improve from 0.91320
# 781/781 [==============================] - 49s 63ms/step - loss: 0.0453 - prediction_coarse_accuracy: 0.9843 - prediction_medium_accuracy: 0.9665 - prediction_fine_accuracy: 0.9614 - val_loss: 0.0269 - val_prediction_coarse_accuracy: 0.9870 - val_prediction_medium_accuracy: 0.9385 - val_prediction_fine_accuracy: 0.9125 - lr: 2.2467e-05
# Epoch 85/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0446 - prediction_coarse_accuracy: 0.9855 - prediction_medium_accuracy: 0.9683 - prediction_fine_accuracy: 0.9633
#   • Coarse Accuracy = 98.55% | Val_Accuracy = 98.76% | LossWeight = 0.26
#   • Medium Accuracy = 96.83% | Val_Accuracy = 93.94% | LossWeight = 0.40
#   • Fine   Accuracy = 96.33% | Val_Accuracy = 91.27% | LossWeight = 0.34
#
# Epoch 85: val_prediction_fine_accuracy did not improve from 0.91320
# 781/781 [==============================] - 49s 63ms/step - loss: 0.0446 - prediction_coarse_accuracy: 0.9855 - prediction_medium_accuracy: 0.9683 - prediction_fine_accuracy: 0.9633 - val_loss: 0.0268 - val_prediction_coarse_accuracy: 0.9876 - val_prediction_medium_accuracy: 0.9394 - val_prediction_fine_accuracy: 0.9127 - lr: 2.1344e-05
# Epoch 86/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0446 - prediction_coarse_accuracy: 0.9855 - prediction_medium_accuracy: 0.9694 - prediction_fine_accuracy: 0.9649
#   • Coarse Accuracy = 98.55% | Val_Accuracy = 98.75% | LossWeight = 0.27
#   • Medium Accuracy = 96.94% | Val_Accuracy = 93.92% | LossWeight = 0.39
#   • Fine   Accuracy = 96.49% | Val_Accuracy = 91.32% | LossWeight = 0.34
#
# Epoch 86: val_prediction_fine_accuracy did not improve from 0.91320
# 781/781 [==============================] - 49s 63ms/step - loss: 0.0446 - prediction_coarse_accuracy: 0.9855 - prediction_medium_accuracy: 0.9694 - prediction_fine_accuracy: 0.9649 - val_loss: 0.0268 - val_prediction_coarse_accuracy: 0.9875 - val_prediction_medium_accuracy: 0.9392 - val_prediction_fine_accuracy: 0.9132 - lr: 2.0277e-05
# Epoch 87/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0458 - prediction_coarse_accuracy: 0.9845 - prediction_medium_accuracy: 0.9672 - prediction_fine_accuracy: 0.9622
#   • Coarse Accuracy = 98.45% | Val_Accuracy = 98.73% | LossWeight = 0.26
#   • Medium Accuracy = 96.72% | Val_Accuracy = 93.82% | LossWeight = 0.39
#   • Fine   Accuracy = 96.22% | Val_Accuracy = 91.20% | LossWeight = 0.34
#
# Epoch 87: val_prediction_fine_accuracy did not improve from 0.91320
# 781/781 [==============================] - 49s 63ms/step - loss: 0.0458 - prediction_coarse_accuracy: 0.9845 - prediction_medium_accuracy: 0.9672 - prediction_fine_accuracy: 0.9622 - val_loss: 0.0270 - val_prediction_coarse_accuracy: 0.9873 - val_prediction_medium_accuracy: 0.9382 - val_prediction_fine_accuracy: 0.9120 - lr: 1.9263e-05
# Epoch 88/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0448 - prediction_coarse_accuracy: 0.9855 - prediction_medium_accuracy: 0.9685 - prediction_fine_accuracy: 0.9632
#   • Coarse Accuracy = 98.55% | Val_Accuracy = 98.72% | LossWeight = 0.26
#   • Medium Accuracy = 96.85% | Val_Accuracy = 93.91% | LossWeight = 0.40
#   • Fine   Accuracy = 96.32% | Val_Accuracy = 91.14% | LossWeight = 0.35
#
# Epoch 88: val_prediction_fine_accuracy did not improve from 0.91320
# 781/781 [==============================] - 47s 61ms/step - loss: 0.0448 - prediction_coarse_accuracy: 0.9855 - prediction_medium_accuracy: 0.9685 - prediction_fine_accuracy: 0.9632 - val_loss: 0.0269 - val_prediction_coarse_accuracy: 0.9872 - val_prediction_medium_accuracy: 0.9391 - val_prediction_fine_accuracy: 0.9114 - lr: 1.8300e-05
# Epoch 89/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0452 - prediction_coarse_accuracy: 0.9845 - prediction_medium_accuracy: 0.9669 - prediction_fine_accuracy: 0.9623
#   • Coarse Accuracy = 98.45% | Val_Accuracy = 98.77% | LossWeight = 0.26
#   • Medium Accuracy = 96.69% | Val_Accuracy = 93.90% | LossWeight = 0.40
#   • Fine   Accuracy = 96.23% | Val_Accuracy = 91.17% | LossWeight = 0.34
#
# Epoch 89: val_prediction_fine_accuracy did not improve from 0.91320
# 781/781 [==============================] - 49s 63ms/step - loss: 0.0452 - prediction_coarse_accuracy: 0.9845 - prediction_medium_accuracy: 0.9669 - prediction_fine_accuracy: 0.9623 - val_loss: 0.0268 - val_prediction_coarse_accuracy: 0.9877 - val_prediction_medium_accuracy: 0.9390 - val_prediction_fine_accuracy: 0.9117 - lr: 1.7385e-05
# Epoch 90/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0450 - prediction_coarse_accuracy: 0.9856 - prediction_medium_accuracy: 0.9687 - prediction_fine_accuracy: 0.9641
#   • Coarse Accuracy = 98.56% | Val_Accuracy = 98.75% | LossWeight = 0.26
#   • Medium Accuracy = 96.87% | Val_Accuracy = 93.85% | LossWeight = 0.40
#   • Fine   Accuracy = 96.41% | Val_Accuracy = 91.18% | LossWeight = 0.34
#
# Epoch 90: val_prediction_fine_accuracy did not improve from 0.91320
# 781/781 [==============================] - 49s 63ms/step - loss: 0.0450 - prediction_coarse_accuracy: 0.9856 - prediction_medium_accuracy: 0.9687 - prediction_fine_accuracy: 0.9641 - val_loss: 0.0267 - val_prediction_coarse_accuracy: 0.9875 - val_prediction_medium_accuracy: 0.9385 - val_prediction_fine_accuracy: 0.9118 - lr: 1.6515e-05
# Epoch 91/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0447 - prediction_coarse_accuracy: 0.9857 - prediction_medium_accuracy: 0.9685 - prediction_fine_accuracy: 0.9628
#   • Coarse Accuracy = 98.57% | Val_Accuracy = 98.73% | LossWeight = 0.25
#   • Medium Accuracy = 96.85% | Val_Accuracy = 93.88% | LossWeight = 0.40
#   • Fine   Accuracy = 96.28% | Val_Accuracy = 91.16% | LossWeight = 0.35
#
# Epoch 91: val_prediction_fine_accuracy did not improve from 0.91320
# 781/781 [==============================] - 49s 62ms/step - loss: 0.0447 - prediction_coarse_accuracy: 0.9857 - prediction_medium_accuracy: 0.9685 - prediction_fine_accuracy: 0.9628 - val_loss: 0.0269 - val_prediction_coarse_accuracy: 0.9873 - val_prediction_medium_accuracy: 0.9388 - val_prediction_fine_accuracy: 0.9116 - lr: 1.5690e-05
# Epoch 92/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0446 - prediction_coarse_accuracy: 0.9850 - prediction_medium_accuracy: 0.9678 - prediction_fine_accuracy: 0.9635
#   • Coarse Accuracy = 98.50% | Val_Accuracy = 98.76% | LossWeight = 0.26
#   • Medium Accuracy = 96.78% | Val_Accuracy = 93.80% | LossWeight = 0.40
#   • Fine   Accuracy = 96.35% | Val_Accuracy = 91.18% | LossWeight = 0.34
#
# Epoch 92: val_prediction_fine_accuracy did not improve from 0.91320
# 781/781 [==============================] - 49s 62ms/step - loss: 0.0446 - prediction_coarse_accuracy: 0.9850 - prediction_medium_accuracy: 0.9678 - prediction_fine_accuracy: 0.9635 - val_loss: 0.0268 - val_prediction_coarse_accuracy: 0.9876 - val_prediction_medium_accuracy: 0.9380 - val_prediction_fine_accuracy: 0.9118 - lr: 1.4905e-05
# Epoch 93/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0448 - prediction_coarse_accuracy: 0.9847 - prediction_medium_accuracy: 0.9680 - prediction_fine_accuracy: 0.9636
#   • Coarse Accuracy = 98.47% | Val_Accuracy = 98.74% | LossWeight = 0.27
#   • Medium Accuracy = 96.80% | Val_Accuracy = 93.80% | LossWeight = 0.39
#   • Fine   Accuracy = 96.36% | Val_Accuracy = 91.10% | LossWeight = 0.34
#
# Epoch 93: val_prediction_fine_accuracy did not improve from 0.91320
# 781/781 [==============================] - 49s 62ms/step - loss: 0.0448 - prediction_coarse_accuracy: 0.9847 - prediction_medium_accuracy: 0.9680 - prediction_fine_accuracy: 0.9636 - val_loss: 0.0268 - val_prediction_coarse_accuracy: 0.9874 - val_prediction_medium_accuracy: 0.9380 - val_prediction_fine_accuracy: 0.9110 - lr: 1.4160e-05
# Epoch 94/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0451 - prediction_coarse_accuracy: 0.9860 - prediction_medium_accuracy: 0.9692 - prediction_fine_accuracy: 0.9645
#   • Coarse Accuracy = 98.60% | Val_Accuracy = 98.76% | LossWeight = 0.26
#   • Medium Accuracy = 96.92% | Val_Accuracy = 93.78% | LossWeight = 0.40
#   • Fine   Accuracy = 96.45% | Val_Accuracy = 91.21% | LossWeight = 0.34
#
# Epoch 94: val_prediction_fine_accuracy did not improve from 0.91320
# 781/781 [==============================] - 49s 62ms/step - loss: 0.0451 - prediction_coarse_accuracy: 0.9860 - prediction_medium_accuracy: 0.9692 - prediction_fine_accuracy: 0.9645 - val_loss: 0.0268 - val_prediction_coarse_accuracy: 0.9876 - val_prediction_medium_accuracy: 0.9378 - val_prediction_fine_accuracy: 0.9121 - lr: 1.3452e-05
# Epoch 95/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0446 - prediction_coarse_accuracy: 0.9853 - prediction_medium_accuracy: 0.9682 - prediction_fine_accuracy: 0.9642
#   • Coarse Accuracy = 98.53% | Val_Accuracy = 98.74% | LossWeight = 0.26
#   • Medium Accuracy = 96.82% | Val_Accuracy = 93.90% | LossWeight = 0.40
#   • Fine   Accuracy = 96.42% | Val_Accuracy = 91.25% | LossWeight = 0.34
#
# Epoch 95: val_prediction_fine_accuracy did not improve from 0.91320
# 781/781 [==============================] - 49s 63ms/step - loss: 0.0446 - prediction_coarse_accuracy: 0.9853 - prediction_medium_accuracy: 0.9682 - prediction_fine_accuracy: 0.9642 - val_loss: 0.0267 - val_prediction_coarse_accuracy: 0.9874 - val_prediction_medium_accuracy: 0.9390 - val_prediction_fine_accuracy: 0.9125 - lr: 1.2779e-05
# Epoch 96/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0447 - prediction_coarse_accuracy: 0.9858 - prediction_medium_accuracy: 0.9681 - prediction_fine_accuracy: 0.9633
#   • Coarse Accuracy = 98.58% | Val_Accuracy = 98.76% | LossWeight = 0.25
#   • Medium Accuracy = 96.81% | Val_Accuracy = 93.88% | LossWeight = 0.40
#   • Fine   Accuracy = 96.33% | Val_Accuracy = 91.28% | LossWeight = 0.35
#
# Epoch 96: val_prediction_fine_accuracy did not improve from 0.91320
# 781/781 [==============================] - 49s 63ms/step - loss: 0.0447 - prediction_coarse_accuracy: 0.9858 - prediction_medium_accuracy: 0.9681 - prediction_fine_accuracy: 0.9633 - val_loss: 0.0269 - val_prediction_coarse_accuracy: 0.9876 - val_prediction_medium_accuracy: 0.9388 - val_prediction_fine_accuracy: 0.9128 - lr: 1.2140e-05
# Epoch 97/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0449 - prediction_coarse_accuracy: 0.9847 - prediction_medium_accuracy: 0.9690 - prediction_fine_accuracy: 0.9636
#   • Coarse Accuracy = 98.47% | Val_Accuracy = 98.71% | LossWeight = 0.27
#   • Medium Accuracy = 96.90% | Val_Accuracy = 93.92% | LossWeight = 0.39
#   • Fine   Accuracy = 96.36% | Val_Accuracy = 91.34% | LossWeight = 0.34
#
# Epoch 97: val_prediction_fine_accuracy improved from 0.91320 to 0.91340, saving model to ../../logs/MOD_1/3_CIFAR_10/HD_CapsNet/BU_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 49s 63ms/step - loss: 0.0449 - prediction_coarse_accuracy: 0.9847 - prediction_medium_accuracy: 0.9690 - prediction_fine_accuracy: 0.9636 - val_loss: 0.0267 - val_prediction_coarse_accuracy: 0.9871 - val_prediction_medium_accuracy: 0.9392 - val_prediction_fine_accuracy: 0.9134 - lr: 1.1533e-05
# Epoch 98/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0448 - prediction_coarse_accuracy: 0.9856 - prediction_medium_accuracy: 0.9686 - prediction_fine_accuracy: 0.9634
#   • Coarse Accuracy = 98.56% | Val_Accuracy = 98.69% | LossWeight = 0.26
#   • Medium Accuracy = 96.86% | Val_Accuracy = 93.88% | LossWeight = 0.40
#   • Fine   Accuracy = 96.34% | Val_Accuracy = 91.22% | LossWeight = 0.35
#
# Epoch 98: val_prediction_fine_accuracy did not improve from 0.91340
# 781/781 [==============================] - 49s 63ms/step - loss: 0.0448 - prediction_coarse_accuracy: 0.9856 - prediction_medium_accuracy: 0.9686 - prediction_fine_accuracy: 0.9634 - val_loss: 0.0270 - val_prediction_coarse_accuracy: 0.9869 - val_prediction_medium_accuracy: 0.9388 - val_prediction_fine_accuracy: 0.9122 - lr: 1.0957e-05
# Epoch 99/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0446 - prediction_coarse_accuracy: 0.9856 - prediction_medium_accuracy: 0.9685 - prediction_fine_accuracy: 0.9644
#   • Coarse Accuracy = 98.56% | Val_Accuracy = 98.71% | LossWeight = 0.26
#   • Medium Accuracy = 96.85% | Val_Accuracy = 93.99% | LossWeight = 0.40
#   • Fine   Accuracy = 96.44% | Val_Accuracy = 91.24% | LossWeight = 0.34
#
# Epoch 99: val_prediction_fine_accuracy did not improve from 0.91340
# 781/781 [==============================] - 49s 63ms/step - loss: 0.0446 - prediction_coarse_accuracy: 0.9856 - prediction_medium_accuracy: 0.9685 - prediction_fine_accuracy: 0.9644 - val_loss: 0.0267 - val_prediction_coarse_accuracy: 0.9871 - val_prediction_medium_accuracy: 0.9399 - val_prediction_fine_accuracy: 0.9124 - lr: 1.0409e-05
# Epoch 100/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0446 - prediction_coarse_accuracy: 0.9855 - prediction_medium_accuracy: 0.9693 - prediction_fine_accuracy: 0.9643
#   • Coarse Accuracy = 98.55% | Val_Accuracy = 98.71% | LossWeight = 0.26
#   • Medium Accuracy = 96.93% | Val_Accuracy = 93.96% | LossWeight = 0.39
#   • Fine   Accuracy = 96.43% | Val_Accuracy = 91.16% | LossWeight = 0.34
#
# Epoch 100: val_prediction_fine_accuracy did not improve from 0.91340
# 781/781 [==============================] - 50s 63ms/step - loss: 0.0446 - prediction_coarse_accuracy: 0.9855 - prediction_medium_accuracy: 0.9693 - prediction_fine_accuracy: 0.9643 - val_loss: 0.0267 - val_prediction_coarse_accuracy: 0.9871 - val_prediction_medium_accuracy: 0.9396 - val_prediction_fine_accuracy: 0.9116 - lr: 9.8884e-06

# %%
try:
    history_dict = history.history

    plotter = tfdocs.plots.HistoryPlotter()
    plotter.plot({"Coarse": history}, metric = "prediction_coarse_accuracy")
    plotter.plot({"Medium": history}, metric = "prediction_medium_accuracy")
    plotter.plot({"Fine": history}, metric = "prediction_fine_accuracy")
    plt.title("Model Accuracy")
    plt.ylim([0,1])

except:
    print('Trained model weights loaded')

# %%
try:
    plotter = tfdocs.plots.HistoryPlotter()
    plotter.plot({"loss": history}, metric = "loss")
    plt.title("Model Loss")
    plt.ylim([0,1])

except:
    print('Trained model weights loaded')

# %% [markdown]
# ## Model Analysis

# %%
final_model = keras.Model(model.inputs[:1], model.output)

lossfn = models.MarginLoss()
final_model.compile(optimizer='adam', 
                    loss={'prediction_fine' : lossfn,
                          'prediction_medium' : lossfn,
                          'prediction_coarse' : lossfn},

                    loss_weights={'prediction_fine' : lossweight['fine_lw'],
                                  'prediction_medium' : lossweight['medium_lw'],
                                  'prediction_coarse' : lossweight['coarse_lw']},

                    metrics={'prediction_fine': 'accuracy',
                             'prediction_medium': 'accuracy',
                             'prediction_coarse': 'accuracy'
                            }
                   )

# %%
model_analysis = models.model_analysis(final_model, dataset)
results = model_analysis.evaluate()
predictions = model_analysis.prediction()
# Out:
# 313/313 [==============================] - 7s 17ms/step - loss: 0.0428 - prediction_coarse_loss: 0.0102 - prediction_medium_loss: 0.0452 - prediction_fine_loss: 0.0651 - prediction_coarse_accuracy: 0.9871 - prediction_medium_accuracy: 0.9396 - prediction_fine_accuracy: 0.9116
# 1. loss ==> 0.04282010346651077
# 2. prediction_coarse_loss ==> 0.010240387171506882
# 3. prediction_medium_loss ==> 0.045225292444229126
# 4. prediction_fine_loss ==> 0.06505919992923737
# 5. prediction_coarse_accuracy ==> 0.9871000051498413
# 6. prediction_medium_accuracy ==> 0.9395999908447266
# 7. prediction_fine_accuracy ==> 0.9115999937057495
# 313/313 [==============================] - 4s 11ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
true_label = [dataset['y_test_coarse'],dataset['y_test_medium'],dataset['y_test_fine']]
pred_label = [predictions[0],predictions[1],predictions[2]]
metrics.lvl_wise_metric(true_label,pred_label)
# Out:
#   • Confusion_Matrix
#
#   • COARSE LEVEL
# [[3950   50]
#  [  79 5921]]
#
#   • MEDIUM LEVEL
# [[ 943   17   14   12    1    9    4]
#  [  22  950   20    3    1    3    1]
#  [   9   13 1968    1    4    4    1]
#  [  28    2    4  865   22   48   31]
#  [   6    4    4   14  945   22    5]
#  [  12    6   11   39   37 1841   54]
#  [   8    2    4   30   20   52 1884]]
#
#   • FINE LEVEL
# [[945   4  12   5   2   2   1   2  17  10]
#  [  3 967   2   0   1   0   1   0   6  20]
#  [ 29   2 866  29  17  21  21  11   2   2]
#  [  9   2  28 803  16  88  30  10   8   6]
#  [  6   1  22  23 900   8  22  17   1   0]
#  [  5   1  15  89  18 852   7  12   0   1]
#  [  6   2  14  22   4   3 942   1   5   1]
#  [  4   0  11  10  18  10   1 945   0   1]
#  [ 24   5   3   3   0   0   1   1 952  11]
#  [  8  31   1   3   0   1   3   1   8 944]]
#
#   • Classification Report
#
#
#   • COARSE LEVEL
#               precision    recall  f1-score   support
#
#            0    0.98039   0.98750   0.98393      4000
#            1    0.99163   0.98683   0.98922      6000
#
#     accuracy                        0.98710     10000
#    macro avg    0.98601   0.98717   0.98658     10000
# weighted avg    0.98713   0.98710   0.98711     10000
#
#
#   • MEDIUM LEVEL
#               precision    recall  f1-score   support
#
#            0    0.91732   0.94300   0.92998      1000
#            1    0.95573   0.95000   0.95286      1000
#            2    0.97185   0.98400   0.97789      2000
#            3    0.89730   0.86500   0.88086      1000
#            4    0.91748   0.94500   0.93103      1000
#            5    0.93027   0.92050   0.92536      2000
#            6    0.95152   0.94200   0.94673      2000
#
#     accuracy                        0.93960     10000
#    macro avg    0.93449   0.93564   0.93496     10000
# weighted avg    0.93951   0.93960   0.93947     10000
#
#
#   • FINE LEVEL
#               precision    recall  f1-score   support
#
#            0    0.90953   0.94500   0.92692      1000
#            1    0.95271   0.96700   0.95980      1000
#            2    0.88912   0.86600   0.87741      1000
#            3    0.81358   0.80300   0.80825      1000
#            4    0.92213   0.90000   0.91093      1000
#            5    0.86497   0.85200   0.85844      1000
#            6    0.91545   0.94200   0.92854      1000
#            7    0.94500   0.94500   0.94500      1000
#            8    0.95295   0.95200   0.95248      1000
#            9    0.94779   0.94400   0.94589      1000
#
#     accuracy                        0.91160     10000
#    macro avg    0.91132   0.91160   0.91137     10000
# weighted avg    0.91132   0.91160   0.91137     10000

# %%
h_measurements,consistency,exact_match = metrics.hmeasurements(true_label,
                                       pred_label,
                                       dataset['tree'])
print('\nHierarchical Precision =',h_measurements[0],
      '\nHierarchical Recall =', h_measurements[1],
      '\nHierarchical F1-Score =',h_measurements[2],
      '\nConsistency = ', consistency,
      '\nExact Match = ', exact_match,
     )
# Out:
# Hierarchical Precision = 0.9455533333333332
# Hierarchical Recall = 0.9472333333333333
# Hierarchical F1-Score = 0.9462440476190476
# Consistency =  0.9913
# Exact Match =  0.9089
