# %% [markdown]
# # Running Jupyter notebooks

# %% [markdown]
# ## HD_CapsNet_Mod_3_1

# %%
# %run HD_CapsNet_Mod_3_1.ipynb
# Out:
# • Computer Name = SARUMAN
# • Working Directory = D:\knoor\Deep Learning with Python\RunningOnServer\HD-CapsNet_MOD\Training_and_Analysis\2_FMNIST
# • Python Version = 3.8.12 (default, Oct 12 2021, 03:01:40) [MSC v.1916 64 bit (AMD64)]
# • TensorFlow Version = 2.8.0
# • Keras Version = 2.8.0
# • Current Environment = Anaconda Environment Name : D:\knoor\AnacondaEnvironment\py38tf28
# Following GPUS are selected =  7
# Done: GPU PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# 1 Physical GPUs, 1 Logical GPUs
# FOLDER CREATED =  ../../logs/2_FMNIST/HD_CapsNet/Mod_3_1
# Fashion-MNIST dataset: Training have 60,000 samples and testing have 10,000 samples
# WARNING:tensorflow:The following Variables were used in a Lambda layer's call (tf.math.multiply_9), but are not present in its tracked objects:   <tf.Variable 'coarse_lw:0' shape=() dtype=float32>. This is a strong indication that the Lambda layer should be rewritten as a subclassed Layer.
# Model: "HD-CapsNet"
# ...

# %% [raw]
# !jupyter nbconvert --execute --to HD_CapsNet_Mod_3_1.ipynb --inplace HD_CapsNet_Mod_3_1.ipynb

# %% [markdown]
# ## HD_CapsNet_Mod_3_2

# %%
# %run HD_CapsNet_Mod_3_2.ipynb
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#
# • Computer Name = SARUMAN
# • Working Directory = D:\knoor\Deep Learning with Python\RunningOnServer\HD-CapsNet_MOD\Training_and_Analysis\2_FMNIST
# • Python Version = 3.8.12 (default, Oct 12 2021, 03:01:40) [MSC v.1916 64 bit (AMD64)]
# • TensorFlow Version = 2.8.0
# • Keras Version = 2.8.0
# • Current Environment = Anaconda Environment Name : D:\knoor\AnacondaEnvironment\py38tf28
# Following GPUS are selected =  7
# Done: GPU PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# 1 Physical GPUs, 1 Logical GPUs
# FOLDER CREATED =  ../../logs/2_FMNIST/HD_CapsNet/Mod_3_2
# Fashion-MNIST dataset: Training have 60,000 samples and testing have 10,000 samples
# ...

# %% [markdown]
# ## HD_CapsNet_Mod_3_3

# %%
# %run HD_CapsNet_Mod_3_3.ipynb
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#
# • Computer Name = SARUMAN
# • Working Directory = D:\knoor\Deep Learning with Python\RunningOnServer\HD-CapsNet_MOD\Training_and_Analysis\2_FMNIST
# • Python Version = 3.8.12 (default, Oct 12 2021, 03:01:40) [MSC v.1916 64 bit (AMD64)]
# • TensorFlow Version = 2.8.0
# • Keras Version = 2.8.0
# • Current Environment = Anaconda Environment Name : D:\knoor\AnacondaEnvironment\py38tf28
# Following GPUS are selected =  7
# Done: GPU PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# 1 Physical GPUs, 1 Logical GPUs
# FOLDER CREATED =  ../../logs/2_FMNIST/HD_CapsNet/Mod_3_3
# Fashion-MNIST dataset: Training have 60,000 samples and testing have 10,000 samples
# ...

# %% [markdown]
# ## HD_CapsNet_Mod_3_4

# %%
# %run HD_CapsNet_Mod_3_4.ipynb
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#
# • Computer Name = SARUMAN
# • Working Directory = D:\knoor\Deep Learning with Python\RunningOnServer\HD-CapsNet_MOD\Training_and_Analysis\2_FMNIST
# • Python Version = 3.8.12 (default, Oct 12 2021, 03:01:40) [MSC v.1916 64 bit (AMD64)]
# • TensorFlow Version = 2.8.0
# • Keras Version = 2.8.0
# • Current Environment = Anaconda Environment Name : D:\knoor\AnacondaEnvironment\py38tf28
# Following GPUS are selected =  7
# Done: GPU PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# 1 Physical GPUs, 1 Logical GPUs
# FOLDER CREATED =  ../../logs/2_FMNIST/HD_CapsNet/Mod_3_4
# Fashion-MNIST dataset: Training have 60,000 samples and testing have 10,000 samples
# ...
