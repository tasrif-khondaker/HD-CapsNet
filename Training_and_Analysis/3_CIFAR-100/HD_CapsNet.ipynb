# %% [markdown]
# ***
# <font size="6"><center><b> HD-CapsNet: A Hierarchical Deep Capsule Network for Image Classification </b></center></font>
# ***

# %% [markdown]
# **Changing Model Architecture**
# - **(Mod-3.1)** 32D>16D>8D (Coarse>Medium>FINE) use skip connections between Secondary Capsules $Concatenate([P_{caps}, S_{coarse}])$ > input for $S_{medium}$ and $Concatenate([P_{caps}, S_{medium}])$ > input for $S_{fine}$
# - With $L_{Cons}$

# %% [markdown]
# # Files and Libraries

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras import regularizers, optimizers
from tensorflow.keras import backend as K

import tensorflow_docs as tfdocs
import tensorflow_docs.plots

# Supporting Libraries:
    #Mathplot lib for ploting graphs
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
    # numpy and pandas
import numpy as np
import pandas as pd
    #system
import os
import sys
import csv
    #import other libraries
import math
import random
from datetime import datetime
from treelib import Tree
    # ML model, Dataset and evalution metrics
sys.path.append('../../') ### adding system parth for src folder
from src import datasets # load datasets
from src import MixUp_add_loss # load datasets
from src import metrics # load hierarchcial metrics
from src import sysenv # load hierarchcial metrics
from src import models # load machine learning models

    ## Tensorflow_docs
import tensorflow_docs as tfdocs
import tensorflow_docs.plots

    # Auto reload local libraries if updated
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # System information & GPU growth

# %%
systeminfo = sysenv.systeminfo()
print(systeminfo)
# Out:
# • Computer Name = 30BFPC1AXW95
# • Working Directory = c:\Users\knoor\Downloads\temp\HD-CapsNet\Training_and_Analysis\3_CIFAR-100
# • Python Version = 3.8.12 (default, Oct 12 2021, 03:01:40) [MSC v.1916 64 bit (AMD64)]
# • TensorFlow Version = 2.8.0
# • Keras Version = 2.8.0
# • Current Environment = Anaconda Environment Name : py38tf

# %%
gpus = "0,1,2,3,4,5,6,7" ## Selecting Available gpus (Multi-GPUS)
gpus = "0" ## Selecting Available gpus (Single GPU)
gpugrowth = sysenv.gpugrowth(gpus = gpus) ## Limiting GPUS from OS environment
gpugrowth.memory_growth() #GPU memory growth
# Out:
# Following GPUS are selected =  0
# Done: GPU PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# 1 Physical GPUs, 1 Logical GPUs

# %% [markdown]
# ## log directory

# %%
directory = sysenv.log_dir('4_CIFAR_100/HD_CapsNet/HD_CapsNet')
# Out:
# Warning: Folder already exist.

# %% [markdown]
# # Import Dataset : CIFAR-100

# %%
dataset = datasets.CIFAR100(version = 'ALL') # importing CIFAR10 Dataset
# dataset = datasets.CIFAR100(version = 'reduce') # importing CIFAR10 Dataset
# Out:
# CIFAR-100 dataset: Training have 50,000 samples and testing have 10,000 samples

# %% [markdown]
# # Parameters

# %%
train_params = {"n_epochs" : 100,
                "batch_size": 64,
                "lr": 0.001, # Initial learning rate
                "lr_decay": 0.95, # Learning rate decay
                "decay_exe": 9, #learning rate decay execution epoch after
               }
model_params = {"optimizer": tf.keras.optimizers.Adam(train_params['lr']),
                "loss_function": models.MarginLoss(),
               }

# %% [markdown]
# ## Learning Rate Decay Scheduler

# %%
def scheduler(epoch):
    learning_rate_init = train_params["lr"]
    
    if epoch > train_params["decay_exe"]:
        learning_rate_init = train_params["lr"] * (train_params["lr_decay"] ** (epoch-9))
        
    tf.summary.scalar('learning rate', data=learning_rate_init, step=epoch)
        
    return learning_rate_init

# %% [markdown]
# # Bottom up Approach

# %% [markdown]
# ## Loss Function

# %%
number_of_classes_c = len(np.unique(np.argmax(dataset['y_train_coarse'], axis=1)))
number_of_classes_m = len(np.unique(np.argmax(dataset['y_train_medium'], axis=1)))
number_of_classes_f = len(np.unique(np.argmax(dataset['y_train_fine'], axis=1)))

## For Dynamic LossWeights
initial_lw = models.initial_lw({"coarse": number_of_classes_c,
                                "medium": number_of_classes_m,
                                "fine": number_of_classes_f})

lossweight = {'coarse_lw' : K.variable(value = initial_lw['coarse'], dtype="float32", name="coarse_lw"),
             'medium_lw' : K.variable(value = initial_lw['medium'], dtype="float32", name="medium_lw"),
             'fine_lw' : K.variable(value = initial_lw['fine'], dtype="float32", name="fine_lw"),
              'decoder_lw' : 0.0
             }

# %%
coarse_to_medium_array = np.zeros(shape=[number_of_classes_c,number_of_classes_m], dtype=np.int32)
medium_to_fine_array = np.zeros(shape=[number_of_classes_m,number_of_classes_f], dtype=np.int32)

c_id = np.argmax(dataset['y_train_coarse'],1)

m_id = np.argmax(dataset['y_train_medium'],1)

f_id = np.argmax(dataset['y_train_fine'],1)

for x in range(len(dataset['y_test_medium'])):
    coarse_to_medium_array[c_id[x]][m_id[x]] = 1
    
for x in range(len(dataset['y_test_fine'])):
    medium_to_fine_array[m_id[x]][f_id[x]] = 1

Matrix_coarse_to_medium_OneHot = tf.constant(coarse_to_medium_array, dtype=tf.float32)
Matrix_medium_to_fine_OneHot = tf.constant(medium_to_fine_array, dtype=tf.float32)

# %%
def margin_loss(y_true, y_proba):
    
    present_error_raw = tf.square(tf.maximum(0., 0.9 - y_proba), name="present_error_raw")
    absent_error_raw = tf.square(tf.maximum(0., y_proba - 0.1), name="absent_error_raw")
    L = tf.add(y_true * present_error_raw, 0.5 * (1.0 - y_true) * absent_error_raw,name="L")
    total_marginloss = tf.reduce_sum(L, axis=1, name="margin_loss")

    return total_marginloss


def consistency_check(y_pred_ancestor,y_pred_current,lookup_matrix,num_class_current):
    pred_max_ancestor = tf.argmax(y_pred_ancestor,axis=1)
    pred_max_current = tf.argmax(y_pred_current,axis=1)
    
    consistant_check = tf.gather(lookup_matrix, indices=pred_max_ancestor)*tf.one_hot(pred_max_current,num_class_current)
    
    return tf.reduce_sum(consistant_check,1)

def get_consistency(y_true_ancestor, y_pred, lookup_matrix):
    '''
    Get consistency based on 2 levels
    Provide ture levels for the level above, predictions for the current level and a look up metrix
    '''
    y_prob = tf.math.divide(y_pred,tf.reshape(tf.reduce_sum(y_pred,-1),(-1,1),name='reshape'),name='Probability')
    
    index_for_predictions = tf.cast(tf.math.argmax(y_true_ancestor,axis=1),dtype= 'int32')
    consistent_fine = tf.gather(lookup_matrix, indices=index_for_predictions) * y_prob
    Consistency_sum_array = tf.reduce_sum(consistent_fine, axis =1)
    
    return tf.abs(1-Consistency_sum_array)

def CustomLoss(y_true_c, y_true_m, y_true_f, y_pred_c, y_pred_m, y_pred_f, LW_C, LW_M, LW_F,tree: Tree,C_Weight=0.2):
    
    con_m = consistency_check(y_pred_c,y_pred_m,Matrix_coarse_to_medium_OneHot,num_class_current=number_of_classes_m)
    con_m_not = tf.abs(con_m-1)
    
    con_f = consistency_check(y_pred_m,y_pred_f,Matrix_medium_to_fine_OneHot,num_class_current=number_of_classes_f)
    con_f_not = tf.abs(con_f-1)
    
    con_sum_m = get_consistency(y_true_c,y_pred_m,Matrix_coarse_to_medium_OneHot)
    con_sum_f = get_consistency(y_true_m,y_pred_f,Matrix_medium_to_fine_OneHot)
    
    medium_lvl_cosistency = con_sum_m * con_m_not
    fine_lvl_cosistency = con_sum_f * con_f_not    
   
    ML_c = margin_loss(y_true_c, y_pred_c)*LW_C
    ML_m = LW_M*((1-C_Weight)*(margin_loss(y_true_m, y_pred_m))+C_Weight*(medium_lvl_cosistency))
    ML_f = LW_F*((1-C_Weight)*(margin_loss(y_true_f, y_pred_f))+C_Weight*(fine_lvl_cosistency))
    
    batch_loss = ML_c + ML_m+ ML_f

    return tf.reduce_mean(batch_loss)

# %% [markdown]
# ## Model Architecture

# %%
def get_compiled_model():
    input_shape = dataset['x_train'].shape[1:]

    input_shape_yc = dataset['y_train_coarse'].shape[1:]
    input_shape_ym = dataset['y_train_medium'].shape[1:]
    input_shape_yf = dataset['y_train_fine'].shape[1:]

    no_coarse_class = number_of_classes_c
    no_medium_class = number_of_classes_m
    no_fine_class = number_of_classes_f

    PCap_n_dims = 8

    SCap_f_dims = 8
    SCap_m_dims = 16
    SCap_c_dims = 32


    # Input image
    x_input = keras.layers.Input(shape=input_shape, name="Input_Image")

    # Input True Labels
    y_c = keras.layers.Input(shape=input_shape_yc, name='input_yc')
    y_m = keras.layers.Input(shape=input_shape_ym, name='input_ym')
    y_f = keras.layers.Input(shape=input_shape_yf, name='input_yf')

    #--- block 1 ---
    x = keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv1')(x_input)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv2')(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.MaxPooling2D((2, 2), strides=(2, 2), name='block1_pool')(x)

    #--- block 2 ---
    x = keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv1')(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv2')(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.MaxPooling2D((2, 2), strides=(2, 2), name='block2_pool')(x)

    #--- block 3 ---
    x = keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv1')(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv2')(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.MaxPooling2D((2, 2), strides=(2, 2), name='block3_pool')(x)

    #--- block 4 ---
    x = keras.layers.Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv1')(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv2')(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.MaxPooling2D((2, 2), strides=(2, 2), name='block4_pool')(x)


    # Layer 3: Reshape to 8D primary capsules 
    reshapec = keras.layers.Reshape((int((tf.reduce_prod(x.shape[1:]).numpy())/PCap_n_dims),
                                     PCap_n_dims), name="reshape_layer")(x)
    p_caps = keras.layers.Lambda(models.squash, name='p_caps')(reshapec)

    ## Layer Secondary Capsule: For coarse level
    s_caps_c = models.SecondaryCapsule(n_caps=no_coarse_class, n_dims=SCap_c_dims, 
                        name="s_caps_coarse")(p_caps)
    
    ## Skip Connection: For Medium Level
    p_caps_m = keras.layers.Reshape((int((tf.reduce_prod(p_caps.shape[1:]).numpy())/s_caps_c.shape[-1]),
                                     s_caps_c.shape[-1]), name="primary_skip_m")(p_caps)
    skip_m = keras.layers.Concatenate(axis=1)([p_caps_m, s_caps_c])

    ## Layer Secondary Capsule: For medium level
    s_caps_m = models.SecondaryCapsule(n_caps=no_medium_class, n_dims=SCap_m_dims, 
                        name="s_caps_medium")(skip_m)
    
    ## Skip Connection: For Fine Level
    p_caps_f = keras.layers.Reshape((int((tf.reduce_prod(p_caps.shape[1:]).numpy())/s_caps_m.shape[-1]),
                                     s_caps_m.shape[-1]), name="primary_skip_f")(p_caps)
    skip_f = keras.layers.Concatenate(axis=1)([p_caps_f, s_caps_m])

    ## Layer Secondary Capsule: For fine level
    s_caps_f = models.SecondaryCapsule(n_caps=no_fine_class, n_dims=SCap_f_dims, 
                        name="s_caps_fine")(skip_f)

    pred_c = models.LengthLayer(name='prediction_coarse')(s_caps_c)

    pred_m = models.LengthLayer(name='prediction_medium')(s_caps_m)

    pred_f = models.LengthLayer(name='prediction_fine')(s_caps_f)

    model = keras.Model(inputs= [x_input, y_c, y_m, y_f],
                        outputs= [pred_c, pred_m, pred_f],
                        name='HD-CapsNet')
    
    ## Saving Model Architecture
    keras.utils.plot_model(model, to_file = directory+"/Architecture.png", show_shapes=True)

    model.add_loss(CustomLoss(y_c, y_m, y_f, pred_c, pred_m, pred_f, 
                              lossweight['coarse_lw'], lossweight['medium_lw'], lossweight['fine_lw'],
                              dataset['tree']))

    model.compile(optimizer='adam',                  
                  metrics={'prediction_fine': 'accuracy',
                           'prediction_medium': 'accuracy',
                           'prediction_coarse': 'accuracy'
                          }
    )
    return model

# %%
model = get_compiled_model()
# Out:
# WARNING:tensorflow:The following Variables were used in a Lambda layer's call (tf.math.multiply_9), but are not present in its tracked objects:   <tf.Variable 'coarse_lw:0' shape=() dtype=float32>. This is a strong indication that the Lambda layer should be rewritten as a subclassed Layer.

# %% [raw]
# strategy = multi_gpu_select('windows')
#
# print("Number of devices: {}".format(strategy.num_replicas_in_sync))
#
# with strategy.scope():
#     # Everything that creates variables should be under the strategy scope.
#     # In general this is only model construction & `compile()`.
#     model = get_compiled_model()

# %%
model.summary()
# Out:
# Model: "HD-CapsNet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Input_Image (InputLayer)       [(None, 32, 32, 3)]  0           []
#
#  block1_conv1 (Conv2D)          (None, 32, 32, 64)   1792        ['Input_Image[0][0]']
#
#  batch_normalization (BatchNorm  (None, 32, 32, 64)  256         ['block1_conv1[0][0]']
#  alization)
#
#  block1_conv2 (Conv2D)          (None, 32, 32, 64)   36928       ['batch_normalization[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 32, 32, 64)  256         ['block1_conv2[0][0]']
#  rmalization)
#
#  block1_pool (MaxPooling2D)     (None, 16, 16, 64)   0           ['batch_normalization_1[0][0]']
#
#  block2_conv1 (Conv2D)          (None, 16, 16, 128)  73856       ['block1_pool[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 16, 16, 128)  512        ['block2_conv1[0][0]']
#  rmalization)
#
#  block2_conv2 (Conv2D)          (None, 16, 16, 128)  147584      ['batch_normalization_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 16, 16, 128)  512        ['block2_conv2[0][0]']
#  rmalization)
#
#  block2_pool (MaxPooling2D)     (None, 8, 8, 128)    0           ['batch_normalization_3[0][0]']
#
#  block3_conv1 (Conv2D)          (None, 8, 8, 256)    295168      ['block2_pool[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 8, 8, 256)   1024        ['block3_conv1[0][0]']
#  rmalization)
#
#  block3_conv2 (Conv2D)          (None, 8, 8, 256)    590080      ['batch_normalization_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 8, 8, 256)   1024        ['block3_conv2[0][0]']
#  rmalization)
#
#  block3_pool (MaxPooling2D)     (None, 4, 4, 256)    0           ['batch_normalization_5[0][0]']
#
#  block4_conv1 (Conv2D)          (None, 4, 4, 512)    1180160     ['block3_pool[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 4, 4, 512)   2048        ['block4_conv1[0][0]']
#  rmalization)
#
#  block4_conv2 (Conv2D)          (None, 4, 4, 512)    2359808     ['batch_normalization_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 4, 4, 512)   2048        ['block4_conv2[0][0]']
#  rmalization)
#
#  block4_pool (MaxPooling2D)     (None, 2, 2, 512)    0           ['batch_normalization_7[0][0]']
#
#  reshape_layer (Reshape)        (None, 256, 8)       0           ['block4_pool[0][0]']
#
#  p_caps (Lambda)                (None, 256, 8)       0           ['reshape_layer[0][0]']
#
#  s_caps_coarse (SecondaryCapsul  (None, 8, 32)       524288      ['p_caps[0][0]']
#  e)
#
#  primary_skip_m (Reshape)       (None, 64, 32)       0           ['p_caps[0][0]']
#
#  concatenate (Concatenate)      (None, 72, 32)       0           ['primary_skip_m[0][0]',
#                                                                   's_caps_coarse[0][0]']
#
#  s_caps_medium (SecondaryCapsul  (None, 20, 16)      737280      ['concatenate[0][0]']
#  e)
#
#  primary_skip_f (Reshape)       (None, 128, 16)      0           ['p_caps[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 148, 16)      0           ['primary_skip_f[0][0]',
#                                                                   's_caps_medium[0][0]']
#
#  s_caps_fine (SecondaryCapsule)  (None, 100, 8)      1894400     ['concatenate_1[0][0]']
#
#  input_yc (InputLayer)          [(None, 8)]          0           []
#
#  input_ym (InputLayer)          [(None, 20)]         0           []
#
#  input_yf (InputLayer)          [(None, 100)]        0           []
#
#  prediction_coarse (LengthLayer  (None, 8)           0           ['s_caps_coarse[0][0]']
#  )
#
#  prediction_medium (LengthLayer  (None, 20)          0           ['s_caps_medium[0][0]']
#  )
#
#  prediction_fine (LengthLayer)  (None, 100)          0           ['s_caps_fine[0][0]']
#
#  tf.math.argmax_4 (TFOpLambda)  (None,)              0           ['input_yc[0][0]']
#
#  tf.math.reduce_sum_2 (TFOpLamb  (None,)             0           ['prediction_medium[0][0]']
#  da)
#
#  tf.cast (TFOpLambda)           (None,)              0           ['tf.math.argmax_4[0][0]']
#
#  tf.reshape (TFOpLambda)        (None, 1)            0           ['tf.math.reduce_sum_2[0][0]']
#
#  tf.math.argmax (TFOpLambda)    (None,)              0           ['prediction_coarse[0][0]']
#
#  tf.math.argmax_1 (TFOpLambda)  (None,)              0           ['prediction_medium[0][0]']
#
#  tf.math.argmax_5 (TFOpLambda)  (None,)              0           ['input_ym[0][0]']
#
#  tf.math.reduce_sum_4 (TFOpLamb  (None,)             0           ['prediction_fine[0][0]']
#  da)
#
#  tf.math.subtract_7 (TFOpLambda  (None, 20)          0           ['prediction_medium[0][0]']
#  )
#
#  tf.math.subtract_8 (TFOpLambda  (None, 20)          0           ['prediction_medium[0][0]']
#  )
#
#  tf.compat.v1.gather_2 (TFOpLam  (None, 20)          0           ['tf.cast[0][0]']
#  bda)
#
#  tf.math.divide (TFOpLambda)    (None, 20)           0           ['prediction_medium[0][0]',
#                                                                   'tf.reshape[0][0]']
#
#  tf.compat.v1.gather (TFOpLambd  (None, 20)          0           ['tf.math.argmax[0][0]']
#  a)
#
#  tf.one_hot (TFOpLambda)        (None, 20)           0           ['tf.math.argmax_1[0][0]']
#
#  tf.cast_1 (TFOpLambda)         (None,)              0           ['tf.math.argmax_5[0][0]']
#
#  tf.reshape_1 (TFOpLambda)      (None, 1)            0           ['tf.math.reduce_sum_4[0][0]']
#
#  tf.math.argmax_2 (TFOpLambda)  (None,)              0           ['prediction_medium[0][0]']
#
#  tf.math.argmax_3 (TFOpLambda)  (None,)              0           ['prediction_fine[0][0]']
#
#  tf.math.maximum_2 (TFOpLambda)  (None, 20)          0           ['tf.math.subtract_7[0][0]']
#
#  tf.math.subtract_9 (TFOpLambda  (None, 20)          0           ['input_ym[0][0]']
#  )
#
#  tf.math.maximum_3 (TFOpLambda)  (None, 20)          0           ['tf.math.subtract_8[0][0]']
#
#  tf.math.multiply_2 (TFOpLambda  (None, 20)          0           ['tf.compat.v1.gather_2[0][0]',
#  )                                                                'tf.math.divide[0][0]']
#
#  tf.math.multiply (TFOpLambda)  (None, 20)           0           ['tf.compat.v1.gather[0][0]',
#                                                                   'tf.one_hot[0][0]']
#
#  tf.math.subtract_10 (TFOpLambd  (None, 100)         0           ['prediction_fine[0][0]']
#  a)
#
#  tf.math.subtract_11 (TFOpLambd  (None, 100)         0           ['prediction_fine[0][0]']
#  a)
#
#  tf.compat.v1.gather_3 (TFOpLam  (None, 100)         0           ['tf.cast_1[0][0]']
#  bda)
#
#  tf.math.divide_1 (TFOpLambda)  (None, 100)          0           ['prediction_fine[0][0]',
#                                                                   'tf.reshape_1[0][0]']
#
#  tf.compat.v1.gather_1 (TFOpLam  (None, 100)         0           ['tf.math.argmax_2[0][0]']
#  bda)
#
#  tf.one_hot_1 (TFOpLambda)      (None, 100)          0           ['tf.math.argmax_3[0][0]']
#
#  tf.math.subtract_4 (TFOpLambda  (None, 8)           0           ['prediction_coarse[0][0]']
#  )
#
#  tf.math.subtract_5 (TFOpLambda  (None, 8)           0           ['prediction_coarse[0][0]']
#  )
#
#  tf.math.square_2 (TFOpLambda)  (None, 20)           0           ['tf.math.maximum_2[0][0]']
#
#  tf.math.multiply_11 (TFOpLambd  (None, 20)          0           ['tf.math.subtract_9[0][0]']
#  a)
#
#  tf.math.square_3 (TFOpLambda)  (None, 20)           0           ['tf.math.maximum_3[0][0]']
#
#  tf.math.reduce_sum_3 (TFOpLamb  (None,)             0           ['tf.math.multiply_2[0][0]']
#  da)
#
#  tf.math.reduce_sum (TFOpLambda  (None,)             0           ['tf.math.multiply[0][0]']
#  )
#
#  tf.math.maximum_4 (TFOpLambda)  (None, 100)         0           ['tf.math.subtract_10[0][0]']
#
#  tf.math.subtract_12 (TFOpLambd  (None, 100)         0           ['input_yf[0][0]']
#  a)
#
#  tf.math.maximum_5 (TFOpLambda)  (None, 100)         0           ['tf.math.subtract_11[0][0]']
#
#  tf.math.multiply_3 (TFOpLambda  (None, 100)         0           ['tf.compat.v1.gather_3[0][0]',
#  )                                                                'tf.math.divide_1[0][0]']
#
#  tf.math.multiply_1 (TFOpLambda  (None, 100)         0           ['tf.compat.v1.gather_1[0][0]',
#  )                                                                'tf.one_hot_1[0][0]']
#
#  tf.math.maximum (TFOpLambda)   (None, 8)            0           ['tf.math.subtract_4[0][0]']
#
#  tf.math.subtract_6 (TFOpLambda  (None, 8)           0           ['input_yc[0][0]']
#  )
#
#  tf.math.maximum_1 (TFOpLambda)  (None, 8)           0           ['tf.math.subtract_5[0][0]']
#
#  tf.math.multiply_10 (TFOpLambd  (None, 20)          0           ['input_ym[0][0]',
#  a)                                                               'tf.math.square_2[0][0]']
#
#  tf.math.multiply_12 (TFOpLambd  (None, 20)          0           ['tf.math.multiply_11[0][0]',
#  a)                                                               'tf.math.square_3[0][0]']
#
#  tf.math.subtract_2 (TFOpLambda  (None,)             0           ['tf.math.reduce_sum_3[0][0]']
#  )
#
#  tf.math.subtract (TFOpLambda)  (None,)              0           ['tf.math.reduce_sum[0][0]']
#
#  tf.math.square_4 (TFOpLambda)  (None, 100)          0           ['tf.math.maximum_4[0][0]']
#
#  tf.math.multiply_17 (TFOpLambd  (None, 100)         0           ['tf.math.subtract_12[0][0]']
#  a)
#
#  tf.math.square_5 (TFOpLambda)  (None, 100)          0           ['tf.math.maximum_5[0][0]']
#
#  tf.math.reduce_sum_5 (TFOpLamb  (None,)             0           ['tf.math.multiply_3[0][0]']
#  da)
#
#  tf.math.reduce_sum_1 (TFOpLamb  (None,)             0           ['tf.math.multiply_1[0][0]']
#  da)
#
#  tf.math.square (TFOpLambda)    (None, 8)            0           ['tf.math.maximum[0][0]']
#
#  tf.math.multiply_7 (TFOpLambda  (None, 8)           0           ['tf.math.subtract_6[0][0]']
#  )
#
#  tf.math.square_1 (TFOpLambda)  (None, 8)            0           ['tf.math.maximum_1[0][0]']
#
#  tf.math.add_1 (TFOpLambda)     (None, 20)           0           ['tf.math.multiply_10[0][0]',
#                                                                   'tf.math.multiply_12[0][0]']
#
#  tf.math.abs_2 (TFOpLambda)     (None,)              0           ['tf.math.subtract_2[0][0]']
#
#  tf.math.abs (TFOpLambda)       (None,)              0           ['tf.math.subtract[0][0]']
#
#  tf.math.multiply_16 (TFOpLambd  (None, 100)         0           ['input_yf[0][0]',
#  a)                                                               'tf.math.square_4[0][0]']
#
#  tf.math.multiply_18 (TFOpLambd  (None, 100)         0           ['tf.math.multiply_17[0][0]',
#  a)                                                               'tf.math.square_5[0][0]']
#
#  tf.math.subtract_3 (TFOpLambda  (None,)             0           ['tf.math.reduce_sum_5[0][0]']
#  )
#
#  tf.math.subtract_1 (TFOpLambda  (None,)             0           ['tf.math.reduce_sum_1[0][0]']
#  )
#
#  tf.math.multiply_6 (TFOpLambda  (None, 8)           0           ['input_yc[0][0]',
#  )                                                                'tf.math.square[0][0]']
#
#  tf.math.multiply_8 (TFOpLambda  (None, 8)           0           ['tf.math.multiply_7[0][0]',
#  )                                                                'tf.math.square_1[0][0]']
#
#  tf.math.reduce_sum_7 (TFOpLamb  (None,)             0           ['tf.math.add_1[0][0]']
#  da)
#
#  tf.math.multiply_4 (TFOpLambda  (None,)             0           ['tf.math.abs_2[0][0]',
#  )                                                                'tf.math.abs[0][0]']
#
#  tf.math.add_2 (TFOpLambda)     (None, 100)          0           ['tf.math.multiply_16[0][0]',
#                                                                   'tf.math.multiply_18[0][0]']
#
#  tf.math.abs_3 (TFOpLambda)     (None,)              0           ['tf.math.subtract_3[0][0]']
#
#  tf.math.abs_1 (TFOpLambda)     (None,)              0           ['tf.math.subtract_1[0][0]']
#
#  tf.math.add (TFOpLambda)       (None, 8)            0           ['tf.math.multiply_6[0][0]',
#                                                                   'tf.math.multiply_8[0][0]']
#
#  tf.math.multiply_13 (TFOpLambd  (None,)             0           ['tf.math.reduce_sum_7[0][0]']
#  a)
#
#  tf.math.multiply_14 (TFOpLambd  (None,)             0           ['tf.math.multiply_4[0][0]']
#  a)
#
#  tf.math.reduce_sum_8 (TFOpLamb  (None,)             0           ['tf.math.add_2[0][0]']
#  da)
#
#  tf.math.multiply_5 (TFOpLambda  (None,)             0           ['tf.math.abs_3[0][0]',
#  )                                                                'tf.math.abs_1[0][0]']
#
#  tf.math.reduce_sum_6 (TFOpLamb  (None,)             0           ['tf.math.add[0][0]']
#  da)
#
#  tf.__operators__.add (TFOpLamb  (None,)             0           ['tf.math.multiply_13[0][0]',
#  da)                                                              'tf.math.multiply_14[0][0]']
#
#  tf.math.multiply_19 (TFOpLambd  (None,)             0           ['tf.math.reduce_sum_8[0][0]']
#  a)
#
#  tf.math.multiply_20 (TFOpLambd  (None,)             0           ['tf.math.multiply_5[0][0]']
#  a)
#
#  tf.math.multiply_9 (TFOpLambda  (None,)             0           ['tf.math.reduce_sum_6[0][0]']
#  )
#
#  tf.math.multiply_15 (TFOpLambd  (None,)             0           ['tf.__operators__.add[0][0]']
#  a)
#
#  tf.__operators__.add_1 (TFOpLa  (None,)             0           ['tf.math.multiply_19[0][0]',
#  mbda)                                                            'tf.math.multiply_20[0][0]']
#
#  tf.__operators__.add_2 (TFOpLa  (None,)             0           ['tf.math.multiply_9[0][0]',
#  mbda)                                                            'tf.math.multiply_15[0][0]']
#
#  tf.math.multiply_21 (TFOpLambd  (None,)             0           ['tf.__operators__.add_1[0][0]']
#  a)
#
#  tf.__operators__.add_3 (TFOpLa  (None,)             0           ['tf.__operators__.add_2[0][0]',
#  mbda)                                                            'tf.math.multiply_21[0][0]']
#
#  tf.math.reduce_mean (TFOpLambd  ()                  0           ['tf.__operators__.add_3[0][0]']
#  a)
#
#  add_loss (AddLoss)             ()                   0           ['tf.math.reduce_mean[0][0]']
#
# ==================================================================================================
# Total params: 7,849,024
# Trainable params: 7,845,184
# Non-trainable params: 3,840
# __________________________________________________________________________________________________

# %% [markdown]
# ## Data Augmentation

# %%
datagen = ImageDataGenerator(width_shift_range=0.1,
                            height_shift_range=0.1)

training_generator = MixUp_add_loss.MixupGenerator_3level(dataset['x_train'],
                                                 dataset['y_train_coarse'], 
                                                 dataset['y_train_medium'],
                                                 dataset['y_train_fine'],
                                                 batch_size=train_params["batch_size"],
                                                 alpha=0.2, 
                                                 datagen=datagen
                                                )()

# %% [markdown]
# ## Callback

# %%
tb = keras.callbacks.TensorBoard(directory+'./tb_logs'+ datetime.now().strftime("%Y%m%d-%H%M%S"))
log = keras.callbacks.CSVLogger(directory+'/log.csv', append=True)

checkpoint = keras.callbacks.ModelCheckpoint(
    directory+'/epoch-best.h5', 
    monitor='val_prediction_fine_accuracy',
    save_best_only=True, save_weights_only=True, verbose=1)
change_lw = models.LossWeightsModifier(lossweight = lossweight,
                               initial_lw = initial_lw,
                               directory = directory)
lr_decay = keras.callbacks.LearningRateScheduler(scheduler)

# %% [markdown]
# ## Model Training

# %%
model_save_dir = str(directory+'/trained_model_2.h5')
try:
    model.load_weights(model_save_dir)
except:
    history = model.fit(training_generator,
                        steps_per_epoch = int(dataset['x_train'].shape[0] / train_params["batch_size"]),
                        epochs = train_params["n_epochs"],
                        validation_data = ([dataset['x_test'],
                                            dataset['y_test_coarse'],dataset['y_test_medium'],dataset['y_test_fine']],
                                           [dataset['y_test_coarse'],dataset['y_test_medium'],dataset['y_test_fine']]),
                        callbacks = [tb,log,change_lw,lr_decay,checkpoint],
                        verbose=1)
    
    model.save_weights(model_save_dir)

# %%
try:
    history_dict = history.history

    plotter = tfdocs.plots.HistoryPlotter()
    plotter.plot({"Coarse": history}, metric = "prediction_coarse_accuracy")
    plotter.plot({"Medium": history}, metric = "prediction_medium_accuracy")
    plotter.plot({"Fine": history}, metric = "prediction_fine_accuracy")
    plt.title("Model Accuracy")
    plt.ylim([0,1])
except:
    print('Trained model weights loaded')
# Out:
# Trained model weights loaded

# %%
try:
    plotter = tfdocs.plots.HistoryPlotter()
    plotter.plot({"loss": history}, metric = "loss")
    plt.title("Model Loss")
    plt.ylim([0,1])
except:
    print('Trained model weights loaded')
# Out:
# Trained model weights loaded

# %% [markdown]
# ## Model Analysis

# %%
final_model = keras.Model(model.inputs[:1], model.output)

lossfn = models.MarginLoss()
final_model.compile(optimizer='adam', 
                    loss={'prediction_fine' : lossfn,
                          'prediction_medium' : lossfn,
                          'prediction_coarse' : lossfn},

                    loss_weights={'prediction_fine' : lossweight['fine_lw'],
                                  'prediction_medium' : lossweight['medium_lw'],
                                  'prediction_coarse' : lossweight['coarse_lw']},

                    metrics={'prediction_fine': 'accuracy',
                             'prediction_medium': 'accuracy',
                             'prediction_coarse': 'accuracy'
                            }
                   )

# %%
model_analysis = models.model_analysis(final_model, dataset)
results = model_analysis.evaluate()
predictions = model_analysis.prediction()
# Out:
# 313/313 [==============================] - 16s 22ms/step - loss: 0.1408 - prediction_coarse_loss: 0.0953 - prediction_medium_loss: 0.1569 - prediction_fine_loss: 0.2737 - prediction_coarse_accuracy: 0.8693 - prediction_medium_accuracy: 0.7931 - prediction_fine_accuracy: 0.6638
# 1. loss ==> 0.1407802402973175
# 2. prediction_coarse_loss ==> 0.09529387205839157
# 3. prediction_medium_loss ==> 0.15685723721981049
# 4. prediction_fine_loss ==> 0.2737104594707489
# 5. prediction_coarse_accuracy ==> 0.8693000078201294
# 6. prediction_medium_accuracy ==> 0.7930999994277954
# 7. prediction_fine_accuracy ==> 0.6638000011444092
# 313/313 [==============================] - 5s 15ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
true_label = [dataset['y_test_coarse'],dataset['y_test_medium'],dataset['y_test_fine']]
pred_label = [predictions[0],predictions[1],predictions[2]]
metrics.lvl_wise_metric(true_label,pred_label,directory)
# Out:
#   • Confusion_Matrix Level = 0
#   • Classification Report for Level = 0
#
#               precision    recall  f1-score   support
#
#            0    0.82890   0.71700   0.76890      1000
#            1    0.91823   0.91333   0.91578      1500
#            2    0.87846   0.91067   0.89427      1500
#            3    0.81697   0.79900   0.80789      1000
#            4    0.82997   0.88840   0.85819      2500
#            5    0.91975   0.89400   0.90669      1000
#            6    0.92123   0.84200   0.87983       500
#            7    0.90050   0.90500   0.90274      1000
#
#     accuracy                        0.86930     10000
#    macro avg    0.87675   0.85867   0.86679     10000
# weighted avg    0.86967   0.86930   0.86867     10000
#
#   • Confusion_Matrix Level = 1
#   • Classification Report for Level = 1
#
#               precision    recall  f1-score   support
#
#            0    0.72261   0.62000   0.66738       500
#            1    0.77479   0.75000   0.76220       500
#            2    0.86628   0.89400   0.87992       500
#            3    0.82077   0.80600   0.81332       500
#            4    0.83202   0.84200   0.83698       500
#            5    0.72477   0.79000   0.75598       500
#            6    0.87830   0.86600   0.87210       500
#            7    0.78405   0.80600   0.79487       500
#            8    0.70567   0.77200   0.73734       500
#            9    0.86847   0.89800   0.88299       500
#           10    0.91368   0.86800   0.89026       500
#           11    0.75547   0.76000   0.75773       500
#           12    0.69674   0.72600   0.71107       500
#           13    0.68616   0.70400   0.69497       500
#           14    0.89897   0.87200   0.88528       500
#           15    0.64509   0.61800   0.63126       500
#           16    0.71581   0.67000   0.69215       500
#           17    0.92843   0.93400   0.93121       500
#           18    0.83366   0.86200   0.84759       500
#           19    0.81377   0.80400   0.80885       500
#
#     accuracy                        0.79310     10000
#    macro avg    0.79327   0.79310   0.79267     10000
# weighted avg    0.79327   0.79310   0.79267     10000
#
#   • Confusion_Matrix Level = 2
#   • Classification Report for Level = 2
#
#               precision    recall  f1-score   support
#
#            0    0.89011   0.81000   0.84817       100
#            1    0.82222   0.74000   0.77895       100
#            2    0.51456   0.53000   0.52217       100
#            3    0.51111   0.46000   0.48421       100
#            4    0.51852   0.42000   0.46409       100
#            5    0.69388   0.68000   0.68687       100
#            6    0.73118   0.68000   0.70466       100
#            7    0.65741   0.71000   0.68269       100
#            8    0.84375   0.81000   0.82653       100
#            9    0.81915   0.77000   0.79381       100
#           10    0.59783   0.55000   0.57292       100
#           11    0.44186   0.38000   0.40860       100
#           12    0.70909   0.78000   0.74286       100
#           13    0.59140   0.55000   0.56995       100
#           14    0.58475   0.69000   0.63303       100
#           15    0.58772   0.67000   0.62617       100
#           16    0.68687   0.68000   0.68342       100
#           17    0.85263   0.81000   0.83077       100
#           18    0.65957   0.62000   0.63918       100
#           19    0.57407   0.62000   0.59615       100
#           20    0.79817   0.87000   0.83254       100
#           21    0.75926   0.82000   0.78846       100
#           22    0.67961   0.70000   0.68966       100
#           23    0.84444   0.76000   0.80000       100
#           24    0.82979   0.78000   0.80412       100
#           25    0.58242   0.53000   0.55497       100
#           26    0.60000   0.66000   0.62857       100
#           27    0.57143   0.48000   0.52174       100
#           28    0.75701   0.81000   0.78261       100
#           29    0.62887   0.61000   0.61929       100
#           30    0.66667   0.64000   0.65306       100
#           31    0.72000   0.54000   0.61714       100
#           32    0.71765   0.61000   0.65946       100
#           33    0.70930   0.61000   0.65591       100
#           34    0.78161   0.68000   0.72727       100
#           35    0.42857   0.45000   0.43902       100
#           36    0.74490   0.73000   0.73737       100
#           37    0.74444   0.67000   0.70526       100
#           38    0.58763   0.57000   0.57868       100
#           39    0.71545   0.88000   0.78924       100
#           40    0.63441   0.59000   0.61140       100
#           41    0.80374   0.86000   0.83092       100
#           42    0.46512   0.80000   0.58824       100
#           43    0.71579   0.68000   0.69744       100
#           44    0.31068   0.32000   0.31527       100
#           45    0.53846   0.49000   0.51309       100
#           46    0.40816   0.40000   0.40404       100
#           47    0.61111   0.66000   0.63462       100
#           48    0.73643   0.95000   0.82969       100
#           49    0.74545   0.82000   0.78095       100
#           50    0.43617   0.41000   0.42268       100
#           51    0.64815   0.70000   0.67308       100
#           52    0.56667   0.68000   0.61818       100
#           53    0.79464   0.89000   0.83962       100
#           54    0.68696   0.79000   0.73488       100
#           55    0.38028   0.27000   0.31579       100
#           56    0.87000   0.87000   0.87000       100
#           57    0.68224   0.73000   0.70531       100
#           58    0.84043   0.79000   0.81443       100
#           59    0.66990   0.69000   0.67980       100
#           60    0.82075   0.87000   0.84466       100
#           61    0.67778   0.61000   0.64211       100
#           62    0.68571   0.72000   0.70244       100
#           63    0.64835   0.59000   0.61780       100
#           64    0.50000   0.50000   0.50000       100
#           65    0.51351   0.38000   0.43678       100
#           66    0.63158   0.72000   0.67290       100
#           67    0.55789   0.53000   0.54359       100
#           68    0.84404   0.92000   0.88038       100
#           69    0.80000   0.80000   0.80000       100
#           70    0.69474   0.66000   0.67692       100
#           71    0.75472   0.80000   0.77670       100
#           72    0.33735   0.28000   0.30601       100
#           73    0.52083   0.50000   0.51020       100
#           74    0.42478   0.48000   0.45070       100
#           75    0.83654   0.87000   0.85294       100
#           76    0.86538   0.90000   0.88235       100
#           77    0.60870   0.56000   0.58333       100
#           78    0.45522   0.61000   0.52137       100
#           79    0.77778   0.70000   0.73684       100
#           80    0.59091   0.39000   0.46988       100
#           81    0.60684   0.71000   0.65438       100
#           82    0.84259   0.91000   0.87500       100
#           83    0.65306   0.64000   0.64646       100
#           84    0.72619   0.61000   0.66304       100
#           85    0.77670   0.80000   0.78818       100
#           86    0.61864   0.73000   0.66972       100
#           87    0.71053   0.81000   0.75701       100
#           88    0.74227   0.72000   0.73096       100
#           89    0.78351   0.76000   0.77157       100
#           90    0.67544   0.77000   0.71963       100
#           91    0.75472   0.80000   0.77670       100
#           92    0.59574   0.56000   0.57732       100
#           93    0.66667   0.48000   0.55814       100
#           94    0.85185   0.92000   0.88462       100
#           95    0.69307   0.70000   0.69652       100
#           96    0.68421   0.52000   0.59091       100
#           97    0.75000   0.66000   0.70213       100
#           98    0.45556   0.41000   0.43158       100
#           99    0.56154   0.73000   0.63478       100
#
#     accuracy                        0.66380     10000
#    macro avg    0.66395   0.66380   0.66096     10000
# weighted avg    0.66395   0.66380   0.66096     10000

# %%
h_measurements,consistency,exact_match, get_performance_report = metrics.hmeasurements(true_label, pred_label, dataset['tree'])

get_performance_report = {**{'Dataset': dataset['name'],
                             'Model': 'HD-CapsNet'},
                             **get_performance_report
                             } # merging two dictionaries (adding Dataset and Model name)
performance_metrics = pd.DataFrame(pd.DataFrame(get_performance_report.values(), get_performance_report.keys(), columns = ['Value']))
performance_metrics.to_csv(os.path.join(directory,'performance_metrics.csv'))
display(performance_metrics)
# Out:
#                               Value
# Dataset                   CIFAR-100
# Model                    HD-CapsNet
# Accuracy L_0                 0.8693
# Accuracy L_1                 0.7931
# Accuracy L_2                 0.6638
# HarmonicM_Accuracy_k1      0.765755
# HarmonicM_Accuracy_k2      0.853885
# HarmonicM_Accuracy_k5      0.910023
# ArithmeticM_Accuracy_k1      0.7754
# ArithmeticM_Accuracy_k2    0.860833
# ArithmeticM_Accuracy_k5    0.914933
# hP                         0.774252
# hR                         0.791967
# hF1                         0.78119
# consistency                   0.898
# exact_match                   0.638

# %% [markdown]
# # Training Again

# %%
model_save_dir = str(directory+'/trained_model_2.h5')
try:
    model.load_weights(model_save_dir)
except:
    history = model.fit(training_generator,
                        steps_per_epoch = int(dataset['x_train'].shape[0] / train_params["batch_size"]),
                        epochs = train_params["n_epochs"],
                        validation_data = ([dataset['x_test'],
                                            dataset['y_test_coarse'],dataset['y_test_medium'],dataset['y_test_fine']],
                                           [dataset['y_test_coarse'],dataset['y_test_medium'],dataset['y_test_fine']]),
                        callbacks = [tb,log,change_lw,lr_decay,checkpoint],
                        verbose=1)
    
    model.save_weights(model_save_dir)
# Out:
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring... Layer tf.math.multiply_9 was passed non-JSON-serializable arguments. Arguments had types: {'y': <class 'tensorflow.python.ops.resource_variable_ops.ResourceVariable'>, 'name': <class 'NoneType'>}. They cannot be serialized out when saving the model.
# Epoch 1/100
#   6/781 [..............................] - ETA: 1:37 - loss: 0.0879 - prediction_coarse_accuracy: 0.9505 - prediction_medium_accuracy: 0.9375 - prediction_fine_accuracy: 0.8932WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0694s vs `on_train_batch_end` time: 0.0742s). Check your callbacks.
# 781/781 [==============================] - ETA: 0s - loss: 0.1124 - prediction_coarse_accuracy: 0.9250 - prediction_medium_accuracy: 0.8921 - prediction_fine_accuracy: 0.7999
#   • Coarse Accuracy = 92.50% | Val_Accuracy = 83.82% | LossWeight = 0.34
#   • Medium Accuracy = 89.21% | Val_Accuracy = 74.51% | LossWeight = 0.44
#   • Fine   Accuracy = 79.99% | Val_Accuracy = 61.03% | LossWeight = 0.21
#
# Epoch 1: val_prediction_fine_accuracy did not improve from 0.66120
# 781/781 [==============================] - 107s 137ms/step - loss: 0.1124 - prediction_coarse_accuracy: 0.9250 - prediction_medium_accuracy: 0.8921 - prediction_fine_accuracy: 0.7999 - val_loss: 0.1449 - val_prediction_coarse_accuracy: 0.8382 - val_prediction_medium_accuracy: 0.7451 - val_prediction_fine_accuracy: 0.6103 - lr: 0.0010
# Epoch 2/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1044 - prediction_coarse_accuracy: 0.9308 - prediction_medium_accuracy: 0.9036 - prediction_fine_accuracy: 0.8023
#   • Coarse Accuracy = 93.08% | Val_Accuracy = 83.54% | LossWeight = 0.34
#   • Medium Accuracy = 90.36% | Val_Accuracy = 75.23% | LossWeight = 0.43
#   • Fine   Accuracy = 80.23% | Val_Accuracy = 61.76% | LossWeight = 0.23
#
# Epoch 2: val_prediction_fine_accuracy did not improve from 0.66120
# 781/781 [==============================] - 107s 137ms/step - loss: 0.1044 - prediction_coarse_accuracy: 0.9308 - prediction_medium_accuracy: 0.9036 - prediction_fine_accuracy: 0.8023 - val_loss: 0.1385 - val_prediction_coarse_accuracy: 0.8354 - val_prediction_medium_accuracy: 0.7523 - val_prediction_fine_accuracy: 0.6176 - lr: 0.0010
# Epoch 3/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1002 - prediction_coarse_accuracy: 0.9368 - prediction_medium_accuracy: 0.9117 - prediction_fine_accuracy: 0.8170
#   • Coarse Accuracy = 93.68% | Val_Accuracy = 83.98% | LossWeight = 0.34
#   • Medium Accuracy = 91.17% | Val_Accuracy = 74.67% | LossWeight = 0.43
#   • Fine   Accuracy = 81.70% | Val_Accuracy = 62.06% | LossWeight = 0.23
#
# Epoch 3: val_prediction_fine_accuracy did not improve from 0.66120
# 781/781 [==============================] - 107s 137ms/step - loss: 0.1002 - prediction_coarse_accuracy: 0.9368 - prediction_medium_accuracy: 0.9117 - prediction_fine_accuracy: 0.8170 - val_loss: 0.1389 - val_prediction_coarse_accuracy: 0.8398 - val_prediction_medium_accuracy: 0.7467 - val_prediction_fine_accuracy: 0.6206 - lr: 0.0010
# Epoch 4/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0997 - prediction_coarse_accuracy: 0.9377 - prediction_medium_accuracy: 0.9122 - prediction_fine_accuracy: 0.8205
#   • Coarse Accuracy = 93.77% | Val_Accuracy = 84.36% | LossWeight = 0.34
#   • Medium Accuracy = 91.22% | Val_Accuracy = 75.36% | LossWeight = 0.43
#   • Fine   Accuracy = 82.05% | Val_Accuracy = 62.26% | LossWeight = 0.23
#
# Epoch 4: val_prediction_fine_accuracy did not improve from 0.66120
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0997 - prediction_coarse_accuracy: 0.9377 - prediction_medium_accuracy: 0.9122 - prediction_fine_accuracy: 0.8205 - val_loss: 0.1344 - val_prediction_coarse_accuracy: 0.8436 - val_prediction_medium_accuracy: 0.7536 - val_prediction_fine_accuracy: 0.6226 - lr: 0.0010
# Epoch 5/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0988 - prediction_coarse_accuracy: 0.9368 - prediction_medium_accuracy: 0.9144 - prediction_fine_accuracy: 0.8223
#   • Coarse Accuracy = 93.68% | Val_Accuracy = 83.97% | LossWeight = 0.35
#   • Medium Accuracy = 91.44% | Val_Accuracy = 74.23% | LossWeight = 0.42
#   • Fine   Accuracy = 82.23% | Val_Accuracy = 61.56% | LossWeight = 0.23
#
# Epoch 5: val_prediction_fine_accuracy did not improve from 0.66120
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0988 - prediction_coarse_accuracy: 0.9368 - prediction_medium_accuracy: 0.9144 - prediction_fine_accuracy: 0.8223 - val_loss: 0.1393 - val_prediction_coarse_accuracy: 0.8397 - val_prediction_medium_accuracy: 0.7423 - val_prediction_fine_accuracy: 0.6156 - lr: 0.0010
# Epoch 6/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0986 - prediction_coarse_accuracy: 0.9369 - prediction_medium_accuracy: 0.9144 - prediction_fine_accuracy: 0.8234
#   • Coarse Accuracy = 93.69% | Val_Accuracy = 84.97% | LossWeight = 0.35
#   • Medium Accuracy = 91.44% | Val_Accuracy = 75.74% | LossWeight = 0.42
#   • Fine   Accuracy = 82.34% | Val_Accuracy = 62.82% | LossWeight = 0.23
#
# Epoch 6: val_prediction_fine_accuracy did not improve from 0.66120
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0986 - prediction_coarse_accuracy: 0.9369 - prediction_medium_accuracy: 0.9144 - prediction_fine_accuracy: 0.8234 - val_loss: 0.1330 - val_prediction_coarse_accuracy: 0.8497 - val_prediction_medium_accuracy: 0.7574 - val_prediction_fine_accuracy: 0.6282 - lr: 0.0010
# Epoch 7/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0971 - prediction_coarse_accuracy: 0.9409 - prediction_medium_accuracy: 0.9178 - prediction_fine_accuracy: 0.8272
#   • Coarse Accuracy = 94.09% | Val_Accuracy = 84.04% | LossWeight = 0.34
#   • Medium Accuracy = 91.78% | Val_Accuracy = 75.37% | LossWeight = 0.43
#   • Fine   Accuracy = 82.72% | Val_Accuracy = 62.03% | LossWeight = 0.23
#
# Epoch 7: val_prediction_fine_accuracy did not improve from 0.66120
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0971 - prediction_coarse_accuracy: 0.9409 - prediction_medium_accuracy: 0.9178 - prediction_fine_accuracy: 0.8272 - val_loss: 0.1374 - val_prediction_coarse_accuracy: 0.8404 - val_prediction_medium_accuracy: 0.7537 - val_prediction_fine_accuracy: 0.6203 - lr: 0.0010
# Epoch 8/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0964 - prediction_coarse_accuracy: 0.9407 - prediction_medium_accuracy: 0.9197 - prediction_fine_accuracy: 0.8305
#   • Coarse Accuracy = 94.07% | Val_Accuracy = 84.95% | LossWeight = 0.35
#   • Medium Accuracy = 91.97% | Val_Accuracy = 75.71% | LossWeight = 0.42
#   • Fine   Accuracy = 83.05% | Val_Accuracy = 62.82% | LossWeight = 0.23
#
# Epoch 8: val_prediction_fine_accuracy did not improve from 0.66120
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0964 - prediction_coarse_accuracy: 0.9407 - prediction_medium_accuracy: 0.9197 - prediction_fine_accuracy: 0.8305 - val_loss: 0.1335 - val_prediction_coarse_accuracy: 0.8495 - val_prediction_medium_accuracy: 0.7571 - val_prediction_fine_accuracy: 0.6282 - lr: 0.0010
# Epoch 9/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0958 - prediction_coarse_accuracy: 0.9405 - prediction_medium_accuracy: 0.9195 - prediction_fine_accuracy: 0.8334
#   • Coarse Accuracy = 94.05% | Val_Accuracy = 85.12% | LossWeight = 0.35
#   • Medium Accuracy = 91.95% | Val_Accuracy = 76.03% | LossWeight = 0.42
#   • Fine   Accuracy = 83.34% | Val_Accuracy = 62.98% | LossWeight = 0.23
#
# Epoch 9: val_prediction_fine_accuracy did not improve from 0.66120
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0958 - prediction_coarse_accuracy: 0.9405 - prediction_medium_accuracy: 0.9195 - prediction_fine_accuracy: 0.8334 - val_loss: 0.1327 - val_prediction_coarse_accuracy: 0.8512 - val_prediction_medium_accuracy: 0.7603 - val_prediction_fine_accuracy: 0.6298 - lr: 0.0010
# Epoch 10/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0967 - prediction_coarse_accuracy: 0.9386 - prediction_medium_accuracy: 0.9190 - prediction_fine_accuracy: 0.8347
#   • Coarse Accuracy = 93.86% | Val_Accuracy = 84.49% | LossWeight = 0.36
#   • Medium Accuracy = 91.90% | Val_Accuracy = 75.31% | LossWeight = 0.42
#   • Fine   Accuracy = 83.47% | Val_Accuracy = 62.14% | LossWeight = 0.22
#
# Epoch 10: val_prediction_fine_accuracy did not improve from 0.66120
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0967 - prediction_coarse_accuracy: 0.9386 - prediction_medium_accuracy: 0.9190 - prediction_fine_accuracy: 0.8347 - val_loss: 0.1367 - val_prediction_coarse_accuracy: 0.8449 - val_prediction_medium_accuracy: 0.7531 - val_prediction_fine_accuracy: 0.6214 - lr: 0.0010
# Epoch 11/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0940 - prediction_coarse_accuracy: 0.9447 - prediction_medium_accuracy: 0.9253 - prediction_fine_accuracy: 0.8437
#   • Coarse Accuracy = 94.47% | Val_Accuracy = 84.19% | LossWeight = 0.35
#   • Medium Accuracy = 92.53% | Val_Accuracy = 75.56% | LossWeight = 0.42
#   • Fine   Accuracy = 84.37% | Val_Accuracy = 62.25% | LossWeight = 0.23
#
# Epoch 11: val_prediction_fine_accuracy did not improve from 0.66120
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0940 - prediction_coarse_accuracy: 0.9447 - prediction_medium_accuracy: 0.9253 - prediction_fine_accuracy: 0.8437 - val_loss: 0.1360 - val_prediction_coarse_accuracy: 0.8419 - val_prediction_medium_accuracy: 0.7556 - val_prediction_fine_accuracy: 0.6225 - lr: 9.5000e-04
# Epoch 12/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0922 - prediction_coarse_accuracy: 0.9462 - prediction_medium_accuracy: 0.9258 - prediction_fine_accuracy: 0.8462
#   • Coarse Accuracy = 94.62% | Val_Accuracy = 85.03% | LossWeight = 0.34
#   • Medium Accuracy = 92.58% | Val_Accuracy = 75.63% | LossWeight = 0.43
#   • Fine   Accuracy = 84.62% | Val_Accuracy = 62.14% | LossWeight = 0.23
#
# Epoch 12: val_prediction_fine_accuracy did not improve from 0.66120
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0922 - prediction_coarse_accuracy: 0.9462 - prediction_medium_accuracy: 0.9258 - prediction_fine_accuracy: 0.8462 - val_loss: 0.1346 - val_prediction_coarse_accuracy: 0.8503 - val_prediction_medium_accuracy: 0.7563 - val_prediction_fine_accuracy: 0.6214 - lr: 9.0250e-04
# Epoch 13/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0914 - prediction_coarse_accuracy: 0.9463 - prediction_medium_accuracy: 0.9281 - prediction_fine_accuracy: 0.8509
#   • Coarse Accuracy = 94.63% | Val_Accuracy = 84.39% | LossWeight = 0.35
#   • Medium Accuracy = 92.81% | Val_Accuracy = 75.29% | LossWeight = 0.42
#   • Fine   Accuracy = 85.09% | Val_Accuracy = 62.02% | LossWeight = 0.23
#
# Epoch 13: val_prediction_fine_accuracy did not improve from 0.66120
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0914 - prediction_coarse_accuracy: 0.9463 - prediction_medium_accuracy: 0.9281 - prediction_fine_accuracy: 0.8509 - val_loss: 0.1356 - val_prediction_coarse_accuracy: 0.8439 - val_prediction_medium_accuracy: 0.7529 - val_prediction_fine_accuracy: 0.6202 - lr: 8.5737e-04
# Epoch 14/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0905 - prediction_coarse_accuracy: 0.9463 - prediction_medium_accuracy: 0.9292 - prediction_fine_accuracy: 0.8595
#   • Coarse Accuracy = 94.63% | Val_Accuracy = 85.12% | LossWeight = 0.36
#   • Medium Accuracy = 92.92% | Val_Accuracy = 76.23% | LossWeight = 0.42
#   • Fine   Accuracy = 85.95% | Val_Accuracy = 63.18% | LossWeight = 0.22
#
# Epoch 14: val_prediction_fine_accuracy did not improve from 0.66120
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0905 - prediction_coarse_accuracy: 0.9463 - prediction_medium_accuracy: 0.9292 - prediction_fine_accuracy: 0.8595 - val_loss: 0.1317 - val_prediction_coarse_accuracy: 0.8512 - val_prediction_medium_accuracy: 0.7623 - val_prediction_fine_accuracy: 0.6318 - lr: 8.1451e-04
# Epoch 15/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0904 - prediction_coarse_accuracy: 0.9480 - prediction_medium_accuracy: 0.9311 - prediction_fine_accuracy: 0.8628
#   • Coarse Accuracy = 94.80% | Val_Accuracy = 85.23% | LossWeight = 0.36
#   • Medium Accuracy = 93.11% | Val_Accuracy = 76.49% | LossWeight = 0.42
#   • Fine   Accuracy = 86.28% | Val_Accuracy = 62.99% | LossWeight = 0.22
#
# Epoch 15: val_prediction_fine_accuracy did not improve from 0.66120
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0904 - prediction_coarse_accuracy: 0.9480 - prediction_medium_accuracy: 0.9311 - prediction_fine_accuracy: 0.8628 - val_loss: 0.1322 - val_prediction_coarse_accuracy: 0.8523 - val_prediction_medium_accuracy: 0.7649 - val_prediction_fine_accuracy: 0.6299 - lr: 7.7378e-04
# Epoch 16/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0893 - prediction_coarse_accuracy: 0.9479 - prediction_medium_accuracy: 0.9329 - prediction_fine_accuracy: 0.8669
#   • Coarse Accuracy = 94.79% | Val_Accuracy = 85.31% | LossWeight = 0.36
#   • Medium Accuracy = 93.29% | Val_Accuracy = 76.70% | LossWeight = 0.42
#   • Fine   Accuracy = 86.69% | Val_Accuracy = 63.75% | LossWeight = 0.22
#
# Epoch 16: val_prediction_fine_accuracy did not improve from 0.66120
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0893 - prediction_coarse_accuracy: 0.9479 - prediction_medium_accuracy: 0.9329 - prediction_fine_accuracy: 0.8669 - val_loss: 0.1301 - val_prediction_coarse_accuracy: 0.8531 - val_prediction_medium_accuracy: 0.7670 - val_prediction_fine_accuracy: 0.6375 - lr: 7.3509e-04
# Epoch 17/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0878 - prediction_coarse_accuracy: 0.9508 - prediction_medium_accuracy: 0.9352 - prediction_fine_accuracy: 0.8733
#   • Coarse Accuracy = 95.08% | Val_Accuracy = 85.19% | LossWeight = 0.36
#   • Medium Accuracy = 93.52% | Val_Accuracy = 77.16% | LossWeight = 0.43
#   • Fine   Accuracy = 87.33% | Val_Accuracy = 64.01% | LossWeight = 0.22
#
# Epoch 17: val_prediction_fine_accuracy did not improve from 0.66120
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0878 - prediction_coarse_accuracy: 0.9508 - prediction_medium_accuracy: 0.9352 - prediction_fine_accuracy: 0.8733 - val_loss: 0.1291 - val_prediction_coarse_accuracy: 0.8519 - val_prediction_medium_accuracy: 0.7716 - val_prediction_fine_accuracy: 0.6401 - lr: 6.9834e-04
# Epoch 18/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0860 - prediction_coarse_accuracy: 0.9524 - prediction_medium_accuracy: 0.9368 - prediction_fine_accuracy: 0.8783
#   • Coarse Accuracy = 95.24% | Val_Accuracy = 85.78% | LossWeight = 0.36
#   • Medium Accuracy = 93.68% | Val_Accuracy = 76.55% | LossWeight = 0.43
#   • Fine   Accuracy = 87.83% | Val_Accuracy = 63.46% | LossWeight = 0.21
#
# Epoch 18: val_prediction_fine_accuracy did not improve from 0.66120
# 781/781 [==============================] - 107s 138ms/step - loss: 0.0860 - prediction_coarse_accuracy: 0.9524 - prediction_medium_accuracy: 0.9368 - prediction_fine_accuracy: 0.8783 - val_loss: 0.1281 - val_prediction_coarse_accuracy: 0.8578 - val_prediction_medium_accuracy: 0.7655 - val_prediction_fine_accuracy: 0.6346 - lr: 6.6342e-04
# Epoch 19/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0860 - prediction_coarse_accuracy: 0.9512 - prediction_medium_accuracy: 0.9379 - prediction_fine_accuracy: 0.8833
#   • Coarse Accuracy = 95.12% | Val_Accuracy = 85.90% | LossWeight = 0.37
#   • Medium Accuracy = 93.79% | Val_Accuracy = 77.44% | LossWeight = 0.42
#   • Fine   Accuracy = 88.33% | Val_Accuracy = 63.89% | LossWeight = 0.21
#
# Epoch 19: val_prediction_fine_accuracy did not improve from 0.66120
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0860 - prediction_coarse_accuracy: 0.9512 - prediction_medium_accuracy: 0.9379 - prediction_fine_accuracy: 0.8833 - val_loss: 0.1275 - val_prediction_coarse_accuracy: 0.8590 - val_prediction_medium_accuracy: 0.7744 - val_prediction_fine_accuracy: 0.6389 - lr: 6.3025e-04
# Epoch 20/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0854 - prediction_coarse_accuracy: 0.9554 - prediction_medium_accuracy: 0.9395 - prediction_fine_accuracy: 0.8870
#   • Coarse Accuracy = 95.54% | Val_Accuracy = 86.17% | LossWeight = 0.36
#   • Medium Accuracy = 93.95% | Val_Accuracy = 77.38% | LossWeight = 0.43
#   • Fine   Accuracy = 88.70% | Val_Accuracy = 63.80% | LossWeight = 0.21
#
# Epoch 20: val_prediction_fine_accuracy did not improve from 0.66120
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0854 - prediction_coarse_accuracy: 0.9554 - prediction_medium_accuracy: 0.9395 - prediction_fine_accuracy: 0.8870 - val_loss: 0.1276 - val_prediction_coarse_accuracy: 0.8617 - val_prediction_medium_accuracy: 0.7738 - val_prediction_fine_accuracy: 0.6380 - lr: 5.9874e-04
# Epoch 21/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0836 - prediction_coarse_accuracy: 0.9548 - prediction_medium_accuracy: 0.9402 - prediction_fine_accuracy: 0.8899
#   • Coarse Accuracy = 95.48% | Val_Accuracy = 85.89% | LossWeight = 0.36
#   • Medium Accuracy = 94.02% | Val_Accuracy = 77.63% | LossWeight = 0.43
#   • Fine   Accuracy = 88.99% | Val_Accuracy = 64.01% | LossWeight = 0.21
#
# Epoch 21: val_prediction_fine_accuracy did not improve from 0.66120
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0836 - prediction_coarse_accuracy: 0.9548 - prediction_medium_accuracy: 0.9402 - prediction_fine_accuracy: 0.8899 - val_loss: 0.1277 - val_prediction_coarse_accuracy: 0.8589 - val_prediction_medium_accuracy: 0.7763 - val_prediction_fine_accuracy: 0.6401 - lr: 5.6880e-04
# Epoch 22/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0845 - prediction_coarse_accuracy: 0.9531 - prediction_medium_accuracy: 0.9393 - prediction_fine_accuracy: 0.8903
#   • Coarse Accuracy = 95.31% | Val_Accuracy = 85.66% | LossWeight = 0.37
#   • Medium Accuracy = 93.93% | Val_Accuracy = 77.41% | LossWeight = 0.43
#   • Fine   Accuracy = 89.03% | Val_Accuracy = 63.96% | LossWeight = 0.20
#
# Epoch 22: val_prediction_fine_accuracy did not improve from 0.66120
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0845 - prediction_coarse_accuracy: 0.9531 - prediction_medium_accuracy: 0.9393 - prediction_fine_accuracy: 0.8903 - val_loss: 0.1290 - val_prediction_coarse_accuracy: 0.8566 - val_prediction_medium_accuracy: 0.7741 - val_prediction_fine_accuracy: 0.6396 - lr: 5.4036e-04
# Epoch 23/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0850 - prediction_coarse_accuracy: 0.9534 - prediction_medium_accuracy: 0.9398 - prediction_fine_accuracy: 0.8928
#   • Coarse Accuracy = 95.34% | Val_Accuracy = 86.12% | LossWeight = 0.37
#   • Medium Accuracy = 93.98% | Val_Accuracy = 77.77% | LossWeight = 0.43
#   • Fine   Accuracy = 89.28% | Val_Accuracy = 64.14% | LossWeight = 0.20
#
# Epoch 23: val_prediction_fine_accuracy did not improve from 0.66120
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0850 - prediction_coarse_accuracy: 0.9534 - prediction_medium_accuracy: 0.9398 - prediction_fine_accuracy: 0.8928 - val_loss: 0.1266 - val_prediction_coarse_accuracy: 0.8612 - val_prediction_medium_accuracy: 0.7777 - val_prediction_fine_accuracy: 0.6414 - lr: 5.1334e-04
# Epoch 24/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0828 - prediction_coarse_accuracy: 0.9575 - prediction_medium_accuracy: 0.9452 - prediction_fine_accuracy: 0.8998
#   • Coarse Accuracy = 95.75% | Val_Accuracy = 86.03% | LossWeight = 0.37
#   • Medium Accuracy = 94.52% | Val_Accuracy = 77.51% | LossWeight = 0.43
#   • Fine   Accuracy = 89.98% | Val_Accuracy = 64.55% | LossWeight = 0.20
#
# Epoch 24: val_prediction_fine_accuracy did not improve from 0.66120
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0828 - prediction_coarse_accuracy: 0.9575 - prediction_medium_accuracy: 0.9452 - prediction_fine_accuracy: 0.8998 - val_loss: 0.1267 - val_prediction_coarse_accuracy: 0.8603 - val_prediction_medium_accuracy: 0.7751 - val_prediction_fine_accuracy: 0.6455 - lr: 4.8767e-04
# Epoch 25/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0835 - prediction_coarse_accuracy: 0.9550 - prediction_medium_accuracy: 0.9424 - prediction_fine_accuracy: 0.9000
#   • Coarse Accuracy = 95.50% | Val_Accuracy = 85.82% | LossWeight = 0.37
#   • Medium Accuracy = 94.24% | Val_Accuracy = 77.75% | LossWeight = 0.43
#   • Fine   Accuracy = 90.00% | Val_Accuracy = 64.56% | LossWeight = 0.19
#
# Epoch 25: val_prediction_fine_accuracy did not improve from 0.66120
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0835 - prediction_coarse_accuracy: 0.9550 - prediction_medium_accuracy: 0.9424 - prediction_fine_accuracy: 0.9000 - val_loss: 0.1262 - val_prediction_coarse_accuracy: 0.8582 - val_prediction_medium_accuracy: 0.7775 - val_prediction_fine_accuracy: 0.6456 - lr: 4.6329e-04
# Epoch 26/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0825 - prediction_coarse_accuracy: 0.9568 - prediction_medium_accuracy: 0.9451 - prediction_fine_accuracy: 0.9041
#   • Coarse Accuracy = 95.68% | Val_Accuracy = 86.28% | LossWeight = 0.38
#   • Medium Accuracy = 94.51% | Val_Accuracy = 78.08% | LossWeight = 0.43
#   • Fine   Accuracy = 90.41% | Val_Accuracy = 64.63% | LossWeight = 0.19
#
# Epoch 26: val_prediction_fine_accuracy did not improve from 0.66120
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0825 - prediction_coarse_accuracy: 0.9568 - prediction_medium_accuracy: 0.9451 - prediction_fine_accuracy: 0.9041 - val_loss: 0.1245 - val_prediction_coarse_accuracy: 0.8628 - val_prediction_medium_accuracy: 0.7808 - val_prediction_fine_accuracy: 0.6463 - lr: 4.4013e-04
# Epoch 27/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0817 - prediction_coarse_accuracy: 0.9579 - prediction_medium_accuracy: 0.9466 - prediction_fine_accuracy: 0.9078
#   • Coarse Accuracy = 95.79% | Val_Accuracy = 86.25% | LossWeight = 0.38
#   • Medium Accuracy = 94.66% | Val_Accuracy = 78.14% | LossWeight = 0.43
#   • Fine   Accuracy = 90.78% | Val_Accuracy = 65.00% | LossWeight = 0.19
#
# Epoch 27: val_prediction_fine_accuracy did not improve from 0.66120
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0817 - prediction_coarse_accuracy: 0.9579 - prediction_medium_accuracy: 0.9466 - prediction_fine_accuracy: 0.9078 - val_loss: 0.1249 - val_prediction_coarse_accuracy: 0.8625 - val_prediction_medium_accuracy: 0.7814 - val_prediction_fine_accuracy: 0.6500 - lr: 4.1812e-04
# Epoch 28/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0816 - prediction_coarse_accuracy: 0.9584 - prediction_medium_accuracy: 0.9466 - prediction_fine_accuracy: 0.9094
#   • Coarse Accuracy = 95.84% | Val_Accuracy = 86.31% | LossWeight = 0.38
#   • Medium Accuracy = 94.66% | Val_Accuracy = 78.37% | LossWeight = 0.43
#   • Fine   Accuracy = 90.94% | Val_Accuracy = 65.25% | LossWeight = 0.19
#
# Epoch 28: val_prediction_fine_accuracy did not improve from 0.66120
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0816 - prediction_coarse_accuracy: 0.9584 - prediction_medium_accuracy: 0.9466 - prediction_fine_accuracy: 0.9094 - val_loss: 0.1239 - val_prediction_coarse_accuracy: 0.8631 - val_prediction_medium_accuracy: 0.7837 - val_prediction_fine_accuracy: 0.6525 - lr: 3.9721e-04
# Epoch 29/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0807 - prediction_coarse_accuracy: 0.9603 - prediction_medium_accuracy: 0.9488 - prediction_fine_accuracy: 0.9120
#   • Coarse Accuracy = 96.03% | Val_Accuracy = 86.69% | LossWeight = 0.37
#   • Medium Accuracy = 94.88% | Val_Accuracy = 78.78% | LossWeight = 0.43
#   • Fine   Accuracy = 91.20% | Val_Accuracy = 65.17% | LossWeight = 0.19
#
# Epoch 29: val_prediction_fine_accuracy did not improve from 0.66120
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0807 - prediction_coarse_accuracy: 0.9603 - prediction_medium_accuracy: 0.9488 - prediction_fine_accuracy: 0.9120 - val_loss: 0.1221 - val_prediction_coarse_accuracy: 0.8669 - val_prediction_medium_accuracy: 0.7878 - val_prediction_fine_accuracy: 0.6517 - lr: 3.7735e-04
# Epoch 30/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0813 - prediction_coarse_accuracy: 0.9575 - prediction_medium_accuracy: 0.9460 - prediction_fine_accuracy: 0.9105
#   • Coarse Accuracy = 95.75% | Val_Accuracy = 86.01% | LossWeight = 0.38
#   • Medium Accuracy = 94.60% | Val_Accuracy = 77.82% | LossWeight = 0.43
#   • Fine   Accuracy = 91.05% | Val_Accuracy = 64.76% | LossWeight = 0.19
#
# Epoch 30: val_prediction_fine_accuracy did not improve from 0.66120
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0813 - prediction_coarse_accuracy: 0.9575 - prediction_medium_accuracy: 0.9460 - prediction_fine_accuracy: 0.9105 - val_loss: 0.1259 - val_prediction_coarse_accuracy: 0.8601 - val_prediction_medium_accuracy: 0.7782 - val_prediction_fine_accuracy: 0.6476 - lr: 3.5849e-04
# Epoch 31/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0804 - prediction_coarse_accuracy: 0.9591 - prediction_medium_accuracy: 0.9488 - prediction_fine_accuracy: 0.9153
#   • Coarse Accuracy = 95.91% | Val_Accuracy = 86.27% | LossWeight = 0.38
#   • Medium Accuracy = 94.88% | Val_Accuracy = 78.48% | LossWeight = 0.43
#   • Fine   Accuracy = 91.53% | Val_Accuracy = 65.02% | LossWeight = 0.19
#
# Epoch 31: val_prediction_fine_accuracy did not improve from 0.66120
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0804 - prediction_coarse_accuracy: 0.9591 - prediction_medium_accuracy: 0.9488 - prediction_fine_accuracy: 0.9153 - val_loss: 0.1246 - val_prediction_coarse_accuracy: 0.8627 - val_prediction_medium_accuracy: 0.7848 - val_prediction_fine_accuracy: 0.6502 - lr: 3.4056e-04
# Epoch 32/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0815 - prediction_coarse_accuracy: 0.9584 - prediction_medium_accuracy: 0.9473 - prediction_fine_accuracy: 0.9147
#   • Coarse Accuracy = 95.84% | Val_Accuracy = 86.51% | LossWeight = 0.38
#   • Medium Accuracy = 94.73% | Val_Accuracy = 78.54% | LossWeight = 0.44
#   • Fine   Accuracy = 91.47% | Val_Accuracy = 65.29% | LossWeight = 0.18
#
# Epoch 32: val_prediction_fine_accuracy did not improve from 0.66120
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0815 - prediction_coarse_accuracy: 0.9584 - prediction_medium_accuracy: 0.9473 - prediction_fine_accuracy: 0.9147 - val_loss: 0.1223 - val_prediction_coarse_accuracy: 0.8651 - val_prediction_medium_accuracy: 0.7854 - val_prediction_fine_accuracy: 0.6529 - lr: 3.2353e-04
# Epoch 33/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0806 - prediction_coarse_accuracy: 0.9592 - prediction_medium_accuracy: 0.9475 - prediction_fine_accuracy: 0.9162
#   • Coarse Accuracy = 95.92% | Val_Accuracy = 86.28% | LossWeight = 0.38
#   • Medium Accuracy = 94.75% | Val_Accuracy = 78.66% | LossWeight = 0.44
#   • Fine   Accuracy = 91.62% | Val_Accuracy = 65.29% | LossWeight = 0.18
#
# Epoch 33: val_prediction_fine_accuracy did not improve from 0.66120
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0806 - prediction_coarse_accuracy: 0.9592 - prediction_medium_accuracy: 0.9475 - prediction_fine_accuracy: 0.9162 - val_loss: 0.1234 - val_prediction_coarse_accuracy: 0.8628 - val_prediction_medium_accuracy: 0.7866 - val_prediction_fine_accuracy: 0.6529 - lr: 3.0736e-04
# Epoch 34/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0807 - prediction_coarse_accuracy: 0.9572 - prediction_medium_accuracy: 0.9464 - prediction_fine_accuracy: 0.9165
#   • Coarse Accuracy = 95.72% | Val_Accuracy = 86.51% | LossWeight = 0.39
#   • Medium Accuracy = 94.64% | Val_Accuracy = 78.14% | LossWeight = 0.44
#   • Fine   Accuracy = 91.65% | Val_Accuracy = 64.85% | LossWeight = 0.18
#
# Epoch 34: val_prediction_fine_accuracy did not improve from 0.66120
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0807 - prediction_coarse_accuracy: 0.9572 - prediction_medium_accuracy: 0.9464 - prediction_fine_accuracy: 0.9165 - val_loss: 0.1229 - val_prediction_coarse_accuracy: 0.8651 - val_prediction_medium_accuracy: 0.7814 - val_prediction_fine_accuracy: 0.6485 - lr: 2.9199e-04
# Epoch 35/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0810 - prediction_coarse_accuracy: 0.9583 - prediction_medium_accuracy: 0.9477 - prediction_fine_accuracy: 0.9173
#   • Coarse Accuracy = 95.83% | Val_Accuracy = 86.62% | LossWeight = 0.39
#   • Medium Accuracy = 94.77% | Val_Accuracy = 78.39% | LossWeight = 0.44
#   • Fine   Accuracy = 91.73% | Val_Accuracy = 65.49% | LossWeight = 0.18
#
# Epoch 35: val_prediction_fine_accuracy did not improve from 0.66120
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0810 - prediction_coarse_accuracy: 0.9583 - prediction_medium_accuracy: 0.9477 - prediction_fine_accuracy: 0.9173 - val_loss: 0.1236 - val_prediction_coarse_accuracy: 0.8662 - val_prediction_medium_accuracy: 0.7839 - val_prediction_fine_accuracy: 0.6549 - lr: 2.7739e-04
# Epoch 36/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0799 - prediction_coarse_accuracy: 0.9592 - prediction_medium_accuracy: 0.9486 - prediction_fine_accuracy: 0.9181
#   • Coarse Accuracy = 95.92% | Val_Accuracy = 86.62% | LossWeight = 0.38
#   • Medium Accuracy = 94.86% | Val_Accuracy = 78.52% | LossWeight = 0.44
#   • Fine   Accuracy = 91.81% | Val_Accuracy = 65.63% | LossWeight = 0.18
#
# Epoch 36: val_prediction_fine_accuracy did not improve from 0.66120
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0799 - prediction_coarse_accuracy: 0.9592 - prediction_medium_accuracy: 0.9486 - prediction_fine_accuracy: 0.9181 - val_loss: 0.1232 - val_prediction_coarse_accuracy: 0.8662 - val_prediction_medium_accuracy: 0.7852 - val_prediction_fine_accuracy: 0.6563 - lr: 2.6352e-04
# Epoch 37/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0802 - prediction_coarse_accuracy: 0.9591 - prediction_medium_accuracy: 0.9484 - prediction_fine_accuracy: 0.9189
#   • Coarse Accuracy = 95.91% | Val_Accuracy = 86.90% | LossWeight = 0.38
#   • Medium Accuracy = 94.84% | Val_Accuracy = 78.77% | LossWeight = 0.44
#   • Fine   Accuracy = 91.89% | Val_Accuracy = 65.88% | LossWeight = 0.18
#
# Epoch 37: val_prediction_fine_accuracy did not improve from 0.66120
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0802 - prediction_coarse_accuracy: 0.9591 - prediction_medium_accuracy: 0.9484 - prediction_fine_accuracy: 0.9189 - val_loss: 0.1215 - val_prediction_coarse_accuracy: 0.8690 - val_prediction_medium_accuracy: 0.7877 - val_prediction_fine_accuracy: 0.6588 - lr: 2.5034e-04
# Epoch 38/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0788 - prediction_coarse_accuracy: 0.9604 - prediction_medium_accuracy: 0.9497 - prediction_fine_accuracy: 0.9215
#   • Coarse Accuracy = 96.04% | Val_Accuracy = 86.70% | LossWeight = 0.38
#   • Medium Accuracy = 94.97% | Val_Accuracy = 78.75% | LossWeight = 0.44
#   • Fine   Accuracy = 92.15% | Val_Accuracy = 65.70% | LossWeight = 0.18
#
# Epoch 38: val_prediction_fine_accuracy did not improve from 0.66120
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0788 - prediction_coarse_accuracy: 0.9604 - prediction_medium_accuracy: 0.9497 - prediction_fine_accuracy: 0.9215 - val_loss: 0.1218 - val_prediction_coarse_accuracy: 0.8670 - val_prediction_medium_accuracy: 0.7875 - val_prediction_fine_accuracy: 0.6570 - lr: 2.3783e-04
# Epoch 39/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0787 - prediction_coarse_accuracy: 0.9604 - prediction_medium_accuracy: 0.9507 - prediction_fine_accuracy: 0.9235
#   • Coarse Accuracy = 96.04% | Val_Accuracy = 86.69% | LossWeight = 0.39
#   • Medium Accuracy = 95.07% | Val_Accuracy = 78.74% | LossWeight = 0.44
#   • Fine   Accuracy = 92.35% | Val_Accuracy = 65.90% | LossWeight = 0.18
#
# Epoch 39: val_prediction_fine_accuracy did not improve from 0.66120
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0787 - prediction_coarse_accuracy: 0.9604 - prediction_medium_accuracy: 0.9507 - prediction_fine_accuracy: 0.9235 - val_loss: 0.1231 - val_prediction_coarse_accuracy: 0.8669 - val_prediction_medium_accuracy: 0.7874 - val_prediction_fine_accuracy: 0.6590 - lr: 2.2594e-04
# Epoch 40/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0797 - prediction_coarse_accuracy: 0.9587 - prediction_medium_accuracy: 0.9490 - prediction_fine_accuracy: 0.9228
#   • Coarse Accuracy = 95.87% | Val_Accuracy = 86.95% | LossWeight = 0.39
#   • Medium Accuracy = 94.90% | Val_Accuracy = 78.94% | LossWeight = 0.44
#   • Fine   Accuracy = 92.28% | Val_Accuracy = 65.69% | LossWeight = 0.17
#
# Epoch 40: val_prediction_fine_accuracy did not improve from 0.66120
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0797 - prediction_coarse_accuracy: 0.9587 - prediction_medium_accuracy: 0.9490 - prediction_fine_accuracy: 0.9228 - val_loss: 0.1220 - val_prediction_coarse_accuracy: 0.8695 - val_prediction_medium_accuracy: 0.7894 - val_prediction_fine_accuracy: 0.6569 - lr: 2.1464e-04
# Epoch 41/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0793 - prediction_coarse_accuracy: 0.9601 - prediction_medium_accuracy: 0.9496 - prediction_fine_accuracy: 0.9242
#   • Coarse Accuracy = 96.01% | Val_Accuracy = 86.70% | LossWeight = 0.39
#   • Medium Accuracy = 94.96% | Val_Accuracy = 79.10% | LossWeight = 0.44
#   • Fine   Accuracy = 92.42% | Val_Accuracy = 66.17% | LossWeight = 0.17
#
# Epoch 41: val_prediction_fine_accuracy improved from 0.66120 to 0.66170, saving model to ../../logs/4_CIFAR_100/HD_CapsNet/Mod_3_1\epoch-best.h5
# 781/781 [==============================] - 107s 138ms/step - loss: 0.0793 - prediction_coarse_accuracy: 0.9601 - prediction_medium_accuracy: 0.9496 - prediction_fine_accuracy: 0.9242 - val_loss: 0.1222 - val_prediction_coarse_accuracy: 0.8670 - val_prediction_medium_accuracy: 0.7910 - val_prediction_fine_accuracy: 0.6617 - lr: 2.0391e-04
# Epoch 42/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0785 - prediction_coarse_accuracy: 0.9603 - prediction_medium_accuracy: 0.9501 - prediction_fine_accuracy: 0.9249
#   • Coarse Accuracy = 96.03% | Val_Accuracy = 86.71% | LossWeight = 0.39
#   • Medium Accuracy = 95.01% | Val_Accuracy = 78.75% | LossWeight = 0.44
#   • Fine   Accuracy = 92.49% | Val_Accuracy = 65.90% | LossWeight = 0.17
#
# Epoch 42: val_prediction_fine_accuracy did not improve from 0.66170
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0785 - prediction_coarse_accuracy: 0.9603 - prediction_medium_accuracy: 0.9501 - prediction_fine_accuracy: 0.9249 - val_loss: 0.1223 - val_prediction_coarse_accuracy: 0.8671 - val_prediction_medium_accuracy: 0.7875 - val_prediction_fine_accuracy: 0.6590 - lr: 1.9371e-04
# Epoch 43/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0785 - prediction_coarse_accuracy: 0.9604 - prediction_medium_accuracy: 0.9503 - prediction_fine_accuracy: 0.9252
#   • Coarse Accuracy = 96.04% | Val_Accuracy = 86.69% | LossWeight = 0.39
#   • Medium Accuracy = 95.03% | Val_Accuracy = 78.66% | LossWeight = 0.44
#   • Fine   Accuracy = 92.52% | Val_Accuracy = 65.90% | LossWeight = 0.17
#
# Epoch 43: val_prediction_fine_accuracy did not improve from 0.66170
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0785 - prediction_coarse_accuracy: 0.9604 - prediction_medium_accuracy: 0.9503 - prediction_fine_accuracy: 0.9252 - val_loss: 0.1232 - val_prediction_coarse_accuracy: 0.8669 - val_prediction_medium_accuracy: 0.7866 - val_prediction_fine_accuracy: 0.6590 - lr: 1.8403e-04
# Epoch 44/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0785 - prediction_coarse_accuracy: 0.9598 - prediction_medium_accuracy: 0.9503 - prediction_fine_accuracy: 0.9270
#   • Coarse Accuracy = 95.98% | Val_Accuracy = 86.77% | LossWeight = 0.39
#   • Medium Accuracy = 95.03% | Val_Accuracy = 78.66% | LossWeight = 0.44
#   • Fine   Accuracy = 92.70% | Val_Accuracy = 65.81% | LossWeight = 0.17
#
# Epoch 44: val_prediction_fine_accuracy did not improve from 0.66170
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0785 - prediction_coarse_accuracy: 0.9598 - prediction_medium_accuracy: 0.9503 - prediction_fine_accuracy: 0.9270 - val_loss: 0.1215 - val_prediction_coarse_accuracy: 0.8677 - val_prediction_medium_accuracy: 0.7866 - val_prediction_fine_accuracy: 0.6581 - lr: 1.7482e-04
# Epoch 45/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0776 - prediction_coarse_accuracy: 0.9626 - prediction_medium_accuracy: 0.9529 - prediction_fine_accuracy: 0.9274
#   • Coarse Accuracy = 96.26% | Val_Accuracy = 86.63% | LossWeight = 0.39
#   • Medium Accuracy = 95.29% | Val_Accuracy = 78.76% | LossWeight = 0.44
#   • Fine   Accuracy = 92.74% | Val_Accuracy = 65.96% | LossWeight = 0.18
#
# Epoch 45: val_prediction_fine_accuracy did not improve from 0.66170
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0776 - prediction_coarse_accuracy: 0.9626 - prediction_medium_accuracy: 0.9529 - prediction_fine_accuracy: 0.9274 - val_loss: 0.1220 - val_prediction_coarse_accuracy: 0.8663 - val_prediction_medium_accuracy: 0.7876 - val_prediction_fine_accuracy: 0.6596 - lr: 1.6608e-04
# Epoch 46/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0782 - prediction_coarse_accuracy: 0.9597 - prediction_medium_accuracy: 0.9499 - prediction_fine_accuracy: 0.9264
#   • Coarse Accuracy = 95.97% | Val_Accuracy = 86.79% | LossWeight = 0.39
#   • Medium Accuracy = 94.99% | Val_Accuracy = 79.08% | LossWeight = 0.44
#   • Fine   Accuracy = 92.64% | Val_Accuracy = 66.26% | LossWeight = 0.17
#
# Epoch 46: val_prediction_fine_accuracy improved from 0.66170 to 0.66260, saving model to ../../logs/4_CIFAR_100/HD_CapsNet/Mod_3_1\epoch-best.h5
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0782 - prediction_coarse_accuracy: 0.9597 - prediction_medium_accuracy: 0.9499 - prediction_fine_accuracy: 0.9264 - val_loss: 0.1207 - val_prediction_coarse_accuracy: 0.8679 - val_prediction_medium_accuracy: 0.7908 - val_prediction_fine_accuracy: 0.6626 - lr: 1.5778e-04
# Epoch 47/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0786 - prediction_coarse_accuracy: 0.9614 - prediction_medium_accuracy: 0.9516 - prediction_fine_accuracy: 0.9280
#   • Coarse Accuracy = 96.14% | Val_Accuracy = 86.77% | LossWeight = 0.39
#   • Medium Accuracy = 95.16% | Val_Accuracy = 78.80% | LossWeight = 0.44
#   • Fine   Accuracy = 92.80% | Val_Accuracy = 66.13% | LossWeight = 0.17
#
# Epoch 47: val_prediction_fine_accuracy did not improve from 0.66260
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0786 - prediction_coarse_accuracy: 0.9614 - prediction_medium_accuracy: 0.9516 - prediction_fine_accuracy: 0.9280 - val_loss: 0.1214 - val_prediction_coarse_accuracy: 0.8677 - val_prediction_medium_accuracy: 0.7880 - val_prediction_fine_accuracy: 0.6613 - lr: 1.4989e-04
# Epoch 48/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0777 - prediction_coarse_accuracy: 0.9614 - prediction_medium_accuracy: 0.9527 - prediction_fine_accuracy: 0.9292
#   • Coarse Accuracy = 96.14% | Val_Accuracy = 86.80% | LossWeight = 0.40
#   • Medium Accuracy = 95.27% | Val_Accuracy = 78.91% | LossWeight = 0.44
#   • Fine   Accuracy = 92.92% | Val_Accuracy = 65.83% | LossWeight = 0.17
#
# Epoch 48: val_prediction_fine_accuracy did not improve from 0.66260
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0777 - prediction_coarse_accuracy: 0.9614 - prediction_medium_accuracy: 0.9527 - prediction_fine_accuracy: 0.9292 - val_loss: 0.1205 - val_prediction_coarse_accuracy: 0.8680 - val_prediction_medium_accuracy: 0.7891 - val_prediction_fine_accuracy: 0.6583 - lr: 1.4240e-04
# Epoch 49/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0774 - prediction_coarse_accuracy: 0.9616 - prediction_medium_accuracy: 0.9514 - prediction_fine_accuracy: 0.9301
#   • Coarse Accuracy = 96.16% | Val_Accuracy = 87.07% | LossWeight = 0.39
#   • Medium Accuracy = 95.14% | Val_Accuracy = 78.75% | LossWeight = 0.44
#   • Fine   Accuracy = 93.01% | Val_Accuracy = 66.34% | LossWeight = 0.17
#
# Epoch 49: val_prediction_fine_accuracy improved from 0.66260 to 0.66340, saving model to ../../logs/4_CIFAR_100/HD_CapsNet/Mod_3_1\epoch-best.h5
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0774 - prediction_coarse_accuracy: 0.9616 - prediction_medium_accuracy: 0.9514 - prediction_fine_accuracy: 0.9301 - val_loss: 0.1209 - val_prediction_coarse_accuracy: 0.8707 - val_prediction_medium_accuracy: 0.7875 - val_prediction_fine_accuracy: 0.6634 - lr: 1.3528e-04
# Epoch 50/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0775 - prediction_coarse_accuracy: 0.9631 - prediction_medium_accuracy: 0.9524 - prediction_fine_accuracy: 0.9301
#   • Coarse Accuracy = 96.31% | Val_Accuracy = 86.70% | LossWeight = 0.38
#   • Medium Accuracy = 95.24% | Val_Accuracy = 78.95% | LossWeight = 0.45
#   • Fine   Accuracy = 93.01% | Val_Accuracy = 66.18% | LossWeight = 0.17
#
# Epoch 50: val_prediction_fine_accuracy did not improve from 0.66340
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0775 - prediction_coarse_accuracy: 0.9631 - prediction_medium_accuracy: 0.9524 - prediction_fine_accuracy: 0.9301 - val_loss: 0.1211 - val_prediction_coarse_accuracy: 0.8670 - val_prediction_medium_accuracy: 0.7895 - val_prediction_fine_accuracy: 0.6618 - lr: 1.2851e-04
# Epoch 51/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0772 - prediction_coarse_accuracy: 0.9618 - prediction_medium_accuracy: 0.9524 - prediction_fine_accuracy: 0.9295
#   • Coarse Accuracy = 96.18% | Val_Accuracy = 87.03% | LossWeight = 0.39
#   • Medium Accuracy = 95.24% | Val_Accuracy = 79.18% | LossWeight = 0.44
#   • Fine   Accuracy = 92.95% | Val_Accuracy = 66.32% | LossWeight = 0.17
#
# Epoch 51: val_prediction_fine_accuracy did not improve from 0.66340
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0772 - prediction_coarse_accuracy: 0.9618 - prediction_medium_accuracy: 0.9524 - prediction_fine_accuracy: 0.9295 - val_loss: 0.1193 - val_prediction_coarse_accuracy: 0.8703 - val_prediction_medium_accuracy: 0.7918 - val_prediction_fine_accuracy: 0.6632 - lr: 1.2209e-04
# Epoch 52/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0780 - prediction_coarse_accuracy: 0.9618 - prediction_medium_accuracy: 0.9516 - prediction_fine_accuracy: 0.9302
#   • Coarse Accuracy = 96.18% | Val_Accuracy = 86.86% | LossWeight = 0.39
#   • Medium Accuracy = 95.16% | Val_Accuracy = 79.04% | LossWeight = 0.44
#   • Fine   Accuracy = 93.02% | Val_Accuracy = 66.09% | LossWeight = 0.17
#
# Epoch 52: val_prediction_fine_accuracy did not improve from 0.66340
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0780 - prediction_coarse_accuracy: 0.9618 - prediction_medium_accuracy: 0.9516 - prediction_fine_accuracy: 0.9302 - val_loss: 0.1207 - val_prediction_coarse_accuracy: 0.8686 - val_prediction_medium_accuracy: 0.7904 - val_prediction_fine_accuracy: 0.6609 - lr: 1.1598e-04
# Epoch 53/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0777 - prediction_coarse_accuracy: 0.9634 - prediction_medium_accuracy: 0.9551 - prediction_fine_accuracy: 0.9320
#   • Coarse Accuracy = 96.34% | Val_Accuracy = 86.88% | LossWeight = 0.39
#   • Medium Accuracy = 95.51% | Val_Accuracy = 78.90% | LossWeight = 0.44
#   • Fine   Accuracy = 93.20% | Val_Accuracy = 66.29% | LossWeight = 0.17
#
# Epoch 53: val_prediction_fine_accuracy did not improve from 0.66340
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0777 - prediction_coarse_accuracy: 0.9634 - prediction_medium_accuracy: 0.9551 - prediction_fine_accuracy: 0.9320 - val_loss: 0.1196 - val_prediction_coarse_accuracy: 0.8688 - val_prediction_medium_accuracy: 0.7890 - val_prediction_fine_accuracy: 0.6629 - lr: 1.1018e-04
# Epoch 54/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0782 - prediction_coarse_accuracy: 0.9615 - prediction_medium_accuracy: 0.9523 - prediction_fine_accuracy: 0.9289
#   • Coarse Accuracy = 96.15% | Val_Accuracy = 86.93% | LossWeight = 0.39
#   • Medium Accuracy = 95.23% | Val_Accuracy = 79.00% | LossWeight = 0.44
#   • Fine   Accuracy = 92.89% | Val_Accuracy = 66.14% | LossWeight = 0.17
#
# Epoch 54: val_prediction_fine_accuracy did not improve from 0.66340
# 781/781 [==============================] - 107s 138ms/step - loss: 0.0782 - prediction_coarse_accuracy: 0.9615 - prediction_medium_accuracy: 0.9523 - prediction_fine_accuracy: 0.9289 - val_loss: 0.1204 - val_prediction_coarse_accuracy: 0.8693 - val_prediction_medium_accuracy: 0.7900 - val_prediction_fine_accuracy: 0.6614 - lr: 1.0467e-04
# Epoch 55/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0789 - prediction_coarse_accuracy: 0.9595 - prediction_medium_accuracy: 0.9497 - prediction_fine_accuracy: 0.9284
#   • Coarse Accuracy = 95.95% | Val_Accuracy = 87.04% | LossWeight = 0.40
#   • Medium Accuracy = 94.97% | Val_Accuracy = 79.02% | LossWeight = 0.44
#   • Fine   Accuracy = 92.84% | Val_Accuracy = 66.22% | LossWeight = 0.16
#
# Epoch 55: val_prediction_fine_accuracy did not improve from 0.66340
# 781/781 [==============================] - 104s 133ms/step - loss: 0.0789 - prediction_coarse_accuracy: 0.9595 - prediction_medium_accuracy: 0.9497 - prediction_fine_accuracy: 0.9284 - val_loss: 0.1204 - val_prediction_coarse_accuracy: 0.8704 - val_prediction_medium_accuracy: 0.7902 - val_prediction_fine_accuracy: 0.6622 - lr: 9.9440e-05
# Epoch 56/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0788 - prediction_coarse_accuracy: 0.9612 - prediction_medium_accuracy: 0.9510 - prediction_fine_accuracy: 0.9295
#   • Coarse Accuracy = 96.12% | Val_Accuracy = 86.92% | LossWeight = 0.39
#   • Medium Accuracy = 95.10% | Val_Accuracy = 79.06% | LossWeight = 0.44
#   • Fine   Accuracy = 92.95% | Val_Accuracy = 66.04% | LossWeight = 0.17
#
# Epoch 56: val_prediction_fine_accuracy did not improve from 0.66340
# 781/781 [==============================] - 107s 138ms/step - loss: 0.0788 - prediction_coarse_accuracy: 0.9612 - prediction_medium_accuracy: 0.9510 - prediction_fine_accuracy: 0.9295 - val_loss: 0.1203 - val_prediction_coarse_accuracy: 0.8692 - val_prediction_medium_accuracy: 0.7906 - val_prediction_fine_accuracy: 0.6604 - lr: 9.4468e-05
# Epoch 57/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0776 - prediction_coarse_accuracy: 0.9618 - prediction_medium_accuracy: 0.9522 - prediction_fine_accuracy: 0.9301
#   • Coarse Accuracy = 96.18% | Val_Accuracy = 86.97% | LossWeight = 0.39
#   • Medium Accuracy = 95.22% | Val_Accuracy = 79.26% | LossWeight = 0.44
#   • Fine   Accuracy = 93.01% | Val_Accuracy = 66.18% | LossWeight = 0.17
#
# Epoch 57: val_prediction_fine_accuracy did not improve from 0.66340
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0776 - prediction_coarse_accuracy: 0.9618 - prediction_medium_accuracy: 0.9522 - prediction_fine_accuracy: 0.9301 - val_loss: 0.1197 - val_prediction_coarse_accuracy: 0.8697 - val_prediction_medium_accuracy: 0.7926 - val_prediction_fine_accuracy: 0.6618 - lr: 8.9745e-05
# Epoch 58/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0775 - prediction_coarse_accuracy: 0.9626 - prediction_medium_accuracy: 0.9529 - prediction_fine_accuracy: 0.9329
#   • Coarse Accuracy = 96.26% | Val_Accuracy = 87.05% | LossWeight = 0.39
#   • Medium Accuracy = 95.29% | Val_Accuracy = 79.09% | LossWeight = 0.44
#   • Fine   Accuracy = 93.29% | Val_Accuracy = 66.26% | LossWeight = 0.16
#
# ...
# 781/781 [==============================] - 108s 138ms/step - loss: 0.0774 - prediction_coarse_accuracy: 0.9620 - prediction_medium_accuracy: 0.9529 - prediction_fine_accuracy: 0.9333 - val_loss: 0.1189 - val_prediction_coarse_accuracy: 0.8704 - val_prediction_medium_accuracy: 0.7924 - val_prediction_fine_accuracy: 0.6649 - lr: 2.6205e-05
# Epoch 82/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0766 - prediction_coarse_accuracy: 0.9653 - prediction_medium_accuracy: 0.9555 - prediction_fine_accuracy: 0.9377
#   • Coarse Accuracy = 96.53% | Val_Accuracy = 86.97% | LossWeight = 0.39
#   • Medium Accuracy = 95.55% | Val_Accuracy = 79.32% | LossWeight = 0.45
#   • Fine   Accuracy = 93.77% | Val_Accuracy = 66.63% | LossWeight = 0.16
#
# Epoch 82: val_prediction_fine_accuracy improved from 0.66490 to 0.66630, saving model to ../../logs/4_CIFAR_100/HD_CapsNet/Mod_3_1\epoch-best.h5
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0766 - prediction_coarse_accuracy: 0.9653 - prediction_medium_accuracy: 0.9555 - prediction_fine_accuracy: 0.9377 - val_loss: 0.1190 - val_prediction_coarse_accuracy: 0.8697 - val_prediction_medium_accuracy: 0.7932 - val_prediction_fine_accuracy: 0.6663 - lr: 2.4894e-05
# Epoch 83/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0764 - prediction_coarse_accuracy: 0.9625 - prediction_medium_accuracy: 0.9537 - prediction_fine_accuracy: 0.9346
#   • Coarse Accuracy = 96.25% | Val_Accuracy = 86.96% | LossWeight = 0.40
#   • Medium Accuracy = 95.37% | Val_Accuracy = 79.29% | LossWeight = 0.44
#   • Fine   Accuracy = 93.46% | Val_Accuracy = 66.51% | LossWeight = 0.16
#
# Epoch 83: val_prediction_fine_accuracy did not improve from 0.66630
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0764 - prediction_coarse_accuracy: 0.9625 - prediction_medium_accuracy: 0.9537 - prediction_fine_accuracy: 0.9346 - val_loss: 0.1181 - val_prediction_coarse_accuracy: 0.8696 - val_prediction_medium_accuracy: 0.7929 - val_prediction_fine_accuracy: 0.6651 - lr: 2.3650e-05
# Epoch 84/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0768 - prediction_coarse_accuracy: 0.9624 - prediction_medium_accuracy: 0.9528 - prediction_fine_accuracy: 0.9334
#   • Coarse Accuracy = 96.24% | Val_Accuracy = 86.92% | LossWeight = 0.39
#   • Medium Accuracy = 95.28% | Val_Accuracy = 79.25% | LossWeight = 0.44
#   • Fine   Accuracy = 93.34% | Val_Accuracy = 66.37% | LossWeight = 0.16
#
# Epoch 84: val_prediction_fine_accuracy did not improve from 0.66630
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0768 - prediction_coarse_accuracy: 0.9624 - prediction_medium_accuracy: 0.9528 - prediction_fine_accuracy: 0.9334 - val_loss: 0.1194 - val_prediction_coarse_accuracy: 0.8692 - val_prediction_medium_accuracy: 0.7925 - val_prediction_fine_accuracy: 0.6637 - lr: 2.2467e-05
# Epoch 85/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0764 - prediction_coarse_accuracy: 0.9635 - prediction_medium_accuracy: 0.9548 - prediction_fine_accuracy: 0.9360
#   • Coarse Accuracy = 96.35% | Val_Accuracy = 86.90% | LossWeight = 0.40
#   • Medium Accuracy = 95.48% | Val_Accuracy = 79.26% | LossWeight = 0.44
#   • Fine   Accuracy = 93.60% | Val_Accuracy = 66.34% | LossWeight = 0.16
#
# Epoch 85: val_prediction_fine_accuracy did not improve from 0.66630
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0764 - prediction_coarse_accuracy: 0.9635 - prediction_medium_accuracy: 0.9548 - prediction_fine_accuracy: 0.9360 - val_loss: 0.1188 - val_prediction_coarse_accuracy: 0.8690 - val_prediction_medium_accuracy: 0.7926 - val_prediction_fine_accuracy: 0.6634 - lr: 2.1344e-05
# Epoch 86/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0763 - prediction_coarse_accuracy: 0.9628 - prediction_medium_accuracy: 0.9540 - prediction_fine_accuracy: 0.9356
#   • Coarse Accuracy = 96.28% | Val_Accuracy = 86.98% | LossWeight = 0.40
#   • Medium Accuracy = 95.40% | Val_Accuracy = 79.38% | LossWeight = 0.44
#   • Fine   Accuracy = 93.56% | Val_Accuracy = 66.44% | LossWeight = 0.16
#
# Epoch 86: val_prediction_fine_accuracy did not improve from 0.66630
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0763 - prediction_coarse_accuracy: 0.9628 - prediction_medium_accuracy: 0.9540 - prediction_fine_accuracy: 0.9356 - val_loss: 0.1187 - val_prediction_coarse_accuracy: 0.8698 - val_prediction_medium_accuracy: 0.7938 - val_prediction_fine_accuracy: 0.6644 - lr: 2.0277e-05
# Epoch 87/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0772 - prediction_coarse_accuracy: 0.9622 - prediction_medium_accuracy: 0.9534 - prediction_fine_accuracy: 0.9340
#   • Coarse Accuracy = 96.22% | Val_Accuracy = 86.88% | LossWeight = 0.40
#   • Medium Accuracy = 95.34% | Val_Accuracy = 79.43% | LossWeight = 0.44
#   • Fine   Accuracy = 93.40% | Val_Accuracy = 66.35% | LossWeight = 0.16
#
# Epoch 87: val_prediction_fine_accuracy did not improve from 0.66630
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0772 - prediction_coarse_accuracy: 0.9622 - prediction_medium_accuracy: 0.9534 - prediction_fine_accuracy: 0.9340 - val_loss: 0.1189 - val_prediction_coarse_accuracy: 0.8688 - val_prediction_medium_accuracy: 0.7943 - val_prediction_fine_accuracy: 0.6635 - lr: 1.9263e-05
# Epoch 88/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0771 - prediction_coarse_accuracy: 0.9638 - prediction_medium_accuracy: 0.9543 - prediction_fine_accuracy: 0.9354
#   • Coarse Accuracy = 96.38% | Val_Accuracy = 86.90% | LossWeight = 0.39
#   • Medium Accuracy = 95.43% | Val_Accuracy = 79.32% | LossWeight = 0.45
#   • Fine   Accuracy = 93.54% | Val_Accuracy = 66.34% | LossWeight = 0.16
#
# Epoch 88: val_prediction_fine_accuracy did not improve from 0.66630
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0771 - prediction_coarse_accuracy: 0.9638 - prediction_medium_accuracy: 0.9543 - prediction_fine_accuracy: 0.9354 - val_loss: 0.1188 - val_prediction_coarse_accuracy: 0.8690 - val_prediction_medium_accuracy: 0.7932 - val_prediction_fine_accuracy: 0.6634 - lr: 1.8300e-05
# Epoch 89/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0781 - prediction_coarse_accuracy: 0.9620 - prediction_medium_accuracy: 0.9525 - prediction_fine_accuracy: 0.9323
#   • Coarse Accuracy = 96.20% | Val_Accuracy = 86.96% | LossWeight = 0.39
#   • Medium Accuracy = 95.25% | Val_Accuracy = 79.17% | LossWeight = 0.44
#   • Fine   Accuracy = 93.23% | Val_Accuracy = 66.31% | LossWeight = 0.16
#
# Epoch 89: val_prediction_fine_accuracy did not improve from 0.66630
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0781 - prediction_coarse_accuracy: 0.9620 - prediction_medium_accuracy: 0.9525 - prediction_fine_accuracy: 0.9323 - val_loss: 0.1182 - val_prediction_coarse_accuracy: 0.8696 - val_prediction_medium_accuracy: 0.7917 - val_prediction_fine_accuracy: 0.6631 - lr: 1.7385e-05
# Epoch 90/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0765 - prediction_coarse_accuracy: 0.9634 - prediction_medium_accuracy: 0.9545 - prediction_fine_accuracy: 0.9355
#   • Coarse Accuracy = 96.34% | Val_Accuracy = 86.94% | LossWeight = 0.40
#   • Medium Accuracy = 95.45% | Val_Accuracy = 79.22% | LossWeight = 0.44
#   • Fine   Accuracy = 93.55% | Val_Accuracy = 66.54% | LossWeight = 0.16
#
# Epoch 90: val_prediction_fine_accuracy did not improve from 0.66630
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0765 - prediction_coarse_accuracy: 0.9634 - prediction_medium_accuracy: 0.9545 - prediction_fine_accuracy: 0.9355 - val_loss: 0.1183 - val_prediction_coarse_accuracy: 0.8694 - val_prediction_medium_accuracy: 0.7922 - val_prediction_fine_accuracy: 0.6654 - lr: 1.6515e-05
# Epoch 91/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0770 - prediction_coarse_accuracy: 0.9620 - prediction_medium_accuracy: 0.9532 - prediction_fine_accuracy: 0.9335
#   • Coarse Accuracy = 96.20% | Val_Accuracy = 86.81% | LossWeight = 0.40
#   • Medium Accuracy = 95.32% | Val_Accuracy = 79.22% | LossWeight = 0.44
#   • Fine   Accuracy = 93.35% | Val_Accuracy = 66.43% | LossWeight = 0.16
#
# Epoch 91: val_prediction_fine_accuracy did not improve from 0.66630
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0770 - prediction_coarse_accuracy: 0.9620 - prediction_medium_accuracy: 0.9532 - prediction_fine_accuracy: 0.9335 - val_loss: 0.1188 - val_prediction_coarse_accuracy: 0.8681 - val_prediction_medium_accuracy: 0.7922 - val_prediction_fine_accuracy: 0.6643 - lr: 1.5690e-05
# Epoch 92/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0771 - prediction_coarse_accuracy: 0.9629 - prediction_medium_accuracy: 0.9535 - prediction_fine_accuracy: 0.9347
#   • Coarse Accuracy = 96.29% | Val_Accuracy = 86.98% | LossWeight = 0.39
#   • Medium Accuracy = 95.35% | Val_Accuracy = 79.19% | LossWeight = 0.44
#   • Fine   Accuracy = 93.47% | Val_Accuracy = 66.37% | LossWeight = 0.16
#
# Epoch 92: val_prediction_fine_accuracy did not improve from 0.66630
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0771 - prediction_coarse_accuracy: 0.9629 - prediction_medium_accuracy: 0.9535 - prediction_fine_accuracy: 0.9347 - val_loss: 0.1185 - val_prediction_coarse_accuracy: 0.8698 - val_prediction_medium_accuracy: 0.7919 - val_prediction_fine_accuracy: 0.6637 - lr: 1.4905e-05
# Epoch 93/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0765 - prediction_coarse_accuracy: 0.9640 - prediction_medium_accuracy: 0.9546 - prediction_fine_accuracy: 0.9349
#   • Coarse Accuracy = 96.40% | Val_Accuracy = 86.85% | LossWeight = 0.39
#   • Medium Accuracy = 95.46% | Val_Accuracy = 79.27% | LossWeight = 0.44
#   • Fine   Accuracy = 93.49% | Val_Accuracy = 66.28% | LossWeight = 0.17
#
# Epoch 93: val_prediction_fine_accuracy did not improve from 0.66630
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0765 - prediction_coarse_accuracy: 0.9640 - prediction_medium_accuracy: 0.9546 - prediction_fine_accuracy: 0.9349 - val_loss: 0.1184 - val_prediction_coarse_accuracy: 0.8685 - val_prediction_medium_accuracy: 0.7927 - val_prediction_fine_accuracy: 0.6628 - lr: 1.4160e-05
# Epoch 94/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0769 - prediction_coarse_accuracy: 0.9625 - prediction_medium_accuracy: 0.9538 - prediction_fine_accuracy: 0.9345
#   • Coarse Accuracy = 96.25% | Val_Accuracy = 86.98% | LossWeight = 0.40
#   • Medium Accuracy = 95.38% | Val_Accuracy = 79.19% | LossWeight = 0.44
#   • Fine   Accuracy = 93.45% | Val_Accuracy = 66.36% | LossWeight = 0.16
#
# Epoch 94: val_prediction_fine_accuracy did not improve from 0.66630
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0769 - prediction_coarse_accuracy: 0.9625 - prediction_medium_accuracy: 0.9538 - prediction_fine_accuracy: 0.9345 - val_loss: 0.1181 - val_prediction_coarse_accuracy: 0.8698 - val_prediction_medium_accuracy: 0.7919 - val_prediction_fine_accuracy: 0.6636 - lr: 1.3452e-05
# Epoch 95/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0767 - prediction_coarse_accuracy: 0.9640 - prediction_medium_accuracy: 0.9539 - prediction_fine_accuracy: 0.9345
#   • Coarse Accuracy = 96.40% | Val_Accuracy = 86.90% | LossWeight = 0.39
#   • Medium Accuracy = 95.39% | Val_Accuracy = 79.26% | LossWeight = 0.45
#   • Fine   Accuracy = 93.45% | Val_Accuracy = 66.38% | LossWeight = 0.16
#
# Epoch 95: val_prediction_fine_accuracy did not improve from 0.66630
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0767 - prediction_coarse_accuracy: 0.9640 - prediction_medium_accuracy: 0.9539 - prediction_fine_accuracy: 0.9345 - val_loss: 0.1188 - val_prediction_coarse_accuracy: 0.8690 - val_prediction_medium_accuracy: 0.7926 - val_prediction_fine_accuracy: 0.6638 - lr: 1.2779e-05
# Epoch 96/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0766 - prediction_coarse_accuracy: 0.9622 - prediction_medium_accuracy: 0.9527 - prediction_fine_accuracy: 0.9337
#   • Coarse Accuracy = 96.22% | Val_Accuracy = 86.92% | LossWeight = 0.39
#   • Medium Accuracy = 95.27% | Val_Accuracy = 79.28% | LossWeight = 0.44
#   • Fine   Accuracy = 93.37% | Val_Accuracy = 66.36% | LossWeight = 0.16
#
# Epoch 96: val_prediction_fine_accuracy did not improve from 0.66630
# 781/781 [==============================] - 107s 137ms/step - loss: 0.0766 - prediction_coarse_accuracy: 0.9622 - prediction_medium_accuracy: 0.9527 - prediction_fine_accuracy: 0.9337 - val_loss: 0.1180 - val_prediction_coarse_accuracy: 0.8692 - val_prediction_medium_accuracy: 0.7928 - val_prediction_fine_accuracy: 0.6636 - lr: 1.2140e-05
# Epoch 97/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0761 - prediction_coarse_accuracy: 0.9630 - prediction_medium_accuracy: 0.9541 - prediction_fine_accuracy: 0.9362
#   • Coarse Accuracy = 96.30% | Val_Accuracy = 87.00% | LossWeight = 0.40
#   • Medium Accuracy = 95.41% | Val_Accuracy = 79.25% | LossWeight = 0.44
#   • Fine   Accuracy = 93.62% | Val_Accuracy = 66.45% | LossWeight = 0.16
#
# Epoch 97: val_prediction_fine_accuracy did not improve from 0.66630
# 781/781 [==============================] - 108s 138ms/step - loss: 0.0761 - prediction_coarse_accuracy: 0.9630 - prediction_medium_accuracy: 0.9541 - prediction_fine_accuracy: 0.9362 - val_loss: 0.1185 - val_prediction_coarse_accuracy: 0.8700 - val_prediction_medium_accuracy: 0.7925 - val_prediction_fine_accuracy: 0.6645 - lr: 1.1533e-05
# Epoch 98/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0769 - prediction_coarse_accuracy: 0.9630 - prediction_medium_accuracy: 0.9542 - prediction_fine_accuracy: 0.9346
#   • Coarse Accuracy = 96.30% | Val_Accuracy = 86.94% | LossWeight = 0.40
#   • Medium Accuracy = 95.42% | Val_Accuracy = 79.22% | LossWeight = 0.44
#   • Fine   Accuracy = 93.46% | Val_Accuracy = 66.47% | LossWeight = 0.16
#
# Epoch 98: val_prediction_fine_accuracy did not improve from 0.66630
# 781/781 [==============================] - 108s 138ms/step - loss: 0.0769 - prediction_coarse_accuracy: 0.9630 - prediction_medium_accuracy: 0.9542 - prediction_fine_accuracy: 0.9346 - val_loss: 0.1188 - val_prediction_coarse_accuracy: 0.8694 - val_prediction_medium_accuracy: 0.7922 - val_prediction_fine_accuracy: 0.6647 - lr: 1.0957e-05
# Epoch 99/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0764 - prediction_coarse_accuracy: 0.9632 - prediction_medium_accuracy: 0.9542 - prediction_fine_accuracy: 0.9352
#   • Coarse Accuracy = 96.32% | Val_Accuracy = 86.93% | LossWeight = 0.40
#   • Medium Accuracy = 95.42% | Val_Accuracy = 79.27% | LossWeight = 0.44
#   • Fine   Accuracy = 93.52% | Val_Accuracy = 66.56% | LossWeight = 0.16
#
# Epoch 99: val_prediction_fine_accuracy did not improve from 0.66630
# 781/781 [==============================] - 108s 138ms/step - loss: 0.0764 - prediction_coarse_accuracy: 0.9632 - prediction_medium_accuracy: 0.9542 - prediction_fine_accuracy: 0.9352 - val_loss: 0.1186 - val_prediction_coarse_accuracy: 0.8693 - val_prediction_medium_accuracy: 0.7927 - val_prediction_fine_accuracy: 0.6656 - lr: 1.0409e-05
# Epoch 100/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0774 - prediction_coarse_accuracy: 0.9615 - prediction_medium_accuracy: 0.9531 - prediction_fine_accuracy: 0.9331
#   • Coarse Accuracy = 96.15% | Val_Accuracy = 86.93% | LossWeight = 0.40
#   • Medium Accuracy = 95.31% | Val_Accuracy = 79.31% | LossWeight = 0.44
#   • Fine   Accuracy = 93.31% | Val_Accuracy = 66.38% | LossWeight = 0.16
#
# Epoch 100: val_prediction_fine_accuracy did not improve from 0.66630
# 781/781 [==============================] - 107s 138ms/step - loss: 0.0774 - prediction_coarse_accuracy: 0.9615 - prediction_medium_accuracy: 0.9531 - prediction_fine_accuracy: 0.9331 - val_loss: 0.1184 - val_prediction_coarse_accuracy: 0.8693 - val_prediction_medium_accuracy: 0.7931 - val_prediction_fine_accuracy: 0.6638 - lr: 9.8884e-06

# %%
history_dict = history.history

# %%
plotter = tfdocs.plots.HistoryPlotter()
plotter.plot({"Coarse": history}, metric = "prediction_coarse_accuracy")
plotter.plot({"Medium": history}, metric = "prediction_medium_accuracy")
plotter.plot({"Fine": history}, metric = "prediction_fine_accuracy")
plt.title("Model Accuracy")
plt.ylim([0,1])
# Out:
# (0.0, 1.0)

# %%
plotter = tfdocs.plots.HistoryPlotter()
plotter.plot({"loss": history}, metric = "loss")
plt.title("Model Loss")
plt.ylim([0,1])
# Out:
# (0.0, 1.0)

# %% [markdown]
# ## Model Analysis

# %%
final_model = keras.Model(model.inputs[:1], model.output)

lossfn = models.MarginLoss()
final_model.compile(optimizer='adam', 
                    loss={'prediction_fine' : lossfn,
                          'prediction_medium' : lossfn,
                          'prediction_coarse' : lossfn},

                    loss_weights={'prediction_fine' : lossweight['fine_lw'],
                                  'prediction_medium' : lossweight['medium_lw'],
                                  'prediction_coarse' : lossweight['coarse_lw']},

                    metrics={'prediction_fine': 'accuracy',
                             'prediction_medium': 'accuracy',
                             'prediction_coarse': 'accuracy'
                            }
                   )

# %%
model_analysis = models.model_analysis(final_model, dataset)
results = model_analysis.evaluate()
predictions = model_analysis.prediction()
# Out:
# 313/313 [==============================] - 10s 27ms/step - loss: 0.1512 - prediction_coarse_loss: 0.0953 - prediction_medium_loss: 0.1569 - prediction_fine_loss: 0.2737 - prediction_coarse_accuracy: 0.8693 - prediction_medium_accuracy: 0.7931 - prediction_fine_accuracy: 0.6638
# 1. loss ==> 0.15116655826568604
# 2. prediction_coarse_loss ==> 0.09529387205839157
# 3. prediction_medium_loss ==> 0.15685728192329407
# 4. prediction_fine_loss ==> 0.2737105190753937
# 5. prediction_coarse_accuracy ==> 0.8693000078201294
# 6. prediction_medium_accuracy ==> 0.7930999994277954
# 7. prediction_fine_accuracy ==> 0.6638000011444092
# 313/313 [==============================] - 7s 21ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
true_label = [dataset['y_test_coarse'],dataset['y_test_medium'],dataset['y_test_fine']]
pred_label = [predictions[0],predictions[1],predictions[2]]
metrics.lvl_wise_metric(true_label,pred_label,directory)
# Out:
#   • Confusion_Matrix
#
#   • COARSE LEVEL
# [[ 717   14   20   23  193   13   10   10]
#  [   8 1370   28   31   39   18    1    5]
#  [   8   24 1366   18   33   11    9   31]
#  [  22   36   28  799  103    1    1   10]
#  [  94   18   44   81 2221   12   14   16]
#  [   9   19   23    6   24  894    1   24]
#  [   0    7   15   11   40    2  421    4]
#  [   7    4   31    9   23   21    0  905]]
#
#   • MEDIUM LEVEL
# [[310  31   0   1   0   4   3   2  24   2   3  15  31  14   5  20  27   3
#     2   3]
#  [ 25 375   6   5   6   5   1   4   4   3   4   6   6   6   7  18  12   0
#     3   4]
#  [  0   5 447   5  18   1   1  10   0   1   1   1   1   3   2   2   1   1
#     0   0]
#  [  0   2   4 403   9  40   6   1   1   4   0   1   4   6   3   5   0   0
#     3   8]
#  [  1   2  20   9 421   6   0   4   5   0   1   4   4  14   1   4   3   1
#     0   0]
#  [  2   2   2  28   6 395  20   3   0   6   2   3   0   7   7   2   0   3
#     2  10]
#  [  2   3   1  10   2  24 433   0   1   1   1   1   2   4   3   2   0   1
#     5   4]
#  [  3   7  16   2   5   4   2 403   6   1   0   2   4  23   0  14   4   1
#     2   1]
#  [ 19   2   0   2   2   2   1   2 386   1   1  24  25   6   2   9  15   0
#     0   1]
#  [  1   2   0   0   0   6   5   1   0 449  10   2   1   1   0   1   1   3
#     6  11]
#  [  2   6   1   2   1   4   0   3   4  12 434   1   1   2   1   2   2  17
#     1   4]
#  [ 12   2   2   1   3   5   1   1  29   1   1 380  18   0   7  15  20   1
#     0   1]
#  [ 10   3   3   1   2   4   0   3  33   1   1  18 363  11   2  11  28   0
#     4   2]
#  [  5   8   7   6  14   8   2  36   7   0   0   5   5 352   3  31   4   1
#     3   3]
#  [  2   2   2   3   6   7   5   4   5   1   1   7   4   5 436   4   2   0
#     3   1]
#  [ 18  20   1   7   4   6   1  19  16   4   3  13  16  39   3 309  12   3
#     4   2]
#  [ 13   9   3   2   4   5   5  11  21   2   0  17  30  13   3  23 335   0
#     0   4]
#  [  0   1   1   0   1   2   0   2   1   5  10   0   3   2   0   1   1 467
#     2   1]
#  [  1   1   0   1   0   9   5   1   2   9   1   1   2   3   0   1   0   0
#   431  32]
#  [  3   1   0   3   2   8   2   4   2  14   1   2   1   2   0   5   1   1
#    46 402]]
#
#   • FINE LEVEL
# [[81  0  0 ...  0  0  0]
#  [ 0 74  0 ...  0  0  0]
#  [ 0  0 53 ...  0  4  0]
#  ...
#  [ 0  0  0 ... 66  0  0]
#  [ 0  0  4 ...  0 41  1]
#  [ 0  0  0 ...  0  0 73]]
#
#   • Classification Report
#
#
#   • COARSE LEVEL
#               precision    recall  f1-score   support
#
#            0    0.82890   0.71700   0.76890      1000
#            1    0.91823   0.91333   0.91578      1500
#            2    0.87846   0.91067   0.89427      1500
#            3    0.81697   0.79900   0.80789      1000
#            4    0.82997   0.88840   0.85819      2500
#            5    0.91975   0.89400   0.90669      1000
#            6    0.92123   0.84200   0.87983       500
#            7    0.90050   0.90500   0.90274      1000
#
#     accuracy                        0.86930     10000
#    macro avg    0.87675   0.85867   0.86679     10000
# weighted avg    0.86967   0.86930   0.86867     10000
#
#
#   • MEDIUM LEVEL
#               precision    recall  f1-score   support
#
#            0    0.72261   0.62000   0.66738       500
#            1    0.77479   0.75000   0.76220       500
#            2    0.86628   0.89400   0.87992       500
#            3    0.82077   0.80600   0.81332       500
#            4    0.83202   0.84200   0.83698       500
#            5    0.72477   0.79000   0.75598       500
#            6    0.87830   0.86600   0.87210       500
#            7    0.78405   0.80600   0.79487       500
#            8    0.70567   0.77200   0.73734       500
#            9    0.86847   0.89800   0.88299       500
#           10    0.91368   0.86800   0.89026       500
#           11    0.75547   0.76000   0.75773       500
#           12    0.69674   0.72600   0.71107       500
#           13    0.68616   0.70400   0.69497       500
#           14    0.89897   0.87200   0.88528       500
#           15    0.64509   0.61800   0.63126       500
#           16    0.71581   0.67000   0.69215       500
#           17    0.92843   0.93400   0.93121       500
#           18    0.83366   0.86200   0.84759       500
#           19    0.81377   0.80400   0.80885       500
#
#     accuracy                        0.79310     10000
#    macro avg    0.79327   0.79310   0.79267     10000
# weighted avg    0.79327   0.79310   0.79267     10000
#
#
#   • FINE LEVEL
#               precision    recall  f1-score   support
#
#            0    0.89011   0.81000   0.84817       100
#            1    0.82222   0.74000   0.77895       100
#            2    0.51456   0.53000   0.52217       100
#            3    0.51111   0.46000   0.48421       100
#            4    0.51852   0.42000   0.46409       100
#            5    0.69388   0.68000   0.68687       100
#            6    0.73118   0.68000   0.70466       100
#            7    0.65741   0.71000   0.68269       100
#            8    0.84375   0.81000   0.82653       100
#            9    0.81915   0.77000   0.79381       100
#           10    0.59783   0.55000   0.57292       100
#           11    0.44186   0.38000   0.40860       100
#           12    0.70909   0.78000   0.74286       100
#           13    0.59140   0.55000   0.56995       100
#           14    0.58475   0.69000   0.63303       100
#           15    0.58772   0.67000   0.62617       100
#           16    0.68687   0.68000   0.68342       100
#           17    0.85263   0.81000   0.83077       100
#           18    0.65957   0.62000   0.63918       100
#           19    0.57407   0.62000   0.59615       100
#           20    0.79817   0.87000   0.83254       100
#           21    0.75926   0.82000   0.78846       100
#           22    0.67961   0.70000   0.68966       100
#           23    0.84444   0.76000   0.80000       100
#           24    0.82979   0.78000   0.80412       100
#           25    0.58242   0.53000   0.55497       100
#           26    0.60000   0.66000   0.62857       100
#           27    0.57143   0.48000   0.52174       100
#           28    0.75701   0.81000   0.78261       100
#           29    0.62887   0.61000   0.61929       100
#           30    0.66667   0.64000   0.65306       100
#           31    0.72000   0.54000   0.61714       100
#           32    0.71765   0.61000   0.65946       100
#           33    0.70930   0.61000   0.65591       100
#           34    0.78161   0.68000   0.72727       100
#           35    0.42857   0.45000   0.43902       100
#           36    0.74490   0.73000   0.73737       100
#           37    0.74444   0.67000   0.70526       100
#           38    0.58763   0.57000   0.57868       100
#           39    0.71545   0.88000   0.78924       100
#           40    0.63441   0.59000   0.61140       100
#           41    0.80374   0.86000   0.83092       100
#           42    0.46512   0.80000   0.58824       100
#           43    0.71579   0.68000   0.69744       100
#           44    0.31068   0.32000   0.31527       100
#           45    0.53846   0.49000   0.51309       100
#           46    0.40816   0.40000   0.40404       100
#           47    0.61111   0.66000   0.63462       100
#           48    0.73643   0.95000   0.82969       100
#           49    0.74545   0.82000   0.78095       100
#           50    0.43617   0.41000   0.42268       100
#           51    0.64815   0.70000   0.67308       100
#           52    0.56667   0.68000   0.61818       100
#           53    0.79464   0.89000   0.83962       100
#           54    0.68696   0.79000   0.73488       100
#           55    0.38028   0.27000   0.31579       100
#           56    0.87000   0.87000   0.87000       100
#           57    0.68224   0.73000   0.70531       100
#           58    0.84043   0.79000   0.81443       100
#           59    0.66990   0.69000   0.67980       100
#           60    0.82075   0.87000   0.84466       100
#           61    0.67778   0.61000   0.64211       100
#           62    0.68571   0.72000   0.70244       100
#           63    0.64835   0.59000   0.61780       100
#           64    0.50000   0.50000   0.50000       100
#           65    0.51351   0.38000   0.43678       100
#           66    0.63158   0.72000   0.67290       100
#           67    0.55789   0.53000   0.54359       100
#           68    0.84404   0.92000   0.88038       100
#           69    0.80000   0.80000   0.80000       100
#           70    0.69474   0.66000   0.67692       100
#           71    0.75472   0.80000   0.77670       100
#           72    0.33735   0.28000   0.30601       100
#           73    0.52083   0.50000   0.51020       100
#           74    0.42478   0.48000   0.45070       100
#           75    0.83654   0.87000   0.85294       100
#           76    0.86538   0.90000   0.88235       100
#           77    0.60870   0.56000   0.58333       100
#           78    0.45522   0.61000   0.52137       100
#           79    0.77778   0.70000   0.73684       100
#           80    0.59091   0.39000   0.46988       100
#           81    0.60684   0.71000   0.65438       100
#           82    0.84259   0.91000   0.87500       100
#           83    0.65306   0.64000   0.64646       100
#           84    0.72619   0.61000   0.66304       100
#           85    0.77670   0.80000   0.78818       100
#           86    0.61864   0.73000   0.66972       100
#           87    0.71053   0.81000   0.75701       100
#           88    0.74227   0.72000   0.73096       100
#           89    0.78351   0.76000   0.77157       100
#           90    0.67544   0.77000   0.71963       100
#           91    0.75472   0.80000   0.77670       100
#           92    0.59574   0.56000   0.57732       100
#           93    0.66667   0.48000   0.55814       100
#           94    0.85185   0.92000   0.88462       100
#           95    0.69307   0.70000   0.69652       100
#           96    0.68421   0.52000   0.59091       100
#           97    0.75000   0.66000   0.70213       100
#           98    0.45556   0.41000   0.43158       100
#           99    0.56154   0.73000   0.63478       100
#
#     accuracy                        0.66380     10000
#    macro avg    0.66395   0.66380   0.66096     10000
# weighted avg    0.66395   0.66380   0.66096     10000

# %%
h_measurements,consistency,exact_match = metrics.hmeasurements(true_label,
                                       pred_label,
                                       dataset['tree'])
print('\nHierarchical Precision =',h_measurements[0],
      '\nHierarchical Recall =', h_measurements[1],
      '\nHierarchical F1-Score =',h_measurements[2],
      '\nConsistency = ', consistency,
      '\nExact Match = ', exact_match,
     )
# Out:
# Hierarchical Precision = 0.7742516666666667
# Hierarchical Recall = 0.7919666666666666
# Hierarchical F1-Score = 0.7811896825396826
# Consistency =  0.898
# Exact Match =  0.638
