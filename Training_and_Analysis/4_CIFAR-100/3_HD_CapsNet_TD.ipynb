# %% [markdown]
# ***
# <font size="6"><center><b> HD-CapsNet: A Hierarchical Deep Capsule Network for Image Classification </b></center></font>
# ***

# %% [markdown]
# **Changing Model Architecture**
# - **(Mod-2.1)** From coarse-to-Fine slowly decrease the dimension. i.e. 32D>16D>8D (Coarse>Medium>FINE), While keeping the primary capsule dimension same as original ($P_{capsule} = 8D$). Training with $L_{cons}$

# %% [markdown]
# # Files and Libraries

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras import regularizers, optimizers
from tensorflow.keras import backend as K

import tensorflow_docs as tfdocs
import tensorflow_docs.plots

# Supporting Libraries:
    #Mathplot lib for ploting graphs
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
    # numpy and pandas
import numpy as np
import pandas as pd
    #system
import os
import sys
import csv
    #import other libraries
import math
import random
from datetime import datetime
from treelib import Tree
    # ML model, Dataset and evalution metrics
sys.path.append('../../') ### adding system parth for src folder
from src import datasets # load datasets
from src import MixUp_add_loss # load datasets
from src import metrics # load hierarchcial metrics
from src import sysenv # load hierarchcial metrics
from src import models # load machine learning models

    ## Tensorflow_docs
import tensorflow_docs as tfdocs
import tensorflow_docs.plots

    # Auto reload local libraries if updated
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # System information & GPU growth

# %%
systeminfo = sysenv.systeminfo()
print(systeminfo)
# Out:
# • Computer Name = SARUMAN
# • Working Directory = D:\knoor\Deep Learning with Python\RunningOnServer\HD-CapsNet_MOD_2\Training_and_Analysis\4_CIFAR-100
# • Python Version = 3.8.12 (default, Oct 12 2021, 03:01:40) [MSC v.1916 64 bit (AMD64)]
# • TensorFlow Version = 2.8.0
# • Keras Version = 2.8.0
# • Current Environment = Anaconda Environment Name : D:\knoor\AnacondaEnvironment\py38tf28

# %%
gpus = "0,1,2,3,4,5,6,7" ## Selecting Available gpus (Multi-GPUS)
gpus = "4" ## Selecting Available gpus (Single GPU)
gpugrowth = sysenv.gpugrowth(gpus = gpus) ## Limiting GPUS from OS environment
gpugrowth.memory_growth() #GPU memory growth
# Out:
# Following GPUS are selected =  4
# Done: GPU PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# 1 Physical GPUs, 1 Logical GPUs

# %% [markdown]
# ## log directory

# %%
directory = sysenv.log_dir('MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss')
# Out:
# FOLDER CREATED =  ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss

# %% [markdown]
# # Import Dataset : CIFAR-100

# %%
dataset = datasets.CIFAR100(version = 'ALL') # importing CIFAR10 Dataset
# dataset = datasets.CIFAR100(version = 'reduce') # importing CIFAR10 Dataset
# Out:
# CIFAR-100 dataset: Training have 50,000 samples and testing have 10,000 samples

# %% [markdown]
# # Parameters

# %%
train_params = {"n_epochs" : 100,
                "batch_size": 64,
                "lr": 0.001, # Initial learning rate
                "lr_decay": 0.95, # Learning rate decay
                "decay_exe": 9, #learning rate decay execution epoch after
               }
model_params = {"optimizer": tf.keras.optimizers.Adam(train_params['lr']),
                "loss_function": models.MarginLoss(),
               }

# %% [markdown]
# ## Learning Rate Decay Scheduler

# %%
def scheduler(epoch):
    learning_rate_init = train_params["lr"]
    
    if epoch > train_params["decay_exe"]:
        learning_rate_init = train_params["lr"] * (train_params["lr_decay"] ** (epoch-9))
        
    tf.summary.scalar('learning rate', data=learning_rate_init, step=epoch)
        
    return learning_rate_init

# %% [markdown]
# # Bottom up Approach

# %% [markdown]
# ## Loss Function

# %%
number_of_classes_c = len(np.unique(np.argmax(dataset['y_train_coarse'], axis=1)))
number_of_classes_m = len(np.unique(np.argmax(dataset['y_train_medium'], axis=1)))
number_of_classes_f = len(np.unique(np.argmax(dataset['y_train_fine'], axis=1)))

## For Dynamic LossWeights
initial_lw = models.initial_lw({"coarse": number_of_classes_c,
                                "medium": number_of_classes_m,
                                "fine": number_of_classes_f})

lossweight = {'coarse_lw' : K.variable(value = initial_lw['coarse'], dtype="float32", name="coarse_lw"),
             'medium_lw' : K.variable(value = initial_lw['medium'], dtype="float32", name="medium_lw"),
             'fine_lw' : K.variable(value = initial_lw['fine'], dtype="float32", name="fine_lw"),
              'decoder_lw' : 0.0
             }

# %%
coarse_to_medium_array = np.zeros(shape=[number_of_classes_c,number_of_classes_m], dtype=np.int32)
medium_to_fine_array = np.zeros(shape=[number_of_classes_m,number_of_classes_f], dtype=np.int32)

c_id = np.argmax(dataset['y_train_coarse'],1)

m_id = np.argmax(dataset['y_train_medium'],1)

f_id = np.argmax(dataset['y_train_fine'],1)

for x in range(len(dataset['y_test_medium'])):
    coarse_to_medium_array[c_id[x]][m_id[x]] = 1
    
for x in range(len(dataset['y_test_fine'])):
    medium_to_fine_array[m_id[x]][f_id[x]] = 1

Matrix_coarse_to_medium_OneHot = tf.constant(coarse_to_medium_array, dtype=tf.float32)
Matrix_medium_to_fine_OneHot = tf.constant(medium_to_fine_array, dtype=tf.float32)

# %%
def margin_loss(y_true, y_proba):
    
    present_error_raw = tf.square(tf.maximum(0., 0.9 - y_proba), name="present_error_raw")
    absent_error_raw = tf.square(tf.maximum(0., y_proba - 0.1), name="absent_error_raw")
    L = tf.add(y_true * present_error_raw, 0.5 * (1.0 - y_true) * absent_error_raw,name="L")
    total_marginloss = tf.reduce_sum(L, axis=1, name="margin_loss")

    return total_marginloss


def consistency_check(y_pred_ancestor,y_pred_current,lookup_matrix,num_class_current):
    pred_max_ancestor = tf.argmax(y_pred_ancestor,axis=1)
    pred_max_current = tf.argmax(y_pred_current,axis=1)
    
    consistant_check = tf.gather(lookup_matrix, indices=pred_max_ancestor)*tf.one_hot(pred_max_current,num_class_current)
    
    return tf.reduce_sum(consistant_check,1)

def get_consistency(y_true_ancestor, y_pred, lookup_matrix):
    '''
    Get consistency based on 2 levels
    Provide ture levels for the level above, predictions for the current level and a look up metrix
    '''
    y_prob = tf.math.divide(y_pred,tf.reshape(tf.reduce_sum(y_pred,-1),(-1,1),name='reshape'),name='Probability')
    
    index_for_predictions = tf.cast(tf.math.argmax(y_true_ancestor,axis=1),dtype= 'int32')
    consistent_fine = tf.gather(lookup_matrix, indices=index_for_predictions) * y_prob
    Consistency_sum_array = tf.reduce_sum(consistent_fine, axis =1)
    
    return tf.abs(1-Consistency_sum_array)

def CustomLoss(y_true_c, y_true_m, y_true_f, y_pred_c, y_pred_m, y_pred_f, LW_C, LW_M, LW_F,tree: Tree,C_Weight=0.2):
    
    con_m = consistency_check(y_pred_c,y_pred_m,Matrix_coarse_to_medium_OneHot,num_class_current=number_of_classes_m)
    con_m_not = tf.abs(con_m-1)
    
    con_f = consistency_check(y_pred_m,y_pred_f,Matrix_medium_to_fine_OneHot,num_class_current=number_of_classes_f)
    con_f_not = tf.abs(con_f-1)
    
    con_sum_m = get_consistency(y_true_c,y_pred_m,Matrix_coarse_to_medium_OneHot)
    con_sum_f = get_consistency(y_true_m,y_pred_f,Matrix_medium_to_fine_OneHot)
    
    medium_lvl_cosistency = con_sum_m * con_m_not
    fine_lvl_cosistency = con_sum_f * con_f_not    
   
    ML_c = margin_loss(y_true_c, y_pred_c)*LW_C
    ML_m = LW_M*((1-C_Weight)*(margin_loss(y_true_m, y_pred_m))+C_Weight*(medium_lvl_cosistency))
    ML_f = LW_F*((1-C_Weight)*(margin_loss(y_true_f, y_pred_f))+C_Weight*(fine_lvl_cosistency))
    
    batch_loss = ML_c + ML_m+ ML_f

    return tf.reduce_mean(batch_loss)

# %% [markdown]
# ## Model Architecture

# %%
def get_compiled_model():
    input_shape = dataset['x_train'].shape[1:]

    input_shape_yc = dataset['y_train_coarse'].shape[1:]
    input_shape_ym = dataset['y_train_medium'].shape[1:]
    input_shape_yf = dataset['y_train_fine'].shape[1:]

    no_coarse_class = number_of_classes_c
    no_medium_class = number_of_classes_m
    no_fine_class = number_of_classes_f

    PCap_n_dims = 8

    SCap_f_dims = 8
    SCap_m_dims = 16
    SCap_c_dims = 32


    # Input image
    x_input = keras.layers.Input(shape=input_shape, name="Input_Image")

    # Input True Labels
    y_c = keras.layers.Input(shape=input_shape_yc, name='input_yc')
    y_m = keras.layers.Input(shape=input_shape_ym, name='input_ym')
    y_f = keras.layers.Input(shape=input_shape_yf, name='input_yf')

    #--- block 1 ---
    x = keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv1')(x_input)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv2')(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.MaxPooling2D((2, 2), strides=(2, 2), name='block1_pool')(x)

    #--- block 2 ---
    x = keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv1')(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv2')(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.MaxPooling2D((2, 2), strides=(2, 2), name='block2_pool')(x)

    #--- block 3 ---
    x = keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv1')(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv2')(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.MaxPooling2D((2, 2), strides=(2, 2), name='block3_pool')(x)

    #--- block 4 ---
    x = keras.layers.Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv1')(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv2')(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.MaxPooling2D((2, 2), strides=(2, 2), name='block4_pool')(x)


    # Layer 3: Reshape to 8D primary capsules 
    reshapec = keras.layers.Reshape((int((tf.reduce_prod(x.shape[1:]).numpy())/PCap_n_dims),
                                     PCap_n_dims), name="reshape_layer")(x)
    p_caps = keras.layers.Lambda(models.squash, name='p_caps')(reshapec)

    ## Layer Secondary Capsule: For coarse level
    s_caps_c = models.SecondaryCapsule(n_caps=no_coarse_class, n_dims=SCap_c_dims, 
                        name="s_caps_coarse")(p_caps)
    
    ## Layer Secondary Capsule: For medium level
    s_caps_m = models.SecondaryCapsule(n_caps=no_medium_class, n_dims=SCap_m_dims, 
                        name="s_caps_medium")(s_caps_c)

    ## Layer Secondary Capsule: For fine level
    s_caps_f = models.SecondaryCapsule(n_caps=no_fine_class, n_dims=SCap_f_dims, 
                        name="s_caps_fine")(s_caps_m)

    pred_c = models.LengthLayer(name='prediction_coarse')(s_caps_c)

    pred_m = models.LengthLayer(name='prediction_medium')(s_caps_m)

    pred_f = models.LengthLayer(name='prediction_fine')(s_caps_f)

    model = keras.Model(inputs= [x_input, y_c, y_m, y_f],
                        outputs= [pred_c, pred_m, pred_f],
                        name='HD-CapsNet')

    model.add_loss(CustomLoss(y_c, y_m, y_f, pred_c, pred_m, pred_f, 
                              lossweight['coarse_lw'], lossweight['medium_lw'], lossweight['fine_lw'],
                              dataset['tree']))

    model.compile(optimizer='adam',                  
                  metrics={'prediction_fine': 'accuracy',
                           'prediction_medium': 'accuracy',
                           'prediction_coarse': 'accuracy'
                          }
    )
    return model

# %%
model = get_compiled_model()
# Out:
# WARNING:tensorflow:The following Variables were used in a Lambda layer's call (tf.math.multiply_9), but are not present in its tracked objects:   <tf.Variable 'coarse_lw:0' shape=() dtype=float32>. This is a strong indication that the Lambda layer should be rewritten as a subclassed Layer.

# %% [raw]
# strategy = multi_gpu_select('windows')
#
# print("Number of devices: {}".format(strategy.num_replicas_in_sync))
#
# with strategy.scope():
#     # Everything that creates variables should be under the strategy scope.
#     # In general this is only model construction & `compile()`.
#     model = get_compiled_model()

# %%
model.summary()
# keras.utils.plot_model(model, to_file = directory+"/Architecture.png", show_shapes=True)
# Out:
# Model: "HD-CapsNet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Input_Image (InputLayer)       [(None, 32, 32, 3)]  0           []
#
#  block1_conv1 (Conv2D)          (None, 32, 32, 64)   1792        ['Input_Image[0][0]']
#
#  batch_normalization (BatchNorm  (None, 32, 32, 64)  256         ['block1_conv1[0][0]']
#  alization)
#
#  block1_conv2 (Conv2D)          (None, 32, 32, 64)   36928       ['batch_normalization[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 32, 32, 64)  256         ['block1_conv2[0][0]']
#  rmalization)
#
#  block1_pool (MaxPooling2D)     (None, 16, 16, 64)   0           ['batch_normalization_1[0][0]']
#
#  block2_conv1 (Conv2D)          (None, 16, 16, 128)  73856       ['block1_pool[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 16, 16, 128)  512        ['block2_conv1[0][0]']
#  rmalization)
#
#  block2_conv2 (Conv2D)          (None, 16, 16, 128)  147584      ['batch_normalization_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 16, 16, 128)  512        ['block2_conv2[0][0]']
#  rmalization)
#
#  block2_pool (MaxPooling2D)     (None, 8, 8, 128)    0           ['batch_normalization_3[0][0]']
#
#  block3_conv1 (Conv2D)          (None, 8, 8, 256)    295168      ['block2_pool[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 8, 8, 256)   1024        ['block3_conv1[0][0]']
#  rmalization)
#
#  block3_conv2 (Conv2D)          (None, 8, 8, 256)    590080      ['batch_normalization_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 8, 8, 256)   1024        ['block3_conv2[0][0]']
#  rmalization)
#
#  block3_pool (MaxPooling2D)     (None, 4, 4, 256)    0           ['batch_normalization_5[0][0]']
#
#  block4_conv1 (Conv2D)          (None, 4, 4, 512)    1180160     ['block3_pool[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 4, 4, 512)   2048        ['block4_conv1[0][0]']
#  rmalization)
#
#  block4_conv2 (Conv2D)          (None, 4, 4, 512)    2359808     ['batch_normalization_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 4, 4, 512)   2048        ['block4_conv2[0][0]']
#  rmalization)
#
#  block4_pool (MaxPooling2D)     (None, 2, 2, 512)    0           ['batch_normalization_7[0][0]']
#
#  reshape_layer (Reshape)        (None, 256, 8)       0           ['block4_pool[0][0]']
#
#  p_caps (Lambda)                (None, 256, 8)       0           ['reshape_layer[0][0]']
#
#  s_caps_coarse (SecondaryCapsul  (None, 8, 32)       524288      ['p_caps[0][0]']
#  e)
#
#  s_caps_medium (SecondaryCapsul  (None, 20, 16)      81920       ['s_caps_coarse[0][0]']
#  e)
#
#  s_caps_fine (SecondaryCapsule)  (None, 100, 8)      256000      ['s_caps_medium[0][0]']
#
#  input_yc (InputLayer)          [(None, 8)]          0           []
#
#  input_ym (InputLayer)          [(None, 20)]         0           []
#
#  input_yf (InputLayer)          [(None, 100)]        0           []
#
#  prediction_coarse (LengthLayer  (None, 8)           0           ['s_caps_coarse[0][0]']
#  )
#
#  prediction_medium (LengthLayer  (None, 20)          0           ['s_caps_medium[0][0]']
#  )
#
#  prediction_fine (LengthLayer)  (None, 100)          0           ['s_caps_fine[0][0]']
#
#  tf.math.argmax_4 (TFOpLambda)  (None,)              0           ['input_yc[0][0]']
#
#  tf.math.reduce_sum_2 (TFOpLamb  (None,)             0           ['prediction_medium[0][0]']
#  da)
#
#  tf.cast (TFOpLambda)           (None,)              0           ['tf.math.argmax_4[0][0]']
#
#  tf.reshape (TFOpLambda)        (None, 1)            0           ['tf.math.reduce_sum_2[0][0]']
#
#  tf.math.argmax (TFOpLambda)    (None,)              0           ['prediction_coarse[0][0]']
#
#  tf.math.argmax_1 (TFOpLambda)  (None,)              0           ['prediction_medium[0][0]']
#
#  tf.math.argmax_5 (TFOpLambda)  (None,)              0           ['input_ym[0][0]']
#
#  tf.math.reduce_sum_4 (TFOpLamb  (None,)             0           ['prediction_fine[0][0]']
#  da)
#
#  tf.math.subtract_7 (TFOpLambda  (None, 20)          0           ['prediction_medium[0][0]']
#  )
#
#  tf.math.subtract_8 (TFOpLambda  (None, 20)          0           ['prediction_medium[0][0]']
#  )
#
#  tf.compat.v1.gather_2 (TFOpLam  (None, 20)          0           ['tf.cast[0][0]']
#  bda)
#
#  tf.math.divide (TFOpLambda)    (None, 20)           0           ['prediction_medium[0][0]',
#                                                                   'tf.reshape[0][0]']
#
#  tf.compat.v1.gather (TFOpLambd  (None, 20)          0           ['tf.math.argmax[0][0]']
#  a)
#
#  tf.one_hot (TFOpLambda)        (None, 20)           0           ['tf.math.argmax_1[0][0]']
#
#  tf.cast_1 (TFOpLambda)         (None,)              0           ['tf.math.argmax_5[0][0]']
#
#  tf.reshape_1 (TFOpLambda)      (None, 1)            0           ['tf.math.reduce_sum_4[0][0]']
#
#  tf.math.argmax_2 (TFOpLambda)  (None,)              0           ['prediction_medium[0][0]']
#
#  tf.math.argmax_3 (TFOpLambda)  (None,)              0           ['prediction_fine[0][0]']
#
#  tf.math.maximum_2 (TFOpLambda)  (None, 20)          0           ['tf.math.subtract_7[0][0]']
#
#  tf.math.subtract_9 (TFOpLambda  (None, 20)          0           ['input_ym[0][0]']
#  )
#
#  tf.math.maximum_3 (TFOpLambda)  (None, 20)          0           ['tf.math.subtract_8[0][0]']
#
#  tf.math.multiply_2 (TFOpLambda  (None, 20)          0           ['tf.compat.v1.gather_2[0][0]',
#  )                                                                'tf.math.divide[0][0]']
#
#  tf.math.multiply (TFOpLambda)  (None, 20)           0           ['tf.compat.v1.gather[0][0]',
#                                                                   'tf.one_hot[0][0]']
#
#  tf.math.subtract_10 (TFOpLambd  (None, 100)         0           ['prediction_fine[0][0]']
#  a)
#
#  tf.math.subtract_11 (TFOpLambd  (None, 100)         0           ['prediction_fine[0][0]']
#  a)
#
#  tf.compat.v1.gather_3 (TFOpLam  (None, 100)         0           ['tf.cast_1[0][0]']
#  bda)
#
#  tf.math.divide_1 (TFOpLambda)  (None, 100)          0           ['prediction_fine[0][0]',
#                                                                   'tf.reshape_1[0][0]']
#
#  tf.compat.v1.gather_1 (TFOpLam  (None, 100)         0           ['tf.math.argmax_2[0][0]']
#  bda)
#
#  tf.one_hot_1 (TFOpLambda)      (None, 100)          0           ['tf.math.argmax_3[0][0]']
#
#  tf.math.subtract_4 (TFOpLambda  (None, 8)           0           ['prediction_coarse[0][0]']
#  )
#
#  tf.math.subtract_5 (TFOpLambda  (None, 8)           0           ['prediction_coarse[0][0]']
#  )
#
#  tf.math.square_2 (TFOpLambda)  (None, 20)           0           ['tf.math.maximum_2[0][0]']
#
#  tf.math.multiply_11 (TFOpLambd  (None, 20)          0           ['tf.math.subtract_9[0][0]']
#  a)
#
#  tf.math.square_3 (TFOpLambda)  (None, 20)           0           ['tf.math.maximum_3[0][0]']
#
#  tf.math.reduce_sum_3 (TFOpLamb  (None,)             0           ['tf.math.multiply_2[0][0]']
#  da)
#
#  tf.math.reduce_sum (TFOpLambda  (None,)             0           ['tf.math.multiply[0][0]']
#  )
#
#  tf.math.maximum_4 (TFOpLambda)  (None, 100)         0           ['tf.math.subtract_10[0][0]']
#
#  tf.math.subtract_12 (TFOpLambd  (None, 100)         0           ['input_yf[0][0]']
#  a)
#
#  tf.math.maximum_5 (TFOpLambda)  (None, 100)         0           ['tf.math.subtract_11[0][0]']
#
#  tf.math.multiply_3 (TFOpLambda  (None, 100)         0           ['tf.compat.v1.gather_3[0][0]',
#  )                                                                'tf.math.divide_1[0][0]']
#
#  tf.math.multiply_1 (TFOpLambda  (None, 100)         0           ['tf.compat.v1.gather_1[0][0]',
#  )                                                                'tf.one_hot_1[0][0]']
#
#  tf.math.maximum (TFOpLambda)   (None, 8)            0           ['tf.math.subtract_4[0][0]']
#
#  tf.math.subtract_6 (TFOpLambda  (None, 8)           0           ['input_yc[0][0]']
#  )
#
#  tf.math.maximum_1 (TFOpLambda)  (None, 8)           0           ['tf.math.subtract_5[0][0]']
#
#  tf.math.multiply_10 (TFOpLambd  (None, 20)          0           ['input_ym[0][0]',
#  a)                                                               'tf.math.square_2[0][0]']
#
#  tf.math.multiply_12 (TFOpLambd  (None, 20)          0           ['tf.math.multiply_11[0][0]',
#  a)                                                               'tf.math.square_3[0][0]']
#
#  tf.math.subtract_2 (TFOpLambda  (None,)             0           ['tf.math.reduce_sum_3[0][0]']
#  )
#
#  tf.math.subtract (TFOpLambda)  (None,)              0           ['tf.math.reduce_sum[0][0]']
#
#  tf.math.square_4 (TFOpLambda)  (None, 100)          0           ['tf.math.maximum_4[0][0]']
#
#  tf.math.multiply_17 (TFOpLambd  (None, 100)         0           ['tf.math.subtract_12[0][0]']
#  a)
#
#  tf.math.square_5 (TFOpLambda)  (None, 100)          0           ['tf.math.maximum_5[0][0]']
#
#  tf.math.reduce_sum_5 (TFOpLamb  (None,)             0           ['tf.math.multiply_3[0][0]']
#  da)
#
#  tf.math.reduce_sum_1 (TFOpLamb  (None,)             0           ['tf.math.multiply_1[0][0]']
#  da)
#
#  tf.math.square (TFOpLambda)    (None, 8)            0           ['tf.math.maximum[0][0]']
#
#  tf.math.multiply_7 (TFOpLambda  (None, 8)           0           ['tf.math.subtract_6[0][0]']
#  )
#
#  tf.math.square_1 (TFOpLambda)  (None, 8)            0           ['tf.math.maximum_1[0][0]']
#
#  tf.math.add_1 (TFOpLambda)     (None, 20)           0           ['tf.math.multiply_10[0][0]',
#                                                                   'tf.math.multiply_12[0][0]']
#
#  tf.math.abs_2 (TFOpLambda)     (None,)              0           ['tf.math.subtract_2[0][0]']
#
#  tf.math.abs (TFOpLambda)       (None,)              0           ['tf.math.subtract[0][0]']
#
#  tf.math.multiply_16 (TFOpLambd  (None, 100)         0           ['input_yf[0][0]',
#  a)                                                               'tf.math.square_4[0][0]']
#
#  tf.math.multiply_18 (TFOpLambd  (None, 100)         0           ['tf.math.multiply_17[0][0]',
#  a)                                                               'tf.math.square_5[0][0]']
#
#  tf.math.subtract_3 (TFOpLambda  (None,)             0           ['tf.math.reduce_sum_5[0][0]']
#  )
#
#  tf.math.subtract_1 (TFOpLambda  (None,)             0           ['tf.math.reduce_sum_1[0][0]']
#  )
#
#  tf.math.multiply_6 (TFOpLambda  (None, 8)           0           ['input_yc[0][0]',
#  )                                                                'tf.math.square[0][0]']
#
#  tf.math.multiply_8 (TFOpLambda  (None, 8)           0           ['tf.math.multiply_7[0][0]',
#  )                                                                'tf.math.square_1[0][0]']
#
#  tf.math.reduce_sum_7 (TFOpLamb  (None,)             0           ['tf.math.add_1[0][0]']
#  da)
#
#  tf.math.multiply_4 (TFOpLambda  (None,)             0           ['tf.math.abs_2[0][0]',
#  )                                                                'tf.math.abs[0][0]']
#
#  tf.math.add_2 (TFOpLambda)     (None, 100)          0           ['tf.math.multiply_16[0][0]',
#                                                                   'tf.math.multiply_18[0][0]']
#
#  tf.math.abs_3 (TFOpLambda)     (None,)              0           ['tf.math.subtract_3[0][0]']
#
#  tf.math.abs_1 (TFOpLambda)     (None,)              0           ['tf.math.subtract_1[0][0]']
#
#  tf.math.add (TFOpLambda)       (None, 8)            0           ['tf.math.multiply_6[0][0]',
#                                                                   'tf.math.multiply_8[0][0]']
#
#  tf.math.multiply_13 (TFOpLambd  (None,)             0           ['tf.math.reduce_sum_7[0][0]']
#  a)
#
#  tf.math.multiply_14 (TFOpLambd  (None,)             0           ['tf.math.multiply_4[0][0]']
#  a)
#
#  tf.math.reduce_sum_8 (TFOpLamb  (None,)             0           ['tf.math.add_2[0][0]']
#  da)
#
#  tf.math.multiply_5 (TFOpLambda  (None,)             0           ['tf.math.abs_3[0][0]',
#  )                                                                'tf.math.abs_1[0][0]']
#
#  tf.math.reduce_sum_6 (TFOpLamb  (None,)             0           ['tf.math.add[0][0]']
#  da)
#
#  tf.__operators__.add (TFOpLamb  (None,)             0           ['tf.math.multiply_13[0][0]',
#  da)                                                              'tf.math.multiply_14[0][0]']
#
#  tf.math.multiply_19 (TFOpLambd  (None,)             0           ['tf.math.reduce_sum_8[0][0]']
#  a)
#
#  tf.math.multiply_20 (TFOpLambd  (None,)             0           ['tf.math.multiply_5[0][0]']
#  a)
#
#  tf.math.multiply_9 (TFOpLambda  (None,)             0           ['tf.math.reduce_sum_6[0][0]']
#  )
#
#  tf.math.multiply_15 (TFOpLambd  (None,)             0           ['tf.__operators__.add[0][0]']
#  a)
#
#  tf.__operators__.add_1 (TFOpLa  (None,)             0           ['tf.math.multiply_19[0][0]',
#  mbda)                                                            'tf.math.multiply_20[0][0]']
#
#  tf.__operators__.add_2 (TFOpLa  (None,)             0           ['tf.math.multiply_9[0][0]',
#  mbda)                                                            'tf.math.multiply_15[0][0]']
#
#  tf.math.multiply_21 (TFOpLambd  (None,)             0           ['tf.__operators__.add_1[0][0]']
#  a)
#
#  tf.__operators__.add_3 (TFOpLa  (None,)             0           ['tf.__operators__.add_2[0][0]',
#  mbda)                                                            'tf.math.multiply_21[0][0]']
#
#  tf.math.reduce_mean (TFOpLambd  ()                  0           ['tf.__operators__.add_3[0][0]']
#  a)
#
#  add_loss (AddLoss)             ()                   0           ['tf.math.reduce_mean[0][0]']
#
# ==================================================================================================
# Total params: 5,555,264
# Trainable params: 5,551,424
# Non-trainable params: 3,840
# __________________________________________________________________________________________________

# %% [markdown]
# ## Data Augmentation

# %%
datagen = ImageDataGenerator(width_shift_range=0.1,
                            height_shift_range=0.1)

training_generator = MixUp_add_loss.MixupGenerator_3level(dataset['x_train'],
                                                 dataset['y_train_coarse'], 
                                                 dataset['y_train_medium'],
                                                 dataset['y_train_fine'],
                                                 batch_size=train_params["batch_size"],
                                                 alpha=0.2, 
                                                 datagen=datagen
                                                )()

# %% [markdown]
# ## Callback

# %%
tb = keras.callbacks.TensorBoard(directory+'./tb_logs'+ datetime.now().strftime("%Y%m%d-%H%M%S"))
log = keras.callbacks.CSVLogger(directory+'/log.csv', append=True)

checkpoint = keras.callbacks.ModelCheckpoint(
    directory+'/epoch-best.h5', 
    monitor='val_prediction_fine_accuracy',
    save_best_only=True, save_weights_only=True, verbose=1)
change_lw = models.LossWeightsModifier(lossweight = lossweight,
                               initial_lw = initial_lw,
                               directory = directory)
lr_decay = keras.callbacks.LearningRateScheduler(scheduler)

# %% [markdown]
# ## Model Training

# %%
model_save_dir = str(directory+'/trained_model.h5')
try:
    model.load_weights(model_save_dir)
except:
    history = model.fit(training_generator,
                        steps_per_epoch = int(dataset['x_train'].shape[0] / train_params["batch_size"]),
                        epochs = train_params["n_epochs"],
                        validation_data = ([dataset['x_test'],
                                            dataset['y_test_coarse'],dataset['y_test_medium'],dataset['y_test_fine']],
                                           [dataset['y_test_coarse'],dataset['y_test_medium'],dataset['y_test_fine']]),
                        callbacks = [tb,log,change_lw,lr_decay,checkpoint],
                        verbose=1)
    
    model.save_weights(model_save_dir)
# Out:
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring... Layer tf.math.multiply_9 was passed non-JSON-serializable arguments. Arguments had types: {'y': <class 'tensorflow.python.ops.resource_variable_ops.ResourceVariable'>, 'name': <class 'NoneType'>}. They cannot be serialized out when saving the model.
# Epoch 1/100
#   6/781 [..............................] - ETA: 51s - loss: 0.7394 - prediction_coarse_accuracy: 0.1849 - prediction_medium_accuracy: 0.0521 - prediction_fine_accuracy: 0.0104WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0498s vs `on_train_batch_end` time: 0.0631s). Check your callbacks.
# 781/781 [==============================] - ETA: 0s - loss: 0.5243 - prediction_coarse_accuracy: 0.4603 - prediction_medium_accuracy: 0.1832 - prediction_fine_accuracy: 0.0152
#   • Coarse Accuracy = 46.03% | Val_Accuracy = 52.83% | LossWeight = 0.36
#   • Medium Accuracy = 18.32% | Val_Accuracy = 28.49% | LossWeight = 0.49
#   • Fine   Accuracy = 1.52% | Val_Accuracy = 1.71% | LossWeight = 0.15
#
# Epoch 1: val_prediction_fine_accuracy improved from -inf to 0.01710, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 69s 77ms/step - loss: 0.5243 - prediction_coarse_accuracy: 0.4603 - prediction_medium_accuracy: 0.1832 - prediction_fine_accuracy: 0.0152 - val_loss: 0.4381 - val_prediction_coarse_accuracy: 0.5283 - val_prediction_medium_accuracy: 0.2849 - val_prediction_fine_accuracy: 0.0171 - lr: 0.0010
# Epoch 2/100
# 781/781 [==============================] - ETA: 0s - loss: 0.3620 - prediction_coarse_accuracy: 0.5933 - prediction_medium_accuracy: 0.3701 - prediction_fine_accuracy: 0.0340
#   • Coarse Accuracy = 59.33% | Val_Accuracy = 65.08% | LossWeight = 0.34
#   • Medium Accuracy = 37.01% | Val_Accuracy = 43.62% | LossWeight = 0.47
#   • Fine   Accuracy = 3.40% | Val_Accuracy = 4.29% | LossWeight = 0.19
#
# Epoch 2: val_prediction_fine_accuracy improved from 0.01710 to 0.04290, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 58s 75ms/step - loss: 0.3620 - prediction_coarse_accuracy: 0.5933 - prediction_medium_accuracy: 0.3701 - prediction_fine_accuracy: 0.0340 - val_loss: 0.3182 - val_prediction_coarse_accuracy: 0.6508 - val_prediction_medium_accuracy: 0.4362 - val_prediction_fine_accuracy: 0.0429 - lr: 0.0010
# Epoch 3/100
# 781/781 [==============================] - ETA: 0s - loss: 0.3166 - prediction_coarse_accuracy: 0.6641 - prediction_medium_accuracy: 0.4709 - prediction_fine_accuracy: 0.0525
#   • Coarse Accuracy = 66.41% | Val_Accuracy = 69.98% | LossWeight = 0.33
#   • Medium Accuracy = 47.09% | Val_Accuracy = 50.65% | LossWeight = 0.46
#   • Fine   Accuracy = 5.25% | Val_Accuracy = 7.64% | LossWeight = 0.21
#
# Epoch 3: val_prediction_fine_accuracy improved from 0.04290 to 0.07640, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 67s 86ms/step - loss: 0.3166 - prediction_coarse_accuracy: 0.6641 - prediction_medium_accuracy: 0.4709 - prediction_fine_accuracy: 0.0525 - val_loss: 0.2760 - val_prediction_coarse_accuracy: 0.6998 - val_prediction_medium_accuracy: 0.5065 - val_prediction_fine_accuracy: 0.0764 - lr: 0.0010
# Epoch 4/100
# 781/781 [==============================] - ETA: 0s - loss: 0.2874 - prediction_coarse_accuracy: 0.6991 - prediction_medium_accuracy: 0.5273 - prediction_fine_accuracy: 0.0841
#   • Coarse Accuracy = 69.91% | Val_Accuracy = 73.42% | LossWeight = 0.32
#   • Medium Accuracy = 52.73% | Val_Accuracy = 57.46% | LossWeight = 0.45
#   • Fine   Accuracy = 8.41% | Val_Accuracy = 10.09% | LossWeight = 0.23
#
# Epoch 4: val_prediction_fine_accuracy improved from 0.07640 to 0.10090, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 71s 90ms/step - loss: 0.2874 - prediction_coarse_accuracy: 0.6991 - prediction_medium_accuracy: 0.5273 - prediction_fine_accuracy: 0.0841 - val_loss: 0.2466 - val_prediction_coarse_accuracy: 0.7342 - val_prediction_medium_accuracy: 0.5746 - val_prediction_fine_accuracy: 0.1009 - lr: 0.0010
# Epoch 5/100
# 781/781 [==============================] - ETA: 0s - loss: 0.2629 - prediction_coarse_accuracy: 0.7389 - prediction_medium_accuracy: 0.5836 - prediction_fine_accuracy: 0.1082
#   • Coarse Accuracy = 73.89% | Val_Accuracy = 75.67% | LossWeight = 0.31
#   • Medium Accuracy = 58.36% | Val_Accuracy = 59.70% | LossWeight = 0.44
#   • Fine   Accuracy = 10.82% | Val_Accuracy = 11.52% | LossWeight = 0.25
#
# Epoch 5: val_prediction_fine_accuracy improved from 0.10090 to 0.11520, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 70s 89ms/step - loss: 0.2629 - prediction_coarse_accuracy: 0.7389 - prediction_medium_accuracy: 0.5836 - prediction_fine_accuracy: 0.1082 - val_loss: 0.2312 - val_prediction_coarse_accuracy: 0.7567 - val_prediction_medium_accuracy: 0.5970 - val_prediction_fine_accuracy: 0.1152 - lr: 0.0010
# Epoch 6/100
# 781/781 [==============================] - ETA: 0s - loss: 0.2413 - prediction_coarse_accuracy: 0.7650 - prediction_medium_accuracy: 0.6288 - prediction_fine_accuracy: 0.1217
#   • Coarse Accuracy = 76.50% | Val_Accuracy = 77.92% | LossWeight = 0.30
#   • Medium Accuracy = 62.88% | Val_Accuracy = 63.53% | LossWeight = 0.43
#   • Fine   Accuracy = 12.17% | Val_Accuracy = 13.02% | LossWeight = 0.26
#
# Epoch 6: val_prediction_fine_accuracy improved from 0.11520 to 0.13020, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 71s 91ms/step - loss: 0.2413 - prediction_coarse_accuracy: 0.7650 - prediction_medium_accuracy: 0.6288 - prediction_fine_accuracy: 0.1217 - val_loss: 0.2107 - val_prediction_coarse_accuracy: 0.7792 - val_prediction_medium_accuracy: 0.6353 - val_prediction_fine_accuracy: 0.1302 - lr: 0.0010
# Epoch 7/100
# 781/781 [==============================] - ETA: 0s - loss: 0.2235 - prediction_coarse_accuracy: 0.7920 - prediction_medium_accuracy: 0.6687 - prediction_fine_accuracy: 0.1377
#   • Coarse Accuracy = 79.20% | Val_Accuracy = 77.89% | LossWeight = 0.29
#   • Medium Accuracy = 66.87% | Val_Accuracy = 64.11% | LossWeight = 0.42
#   • Fine   Accuracy = 13.77% | Val_Accuracy = 14.00% | LossWeight = 0.28
#
# Epoch 7: val_prediction_fine_accuracy improved from 0.13020 to 0.14000, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 71s 91ms/step - loss: 0.2235 - prediction_coarse_accuracy: 0.7920 - prediction_medium_accuracy: 0.6687 - prediction_fine_accuracy: 0.1377 - val_loss: 0.2038 - val_prediction_coarse_accuracy: 0.7789 - val_prediction_medium_accuracy: 0.6411 - val_prediction_fine_accuracy: 0.1400 - lr: 0.0010
# Epoch 8/100
# 781/781 [==============================] - ETA: 0s - loss: 0.2086 - prediction_coarse_accuracy: 0.8122 - prediction_medium_accuracy: 0.6983 - prediction_fine_accuracy: 0.1524
#   • Coarse Accuracy = 81.22% | Val_Accuracy = 80.52% | LossWeight = 0.29
#   • Medium Accuracy = 69.83% | Val_Accuracy = 67.98% | LossWeight = 0.41
#   • Fine   Accuracy = 15.24% | Val_Accuracy = 15.36% | LossWeight = 0.30
#
# Epoch 8: val_prediction_fine_accuracy improved from 0.14000 to 0.15360, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 72s 92ms/step - loss: 0.2086 - prediction_coarse_accuracy: 0.8122 - prediction_medium_accuracy: 0.6983 - prediction_fine_accuracy: 0.1524 - val_loss: 0.1841 - val_prediction_coarse_accuracy: 0.8052 - val_prediction_medium_accuracy: 0.6798 - val_prediction_fine_accuracy: 0.1536 - lr: 0.0010
# Epoch 9/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1973 - prediction_coarse_accuracy: 0.8292 - prediction_medium_accuracy: 0.7265 - prediction_fine_accuracy: 0.1690
#   • Coarse Accuracy = 82.92% | Val_Accuracy = 80.06% | LossWeight = 0.28
#   • Medium Accuracy = 72.65% | Val_Accuracy = 68.43% | LossWeight = 0.40
#   • Fine   Accuracy = 16.90% | Val_Accuracy = 16.59% | LossWeight = 0.32
#
# Epoch 9: val_prediction_fine_accuracy improved from 0.15360 to 0.16590, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 71s 91ms/step - loss: 0.1973 - prediction_coarse_accuracy: 0.8292 - prediction_medium_accuracy: 0.7265 - prediction_fine_accuracy: 0.1690 - val_loss: 0.1831 - val_prediction_coarse_accuracy: 0.8006 - val_prediction_medium_accuracy: 0.6843 - val_prediction_fine_accuracy: 0.1659 - lr: 0.0010
# Epoch 10/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1885 - prediction_coarse_accuracy: 0.8409 - prediction_medium_accuracy: 0.7455 - prediction_fine_accuracy: 0.1778
#   • Coarse Accuracy = 84.09% | Val_Accuracy = 80.75% | LossWeight = 0.27
#   • Medium Accuracy = 74.55% | Val_Accuracy = 69.24% | LossWeight = 0.39
#   • Fine   Accuracy = 17.78% | Val_Accuracy = 17.14% | LossWeight = 0.33
#
# Epoch 10: val_prediction_fine_accuracy improved from 0.16590 to 0.17140, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 72s 93ms/step - loss: 0.1885 - prediction_coarse_accuracy: 0.8409 - prediction_medium_accuracy: 0.7455 - prediction_fine_accuracy: 0.1778 - val_loss: 0.1792 - val_prediction_coarse_accuracy: 0.8075 - val_prediction_medium_accuracy: 0.6924 - val_prediction_fine_accuracy: 0.1714 - lr: 0.0010
# Epoch 11/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1811 - prediction_coarse_accuracy: 0.8536 - prediction_medium_accuracy: 0.7623 - prediction_fine_accuracy: 0.1904
#   • Coarse Accuracy = 85.36% | Val_Accuracy = 80.30% | LossWeight = 0.27
#   • Medium Accuracy = 76.23% | Val_Accuracy = 68.17% | LossWeight = 0.39
#   • Fine   Accuracy = 19.04% | Val_Accuracy = 18.24% | LossWeight = 0.34
#
# Epoch 11: val_prediction_fine_accuracy improved from 0.17140 to 0.18240, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 71s 90ms/step - loss: 0.1811 - prediction_coarse_accuracy: 0.8536 - prediction_medium_accuracy: 0.7623 - prediction_fine_accuracy: 0.1904 - val_loss: 0.1821 - val_prediction_coarse_accuracy: 0.8030 - val_prediction_medium_accuracy: 0.6817 - val_prediction_fine_accuracy: 0.1824 - lr: 9.5000e-04
# Epoch 12/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1709 - prediction_coarse_accuracy: 0.8670 - prediction_medium_accuracy: 0.7858 - prediction_fine_accuracy: 0.2050
#   • Coarse Accuracy = 86.70% | Val_Accuracy = 81.18% | LossWeight = 0.26
#   • Medium Accuracy = 78.58% | Val_Accuracy = 69.94% | LossWeight = 0.38
#   • Fine   Accuracy = 20.50% | Val_Accuracy = 18.52% | LossWeight = 0.36
#
# Epoch 12: val_prediction_fine_accuracy improved from 0.18240 to 0.18520, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 71s 91ms/step - loss: 0.1709 - prediction_coarse_accuracy: 0.8670 - prediction_medium_accuracy: 0.7858 - prediction_fine_accuracy: 0.2050 - val_loss: 0.1731 - val_prediction_coarse_accuracy: 0.8118 - val_prediction_medium_accuracy: 0.6994 - val_prediction_fine_accuracy: 0.1852 - lr: 9.0250e-04
# Epoch 13/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1649 - prediction_coarse_accuracy: 0.8768 - prediction_medium_accuracy: 0.8039 - prediction_fine_accuracy: 0.2165
#   • Coarse Accuracy = 87.68% | Val_Accuracy = 81.51% | LossWeight = 0.26
#   • Medium Accuracy = 80.39% | Val_Accuracy = 70.64% | LossWeight = 0.37
#   • Fine   Accuracy = 21.65% | Val_Accuracy = 19.86% | LossWeight = 0.38
#
# Epoch 13: val_prediction_fine_accuracy improved from 0.18520 to 0.19860, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 71s 91ms/step - loss: 0.1649 - prediction_coarse_accuracy: 0.8768 - prediction_medium_accuracy: 0.8039 - prediction_fine_accuracy: 0.2165 - val_loss: 0.1695 - val_prediction_coarse_accuracy: 0.8151 - val_prediction_medium_accuracy: 0.7064 - val_prediction_fine_accuracy: 0.1986 - lr: 8.5737e-04
# Epoch 14/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1569 - prediction_coarse_accuracy: 0.8876 - prediction_medium_accuracy: 0.8217 - prediction_fine_accuracy: 0.2281
#   • Coarse Accuracy = 88.76% | Val_Accuracy = 82.11% | LossWeight = 0.25
#   • Medium Accuracy = 82.17% | Val_Accuracy = 70.94% | LossWeight = 0.35
#   • Fine   Accuracy = 22.81% | Val_Accuracy = 20.44% | LossWeight = 0.40
#
# Epoch 14: val_prediction_fine_accuracy improved from 0.19860 to 0.20440, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 71s 91ms/step - loss: 0.1569 - prediction_coarse_accuracy: 0.8876 - prediction_medium_accuracy: 0.8217 - prediction_fine_accuracy: 0.2281 - val_loss: 0.1649 - val_prediction_coarse_accuracy: 0.8211 - val_prediction_medium_accuracy: 0.7094 - val_prediction_fine_accuracy: 0.2044 - lr: 8.1451e-04
# Epoch 15/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1522 - prediction_coarse_accuracy: 0.8950 - prediction_medium_accuracy: 0.8334 - prediction_fine_accuracy: 0.2355
#   • Coarse Accuracy = 89.50% | Val_Accuracy = 83.02% | LossWeight = 0.24
#   • Medium Accuracy = 83.34% | Val_Accuracy = 72.15% | LossWeight = 0.35
#   • Fine   Accuracy = 23.55% | Val_Accuracy = 21.65% | LossWeight = 0.41
#
# Epoch 15: val_prediction_fine_accuracy improved from 0.20440 to 0.21650, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 71s 92ms/step - loss: 0.1522 - prediction_coarse_accuracy: 0.8950 - prediction_medium_accuracy: 0.8334 - prediction_fine_accuracy: 0.2355 - val_loss: 0.1613 - val_prediction_coarse_accuracy: 0.8302 - val_prediction_medium_accuracy: 0.7215 - val_prediction_fine_accuracy: 0.2165 - lr: 7.7378e-04
# Epoch 16/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1455 - prediction_coarse_accuracy: 0.9021 - prediction_medium_accuracy: 0.8473 - prediction_fine_accuracy: 0.2482
#   • Coarse Accuracy = 90.21% | Val_Accuracy = 83.27% | LossWeight = 0.24
#   • Medium Accuracy = 84.73% | Val_Accuracy = 72.51% | LossWeight = 0.33
#   • Fine   Accuracy = 24.82% | Val_Accuracy = 22.91% | LossWeight = 0.43
#
# Epoch 16: val_prediction_fine_accuracy improved from 0.21650 to 0.22910, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 72s 92ms/step - loss: 0.1455 - prediction_coarse_accuracy: 0.9021 - prediction_medium_accuracy: 0.8473 - prediction_fine_accuracy: 0.2482 - val_loss: 0.1550 - val_prediction_coarse_accuracy: 0.8327 - val_prediction_medium_accuracy: 0.7251 - val_prediction_fine_accuracy: 0.2291 - lr: 7.3509e-04
# Epoch 17/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1408 - prediction_coarse_accuracy: 0.9106 - prediction_medium_accuracy: 0.8591 - prediction_fine_accuracy: 0.2580
#   • Coarse Accuracy = 91.06% | Val_Accuracy = 83.55% | LossWeight = 0.23
#   • Medium Accuracy = 85.91% | Val_Accuracy = 73.17% | LossWeight = 0.33
#   • Fine   Accuracy = 25.80% | Val_Accuracy = 23.60% | LossWeight = 0.44
#
# Epoch 17: val_prediction_fine_accuracy improved from 0.22910 to 0.23600, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 71s 91ms/step - loss: 0.1408 - prediction_coarse_accuracy: 0.9106 - prediction_medium_accuracy: 0.8591 - prediction_fine_accuracy: 0.2580 - val_loss: 0.1548 - val_prediction_coarse_accuracy: 0.8355 - val_prediction_medium_accuracy: 0.7317 - val_prediction_fine_accuracy: 0.2360 - lr: 6.9834e-04
# Epoch 18/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1359 - prediction_coarse_accuracy: 0.9146 - prediction_medium_accuracy: 0.8696 - prediction_fine_accuracy: 0.2701
#   • Coarse Accuracy = 91.46% | Val_Accuracy = 84.04% | LossWeight = 0.23
#   • Medium Accuracy = 86.96% | Val_Accuracy = 73.88% | LossWeight = 0.31
#   • Fine   Accuracy = 27.01% | Val_Accuracy = 23.61% | LossWeight = 0.46
#
# Epoch 18: val_prediction_fine_accuracy improved from 0.23600 to 0.23610, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 68s 87ms/step - loss: 0.1359 - prediction_coarse_accuracy: 0.9146 - prediction_medium_accuracy: 0.8696 - prediction_fine_accuracy: 0.2701 - val_loss: 0.1508 - val_prediction_coarse_accuracy: 0.8404 - val_prediction_medium_accuracy: 0.7388 - val_prediction_fine_accuracy: 0.2361 - lr: 6.6342e-04
# Epoch 19/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1319 - prediction_coarse_accuracy: 0.9199 - prediction_medium_accuracy: 0.8808 - prediction_fine_accuracy: 0.2797
#   • Coarse Accuracy = 91.99% | Val_Accuracy = 83.97% | LossWeight = 0.23
#   • Medium Accuracy = 88.08% | Val_Accuracy = 73.51% | LossWeight = 0.30
#   • Fine   Accuracy = 27.97% | Val_Accuracy = 25.04% | LossWeight = 0.47
#
# Epoch 19: val_prediction_fine_accuracy improved from 0.23610 to 0.25040, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 62s 80ms/step - loss: 0.1319 - prediction_coarse_accuracy: 0.9199 - prediction_medium_accuracy: 0.8808 - prediction_fine_accuracy: 0.2797 - val_loss: 0.1504 - val_prediction_coarse_accuracy: 0.8397 - val_prediction_medium_accuracy: 0.7351 - val_prediction_fine_accuracy: 0.2504 - lr: 6.3025e-04
# Epoch 20/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1314 - prediction_coarse_accuracy: 0.9204 - prediction_medium_accuracy: 0.8808 - prediction_fine_accuracy: 0.2862
#   • Coarse Accuracy = 92.04% | Val_Accuracy = 84.46% | LossWeight = 0.23
#   • Medium Accuracy = 88.08% | Val_Accuracy = 74.07% | LossWeight = 0.30
#   • Fine   Accuracy = 28.62% | Val_Accuracy = 25.28% | LossWeight = 0.47
#
# Epoch 20: val_prediction_fine_accuracy improved from 0.25040 to 0.25280, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 60s 77ms/step - loss: 0.1314 - prediction_coarse_accuracy: 0.9204 - prediction_medium_accuracy: 0.8808 - prediction_fine_accuracy: 0.2862 - val_loss: 0.1495 - val_prediction_coarse_accuracy: 0.8446 - val_prediction_medium_accuracy: 0.7407 - val_prediction_fine_accuracy: 0.2528 - lr: 5.9874e-04
# Epoch 21/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1277 - prediction_coarse_accuracy: 0.9264 - prediction_medium_accuracy: 0.8916 - prediction_fine_accuracy: 0.2946
#   • Coarse Accuracy = 92.64% | Val_Accuracy = 84.49% | LossWeight = 0.22
#   • Medium Accuracy = 89.16% | Val_Accuracy = 74.12% | LossWeight = 0.29
#   • Fine   Accuracy = 29.46% | Val_Accuracy = 25.89% | LossWeight = 0.49
#
# Epoch 21: val_prediction_fine_accuracy improved from 0.25280 to 0.25890, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 70s 90ms/step - loss: 0.1277 - prediction_coarse_accuracy: 0.9264 - prediction_medium_accuracy: 0.8916 - prediction_fine_accuracy: 0.2946 - val_loss: 0.1478 - val_prediction_coarse_accuracy: 0.8449 - val_prediction_medium_accuracy: 0.7412 - val_prediction_fine_accuracy: 0.2589 - lr: 5.6880e-04
# Epoch 22/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1244 - prediction_coarse_accuracy: 0.9304 - prediction_medium_accuracy: 0.8966 - prediction_fine_accuracy: 0.3053
#   • Coarse Accuracy = 93.04% | Val_Accuracy = 84.07% | LossWeight = 0.21
#   • Medium Accuracy = 89.66% | Val_Accuracy = 74.06% | LossWeight = 0.29
#   • Fine   Accuracy = 30.53% | Val_Accuracy = 27.12% | LossWeight = 0.50
#
# Epoch 22: val_prediction_fine_accuracy improved from 0.25890 to 0.27120, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 76s 97ms/step - loss: 0.1244 - prediction_coarse_accuracy: 0.9304 - prediction_medium_accuracy: 0.8966 - prediction_fine_accuracy: 0.3053 - val_loss: 0.1472 - val_prediction_coarse_accuracy: 0.8407 - val_prediction_medium_accuracy: 0.7406 - val_prediction_fine_accuracy: 0.2712 - lr: 5.4036e-04
# Epoch 23/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1225 - prediction_coarse_accuracy: 0.9313 - prediction_medium_accuracy: 0.9034 - prediction_fine_accuracy: 0.3146
#   • Coarse Accuracy = 93.13% | Val_Accuracy = 84.60% | LossWeight = 0.22
#   • Medium Accuracy = 90.34% | Val_Accuracy = 74.44% | LossWeight = 0.28
#   • Fine   Accuracy = 31.46% | Val_Accuracy = 27.05% | LossWeight = 0.51
#
# Epoch 23: val_prediction_fine_accuracy did not improve from 0.27120
# 781/781 [==============================] - 80s 103ms/step - loss: 0.1225 - prediction_coarse_accuracy: 0.9313 - prediction_medium_accuracy: 0.9034 - prediction_fine_accuracy: 0.3146 - val_loss: 0.1459 - val_prediction_coarse_accuracy: 0.8460 - val_prediction_medium_accuracy: 0.7444 - val_prediction_fine_accuracy: 0.2705 - lr: 5.1334e-04
# Epoch 24/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1208 - prediction_coarse_accuracy: 0.9326 - prediction_medium_accuracy: 0.9066 - prediction_fine_accuracy: 0.3206
#   • Coarse Accuracy = 93.26% | Val_Accuracy = 84.93% | LossWeight = 0.22
#   • Medium Accuracy = 90.66% | Val_Accuracy = 74.48% | LossWeight = 0.27
#   • Fine   Accuracy = 32.06% | Val_Accuracy = 28.29% | LossWeight = 0.51
#
# Epoch 24: val_prediction_fine_accuracy improved from 0.27120 to 0.28290, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 80s 102ms/step - loss: 0.1208 - prediction_coarse_accuracy: 0.9326 - prediction_medium_accuracy: 0.9066 - prediction_fine_accuracy: 0.3206 - val_loss: 0.1446 - val_prediction_coarse_accuracy: 0.8493 - val_prediction_medium_accuracy: 0.7448 - val_prediction_fine_accuracy: 0.2829 - lr: 4.8767e-04
# Epoch 25/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1183 - prediction_coarse_accuracy: 0.9374 - prediction_medium_accuracy: 0.9120 - prediction_fine_accuracy: 0.3333
#   • Coarse Accuracy = 93.74% | Val_Accuracy = 84.63% | LossWeight = 0.21
#   • Medium Accuracy = 91.20% | Val_Accuracy = 74.60% | LossWeight = 0.27
#   • Fine   Accuracy = 33.33% | Val_Accuracy = 28.31% | LossWeight = 0.52
#
# Epoch 25: val_prediction_fine_accuracy improved from 0.28290 to 0.28310, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 71s 91ms/step - loss: 0.1183 - prediction_coarse_accuracy: 0.9374 - prediction_medium_accuracy: 0.9120 - prediction_fine_accuracy: 0.3333 - val_loss: 0.1451 - val_prediction_coarse_accuracy: 0.8463 - val_prediction_medium_accuracy: 0.7460 - val_prediction_fine_accuracy: 0.2831 - lr: 4.6329e-04
# Epoch 26/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1166 - prediction_coarse_accuracy: 0.9379 - prediction_medium_accuracy: 0.9146 - prediction_fine_accuracy: 0.3426
#   • Coarse Accuracy = 93.79% | Val_Accuracy = 84.78% | LossWeight = 0.21
#   • Medium Accuracy = 91.46% | Val_Accuracy = 74.85% | LossWeight = 0.26
#   • Fine   Accuracy = 34.26% | Val_Accuracy = 29.59% | LossWeight = 0.52
#
# Epoch 26: val_prediction_fine_accuracy improved from 0.28310 to 0.29590, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 71s 91ms/step - loss: 0.1166 - prediction_coarse_accuracy: 0.9379 - prediction_medium_accuracy: 0.9146 - prediction_fine_accuracy: 0.3426 - val_loss: 0.1426 - val_prediction_coarse_accuracy: 0.8478 - val_prediction_medium_accuracy: 0.7485 - val_prediction_fine_accuracy: 0.2959 - lr: 4.4013e-04
# Epoch 27/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1155 - prediction_coarse_accuracy: 0.9401 - prediction_medium_accuracy: 0.9163 - prediction_fine_accuracy: 0.3506
#   • Coarse Accuracy = 94.01% | Val_Accuracy = 83.49% | LossWeight = 0.21
#   • Medium Accuracy = 91.63% | Val_Accuracy = 73.42% | LossWeight = 0.26
#   • Fine   Accuracy = 35.06% | Val_Accuracy = 30.23% | LossWeight = 0.53
#
# Epoch 27: val_prediction_fine_accuracy improved from 0.29590 to 0.30230, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 70s 90ms/step - loss: 0.1155 - prediction_coarse_accuracy: 0.9401 - prediction_medium_accuracy: 0.9163 - prediction_fine_accuracy: 0.3506 - val_loss: 0.1477 - val_prediction_coarse_accuracy: 0.8349 - val_prediction_medium_accuracy: 0.7342 - val_prediction_fine_accuracy: 0.3023 - lr: 4.1812e-04
# Epoch 28/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1144 - prediction_coarse_accuracy: 0.9402 - prediction_medium_accuracy: 0.9181 - prediction_fine_accuracy: 0.3592
#   • Coarse Accuracy = 94.02% | Val_Accuracy = 84.55% | LossWeight = 0.21
#   • Medium Accuracy = 91.81% | Val_Accuracy = 75.19% | LossWeight = 0.26
#   • Fine   Accuracy = 35.92% | Val_Accuracy = 30.89% | LossWeight = 0.53
#
# Epoch 28: val_prediction_fine_accuracy improved from 0.30230 to 0.30890, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 70s 90ms/step - loss: 0.1144 - prediction_coarse_accuracy: 0.9402 - prediction_medium_accuracy: 0.9181 - prediction_fine_accuracy: 0.3592 - val_loss: 0.1406 - val_prediction_coarse_accuracy: 0.8455 - val_prediction_medium_accuracy: 0.7519 - val_prediction_fine_accuracy: 0.3089 - lr: 3.9721e-04
# Epoch 29/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1123 - prediction_coarse_accuracy: 0.9437 - prediction_medium_accuracy: 0.9233 - prediction_fine_accuracy: 0.3674
#   • Coarse Accuracy = 94.37% | Val_Accuracy = 85.15% | LossWeight = 0.21
#   • Medium Accuracy = 92.33% | Val_Accuracy = 75.51% | LossWeight = 0.25
#   • Fine   Accuracy = 36.74% | Val_Accuracy = 31.70% | LossWeight = 0.54
#
# Epoch 29: val_prediction_fine_accuracy improved from 0.30890 to 0.31700, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 73s 93ms/step - loss: 0.1123 - prediction_coarse_accuracy: 0.9437 - prediction_medium_accuracy: 0.9233 - prediction_fine_accuracy: 0.3674 - val_loss: 0.1378 - val_prediction_coarse_accuracy: 0.8515 - val_prediction_medium_accuracy: 0.7551 - val_prediction_fine_accuracy: 0.3170 - lr: 3.7735e-04
# Epoch 30/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1101 - prediction_coarse_accuracy: 0.9446 - prediction_medium_accuracy: 0.9266 - prediction_fine_accuracy: 0.3744
#   • Coarse Accuracy = 94.46% | Val_Accuracy = 84.87% | LossWeight = 0.21
#   • Medium Accuracy = 92.66% | Val_Accuracy = 75.32% | LossWeight = 0.25
#   • Fine   Accuracy = 37.44% | Val_Accuracy = 32.21% | LossWeight = 0.55
#
# Epoch 30: val_prediction_fine_accuracy improved from 0.31700 to 0.32210, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 82s 105ms/step - loss: 0.1101 - prediction_coarse_accuracy: 0.9446 - prediction_medium_accuracy: 0.9266 - prediction_fine_accuracy: 0.3744 - val_loss: 0.1389 - val_prediction_coarse_accuracy: 0.8487 - val_prediction_medium_accuracy: 0.7532 - val_prediction_fine_accuracy: 0.3221 - lr: 3.5849e-04
# Epoch 31/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1097 - prediction_coarse_accuracy: 0.9438 - prediction_medium_accuracy: 0.9262 - prediction_fine_accuracy: 0.3812
#   • Coarse Accuracy = 94.38% | Val_Accuracy = 84.66% | LossWeight = 0.21
#   • Medium Accuracy = 92.62% | Val_Accuracy = 75.31% | LossWeight = 0.25
#   • Fine   Accuracy = 38.12% | Val_Accuracy = 32.81% | LossWeight = 0.54
#
# Epoch 31: val_prediction_fine_accuracy improved from 0.32210 to 0.32810, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 72s 92ms/step - loss: 0.1097 - prediction_coarse_accuracy: 0.9438 - prediction_medium_accuracy: 0.9262 - prediction_fine_accuracy: 0.3812 - val_loss: 0.1399 - val_prediction_coarse_accuracy: 0.8466 - val_prediction_medium_accuracy: 0.7531 - val_prediction_fine_accuracy: 0.3281 - lr: 3.4056e-04
# Epoch 32/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1087 - prediction_coarse_accuracy: 0.9476 - prediction_medium_accuracy: 0.9294 - prediction_fine_accuracy: 0.3932
#   • Coarse Accuracy = 94.76% | Val_Accuracy = 85.49% | LossWeight = 0.20
#   • Medium Accuracy = 92.94% | Val_Accuracy = 75.70% | LossWeight = 0.25
#   • Fine   Accuracy = 39.32% | Val_Accuracy = 33.79% | LossWeight = 0.55
#
# Epoch 32: val_prediction_fine_accuracy improved from 0.32810 to 0.33790, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 71s 92ms/step - loss: 0.1087 - prediction_coarse_accuracy: 0.9476 - prediction_medium_accuracy: 0.9294 - prediction_fine_accuracy: 0.3932 - val_loss: 0.1368 - val_prediction_coarse_accuracy: 0.8549 - val_prediction_medium_accuracy: 0.7570 - val_prediction_fine_accuracy: 0.3379 - lr: 3.2353e-04
# Epoch 33/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1078 - prediction_coarse_accuracy: 0.9464 - prediction_medium_accuracy: 0.9282 - prediction_fine_accuracy: 0.4050
#   • Coarse Accuracy = 94.64% | Val_Accuracy = 85.46% | LossWeight = 0.21
#   • Medium Accuracy = 92.82% | Val_Accuracy = 75.39% | LossWeight = 0.25
#   • Fine   Accuracy = 40.50% | Val_Accuracy = 33.90% | LossWeight = 0.54
#
# Epoch 33: val_prediction_fine_accuracy improved from 0.33790 to 0.33900, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 71s 90ms/step - loss: 0.1078 - prediction_coarse_accuracy: 0.9464 - prediction_medium_accuracy: 0.9282 - prediction_fine_accuracy: 0.4050 - val_loss: 0.1362 - val_prediction_coarse_accuracy: 0.8546 - val_prediction_medium_accuracy: 0.7539 - val_prediction_fine_accuracy: 0.3390 - lr: 3.0736e-04
# Epoch 34/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1070 - prediction_coarse_accuracy: 0.9477 - prediction_medium_accuracy: 0.9309 - prediction_fine_accuracy: 0.4085
#   • Coarse Accuracy = 94.77% | Val_Accuracy = 85.14% | LossWeight = 0.21
#   • Medium Accuracy = 93.09% | Val_Accuracy = 75.76% | LossWeight = 0.25
#   • Fine   Accuracy = 40.85% | Val_Accuracy = 34.54% | LossWeight = 0.55
#
# Epoch 34: val_prediction_fine_accuracy improved from 0.33900 to 0.34540, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 70s 90ms/step - loss: 0.1070 - prediction_coarse_accuracy: 0.9477 - prediction_medium_accuracy: 0.9309 - prediction_fine_accuracy: 0.4085 - val_loss: 0.1368 - val_prediction_coarse_accuracy: 0.8514 - val_prediction_medium_accuracy: 0.7576 - val_prediction_fine_accuracy: 0.3454 - lr: 2.9199e-04
# Epoch 35/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1065 - prediction_coarse_accuracy: 0.9476 - prediction_medium_accuracy: 0.9290 - prediction_fine_accuracy: 0.4122
#   • Coarse Accuracy = 94.76% | Val_Accuracy = 85.17% | LossWeight = 0.21
#   • Medium Accuracy = 92.90% | Val_Accuracy = 75.62% | LossWeight = 0.25
#   • Fine   Accuracy = 41.22% | Val_Accuracy = 34.43% | LossWeight = 0.54
#
# Epoch 35: val_prediction_fine_accuracy did not improve from 0.34540
# 781/781 [==============================] - 70s 89ms/step - loss: 0.1065 - prediction_coarse_accuracy: 0.9476 - prediction_medium_accuracy: 0.9290 - prediction_fine_accuracy: 0.4122 - val_loss: 0.1360 - val_prediction_coarse_accuracy: 0.8517 - val_prediction_medium_accuracy: 0.7562 - val_prediction_fine_accuracy: 0.3443 - lr: 2.7739e-04
# Epoch 36/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1051 - prediction_coarse_accuracy: 0.9510 - prediction_medium_accuracy: 0.9345 - prediction_fine_accuracy: 0.4209
#   • Coarse Accuracy = 95.10% | Val_Accuracy = 85.09% | LossWeight = 0.20
#   • Medium Accuracy = 93.45% | Val_Accuracy = 76.04% | LossWeight = 0.24
#   • Fine   Accuracy = 42.09% | Val_Accuracy = 34.67% | LossWeight = 0.56
#
# Epoch 36: val_prediction_fine_accuracy improved from 0.34540 to 0.34670, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 64s 82ms/step - loss: 0.1051 - prediction_coarse_accuracy: 0.9510 - prediction_medium_accuracy: 0.9345 - prediction_fine_accuracy: 0.4209 - val_loss: 0.1357 - val_prediction_coarse_accuracy: 0.8509 - val_prediction_medium_accuracy: 0.7604 - val_prediction_fine_accuracy: 0.3467 - lr: 2.6352e-04
# Epoch 37/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1047 - prediction_coarse_accuracy: 0.9499 - prediction_medium_accuracy: 0.9325 - prediction_fine_accuracy: 0.4224
#   • Coarse Accuracy = 94.99% | Val_Accuracy = 85.56% | LossWeight = 0.20
#   • Medium Accuracy = 93.25% | Val_Accuracy = 75.96% | LossWeight = 0.25
#   • Fine   Accuracy = 42.24% | Val_Accuracy = 35.17% | LossWeight = 0.55
#
# Epoch 37: val_prediction_fine_accuracy improved from 0.34670 to 0.35170, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 78s 101ms/step - loss: 0.1047 - prediction_coarse_accuracy: 0.9499 - prediction_medium_accuracy: 0.9325 - prediction_fine_accuracy: 0.4224 - val_loss: 0.1339 - val_prediction_coarse_accuracy: 0.8556 - val_prediction_medium_accuracy: 0.7596 - val_prediction_fine_accuracy: 0.3517 - lr: 2.5034e-04
# Epoch 38/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1036 - prediction_coarse_accuracy: 0.9509 - prediction_medium_accuracy: 0.9361 - prediction_fine_accuracy: 0.4308
#   • Coarse Accuracy = 95.09% | Val_Accuracy = 85.42% | LossWeight = 0.20
#   • Medium Accuracy = 93.61% | Val_Accuracy = 75.86% | LossWeight = 0.24
#   • Fine   Accuracy = 43.08% | Val_Accuracy = 35.16% | LossWeight = 0.55
#
# Epoch 38: val_prediction_fine_accuracy did not improve from 0.35170
# 781/781 [==============================] - 77s 99ms/step - loss: 0.1036 - prediction_coarse_accuracy: 0.9509 - prediction_medium_accuracy: 0.9361 - prediction_fine_accuracy: 0.4308 - val_loss: 0.1342 - val_prediction_coarse_accuracy: 0.8542 - val_prediction_medium_accuracy: 0.7586 - val_prediction_fine_accuracy: 0.3516 - lr: 2.3783e-04
# Epoch 39/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1032 - prediction_coarse_accuracy: 0.9501 - prediction_medium_accuracy: 0.9351 - prediction_fine_accuracy: 0.4351
#   • Coarse Accuracy = 95.01% | Val_Accuracy = 85.53% | LossWeight = 0.21
#   • Medium Accuracy = 93.51% | Val_Accuracy = 76.03% | LossWeight = 0.24
#   • Fine   Accuracy = 43.51% | Val_Accuracy = 36.25% | LossWeight = 0.55
#
# Epoch 39: val_prediction_fine_accuracy improved from 0.35170 to 0.36250, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 77s 99ms/step - loss: 0.1032 - prediction_coarse_accuracy: 0.9501 - prediction_medium_accuracy: 0.9351 - prediction_fine_accuracy: 0.4351 - val_loss: 0.1336 - val_prediction_coarse_accuracy: 0.8553 - val_prediction_medium_accuracy: 0.7603 - val_prediction_fine_accuracy: 0.3625 - lr: 2.2594e-04
# Epoch 40/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1026 - prediction_coarse_accuracy: 0.9517 - prediction_medium_accuracy: 0.9371 - prediction_fine_accuracy: 0.4391
#   • Coarse Accuracy = 95.17% | Val_Accuracy = 85.91% | LossWeight = 0.20
#   • Medium Accuracy = 93.71% | Val_Accuracy = 76.50% | LossWeight = 0.24
#   • Fine   Accuracy = 43.91% | Val_Accuracy = 36.57% | LossWeight = 0.55
#
# Epoch 40: val_prediction_fine_accuracy improved from 0.36250 to 0.36570, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 78s 100ms/step - loss: 0.1026 - prediction_coarse_accuracy: 0.9517 - prediction_medium_accuracy: 0.9371 - prediction_fine_accuracy: 0.4391 - val_loss: 0.1341 - val_prediction_coarse_accuracy: 0.8591 - val_prediction_medium_accuracy: 0.7650 - val_prediction_fine_accuracy: 0.3657 - lr: 2.1464e-04
# Epoch 41/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1024 - prediction_coarse_accuracy: 0.9521 - prediction_medium_accuracy: 0.9383 - prediction_fine_accuracy: 0.4439
#   • Coarse Accuracy = 95.21% | Val_Accuracy = 85.05% | LossWeight = 0.21
#   • Medium Accuracy = 93.83% | Val_Accuracy = 75.89% | LossWeight = 0.24
#   • Fine   Accuracy = 44.39% | Val_Accuracy = 36.17% | LossWeight = 0.56
#
# Epoch 41: val_prediction_fine_accuracy did not improve from 0.36570
# 781/781 [==============================] - 77s 99ms/step - loss: 0.1024 - prediction_coarse_accuracy: 0.9521 - prediction_medium_accuracy: 0.9383 - prediction_fine_accuracy: 0.4439 - val_loss: 0.1337 - val_prediction_coarse_accuracy: 0.8505 - val_prediction_medium_accuracy: 0.7589 - val_prediction_fine_accuracy: 0.3617 - lr: 2.0391e-04
# Epoch 42/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1013 - prediction_coarse_accuracy: 0.9526 - prediction_medium_accuracy: 0.9385 - prediction_fine_accuracy: 0.4487
#   • Coarse Accuracy = 95.26% | Val_Accuracy = 85.11% | LossWeight = 0.20
#   • Medium Accuracy = 93.85% | Val_Accuracy = 76.21% | LossWeight = 0.24
#   • Fine   Accuracy = 44.87% | Val_Accuracy = 36.53% | LossWeight = 0.56
#
# Epoch 42: val_prediction_fine_accuracy did not improve from 0.36570
# 781/781 [==============================] - 77s 98ms/step - loss: 0.1013 - prediction_coarse_accuracy: 0.9526 - prediction_medium_accuracy: 0.9385 - prediction_fine_accuracy: 0.4487 - val_loss: 0.1332 - val_prediction_coarse_accuracy: 0.8511 - val_prediction_medium_accuracy: 0.7621 - val_prediction_fine_accuracy: 0.3653 - lr: 1.9371e-04
# Epoch 43/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1019 - prediction_coarse_accuracy: 0.9518 - prediction_medium_accuracy: 0.9376 - prediction_fine_accuracy: 0.4499
#   • Coarse Accuracy = 95.18% | Val_Accuracy = 85.78% | LossWeight = 0.21
#   • Medium Accuracy = 93.76% | Val_Accuracy = 76.91% | LossWeight = 0.24
#   • Fine   Accuracy = 44.99% | Val_Accuracy = 37.26% | LossWeight = 0.55
#
# Epoch 43: val_prediction_fine_accuracy improved from 0.36570 to 0.37260, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 73s 93ms/step - loss: 0.1019 - prediction_coarse_accuracy: 0.9518 - prediction_medium_accuracy: 0.9376 - prediction_fine_accuracy: 0.4499 - val_loss: 0.1318 - val_prediction_coarse_accuracy: 0.8578 - val_prediction_medium_accuracy: 0.7691 - val_prediction_fine_accuracy: 0.3726 - lr: 1.8403e-04
# Epoch 44/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1006 - prediction_coarse_accuracy: 0.9531 - prediction_medium_accuracy: 0.9394 - prediction_fine_accuracy: 0.4531
#   • Coarse Accuracy = 95.31% | Val_Accuracy = 85.27% | LossWeight = 0.20
#   • Medium Accuracy = 93.94% | Val_Accuracy = 76.61% | LossWeight = 0.24
#   • Fine   Accuracy = 45.31% | Val_Accuracy = 36.90% | LossWeight = 0.56
#
# Epoch 44: val_prediction_fine_accuracy did not improve from 0.37260
# 781/781 [==============================] - 65s 83ms/step - loss: 0.1006 - prediction_coarse_accuracy: 0.9531 - prediction_medium_accuracy: 0.9394 - prediction_fine_accuracy: 0.4531 - val_loss: 0.1319 - val_prediction_coarse_accuracy: 0.8527 - val_prediction_medium_accuracy: 0.7661 - val_prediction_fine_accuracy: 0.3690 - lr: 1.7482e-04
# Epoch 45/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0998 - prediction_coarse_accuracy: 0.9554 - prediction_medium_accuracy: 0.9422 - prediction_fine_accuracy: 0.4581
#   • Coarse Accuracy = 95.54% | Val_Accuracy = 85.45% | LossWeight = 0.20
#   • Medium Accuracy = 94.22% | Val_Accuracy = 76.40% | LossWeight = 0.23
#   • Fine   Accuracy = 45.81% | Val_Accuracy = 37.31% | LossWeight = 0.57
#
# Epoch 45: val_prediction_fine_accuracy improved from 0.37260 to 0.37310, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 63s 80ms/step - loss: 0.0998 - prediction_coarse_accuracy: 0.9554 - prediction_medium_accuracy: 0.9422 - prediction_fine_accuracy: 0.4581 - val_loss: 0.1313 - val_prediction_coarse_accuracy: 0.8545 - val_prediction_medium_accuracy: 0.7640 - val_prediction_fine_accuracy: 0.3731 - lr: 1.6608e-04
# Epoch 46/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0990 - prediction_coarse_accuracy: 0.9540 - prediction_medium_accuracy: 0.9407 - prediction_fine_accuracy: 0.4621
#   • Coarse Accuracy = 95.40% | Val_Accuracy = 85.81% | LossWeight = 0.20
#   • Medium Accuracy = 94.07% | Val_Accuracy = 76.57% | LossWeight = 0.24
#   • Fine   Accuracy = 46.21% | Val_Accuracy = 37.97% | LossWeight = 0.56
#
# Epoch 46: val_prediction_fine_accuracy improved from 0.37310 to 0.37970, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 62s 80ms/step - loss: 0.0990 - prediction_coarse_accuracy: 0.9540 - prediction_medium_accuracy: 0.9407 - prediction_fine_accuracy: 0.4621 - val_loss: 0.1305 - val_prediction_coarse_accuracy: 0.8581 - val_prediction_medium_accuracy: 0.7657 - val_prediction_fine_accuracy: 0.3797 - lr: 1.5778e-04
# Epoch 47/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0991 - prediction_coarse_accuracy: 0.9542 - prediction_medium_accuracy: 0.9422 - prediction_fine_accuracy: 0.4642
#   • Coarse Accuracy = 95.42% | Val_Accuracy = 85.65% | LossWeight = 0.21
#   • Medium Accuracy = 94.22% | Val_Accuracy = 76.39% | LossWeight = 0.23
#   • Fine   Accuracy = 46.42% | Val_Accuracy = 37.86% | LossWeight = 0.56
#
# Epoch 47: val_prediction_fine_accuracy did not improve from 0.37970
# 781/781 [==============================] - 57s 73ms/step - loss: 0.0991 - prediction_coarse_accuracy: 0.9542 - prediction_medium_accuracy: 0.9422 - prediction_fine_accuracy: 0.4642 - val_loss: 0.1310 - val_prediction_coarse_accuracy: 0.8565 - val_prediction_medium_accuracy: 0.7639 - val_prediction_fine_accuracy: 0.3786 - lr: 1.4989e-04
# Epoch 48/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0988 - prediction_coarse_accuracy: 0.9548 - prediction_medium_accuracy: 0.9422 - prediction_fine_accuracy: 0.4668
#   • Coarse Accuracy = 95.48% | Val_Accuracy = 85.47% | LossWeight = 0.20
#   • Medium Accuracy = 94.22% | Val_Accuracy = 76.30% | LossWeight = 0.23
#   • Fine   Accuracy = 46.68% | Val_Accuracy = 37.76% | LossWeight = 0.56
#
# Epoch 48: val_prediction_fine_accuracy did not improve from 0.37970
# 781/781 [==============================] - 54s 70ms/step - loss: 0.0988 - prediction_coarse_accuracy: 0.9548 - prediction_medium_accuracy: 0.9422 - prediction_fine_accuracy: 0.4668 - val_loss: 0.1307 - val_prediction_coarse_accuracy: 0.8547 - val_prediction_medium_accuracy: 0.7630 - val_prediction_fine_accuracy: 0.3776 - lr: 1.4240e-04
# Epoch 49/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0980 - prediction_coarse_accuracy: 0.9563 - prediction_medium_accuracy: 0.9430 - prediction_fine_accuracy: 0.4686
#   • Coarse Accuracy = 95.63% | Val_Accuracy = 85.55% | LossWeight = 0.20
#   • Medium Accuracy = 94.30% | Val_Accuracy = 76.52% | LossWeight = 0.23
#   • Fine   Accuracy = 46.86% | Val_Accuracy = 38.08% | LossWeight = 0.57
#
# Epoch 49: val_prediction_fine_accuracy improved from 0.37970 to 0.38080, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 56s 71ms/step - loss: 0.0980 - prediction_coarse_accuracy: 0.9563 - prediction_medium_accuracy: 0.9430 - prediction_fine_accuracy: 0.4686 - val_loss: 0.1305 - val_prediction_coarse_accuracy: 0.8555 - val_prediction_medium_accuracy: 0.7652 - val_prediction_fine_accuracy: 0.3808 - lr: 1.3528e-04
# Epoch 50/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0982 - prediction_coarse_accuracy: 0.9531 - prediction_medium_accuracy: 0.9409 - prediction_fine_accuracy: 0.4713
#   • Coarse Accuracy = 95.31% | Val_Accuracy = 85.61% | LossWeight = 0.21
#   • Medium Accuracy = 94.09% | Val_Accuracy = 76.54% | LossWeight = 0.24
#   • Fine   Accuracy = 47.13% | Val_Accuracy = 38.55% | LossWeight = 0.55
#
# Epoch 50: val_prediction_fine_accuracy improved from 0.38080 to 0.38550, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 55s 71ms/step - loss: 0.0982 - prediction_coarse_accuracy: 0.9531 - prediction_medium_accuracy: 0.9409 - prediction_fine_accuracy: 0.4713 - val_loss: 0.1296 - val_prediction_coarse_accuracy: 0.8561 - val_prediction_medium_accuracy: 0.7654 - val_prediction_fine_accuracy: 0.3855 - lr: 1.2851e-04
# Epoch 51/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0989 - prediction_coarse_accuracy: 0.9541 - prediction_medium_accuracy: 0.9431 - prediction_fine_accuracy: 0.4745
#   • Coarse Accuracy = 95.41% | Val_Accuracy = 85.53% | LossWeight = 0.21
#   • Medium Accuracy = 94.31% | Val_Accuracy = 76.55% | LossWeight = 0.23
#   • Fine   Accuracy = 47.45% | Val_Accuracy = 38.72% | LossWeight = 0.56
#
# Epoch 51: val_prediction_fine_accuracy improved from 0.38550 to 0.38720, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 54s 69ms/step - loss: 0.0989 - prediction_coarse_accuracy: 0.9541 - prediction_medium_accuracy: 0.9431 - prediction_fine_accuracy: 0.4745 - val_loss: 0.1307 - val_prediction_coarse_accuracy: 0.8553 - val_prediction_medium_accuracy: 0.7655 - val_prediction_fine_accuracy: 0.3872 - lr: 1.2209e-04
# Epoch 52/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0983 - prediction_coarse_accuracy: 0.9551 - prediction_medium_accuracy: 0.9422 - prediction_fine_accuracy: 0.4766
#   • Coarse Accuracy = 95.51% | Val_Accuracy = 85.59% | LossWeight = 0.20
#   • Medium Accuracy = 94.22% | Val_Accuracy = 76.52% | LossWeight = 0.24
#   • Fine   Accuracy = 47.66% | Val_Accuracy = 38.83% | LossWeight = 0.56
#
# Epoch 52: val_prediction_fine_accuracy improved from 0.38720 to 0.38830, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 55s 70ms/step - loss: 0.0983 - prediction_coarse_accuracy: 0.9551 - prediction_medium_accuracy: 0.9422 - prediction_fine_accuracy: 0.4766 - val_loss: 0.1302 - val_prediction_coarse_accuracy: 0.8559 - val_prediction_medium_accuracy: 0.7652 - val_prediction_fine_accuracy: 0.3883 - lr: 1.1598e-04
# Epoch 53/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0972 - prediction_coarse_accuracy: 0.9567 - prediction_medium_accuracy: 0.9436 - prediction_fine_accuracy: 0.4784
#   • Coarse Accuracy = 95.67% | Val_Accuracy = 85.78% | LossWeight = 0.20
#   • Medium Accuracy = 94.36% | Val_Accuracy = 76.71% | LossWeight = 0.24
#   • Fine   Accuracy = 47.84% | Val_Accuracy = 38.93% | LossWeight = 0.56
#
# Epoch 53: val_prediction_fine_accuracy improved from 0.38830 to 0.38930, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 55s 70ms/step - loss: 0.0972 - prediction_coarse_accuracy: 0.9567 - prediction_medium_accuracy: 0.9436 - prediction_fine_accuracy: 0.4784 - val_loss: 0.1296 - val_prediction_coarse_accuracy: 0.8578 - val_prediction_medium_accuracy: 0.7671 - val_prediction_fine_accuracy: 0.3893 - lr: 1.1018e-04
# Epoch 54/100
# ...
# Epoch 65/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0958 - prediction_coarse_accuracy: 0.9574 - prediction_medium_accuracy: 0.9456 - prediction_fine_accuracy: 0.5050
#   • Coarse Accuracy = 95.74% | Val_Accuracy = 86.03% | LossWeight = 0.21
#   • Medium Accuracy = 94.56% | Val_Accuracy = 77.35% | LossWeight = 0.24
#   • Fine   Accuracy = 50.50% | Val_Accuracy = 40.43% | LossWeight = 0.56
#
# Epoch 65: val_prediction_fine_accuracy improved from 0.40250 to 0.40430, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 53s 67ms/step - loss: 0.0958 - prediction_coarse_accuracy: 0.9574 - prediction_medium_accuracy: 0.9456 - prediction_fine_accuracy: 0.5050 - val_loss: 0.1275 - val_prediction_coarse_accuracy: 0.8603 - val_prediction_medium_accuracy: 0.7735 - val_prediction_fine_accuracy: 0.4043 - lr: 5.9539e-05
# Epoch 66/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0960 - prediction_coarse_accuracy: 0.9567 - prediction_medium_accuracy: 0.9451 - prediction_fine_accuracy: 0.5031
#   • Coarse Accuracy = 95.67% | Val_Accuracy = 86.06% | LossWeight = 0.21
#   • Medium Accuracy = 94.51% | Val_Accuracy = 77.09% | LossWeight = 0.24
#   • Fine   Accuracy = 50.31% | Val_Accuracy = 40.76% | LossWeight = 0.56
#
# Epoch 66: val_prediction_fine_accuracy improved from 0.40430 to 0.40760, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 52s 67ms/step - loss: 0.0960 - prediction_coarse_accuracy: 0.9567 - prediction_medium_accuracy: 0.9451 - prediction_fine_accuracy: 0.5031 - val_loss: 0.1277 - val_prediction_coarse_accuracy: 0.8606 - val_prediction_medium_accuracy: 0.7709 - val_prediction_fine_accuracy: 0.4076 - lr: 5.6562e-05
# Epoch 67/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0957 - prediction_coarse_accuracy: 0.9571 - prediction_medium_accuracy: 0.9458 - prediction_fine_accuracy: 0.5051
#   • Coarse Accuracy = 95.71% | Val_Accuracy = 86.15% | LossWeight = 0.21
#   • Medium Accuracy = 94.58% | Val_Accuracy = 77.16% | LossWeight = 0.24
#   • Fine   Accuracy = 50.51% | Val_Accuracy = 40.92% | LossWeight = 0.56
#
# Epoch 67: val_prediction_fine_accuracy improved from 0.40760 to 0.40920, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 52s 67ms/step - loss: 0.0957 - prediction_coarse_accuracy: 0.9571 - prediction_medium_accuracy: 0.9458 - prediction_fine_accuracy: 0.5051 - val_loss: 0.1273 - val_prediction_coarse_accuracy: 0.8615 - val_prediction_medium_accuracy: 0.7716 - val_prediction_fine_accuracy: 0.4092 - lr: 5.3734e-05
# Epoch 68/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0953 - prediction_coarse_accuracy: 0.9569 - prediction_medium_accuracy: 0.9451 - prediction_fine_accuracy: 0.5088
#   • Coarse Accuracy = 95.69% | Val_Accuracy = 86.12% | LossWeight = 0.21
#   • Medium Accuracy = 94.51% | Val_Accuracy = 77.39% | LossWeight = 0.24
#   • Fine   Accuracy = 50.88% | Val_Accuracy = 40.97% | LossWeight = 0.55
#
# Epoch 68: val_prediction_fine_accuracy improved from 0.40920 to 0.40970, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 53s 68ms/step - loss: 0.0953 - prediction_coarse_accuracy: 0.9569 - prediction_medium_accuracy: 0.9451 - prediction_fine_accuracy: 0.5088 - val_loss: 0.1273 - val_prediction_coarse_accuracy: 0.8612 - val_prediction_medium_accuracy: 0.7739 - val_prediction_fine_accuracy: 0.4097 - lr: 5.1047e-05
# Epoch 69/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0959 - prediction_coarse_accuracy: 0.9566 - prediction_medium_accuracy: 0.9437 - prediction_fine_accuracy: 0.5104
#   • Coarse Accuracy = 95.66% | Val_Accuracy = 86.03% | LossWeight = 0.21
#   • Medium Accuracy = 94.37% | Val_Accuracy = 77.23% | LossWeight = 0.24
#   • Fine   Accuracy = 51.04% | Val_Accuracy = 41.02% | LossWeight = 0.55
#
# Epoch 69: val_prediction_fine_accuracy improved from 0.40970 to 0.41020, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 73s 93ms/step - loss: 0.0959 - prediction_coarse_accuracy: 0.9566 - prediction_medium_accuracy: 0.9437 - prediction_fine_accuracy: 0.5104 - val_loss: 0.1272 - val_prediction_coarse_accuracy: 0.8603 - val_prediction_medium_accuracy: 0.7723 - val_prediction_fine_accuracy: 0.4102 - lr: 4.8495e-05
# Epoch 70/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0955 - prediction_coarse_accuracy: 0.9582 - prediction_medium_accuracy: 0.9457 - prediction_fine_accuracy: 0.5081
#   • Coarse Accuracy = 95.82% | Val_Accuracy = 86.17% | LossWeight = 0.20
#   • Medium Accuracy = 94.57% | Val_Accuracy = 77.38% | LossWeight = 0.24
#   • Fine   Accuracy = 50.81% | Val_Accuracy = 40.94% | LossWeight = 0.56
#
# Epoch 70: val_prediction_fine_accuracy did not improve from 0.41020
# 781/781 [==============================] - 84s 108ms/step - loss: 0.0955 - prediction_coarse_accuracy: 0.9582 - prediction_medium_accuracy: 0.9457 - prediction_fine_accuracy: 0.5081 - val_loss: 0.1271 - val_prediction_coarse_accuracy: 0.8617 - val_prediction_medium_accuracy: 0.7738 - val_prediction_fine_accuracy: 0.4094 - lr: 4.6070e-05
# Epoch 71/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0950 - prediction_coarse_accuracy: 0.9556 - prediction_medium_accuracy: 0.9452 - prediction_fine_accuracy: 0.5087
#   • Coarse Accuracy = 95.56% | Val_Accuracy = 86.02% | LossWeight = 0.21
#   • Medium Accuracy = 94.52% | Val_Accuracy = 77.27% | LossWeight = 0.24
#   • Fine   Accuracy = 50.87% | Val_Accuracy = 41.18% | LossWeight = 0.55
#
# Epoch 71: val_prediction_fine_accuracy improved from 0.41020 to 0.41180, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 86s 110ms/step - loss: 0.0950 - prediction_coarse_accuracy: 0.9556 - prediction_medium_accuracy: 0.9452 - prediction_fine_accuracy: 0.5087 - val_loss: 0.1270 - val_prediction_coarse_accuracy: 0.8602 - val_prediction_medium_accuracy: 0.7727 - val_prediction_fine_accuracy: 0.4118 - lr: 4.3766e-05
# Epoch 72/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0949 - prediction_coarse_accuracy: 0.9580 - prediction_medium_accuracy: 0.9484 - prediction_fine_accuracy: 0.5151
#   • Coarse Accuracy = 95.80% | Val_Accuracy = 86.06% | LossWeight = 0.21
#   • Medium Accuracy = 94.84% | Val_Accuracy = 77.50% | LossWeight = 0.23
#   • Fine   Accuracy = 51.51% | Val_Accuracy = 41.14% | LossWeight = 0.56
#
# Epoch 72: val_prediction_fine_accuracy did not improve from 0.41180
# 781/781 [==============================] - 87s 111ms/step - loss: 0.0949 - prediction_coarse_accuracy: 0.9580 - prediction_medium_accuracy: 0.9484 - prediction_fine_accuracy: 0.5151 - val_loss: 0.1276 - val_prediction_coarse_accuracy: 0.8606 - val_prediction_medium_accuracy: 0.7750 - val_prediction_fine_accuracy: 0.4114 - lr: 4.1578e-05
# Epoch 73/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0951 - prediction_coarse_accuracy: 0.9565 - prediction_medium_accuracy: 0.9450 - prediction_fine_accuracy: 0.5150
#   • Coarse Accuracy = 95.65% | Val_Accuracy = 86.18% | LossWeight = 0.21
#   • Medium Accuracy = 94.50% | Val_Accuracy = 77.36% | LossWeight = 0.24
#   • Fine   Accuracy = 51.50% | Val_Accuracy = 41.36% | LossWeight = 0.55
#
# Epoch 73: val_prediction_fine_accuracy improved from 0.41180 to 0.41360, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 87s 111ms/step - loss: 0.0951 - prediction_coarse_accuracy: 0.9565 - prediction_medium_accuracy: 0.9450 - prediction_fine_accuracy: 0.5150 - val_loss: 0.1271 - val_prediction_coarse_accuracy: 0.8618 - val_prediction_medium_accuracy: 0.7736 - val_prediction_fine_accuracy: 0.4136 - lr: 3.9499e-05
# Epoch 74/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0954 - prediction_coarse_accuracy: 0.9569 - prediction_medium_accuracy: 0.9449 - prediction_fine_accuracy: 0.5120
#   • Coarse Accuracy = 95.69% | Val_Accuracy = 86.05% | LossWeight = 0.21
#   • Medium Accuracy = 94.49% | Val_Accuracy = 77.19% | LossWeight = 0.24
#   • Fine   Accuracy = 51.20% | Val_Accuracy = 41.46% | LossWeight = 0.55
#
# Epoch 74: val_prediction_fine_accuracy improved from 0.41360 to 0.41460, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 88s 112ms/step - loss: 0.0954 - prediction_coarse_accuracy: 0.9569 - prediction_medium_accuracy: 0.9449 - prediction_fine_accuracy: 0.5120 - val_loss: 0.1276 - val_prediction_coarse_accuracy: 0.8605 - val_prediction_medium_accuracy: 0.7719 - val_prediction_fine_accuracy: 0.4146 - lr: 3.7524e-05
# Epoch 75/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0946 - prediction_coarse_accuracy: 0.9589 - prediction_medium_accuracy: 0.9459 - prediction_fine_accuracy: 0.5116
#   • Coarse Accuracy = 95.89% | Val_Accuracy = 85.96% | LossWeight = 0.20
#   • Medium Accuracy = 94.59% | Val_Accuracy = 77.30% | LossWeight = 0.24
#   • Fine   Accuracy = 51.16% | Val_Accuracy = 41.51% | LossWeight = 0.56
#
# Epoch 75: val_prediction_fine_accuracy improved from 0.41460 to 0.41510, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 87s 111ms/step - loss: 0.0946 - prediction_coarse_accuracy: 0.9589 - prediction_medium_accuracy: 0.9459 - prediction_fine_accuracy: 0.5116 - val_loss: 0.1275 - val_prediction_coarse_accuracy: 0.8596 - val_prediction_medium_accuracy: 0.7730 - val_prediction_fine_accuracy: 0.4151 - lr: 3.5648e-05
# Epoch 76/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0944 - prediction_coarse_accuracy: 0.9570 - prediction_medium_accuracy: 0.9458 - prediction_fine_accuracy: 0.5123
#   • Coarse Accuracy = 95.70% | Val_Accuracy = 86.18% | LossWeight = 0.21
#   • Medium Accuracy = 94.58% | Val_Accuracy = 77.24% | LossWeight = 0.24
#   • Fine   Accuracy = 51.23% | Val_Accuracy = 41.37% | LossWeight = 0.55
#
# Epoch 76: val_prediction_fine_accuracy did not improve from 0.41510
# 781/781 [==============================] - 86s 111ms/step - loss: 0.0944 - prediction_coarse_accuracy: 0.9570 - prediction_medium_accuracy: 0.9458 - prediction_fine_accuracy: 0.5123 - val_loss: 0.1263 - val_prediction_coarse_accuracy: 0.8618 - val_prediction_medium_accuracy: 0.7724 - val_prediction_fine_accuracy: 0.4137 - lr: 3.3866e-05
# Epoch 77/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0944 - prediction_coarse_accuracy: 0.9576 - prediction_medium_accuracy: 0.9471 - prediction_fine_accuracy: 0.5194
#   • Coarse Accuracy = 95.76% | Val_Accuracy = 86.18% | LossWeight = 0.21
#   • Medium Accuracy = 94.71% | Val_Accuracy = 77.38% | LossWeight = 0.24
#   • Fine   Accuracy = 51.94% | Val_Accuracy = 41.32% | LossWeight = 0.55
#
# Epoch 77: val_prediction_fine_accuracy did not improve from 0.41510
# 781/781 [==============================] - 86s 111ms/step - loss: 0.0944 - prediction_coarse_accuracy: 0.9576 - prediction_medium_accuracy: 0.9471 - prediction_fine_accuracy: 0.5194 - val_loss: 0.1268 - val_prediction_coarse_accuracy: 0.8618 - val_prediction_medium_accuracy: 0.7738 - val_prediction_fine_accuracy: 0.4132 - lr: 3.2172e-05
# Epoch 78/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0958 - prediction_coarse_accuracy: 0.9564 - prediction_medium_accuracy: 0.9442 - prediction_fine_accuracy: 0.5151
#   • Coarse Accuracy = 95.64% | Val_Accuracy = 86.08% | LossWeight = 0.21
#   • Medium Accuracy = 94.42% | Val_Accuracy = 77.31% | LossWeight = 0.24
#   • Fine   Accuracy = 51.51% | Val_Accuracy = 41.58% | LossWeight = 0.55
#
# Epoch 78: val_prediction_fine_accuracy improved from 0.41510 to 0.41580, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 87s 112ms/step - loss: 0.0958 - prediction_coarse_accuracy: 0.9564 - prediction_medium_accuracy: 0.9442 - prediction_fine_accuracy: 0.5151 - val_loss: 0.1267 - val_prediction_coarse_accuracy: 0.8608 - val_prediction_medium_accuracy: 0.7731 - val_prediction_fine_accuracy: 0.4158 - lr: 3.0564e-05
# Epoch 79/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0953 - prediction_coarse_accuracy: 0.9564 - prediction_medium_accuracy: 0.9447 - prediction_fine_accuracy: 0.5150
#   • Coarse Accuracy = 95.64% | Val_Accuracy = 86.19% | LossWeight = 0.21
#   • Medium Accuracy = 94.47% | Val_Accuracy = 77.45% | LossWeight = 0.24
#   • Fine   Accuracy = 51.50% | Val_Accuracy = 41.81% | LossWeight = 0.55
#
# Epoch 79: val_prediction_fine_accuracy improved from 0.41580 to 0.41810, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss\epoch-best.h5
# 781/781 [==============================] - 68s 88ms/step - loss: 0.0953 - prediction_coarse_accuracy: 0.9564 - prediction_medium_accuracy: 0.9447 - prediction_fine_accuracy: 0.5150 - val_loss: 0.1266 - val_prediction_coarse_accuracy: 0.8619 - val_prediction_medium_accuracy: 0.7745 - val_prediction_fine_accuracy: 0.4181 - lr: 2.9035e-05
# Epoch 80/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0948 - prediction_coarse_accuracy: 0.9577 - prediction_medium_accuracy: 0.9458 - prediction_fine_accuracy: 0.5160
#   • Coarse Accuracy = 95.77% | Val_Accuracy = 86.11% | LossWeight = 0.21
#   • Medium Accuracy = 94.58% | Val_Accuracy = 77.38% | LossWeight = 0.24
#   • Fine   Accuracy = 51.60% | Val_Accuracy = 41.77% | LossWeight = 0.55
#
# Epoch 80: val_prediction_fine_accuracy did not improve from 0.41810
# 781/781 [==============================] - 52s 67ms/step - loss: 0.0948 - prediction_coarse_accuracy: 0.9577 - prediction_medium_accuracy: 0.9458 - prediction_fine_accuracy: 0.5160 - val_loss: 0.1267 - val_prediction_coarse_accuracy: 0.8611 - val_prediction_medium_accuracy: 0.7738 - val_prediction_fine_accuracy: 0.4177 - lr: 2.7584e-05
# Epoch 81/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0944 - prediction_coarse_accuracy: 0.9582 - prediction_medium_accuracy: 0.9458 - prediction_fine_accuracy: 0.5209
#   • Coarse Accuracy = 95.82% | Val_Accuracy = 86.13% | LossWeight = 0.21
#   • Medium Accuracy = 94.58% | Val_Accuracy = 77.39% | LossWeight = 0.24
#   • Fine   Accuracy = 52.09% | Val_Accuracy = 41.71% | LossWeight = 0.55
#
# Epoch 81: val_prediction_fine_accuracy did not improve from 0.41810
# 781/781 [==============================] - 52s 67ms/step - loss: 0.0944 - prediction_coarse_accuracy: 0.9582 - prediction_medium_accuracy: 0.9458 - prediction_fine_accuracy: 0.5209 - val_loss: 0.1265 - val_prediction_coarse_accuracy: 0.8613 - val_prediction_medium_accuracy: 0.7739 - val_prediction_fine_accuracy: 0.4171 - lr: 2.6205e-05
# Epoch 82/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0947 - prediction_coarse_accuracy: 0.9565 - prediction_medium_accuracy: 0.9453 - prediction_fine_accuracy: 0.5195
#   • Coarse Accuracy = 95.65% | Val_Accuracy = 86.00% | LossWeight = 0.21
#   • Medium Accuracy = 94.53% | Val_Accuracy = 77.35% | LossWeight = 0.24
#   • Fine   Accuracy = 51.95% | Val_Accuracy = 41.44% | LossWeight = 0.55
#
# Epoch 82: val_prediction_fine_accuracy did not improve from 0.41810
# 781/781 [==============================] - 56s 71ms/step - loss: 0.0947 - prediction_coarse_accuracy: 0.9565 - prediction_medium_accuracy: 0.9453 - prediction_fine_accuracy: 0.5195 - val_loss: 0.1267 - val_prediction_coarse_accuracy: 0.8600 - val_prediction_medium_accuracy: 0.7735 - val_prediction_fine_accuracy: 0.4144 - lr: 2.4894e-05
# Epoch 83/100
# 738/781 [===========================>..] - ETA: 2s - loss: 0.0946 - prediction_coarse_accuracy: 0.9587 - prediction_medium_accuracy: 0.9465 - prediction_fine_accuracy: 0.5177

# %%
try:
    history_dict = history.history

    plotter = tfdocs.plots.HistoryPlotter()
    plotter.plot({"Coarse": history}, metric = "prediction_coarse_accuracy")
    plotter.plot({"Medium": history}, metric = "prediction_medium_accuracy")
    plotter.plot({"Fine": history}, metric = "prediction_fine_accuracy")
    plt.title("Model Accuracy")
    plt.ylim([0,1])
except:
    print('Trained model weights loaded')

# %%
try:
    plotter = tfdocs.plots.HistoryPlotter()
    plotter.plot({"loss": history}, metric = "loss")
    plt.title("Model Loss")
    plt.ylim([0,1])
except:
    print('Trained model weights loaded')

# %% [markdown]
# ## Model Analysis

# %%
final_model = keras.Model(model.inputs[:1], model.output)

lossfn = models.MarginLoss()
final_model.compile(optimizer='adam', 
                    loss={'prediction_fine' : lossfn,
                          'prediction_medium' : lossfn,
                          'prediction_coarse' : lossfn},

                    loss_weights={'prediction_fine' : lossweight['fine_lw'],
                                  'prediction_medium' : lossweight['medium_lw'],
                                  'prediction_coarse' : lossweight['coarse_lw']},

                    metrics={'prediction_fine': 'accuracy',
                             'prediction_medium': 'accuracy',
                             'prediction_coarse': 'accuracy'
                            }
                   )

# %%
model_analysis = models.model_analysis(final_model, dataset)
results = model_analysis.evaluate()
predictions = model_analysis.prediction()

# %%
true_label = [dataset['y_test_coarse'],dataset['y_test_medium'],dataset['y_test_fine']]
pred_label = [predictions[0],predictions[1],predictions[2]]
metrics.lvl_wise_metric(true_label,pred_label)

# %%
h_measurements,consistency,exact_match = metrics.hmeasurements(true_label,
                                       pred_label,
                                       dataset['tree'])
print('\nHierarchical Precision =',h_measurements[0],
      '\nHierarchical Recall =', h_measurements[1],
      '\nHierarchical F1-Score =',h_measurements[2],
      '\nConsistency = ', consistency,
      '\nExact Match = ', exact_match,
     )

# %% [markdown]
# # Training Again

# %%
model_save_dir = str(directory+'/trained_model_2.h5')
try:
    model.load_weights(model_save_dir)
except:
    history = model.fit(training_generator,
                        steps_per_epoch = int(dataset['x_train'].shape[0] / train_params["batch_size"]),
                        epochs = train_params["n_epochs"],
                        validation_data = ([dataset['x_test'],
                                            dataset['y_test_coarse'],dataset['y_test_medium'],dataset['y_test_fine']],
                                           [dataset['y_test_coarse'],dataset['y_test_medium'],dataset['y_test_fine']]),
                        callbacks = [tb,log,change_lw,lr_decay,checkpoint],
                        verbose=1)
    
    model.save_weights(model_save_dir)

# %%
history_dict = history.history

# %%
plotter = tfdocs.plots.HistoryPlotter()
plotter.plot({"Coarse": history}, metric = "prediction_coarse_accuracy")
plotter.plot({"Medium": history}, metric = "prediction_medium_accuracy")
plotter.plot({"Fine": history}, metric = "prediction_fine_accuracy")
plt.title("Model Accuracy")
plt.ylim([0,1])

# %%
plotter = tfdocs.plots.HistoryPlotter()
plotter.plot({"loss": history}, metric = "loss")
plt.title("Model Loss")
plt.ylim([0,1])

# %% [markdown]
# ## Model Analysis

# %%
final_model = keras.Model(model.inputs[:1], model.output)

lossfn = models.MarginLoss()
final_model.compile(optimizer='adam', 
                    loss={'prediction_fine' : lossfn,
                          'prediction_medium' : lossfn,
                          'prediction_coarse' : lossfn},

                    loss_weights={'prediction_fine' : lossweight['fine_lw'],
                                  'prediction_medium' : lossweight['medium_lw'],
                                  'prediction_coarse' : lossweight['coarse_lw']},

                    metrics={'prediction_fine': 'accuracy',
                             'prediction_medium': 'accuracy',
                             'prediction_coarse': 'accuracy'
                            }
                   )

# %%
model_analysis = models.model_analysis(final_model, dataset)
results = model_analysis.evaluate()
predictions = model_analysis.prediction()

# %%
true_label = [dataset['y_test_coarse'],dataset['y_test_medium'],dataset['y_test_fine']]
pred_label = [predictions[0],predictions[1],predictions[2]]
metrics.lvl_wise_metric(true_label,pred_label)

# %%
h_measurements,consistency,exact_match = metrics.hmeasurements(true_label,
                                       pred_label,
                                       dataset['tree'])
print('\nHierarchical Precision =',h_measurements[0],
      '\nHierarchical Recall =', h_measurements[1],
      '\nHierarchical F1-Score =',h_measurements[2],
      '\nConsistency = ', consistency,
      '\nExact Match = ', exact_match,
     )
