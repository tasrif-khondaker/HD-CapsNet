# %% [markdown]
# ***
# <font size="6"><center><b> HD-CapsNet: A Hierarchical Deep Capsule Network for Image Classification </b></center></font>
# ***

# %% [markdown]
# **Changing Model Architecture**
# - **(Mod-2.2)** From coarse-to-Fine slowly decrease the dimension. i.e. 32D>16D>8D (Coarse>Medium>FINE), While changing the primary capsule dimension ($P_{capsule} = 16D$). Training with $L_{cons}$

# %% [markdown]
# # Files and Libraries

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras import regularizers, optimizers
from tensorflow.keras import backend as K

import tensorflow_docs as tfdocs
import tensorflow_docs.plots

# Supporting Libraries:
    #Mathplot lib for ploting graphs
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
    # numpy and pandas
import numpy as np
import pandas as pd
    #system
import os
import sys
import csv
    #import other libraries
import math
import random
from datetime import datetime
from treelib import Tree
    # ML model, Dataset and evalution metrics
sys.path.append('../../') ### adding system parth for src folder
from src import datasets # load datasets
from src import MixUp_add_loss # load datasets
from src import metrics # load hierarchcial metrics
from src import sysenv # load hierarchcial metrics
from src import models # load machine learning models

    ## Tensorflow_docs
import tensorflow_docs as tfdocs
import tensorflow_docs.plots

    # Auto reload local libraries if updated
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # System information & GPU growth

# %%
systeminfo = sysenv.systeminfo()
print(systeminfo)
# Out:
# • Computer Name = SARUMAN
# • Working Directory = D:\knoor\Deep Learning with Python\RunningOnServer\HD-CapsNet_MOD_2\Training_and_Analysis\4_CIFAR-100
# • Python Version = 3.8.12 (default, Oct 12 2021, 03:01:40) [MSC v.1916 64 bit (AMD64)]
# • TensorFlow Version = 2.8.0
# • Keras Version = 2.8.0
# • Current Environment = Anaconda Environment Name : D:\knoor\AnacondaEnvironment\py38tf28

# %%
gpus = "0,1,2,3,4,5,6,7" ## Selecting Available gpus (Multi-GPUS)
gpus = "5" ## Selecting Available gpus (Single GPU)
gpugrowth = sysenv.gpugrowth(gpus = gpus) ## Limiting GPUS from OS environment
gpugrowth.memory_growth() #GPU memory growth
# Out:
# Following GPUS are selected =  5
# Done: GPU PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# 1 Physical GPUs, 1 Logical GPUs

# %% [markdown]
# ## log directory

# %%
directory = sysenv.log_dir('MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16')
# Out:
# FOLDER CREATED =  ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16

# %% [markdown]
# # Import Dataset : CIFAR-100

# %%
dataset = datasets.CIFAR100(version = 'ALL') # importing CIFAR10 Dataset
# dataset = datasets.CIFAR100(version = 'reduce') # importing CIFAR10 Dataset
# Out:
# CIFAR-100 dataset: Training have 50,000 samples and testing have 10,000 samples

# %% [markdown]
# # Parameters

# %%
train_params = {"n_epochs" : 100,
                "batch_size": 64,
                "lr": 0.001, # Initial learning rate
                "lr_decay": 0.95, # Learning rate decay
                "decay_exe": 9, #learning rate decay execution epoch after
               }
model_params = {"optimizer": tf.keras.optimizers.Adam(train_params['lr']),
                "loss_function": models.MarginLoss(),
               }

# %% [markdown]
# ## Learning Rate Decay Scheduler

# %%
def scheduler(epoch):
    learning_rate_init = train_params["lr"]
    
    if epoch > train_params["decay_exe"]:
        learning_rate_init = train_params["lr"] * (train_params["lr_decay"] ** (epoch-9))
        
    tf.summary.scalar('learning rate', data=learning_rate_init, step=epoch)
        
    return learning_rate_init

# %% [markdown]
# # Bottom up Approach

# %% [markdown]
# ## Loss Function

# %%
number_of_classes_c = len(np.unique(np.argmax(dataset['y_train_coarse'], axis=1)))
number_of_classes_m = len(np.unique(np.argmax(dataset['y_train_medium'], axis=1)))
number_of_classes_f = len(np.unique(np.argmax(dataset['y_train_fine'], axis=1)))

## For Dynamic LossWeights
initial_lw = models.initial_lw({"coarse": number_of_classes_c,
                                "medium": number_of_classes_m,
                                "fine": number_of_classes_f})

lossweight = {'coarse_lw' : K.variable(value = initial_lw['coarse'], dtype="float32", name="coarse_lw"),
             'medium_lw' : K.variable(value = initial_lw['medium'], dtype="float32", name="medium_lw"),
             'fine_lw' : K.variable(value = initial_lw['fine'], dtype="float32", name="fine_lw"),
              'decoder_lw' : 0.0
             }

# %%
coarse_to_medium_array = np.zeros(shape=[number_of_classes_c,number_of_classes_m], dtype=np.int32)
medium_to_fine_array = np.zeros(shape=[number_of_classes_m,number_of_classes_f], dtype=np.int32)

c_id = np.argmax(dataset['y_train_coarse'],1)

m_id = np.argmax(dataset['y_train_medium'],1)

f_id = np.argmax(dataset['y_train_fine'],1)

for x in range(len(dataset['y_test_medium'])):
    coarse_to_medium_array[c_id[x]][m_id[x]] = 1
    
for x in range(len(dataset['y_test_fine'])):
    medium_to_fine_array[m_id[x]][f_id[x]] = 1

Matrix_coarse_to_medium_OneHot = tf.constant(coarse_to_medium_array, dtype=tf.float32)
Matrix_medium_to_fine_OneHot = tf.constant(medium_to_fine_array, dtype=tf.float32)

# %%
def margin_loss(y_true, y_proba):
    
    present_error_raw = tf.square(tf.maximum(0., 0.9 - y_proba), name="present_error_raw")
    absent_error_raw = tf.square(tf.maximum(0., y_proba - 0.1), name="absent_error_raw")
    L = tf.add(y_true * present_error_raw, 0.5 * (1.0 - y_true) * absent_error_raw,name="L")
    total_marginloss = tf.reduce_sum(L, axis=1, name="margin_loss")

    return total_marginloss


def consistency_check(y_pred_ancestor,y_pred_current,lookup_matrix,num_class_current):
    pred_max_ancestor = tf.argmax(y_pred_ancestor,axis=1)
    pred_max_current = tf.argmax(y_pred_current,axis=1)
    
    consistant_check = tf.gather(lookup_matrix, indices=pred_max_ancestor)*tf.one_hot(pred_max_current,num_class_current)
    
    return tf.reduce_sum(consistant_check,1)

def get_consistency(y_true_ancestor, y_pred, lookup_matrix):
    '''
    Get consistency based on 2 levels
    Provide ture levels for the level above, predictions for the current level and a look up metrix
    '''
    y_prob = tf.math.divide(y_pred,tf.reshape(tf.reduce_sum(y_pred,-1),(-1,1),name='reshape'),name='Probability')
    
    index_for_predictions = tf.cast(tf.math.argmax(y_true_ancestor,axis=1),dtype= 'int32')
    consistent_fine = tf.gather(lookup_matrix, indices=index_for_predictions) * y_prob
    Consistency_sum_array = tf.reduce_sum(consistent_fine, axis =1)
    
    return tf.abs(1-Consistency_sum_array)

def CustomLoss(y_true_c, y_true_m, y_true_f, y_pred_c, y_pred_m, y_pred_f, LW_C, LW_M, LW_F,tree: Tree,C_Weight=0.2):
    
    con_m = consistency_check(y_pred_c,y_pred_m,Matrix_coarse_to_medium_OneHot,num_class_current=number_of_classes_m)
    con_m_not = tf.abs(con_m-1)
    
    con_f = consistency_check(y_pred_m,y_pred_f,Matrix_medium_to_fine_OneHot,num_class_current=number_of_classes_f)
    con_f_not = tf.abs(con_f-1)
    
    con_sum_m = get_consistency(y_true_c,y_pred_m,Matrix_coarse_to_medium_OneHot)
    con_sum_f = get_consistency(y_true_m,y_pred_f,Matrix_medium_to_fine_OneHot)
    
    medium_lvl_cosistency = con_sum_m * con_m_not
    fine_lvl_cosistency = con_sum_f * con_f_not    
   
    ML_c = margin_loss(y_true_c, y_pred_c)*LW_C
    ML_m = LW_M*((1-C_Weight)*(margin_loss(y_true_m, y_pred_m))+C_Weight*(medium_lvl_cosistency))
    ML_f = LW_F*((1-C_Weight)*(margin_loss(y_true_f, y_pred_f))+C_Weight*(fine_lvl_cosistency))
    
    batch_loss = ML_c + ML_m+ ML_f

    return tf.reduce_mean(batch_loss)

# %% [markdown]
# ## Model Architecture

# %%
def get_compiled_model():
    input_shape = dataset['x_train'].shape[1:]

    input_shape_yc = dataset['y_train_coarse'].shape[1:]
    input_shape_ym = dataset['y_train_medium'].shape[1:]
    input_shape_yf = dataset['y_train_fine'].shape[1:]

    no_coarse_class = number_of_classes_c
    no_medium_class = number_of_classes_m
    no_fine_class = number_of_classes_f

    PCap_n_dims = 16

    SCap_f_dims = 8
    SCap_m_dims = 16
    SCap_c_dims = 32


    # Input image
    x_input = keras.layers.Input(shape=input_shape, name="Input_Image")

    # Input True Labels
    y_c = keras.layers.Input(shape=input_shape_yc, name='input_yc')
    y_m = keras.layers.Input(shape=input_shape_ym, name='input_ym')
    y_f = keras.layers.Input(shape=input_shape_yf, name='input_yf')

    #--- block 1 ---
    x = keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv1')(x_input)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv2')(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.MaxPooling2D((2, 2), strides=(2, 2), name='block1_pool')(x)

    #--- block 2 ---
    x = keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv1')(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv2')(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.MaxPooling2D((2, 2), strides=(2, 2), name='block2_pool')(x)

    #--- block 3 ---
    x = keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv1')(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv2')(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.MaxPooling2D((2, 2), strides=(2, 2), name='block3_pool')(x)

    #--- block 4 ---
    x = keras.layers.Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv1')(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv2')(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.MaxPooling2D((2, 2), strides=(2, 2), name='block4_pool')(x)


    # Layer 3: Reshape to 8D primary capsules 
    reshapec = keras.layers.Reshape((int((tf.reduce_prod(x.shape[1:]).numpy())/PCap_n_dims),
                                     PCap_n_dims), name="reshape_layer")(x)
    p_caps = keras.layers.Lambda(models.squash, name='p_caps')(reshapec)

    ## Layer Secondary Capsule: For coarse level
    s_caps_c = models.SecondaryCapsule(n_caps=no_coarse_class, n_dims=SCap_c_dims, 
                        name="s_caps_coarse")(p_caps)
    
    ## Layer Secondary Capsule: For medium level
    s_caps_m = models.SecondaryCapsule(n_caps=no_medium_class, n_dims=SCap_m_dims, 
                        name="s_caps_medium")(s_caps_c)

    ## Layer Secondary Capsule: For fine level
    s_caps_f = models.SecondaryCapsule(n_caps=no_fine_class, n_dims=SCap_f_dims, 
                        name="s_caps_fine")(s_caps_m)

    pred_c = models.LengthLayer(name='prediction_coarse')(s_caps_c)

    pred_m = models.LengthLayer(name='prediction_medium')(s_caps_m)

    pred_f = models.LengthLayer(name='prediction_fine')(s_caps_f)

    model = keras.Model(inputs= [x_input, y_c, y_m, y_f],
                        outputs= [pred_c, pred_m, pred_f],
                        name='HD-CapsNet')

    model.add_loss(CustomLoss(y_c, y_m, y_f, pred_c, pred_m, pred_f, 
                              lossweight['coarse_lw'], lossweight['medium_lw'], lossweight['fine_lw'],
                              dataset['tree']))

    model.compile(optimizer='adam',                  
                  metrics={'prediction_fine': 'accuracy',
                           'prediction_medium': 'accuracy',
                           'prediction_coarse': 'accuracy'
                          }
    )
    return model

# %%
model = get_compiled_model()
# Out:
# WARNING:tensorflow:The following Variables were used in a Lambda layer's call (tf.math.multiply_9), but are not present in its tracked objects:   <tf.Variable 'coarse_lw:0' shape=() dtype=float32>. This is a strong indication that the Lambda layer should be rewritten as a subclassed Layer.

# %% [raw]
# strategy = multi_gpu_select('windows')
#
# print("Number of devices: {}".format(strategy.num_replicas_in_sync))
#
# with strategy.scope():
#     # Everything that creates variables should be under the strategy scope.
#     # In general this is only model construction & `compile()`.
#     model = get_compiled_model()

# %%
model.summary()
# keras.utils.plot_model(model, to_file = directory+"/Architecture.png", show_shapes=True)
# Out:
# Model: "HD-CapsNet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Input_Image (InputLayer)       [(None, 32, 32, 3)]  0           []
#
#  block1_conv1 (Conv2D)          (None, 32, 32, 64)   1792        ['Input_Image[0][0]']
#
#  batch_normalization (BatchNorm  (None, 32, 32, 64)  256         ['block1_conv1[0][0]']
#  alization)
#
#  block1_conv2 (Conv2D)          (None, 32, 32, 64)   36928       ['batch_normalization[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 32, 32, 64)  256         ['block1_conv2[0][0]']
#  rmalization)
#
#  block1_pool (MaxPooling2D)     (None, 16, 16, 64)   0           ['batch_normalization_1[0][0]']
#
#  block2_conv1 (Conv2D)          (None, 16, 16, 128)  73856       ['block1_pool[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 16, 16, 128)  512        ['block2_conv1[0][0]']
#  rmalization)
#
#  block2_conv2 (Conv2D)          (None, 16, 16, 128)  147584      ['batch_normalization_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 16, 16, 128)  512        ['block2_conv2[0][0]']
#  rmalization)
#
#  block2_pool (MaxPooling2D)     (None, 8, 8, 128)    0           ['batch_normalization_3[0][0]']
#
#  block3_conv1 (Conv2D)          (None, 8, 8, 256)    295168      ['block2_pool[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 8, 8, 256)   1024        ['block3_conv1[0][0]']
#  rmalization)
#
#  block3_conv2 (Conv2D)          (None, 8, 8, 256)    590080      ['batch_normalization_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 8, 8, 256)   1024        ['block3_conv2[0][0]']
#  rmalization)
#
#  block3_pool (MaxPooling2D)     (None, 4, 4, 256)    0           ['batch_normalization_5[0][0]']
#
#  block4_conv1 (Conv2D)          (None, 4, 4, 512)    1180160     ['block3_pool[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 4, 4, 512)   2048        ['block4_conv1[0][0]']
#  rmalization)
#
#  block4_conv2 (Conv2D)          (None, 4, 4, 512)    2359808     ['batch_normalization_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 4, 4, 512)   2048        ['block4_conv2[0][0]']
#  rmalization)
#
#  block4_pool (MaxPooling2D)     (None, 2, 2, 512)    0           ['batch_normalization_7[0][0]']
#
#  reshape_layer (Reshape)        (None, 128, 16)      0           ['block4_pool[0][0]']
#
#  p_caps (Lambda)                (None, 128, 16)      0           ['reshape_layer[0][0]']
#
#  s_caps_coarse (SecondaryCapsul  (None, 8, 32)       524288      ['p_caps[0][0]']
#  e)
#
#  s_caps_medium (SecondaryCapsul  (None, 20, 16)      81920       ['s_caps_coarse[0][0]']
#  e)
#
#  s_caps_fine (SecondaryCapsule)  (None, 100, 8)      256000      ['s_caps_medium[0][0]']
#
#  input_yc (InputLayer)          [(None, 8)]          0           []
#
#  input_ym (InputLayer)          [(None, 20)]         0           []
#
#  input_yf (InputLayer)          [(None, 100)]        0           []
#
#  prediction_coarse (LengthLayer  (None, 8)           0           ['s_caps_coarse[0][0]']
#  )
#
#  prediction_medium (LengthLayer  (None, 20)          0           ['s_caps_medium[0][0]']
#  )
#
#  prediction_fine (LengthLayer)  (None, 100)          0           ['s_caps_fine[0][0]']
#
#  tf.math.argmax_4 (TFOpLambda)  (None,)              0           ['input_yc[0][0]']
#
#  tf.math.reduce_sum_2 (TFOpLamb  (None,)             0           ['prediction_medium[0][0]']
#  da)
#
#  tf.cast (TFOpLambda)           (None,)              0           ['tf.math.argmax_4[0][0]']
#
#  tf.reshape (TFOpLambda)        (None, 1)            0           ['tf.math.reduce_sum_2[0][0]']
#
#  tf.math.argmax (TFOpLambda)    (None,)              0           ['prediction_coarse[0][0]']
#
#  tf.math.argmax_1 (TFOpLambda)  (None,)              0           ['prediction_medium[0][0]']
#
#  tf.math.argmax_5 (TFOpLambda)  (None,)              0           ['input_ym[0][0]']
#
#  tf.math.reduce_sum_4 (TFOpLamb  (None,)             0           ['prediction_fine[0][0]']
#  da)
#
#  tf.math.subtract_7 (TFOpLambda  (None, 20)          0           ['prediction_medium[0][0]']
#  )
#
#  tf.math.subtract_8 (TFOpLambda  (None, 20)          0           ['prediction_medium[0][0]']
#  )
#
#  tf.compat.v1.gather_2 (TFOpLam  (None, 20)          0           ['tf.cast[0][0]']
#  bda)
#
#  tf.math.divide (TFOpLambda)    (None, 20)           0           ['prediction_medium[0][0]',
#                                                                   'tf.reshape[0][0]']
#
#  tf.compat.v1.gather (TFOpLambd  (None, 20)          0           ['tf.math.argmax[0][0]']
#  a)
#
#  tf.one_hot (TFOpLambda)        (None, 20)           0           ['tf.math.argmax_1[0][0]']
#
#  tf.cast_1 (TFOpLambda)         (None,)              0           ['tf.math.argmax_5[0][0]']
#
#  tf.reshape_1 (TFOpLambda)      (None, 1)            0           ['tf.math.reduce_sum_4[0][0]']
#
#  tf.math.argmax_2 (TFOpLambda)  (None,)              0           ['prediction_medium[0][0]']
#
#  tf.math.argmax_3 (TFOpLambda)  (None,)              0           ['prediction_fine[0][0]']
#
#  tf.math.maximum_2 (TFOpLambda)  (None, 20)          0           ['tf.math.subtract_7[0][0]']
#
#  tf.math.subtract_9 (TFOpLambda  (None, 20)          0           ['input_ym[0][0]']
#  )
#
#  tf.math.maximum_3 (TFOpLambda)  (None, 20)          0           ['tf.math.subtract_8[0][0]']
#
#  tf.math.multiply_2 (TFOpLambda  (None, 20)          0           ['tf.compat.v1.gather_2[0][0]',
#  )                                                                'tf.math.divide[0][0]']
#
#  tf.math.multiply (TFOpLambda)  (None, 20)           0           ['tf.compat.v1.gather[0][0]',
#                                                                   'tf.one_hot[0][0]']
#
#  tf.math.subtract_10 (TFOpLambd  (None, 100)         0           ['prediction_fine[0][0]']
#  a)
#
#  tf.math.subtract_11 (TFOpLambd  (None, 100)         0           ['prediction_fine[0][0]']
#  a)
#
#  tf.compat.v1.gather_3 (TFOpLam  (None, 100)         0           ['tf.cast_1[0][0]']
#  bda)
#
#  tf.math.divide_1 (TFOpLambda)  (None, 100)          0           ['prediction_fine[0][0]',
#                                                                   'tf.reshape_1[0][0]']
#
#  tf.compat.v1.gather_1 (TFOpLam  (None, 100)         0           ['tf.math.argmax_2[0][0]']
#  bda)
#
#  tf.one_hot_1 (TFOpLambda)      (None, 100)          0           ['tf.math.argmax_3[0][0]']
#
#  tf.math.subtract_4 (TFOpLambda  (None, 8)           0           ['prediction_coarse[0][0]']
#  )
#
#  tf.math.subtract_5 (TFOpLambda  (None, 8)           0           ['prediction_coarse[0][0]']
#  )
#
#  tf.math.square_2 (TFOpLambda)  (None, 20)           0           ['tf.math.maximum_2[0][0]']
#
#  tf.math.multiply_11 (TFOpLambd  (None, 20)          0           ['tf.math.subtract_9[0][0]']
#  a)
#
#  tf.math.square_3 (TFOpLambda)  (None, 20)           0           ['tf.math.maximum_3[0][0]']
#
#  tf.math.reduce_sum_3 (TFOpLamb  (None,)             0           ['tf.math.multiply_2[0][0]']
#  da)
#
#  tf.math.reduce_sum (TFOpLambda  (None,)             0           ['tf.math.multiply[0][0]']
#  )
#
#  tf.math.maximum_4 (TFOpLambda)  (None, 100)         0           ['tf.math.subtract_10[0][0]']
#
#  tf.math.subtract_12 (TFOpLambd  (None, 100)         0           ['input_yf[0][0]']
#  a)
#
#  tf.math.maximum_5 (TFOpLambda)  (None, 100)         0           ['tf.math.subtract_11[0][0]']
#
#  tf.math.multiply_3 (TFOpLambda  (None, 100)         0           ['tf.compat.v1.gather_3[0][0]',
#  )                                                                'tf.math.divide_1[0][0]']
#
#  tf.math.multiply_1 (TFOpLambda  (None, 100)         0           ['tf.compat.v1.gather_1[0][0]',
#  )                                                                'tf.one_hot_1[0][0]']
#
#  tf.math.maximum (TFOpLambda)   (None, 8)            0           ['tf.math.subtract_4[0][0]']
#
#  tf.math.subtract_6 (TFOpLambda  (None, 8)           0           ['input_yc[0][0]']
#  )
#
#  tf.math.maximum_1 (TFOpLambda)  (None, 8)           0           ['tf.math.subtract_5[0][0]']
#
#  tf.math.multiply_10 (TFOpLambd  (None, 20)          0           ['input_ym[0][0]',
#  a)                                                               'tf.math.square_2[0][0]']
#
#  tf.math.multiply_12 (TFOpLambd  (None, 20)          0           ['tf.math.multiply_11[0][0]',
#  a)                                                               'tf.math.square_3[0][0]']
#
#  tf.math.subtract_2 (TFOpLambda  (None,)             0           ['tf.math.reduce_sum_3[0][0]']
#  )
#
#  tf.math.subtract (TFOpLambda)  (None,)              0           ['tf.math.reduce_sum[0][0]']
#
#  tf.math.square_4 (TFOpLambda)  (None, 100)          0           ['tf.math.maximum_4[0][0]']
#
#  tf.math.multiply_17 (TFOpLambd  (None, 100)         0           ['tf.math.subtract_12[0][0]']
#  a)
#
#  tf.math.square_5 (TFOpLambda)  (None, 100)          0           ['tf.math.maximum_5[0][0]']
#
#  tf.math.reduce_sum_5 (TFOpLamb  (None,)             0           ['tf.math.multiply_3[0][0]']
#  da)
#
#  tf.math.reduce_sum_1 (TFOpLamb  (None,)             0           ['tf.math.multiply_1[0][0]']
#  da)
#
#  tf.math.square (TFOpLambda)    (None, 8)            0           ['tf.math.maximum[0][0]']
#
#  tf.math.multiply_7 (TFOpLambda  (None, 8)           0           ['tf.math.subtract_6[0][0]']
#  )
#
#  tf.math.square_1 (TFOpLambda)  (None, 8)            0           ['tf.math.maximum_1[0][0]']
#
#  tf.math.add_1 (TFOpLambda)     (None, 20)           0           ['tf.math.multiply_10[0][0]',
#                                                                   'tf.math.multiply_12[0][0]']
#
#  tf.math.abs_2 (TFOpLambda)     (None,)              0           ['tf.math.subtract_2[0][0]']
#
#  tf.math.abs (TFOpLambda)       (None,)              0           ['tf.math.subtract[0][0]']
#
#  tf.math.multiply_16 (TFOpLambd  (None, 100)         0           ['input_yf[0][0]',
#  a)                                                               'tf.math.square_4[0][0]']
#
#  tf.math.multiply_18 (TFOpLambd  (None, 100)         0           ['tf.math.multiply_17[0][0]',
#  a)                                                               'tf.math.square_5[0][0]']
#
#  tf.math.subtract_3 (TFOpLambda  (None,)             0           ['tf.math.reduce_sum_5[0][0]']
#  )
#
#  tf.math.subtract_1 (TFOpLambda  (None,)             0           ['tf.math.reduce_sum_1[0][0]']
#  )
#
#  tf.math.multiply_6 (TFOpLambda  (None, 8)           0           ['input_yc[0][0]',
#  )                                                                'tf.math.square[0][0]']
#
#  tf.math.multiply_8 (TFOpLambda  (None, 8)           0           ['tf.math.multiply_7[0][0]',
#  )                                                                'tf.math.square_1[0][0]']
#
#  tf.math.reduce_sum_7 (TFOpLamb  (None,)             0           ['tf.math.add_1[0][0]']
#  da)
#
#  tf.math.multiply_4 (TFOpLambda  (None,)             0           ['tf.math.abs_2[0][0]',
#  )                                                                'tf.math.abs[0][0]']
#
#  tf.math.add_2 (TFOpLambda)     (None, 100)          0           ['tf.math.multiply_16[0][0]',
#                                                                   'tf.math.multiply_18[0][0]']
#
#  tf.math.abs_3 (TFOpLambda)     (None,)              0           ['tf.math.subtract_3[0][0]']
#
#  tf.math.abs_1 (TFOpLambda)     (None,)              0           ['tf.math.subtract_1[0][0]']
#
#  tf.math.add (TFOpLambda)       (None, 8)            0           ['tf.math.multiply_6[0][0]',
#                                                                   'tf.math.multiply_8[0][0]']
#
#  tf.math.multiply_13 (TFOpLambd  (None,)             0           ['tf.math.reduce_sum_7[0][0]']
#  a)
#
#  tf.math.multiply_14 (TFOpLambd  (None,)             0           ['tf.math.multiply_4[0][0]']
#  a)
#
#  tf.math.reduce_sum_8 (TFOpLamb  (None,)             0           ['tf.math.add_2[0][0]']
#  da)
#
#  tf.math.multiply_5 (TFOpLambda  (None,)             0           ['tf.math.abs_3[0][0]',
#  )                                                                'tf.math.abs_1[0][0]']
#
#  tf.math.reduce_sum_6 (TFOpLamb  (None,)             0           ['tf.math.add[0][0]']
#  da)
#
#  tf.__operators__.add (TFOpLamb  (None,)             0           ['tf.math.multiply_13[0][0]',
#  da)                                                              'tf.math.multiply_14[0][0]']
#
#  tf.math.multiply_19 (TFOpLambd  (None,)             0           ['tf.math.reduce_sum_8[0][0]']
#  a)
#
#  tf.math.multiply_20 (TFOpLambd  (None,)             0           ['tf.math.multiply_5[0][0]']
#  a)
#
#  tf.math.multiply_9 (TFOpLambda  (None,)             0           ['tf.math.reduce_sum_6[0][0]']
#  )
#
#  tf.math.multiply_15 (TFOpLambd  (None,)             0           ['tf.__operators__.add[0][0]']
#  a)
#
#  tf.__operators__.add_1 (TFOpLa  (None,)             0           ['tf.math.multiply_19[0][0]',
#  mbda)                                                            'tf.math.multiply_20[0][0]']
#
#  tf.__operators__.add_2 (TFOpLa  (None,)             0           ['tf.math.multiply_9[0][0]',
#  mbda)                                                            'tf.math.multiply_15[0][0]']
#
#  tf.math.multiply_21 (TFOpLambd  (None,)             0           ['tf.__operators__.add_1[0][0]']
#  a)
#
#  tf.__operators__.add_3 (TFOpLa  (None,)             0           ['tf.__operators__.add_2[0][0]',
#  mbda)                                                            'tf.math.multiply_21[0][0]']
#
#  tf.math.reduce_mean (TFOpLambd  ()                  0           ['tf.__operators__.add_3[0][0]']
#  a)
#
#  add_loss (AddLoss)             ()                   0           ['tf.math.reduce_mean[0][0]']
#
# ==================================================================================================
# Total params: 5,555,264
# Trainable params: 5,551,424
# Non-trainable params: 3,840
# __________________________________________________________________________________________________

# %% [markdown]
# ## Data Augmentation

# %%
datagen = ImageDataGenerator(width_shift_range=0.1,
                            height_shift_range=0.1)

training_generator = MixUp_add_loss.MixupGenerator_3level(dataset['x_train'],
                                                 dataset['y_train_coarse'], 
                                                 dataset['y_train_medium'],
                                                 dataset['y_train_fine'],
                                                 batch_size=train_params["batch_size"],
                                                 alpha=0.2, 
                                                 datagen=datagen
                                                )()

# %% [markdown]
# ## Callback

# %%
tb = keras.callbacks.TensorBoard(directory+'./tb_logs'+ datetime.now().strftime("%Y%m%d-%H%M%S"))
log = keras.callbacks.CSVLogger(directory+'/log.csv', append=True)

checkpoint = keras.callbacks.ModelCheckpoint(
    directory+'/epoch-best.h5', 
    monitor='val_prediction_fine_accuracy',
    save_best_only=True, save_weights_only=True, verbose=1)
change_lw = models.LossWeightsModifier(lossweight = lossweight,
                               initial_lw = initial_lw,
                               directory = directory)
lr_decay = keras.callbacks.LearningRateScheduler(scheduler)

# %% [markdown]
# ## Model Training

# %%
model_save_dir = str(directory+'/trained_model.h5')
try:
    model.load_weights(model_save_dir)
except:
    history = model.fit(training_generator,
                        steps_per_epoch = int(dataset['x_train'].shape[0] / train_params["batch_size"]),
                        epochs = train_params["n_epochs"],
                        validation_data = ([dataset['x_test'],
                                            dataset['y_test_coarse'],dataset['y_test_medium'],dataset['y_test_fine']],
                                           [dataset['y_test_coarse'],dataset['y_test_medium'],dataset['y_test_fine']]),
                        callbacks = [tb,log,change_lw,lr_decay,checkpoint],
                        verbose=1)
    
    model.save_weights(model_save_dir)
# Out:
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring... Layer tf.math.multiply_9 was passed non-JSON-serializable arguments. Arguments had types: {'y': <class 'tensorflow.python.ops.resource_variable_ops.ResourceVariable'>, 'name': <class 'NoneType'>}. They cannot be serialized out when saving the model.
# Epoch 1/100
#   6/781 [..............................] - ETA: 48s - loss: 0.6532 - prediction_coarse_accuracy: 0.2578 - prediction_medium_accuracy: 0.0417 - prediction_fine_accuracy: 0.0026    WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0466s vs `on_train_batch_end` time: 0.0485s). Check your callbacks.
# 781/781 [==============================] - ETA: 0s - loss: 0.5160 - prediction_coarse_accuracy: 0.4749 - prediction_medium_accuracy: 0.1937 - prediction_fine_accuracy: 0.0108
#   • Coarse Accuracy = 47.49% | Val_Accuracy = 51.07% | LossWeight = 0.35
#   • Medium Accuracy = 19.37% | Val_Accuracy = 28.70% | LossWeight = 0.49
#   • Fine   Accuracy = 1.08% | Val_Accuracy = 1.79% | LossWeight = 0.16
#
# Epoch 1: val_prediction_fine_accuracy improved from -inf to 0.01790, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# 781/781 [==============================] - 64s 71ms/step - loss: 0.5160 - prediction_coarse_accuracy: 0.4749 - prediction_medium_accuracy: 0.1937 - prediction_fine_accuracy: 0.0108 - val_loss: 0.4249 - val_prediction_coarse_accuracy: 0.5107 - val_prediction_medium_accuracy: 0.2870 - val_prediction_fine_accuracy: 0.0179 - lr: 0.0010
# Epoch 2/100
# 781/781 [==============================] - ETA: 0s - loss: 0.3548 - prediction_coarse_accuracy: 0.5970 - prediction_medium_accuracy: 0.3809 - prediction_fine_accuracy: 0.0406
#   • Coarse Accuracy = 59.70% | Val_Accuracy = 64.02% | LossWeight = 0.34
#   • Medium Accuracy = 38.09% | Val_Accuracy = 42.85% | LossWeight = 0.47
#   • Fine   Accuracy = 4.06% | Val_Accuracy = 5.96% | LossWeight = 0.19
#
# Epoch 2: val_prediction_fine_accuracy improved from 0.01790 to 0.05960, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# 781/781 [==============================] - 53s 68ms/step - loss: 0.3548 - prediction_coarse_accuracy: 0.5970 - prediction_medium_accuracy: 0.3809 - prediction_fine_accuracy: 0.0406 - val_loss: 0.3131 - val_prediction_coarse_accuracy: 0.6402 - val_prediction_medium_accuracy: 0.4285 - val_prediction_fine_accuracy: 0.0596 - lr: 0.0010
# Epoch 3/100
# 781/781 [==============================] - ETA: 0s - loss: 0.3121 - prediction_coarse_accuracy: 0.6681 - prediction_medium_accuracy: 0.4787 - prediction_fine_accuracy: 0.0668
#   • Coarse Accuracy = 66.81% | Val_Accuracy = 70.12% | LossWeight = 0.33
#   • Medium Accuracy = 47.87% | Val_Accuracy = 51.79% | LossWeight = 0.46
#   • Fine   Accuracy = 6.68% | Val_Accuracy = 6.00% | LossWeight = 0.21
#
# Epoch 3: val_prediction_fine_accuracy improved from 0.05960 to 0.06000, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# 781/781 [==============================] - 67s 86ms/step - loss: 0.3121 - prediction_coarse_accuracy: 0.6681 - prediction_medium_accuracy: 0.4787 - prediction_fine_accuracy: 0.0668 - val_loss: 0.2764 - val_prediction_coarse_accuracy: 0.7012 - val_prediction_medium_accuracy: 0.5179 - val_prediction_fine_accuracy: 0.0600 - lr: 0.0010
# Epoch 4/100
# 781/781 [==============================] - ETA: 0s - loss: 0.2812 - prediction_coarse_accuracy: 0.7152 - prediction_medium_accuracy: 0.5511 - prediction_fine_accuracy: 0.0845
#   • Coarse Accuracy = 71.52% | Val_Accuracy = 73.25% | LossWeight = 0.32
#   • Medium Accuracy = 55.11% | Val_Accuracy = 57.95% | LossWeight = 0.45
#   • Fine   Accuracy = 8.45% | Val_Accuracy = 10.19% | LossWeight = 0.24
#
# Epoch 4: val_prediction_fine_accuracy improved from 0.06000 to 0.10190, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# 781/781 [==============================] - 84s 107ms/step - loss: 0.2812 - prediction_coarse_accuracy: 0.7152 - prediction_medium_accuracy: 0.5511 - prediction_fine_accuracy: 0.0845 - val_loss: 0.2441 - val_prediction_coarse_accuracy: 0.7325 - val_prediction_medium_accuracy: 0.5795 - val_prediction_fine_accuracy: 0.1019 - lr: 0.0010
# Epoch 5/100
# 781/781 [==============================] - ETA: 0s - loss: 0.2548 - prediction_coarse_accuracy: 0.7541 - prediction_medium_accuracy: 0.6079 - prediction_fine_accuracy: 0.1153
#   • Coarse Accuracy = 75.41% | Val_Accuracy = 76.41% | LossWeight = 0.31
#   • Medium Accuracy = 60.79% | Val_Accuracy = 62.64% | LossWeight = 0.44
#   • Fine   Accuracy = 11.53% | Val_Accuracy = 12.20% | LossWeight = 0.26
#
# Epoch 5: val_prediction_fine_accuracy improved from 0.10190 to 0.12200, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# 781/781 [==============================] - 81s 103ms/step - loss: 0.2548 - prediction_coarse_accuracy: 0.7541 - prediction_medium_accuracy: 0.6079 - prediction_fine_accuracy: 0.1153 - val_loss: 0.2257 - val_prediction_coarse_accuracy: 0.7641 - val_prediction_medium_accuracy: 0.6264 - val_prediction_fine_accuracy: 0.1220 - lr: 0.0010
# Epoch 6/100
# 781/781 [==============================] - ETA: 0s - loss: 0.2357 - prediction_coarse_accuracy: 0.7804 - prediction_medium_accuracy: 0.6527 - prediction_fine_accuracy: 0.1297
#   • Coarse Accuracy = 78.04% | Val_Accuracy = 78.65% | LossWeight = 0.30
#   • Medium Accuracy = 65.27% | Val_Accuracy = 64.60% | LossWeight = 0.43
#   • Fine   Accuracy = 12.97% | Val_Accuracy = 13.24% | LossWeight = 0.28
#
# Epoch 6: val_prediction_fine_accuracy improved from 0.12200 to 0.13240, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# 781/781 [==============================] - 82s 105ms/step - loss: 0.2357 - prediction_coarse_accuracy: 0.7804 - prediction_medium_accuracy: 0.6527 - prediction_fine_accuracy: 0.1297 - val_loss: 0.2071 - val_prediction_coarse_accuracy: 0.7865 - val_prediction_medium_accuracy: 0.6460 - val_prediction_fine_accuracy: 0.1324 - lr: 0.0010
# Epoch 7/100
# 781/781 [==============================] - ETA: 0s - loss: 0.2160 - prediction_coarse_accuracy: 0.8059 - prediction_medium_accuracy: 0.6899 - prediction_fine_accuracy: 0.1427
#   • Coarse Accuracy = 80.59% | Val_Accuracy = 79.83% | LossWeight = 0.29
#   • Medium Accuracy = 68.99% | Val_Accuracy = 65.97% | LossWeight = 0.41
#   • Fine   Accuracy = 14.27% | Val_Accuracy = 14.12% | LossWeight = 0.30
#
# Epoch 7: val_prediction_fine_accuracy improved from 0.13240 to 0.14120, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# 781/781 [==============================] - 84s 107ms/step - loss: 0.2160 - prediction_coarse_accuracy: 0.8059 - prediction_medium_accuracy: 0.6899 - prediction_fine_accuracy: 0.1427 - val_loss: 0.1937 - val_prediction_coarse_accuracy: 0.7983 - val_prediction_medium_accuracy: 0.6597 - val_prediction_fine_accuracy: 0.1412 - lr: 0.0010
# Epoch 8/100
# 781/781 [==============================] - ETA: 0s - loss: 0.2031 - prediction_coarse_accuracy: 0.8242 - prediction_medium_accuracy: 0.7205 - prediction_fine_accuracy: 0.1543
#   • Coarse Accuracy = 82.42% | Val_Accuracy = 80.05% | LossWeight = 0.28
#   • Medium Accuracy = 72.05% | Val_Accuracy = 67.66% | LossWeight = 0.40
#   • Fine   Accuracy = 15.43% | Val_Accuracy = 14.80% | LossWeight = 0.32
#
# Epoch 8: val_prediction_fine_accuracy improved from 0.14120 to 0.14800, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# 781/781 [==============================] - 82s 105ms/step - loss: 0.2031 - prediction_coarse_accuracy: 0.8242 - prediction_medium_accuracy: 0.7205 - prediction_fine_accuracy: 0.1543 - val_loss: 0.1868 - val_prediction_coarse_accuracy: 0.8005 - val_prediction_medium_accuracy: 0.6766 - val_prediction_fine_accuracy: 0.1480 - lr: 0.0010
# Epoch 9/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1931 - prediction_coarse_accuracy: 0.8398 - prediction_medium_accuracy: 0.7454 - prediction_fine_accuracy: 0.1627
#   • Coarse Accuracy = 83.98% | Val_Accuracy = 81.68% | LossWeight = 0.27
#   • Medium Accuracy = 74.54% | Val_Accuracy = 69.14% | LossWeight = 0.39
#   • Fine   Accuracy = 16.27% | Val_Accuracy = 15.50% | LossWeight = 0.33
#
# Epoch 9: val_prediction_fine_accuracy improved from 0.14800 to 0.15500, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# 781/781 [==============================] - 85s 109ms/step - loss: 0.1931 - prediction_coarse_accuracy: 0.8398 - prediction_medium_accuracy: 0.7454 - prediction_fine_accuracy: 0.1627 - val_loss: 0.1821 - val_prediction_coarse_accuracy: 0.8168 - val_prediction_medium_accuracy: 0.6914 - val_prediction_fine_accuracy: 0.1550 - lr: 0.0010
# Epoch 10/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1843 - prediction_coarse_accuracy: 0.8554 - prediction_medium_accuracy: 0.7651 - prediction_fine_accuracy: 0.1695
#   • Coarse Accuracy = 85.54% | Val_Accuracy = 80.64% | LossWeight = 0.26
#   • Medium Accuracy = 76.51% | Val_Accuracy = 68.77% | LossWeight = 0.38
#   • Fine   Accuracy = 16.95% | Val_Accuracy = 15.66% | LossWeight = 0.35
#
# Epoch 10: val_prediction_fine_accuracy improved from 0.15500 to 0.15660, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# 781/781 [==============================] - 80s 103ms/step - loss: 0.1843 - prediction_coarse_accuracy: 0.8554 - prediction_medium_accuracy: 0.7651 - prediction_fine_accuracy: 0.1695 - val_loss: 0.1806 - val_prediction_coarse_accuracy: 0.8064 - val_prediction_medium_accuracy: 0.6877 - val_prediction_fine_accuracy: 0.1566 - lr: 0.0010
# Epoch 11/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1751 - prediction_coarse_accuracy: 0.8666 - prediction_medium_accuracy: 0.7859 - prediction_fine_accuracy: 0.1824
#   • Coarse Accuracy = 86.66% | Val_Accuracy = 81.30% | LossWeight = 0.26
#   • Medium Accuracy = 78.59% | Val_Accuracy = 69.58% | LossWeight = 0.37
#   • Fine   Accuracy = 18.24% | Val_Accuracy = 16.65% | LossWeight = 0.37
#
# Epoch 11: val_prediction_fine_accuracy improved from 0.15660 to 0.16650, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# 781/781 [==============================] - 83s 106ms/step - loss: 0.1751 - prediction_coarse_accuracy: 0.8666 - prediction_medium_accuracy: 0.7859 - prediction_fine_accuracy: 0.1824 - val_loss: 0.1764 - val_prediction_coarse_accuracy: 0.8130 - val_prediction_medium_accuracy: 0.6958 - val_prediction_fine_accuracy: 0.1665 - lr: 9.5000e-04
# Epoch 12/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1661 - prediction_coarse_accuracy: 0.8791 - prediction_medium_accuracy: 0.8086 - prediction_fine_accuracy: 0.1940
#   • Coarse Accuracy = 87.91% | Val_Accuracy = 81.44% | LossWeight = 0.25
#   • Medium Accuracy = 80.86% | Val_Accuracy = 70.38% | LossWeight = 0.36
#   • Fine   Accuracy = 19.40% | Val_Accuracy = 17.51% | LossWeight = 0.39
#
# Epoch 12: val_prediction_fine_accuracy improved from 0.16650 to 0.17510, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# 781/781 [==============================] - 82s 105ms/step - loss: 0.1661 - prediction_coarse_accuracy: 0.8791 - prediction_medium_accuracy: 0.8086 - prediction_fine_accuracy: 0.1940 - val_loss: 0.1712 - val_prediction_coarse_accuracy: 0.8144 - val_prediction_medium_accuracy: 0.7038 - val_prediction_fine_accuracy: 0.1751 - lr: 9.0250e-04
# Epoch 13/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1593 - prediction_coarse_accuracy: 0.8881 - prediction_medium_accuracy: 0.8246 - prediction_fine_accuracy: 0.2038
#   • Coarse Accuracy = 88.81% | Val_Accuracy = 82.81% | LossWeight = 0.25
#   • Medium Accuracy = 82.46% | Val_Accuracy = 71.95% | LossWeight = 0.35
#   • Fine   Accuracy = 20.38% | Val_Accuracy = 18.74% | LossWeight = 0.41
#
# Epoch 13: val_prediction_fine_accuracy improved from 0.17510 to 0.18740, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# 781/781 [==============================] - 78s 100ms/step - loss: 0.1593 - prediction_coarse_accuracy: 0.8881 - prediction_medium_accuracy: 0.8246 - prediction_fine_accuracy: 0.2038 - val_loss: 0.1637 - val_prediction_coarse_accuracy: 0.8281 - val_prediction_medium_accuracy: 0.7195 - val_prediction_fine_accuracy: 0.1874 - lr: 8.5737e-04
# Epoch 14/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1533 - prediction_coarse_accuracy: 0.8969 - prediction_medium_accuracy: 0.8382 - prediction_fine_accuracy: 0.2115
#   • Coarse Accuracy = 89.69% | Val_Accuracy = 82.95% | LossWeight = 0.24
#   • Medium Accuracy = 83.82% | Val_Accuracy = 72.68% | LossWeight = 0.34
#   • Fine   Accuracy = 21.15% | Val_Accuracy = 19.27% | LossWeight = 0.43
#
# Epoch 14: val_prediction_fine_accuracy improved from 0.18740 to 0.19270, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# 781/781 [==============================] - 82s 105ms/step - loss: 0.1533 - prediction_coarse_accuracy: 0.8969 - prediction_medium_accuracy: 0.8382 - prediction_fine_accuracy: 0.2115 - val_loss: 0.1613 - val_prediction_coarse_accuracy: 0.8295 - val_prediction_medium_accuracy: 0.7268 - val_prediction_fine_accuracy: 0.1927 - lr: 8.1451e-04
# Epoch 15/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1471 - prediction_coarse_accuracy: 0.9047 - prediction_medium_accuracy: 0.8513 - prediction_fine_accuracy: 0.2199
#   • Coarse Accuracy = 90.47% | Val_Accuracy = 82.47% | LossWeight = 0.23
#   • Medium Accuracy = 85.13% | Val_Accuracy = 71.57% | LossWeight = 0.33
#   • Fine   Accuracy = 21.99% | Val_Accuracy = 19.87% | LossWeight = 0.44
#
# Epoch 15: val_prediction_fine_accuracy improved from 0.19270 to 0.19870, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# 781/781 [==============================] - 81s 103ms/step - loss: 0.1471 - prediction_coarse_accuracy: 0.9047 - prediction_medium_accuracy: 0.8513 - prediction_fine_accuracy: 0.2199 - val_loss: 0.1624 - val_prediction_coarse_accuracy: 0.8247 - val_prediction_medium_accuracy: 0.7157 - val_prediction_fine_accuracy: 0.1987 - lr: 7.7378e-04
# Epoch 16/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1418 - prediction_coarse_accuracy: 0.9104 - prediction_medium_accuracy: 0.8635 - prediction_fine_accuracy: 0.2284
#   • Coarse Accuracy = 91.04% | Val_Accuracy = 83.37% | LossWeight = 0.23
#   • Medium Accuracy = 86.35% | Val_Accuracy = 73.07% | LossWeight = 0.31
#   • Fine   Accuracy = 22.84% | Val_Accuracy = 20.10% | LossWeight = 0.46
#
# Epoch 16: val_prediction_fine_accuracy improved from 0.19870 to 0.20100, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# 781/781 [==============================] - 78s 99ms/step - loss: 0.1418 - prediction_coarse_accuracy: 0.9104 - prediction_medium_accuracy: 0.8635 - prediction_fine_accuracy: 0.2284 - val_loss: 0.1561 - val_prediction_coarse_accuracy: 0.8337 - val_prediction_medium_accuracy: 0.7307 - val_prediction_fine_accuracy: 0.2010 - lr: 7.3509e-04
# Epoch 17/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1367 - prediction_coarse_accuracy: 0.9155 - prediction_medium_accuracy: 0.8736 - prediction_fine_accuracy: 0.2351
#   • Coarse Accuracy = 91.55% | Val_Accuracy = 83.62% | LossWeight = 0.22
#   • Medium Accuracy = 87.36% | Val_Accuracy = 73.43% | LossWeight = 0.30
#   • Fine   Accuracy = 23.51% | Val_Accuracy = 20.16% | LossWeight = 0.47
#
# Epoch 17: val_prediction_fine_accuracy improved from 0.20100 to 0.20160, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# 781/781 [==============================] - 54s 69ms/step - loss: 0.1367 - prediction_coarse_accuracy: 0.9155 - prediction_medium_accuracy: 0.8736 - prediction_fine_accuracy: 0.2351 - val_loss: 0.1517 - val_prediction_coarse_accuracy: 0.8362 - val_prediction_medium_accuracy: 0.7343 - val_prediction_fine_accuracy: 0.2016 - lr: 6.9834e-04
# Epoch 18/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1328 - prediction_coarse_accuracy: 0.9212 - prediction_medium_accuracy: 0.8833 - prediction_fine_accuracy: 0.2431
#   • Coarse Accuracy = 92.12% | Val_Accuracy = 84.29% | LossWeight = 0.22
#   • Medium Accuracy = 88.33% | Val_Accuracy = 74.34% | LossWeight = 0.29
#   • Fine   Accuracy = 24.31% | Val_Accuracy = 21.91% | LossWeight = 0.49
#
# Epoch 18: val_prediction_fine_accuracy improved from 0.20160 to 0.21910, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# 781/781 [==============================] - 53s 68ms/step - loss: 0.1328 - prediction_coarse_accuracy: 0.9212 - prediction_medium_accuracy: 0.8833 - prediction_fine_accuracy: 0.2431 - val_loss: 0.1491 - val_prediction_coarse_accuracy: 0.8429 - val_prediction_medium_accuracy: 0.7434 - val_prediction_fine_accuracy: 0.2191 - lr: 6.6342e-04
# Epoch 19/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1301 - prediction_coarse_accuracy: 0.9254 - prediction_medium_accuracy: 0.8897 - prediction_fine_accuracy: 0.2529
#   • Coarse Accuracy = 92.54% | Val_Accuracy = 83.38% | LossWeight = 0.21
#   • Medium Accuracy = 88.97% | Val_Accuracy = 73.71% | LossWeight = 0.29
#   • Fine   Accuracy = 25.29% | Val_Accuracy = 22.41% | LossWeight = 0.50
#
# Epoch 19: val_prediction_fine_accuracy improved from 0.21910 to 0.22410, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# 781/781 [==============================] - 56s 72ms/step - loss: 0.1301 - prediction_coarse_accuracy: 0.9254 - prediction_medium_accuracy: 0.8897 - prediction_fine_accuracy: 0.2529 - val_loss: 0.1507 - val_prediction_coarse_accuracy: 0.8338 - val_prediction_medium_accuracy: 0.7371 - val_prediction_fine_accuracy: 0.2241 - lr: 6.3025e-04
# Epoch 20/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1268 - prediction_coarse_accuracy: 0.9273 - prediction_medium_accuracy: 0.8947 - prediction_fine_accuracy: 0.2642
#   • Coarse Accuracy = 92.73% | Val_Accuracy = 83.41% | LossWeight = 0.21
#   • Medium Accuracy = 89.47% | Val_Accuracy = 73.46% | LossWeight = 0.28
#   • Fine   Accuracy = 26.42% | Val_Accuracy = 22.62% | LossWeight = 0.51
#
# Epoch 20: val_prediction_fine_accuracy improved from 0.22410 to 0.22620, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# 781/781 [==============================] - 107s 137ms/step - loss: 0.1268 - prediction_coarse_accuracy: 0.9273 - prediction_medium_accuracy: 0.8947 - prediction_fine_accuracy: 0.2642 - val_loss: 0.1512 - val_prediction_coarse_accuracy: 0.8341 - val_prediction_medium_accuracy: 0.7346 - val_prediction_fine_accuracy: 0.2262 - lr: 5.9874e-04
# Epoch 21/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1249 - prediction_coarse_accuracy: 0.9298 - prediction_medium_accuracy: 0.9002 - prediction_fine_accuracy: 0.2750
#   • Coarse Accuracy = 92.98% | Val_Accuracy = 83.98% | LossWeight = 0.21
#   • Medium Accuracy = 90.02% | Val_Accuracy = 74.06% | LossWeight = 0.27
#   • Fine   Accuracy = 27.50% | Val_Accuracy = 24.40% | LossWeight = 0.51
#
# Epoch 21: val_prediction_fine_accuracy improved from 0.22620 to 0.24400, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# 781/781 [==============================] - 117s 150ms/step - loss: 0.1249 - prediction_coarse_accuracy: 0.9298 - prediction_medium_accuracy: 0.9002 - prediction_fine_accuracy: 0.2750 - val_loss: 0.1480 - val_prediction_coarse_accuracy: 0.8398 - val_prediction_medium_accuracy: 0.7406 - val_prediction_fine_accuracy: 0.2440 - lr: 5.6880e-04
# Epoch 22/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1231 - prediction_coarse_accuracy: 0.9334 - prediction_medium_accuracy: 0.9040 - prediction_fine_accuracy: 0.2876
#   • Coarse Accuracy = 93.34% | Val_Accuracy = 84.21% | LossWeight = 0.21
#   • Medium Accuracy = 90.40% | Val_Accuracy = 74.77% | LossWeight = 0.27
#   • Fine   Accuracy = 28.76% | Val_Accuracy = 25.07% | LossWeight = 0.52
#
# Epoch 22: val_prediction_fine_accuracy improved from 0.24400 to 0.25070, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# 781/781 [==============================] - 108s 138ms/step - loss: 0.1231 - prediction_coarse_accuracy: 0.9334 - prediction_medium_accuracy: 0.9040 - prediction_fine_accuracy: 0.2876 - val_loss: 0.1454 - val_prediction_coarse_accuracy: 0.8421 - val_prediction_medium_accuracy: 0.7477 - val_prediction_fine_accuracy: 0.2507 - lr: 5.4036e-04
# Epoch 23/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1204 - prediction_coarse_accuracy: 0.9371 - prediction_medium_accuracy: 0.9104 - prediction_fine_accuracy: 0.2960
#   • Coarse Accuracy = 93.71% | Val_Accuracy = 84.76% | LossWeight = 0.20
#   • Medium Accuracy = 91.04% | Val_Accuracy = 75.22% | LossWeight = 0.26
#   • Fine   Accuracy = 29.60% | Val_Accuracy = 26.08% | LossWeight = 0.53
#
# Epoch 23: val_prediction_fine_accuracy improved from 0.25070 to 0.26080, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# 781/781 [==============================] - 75s 96ms/step - loss: 0.1204 - prediction_coarse_accuracy: 0.9371 - prediction_medium_accuracy: 0.9104 - prediction_fine_accuracy: 0.2960 - val_loss: 0.1441 - val_prediction_coarse_accuracy: 0.8476 - val_prediction_medium_accuracy: 0.7522 - val_prediction_fine_accuracy: 0.2608 - lr: 5.1334e-04
# Epoch 24/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1179 - prediction_coarse_accuracy: 0.9384 - prediction_medium_accuracy: 0.9142 - prediction_fine_accuracy: 0.3057
#   • Coarse Accuracy = 93.84% | Val_Accuracy = 84.11% | LossWeight = 0.20
#   • Medium Accuracy = 91.42% | Val_Accuracy = 74.53% | LossWeight = 0.26
#   • Fine   Accuracy = 30.57% | Val_Accuracy = 25.71% | LossWeight = 0.54
#
# Epoch 24: val_prediction_fine_accuracy did not improve from 0.26080
# 781/781 [==============================] - 84s 108ms/step - loss: 0.1179 - prediction_coarse_accuracy: 0.9384 - prediction_medium_accuracy: 0.9142 - prediction_fine_accuracy: 0.3057 - val_loss: 0.1448 - val_prediction_coarse_accuracy: 0.8411 - val_prediction_medium_accuracy: 0.7453 - val_prediction_fine_accuracy: 0.2571 - lr: 4.8767e-04
# Epoch 25/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1168 - prediction_coarse_accuracy: 0.9412 - prediction_medium_accuracy: 0.9176 - prediction_fine_accuracy: 0.3200
#   • Coarse Accuracy = 94.12% | Val_Accuracy = 84.88% | LossWeight = 0.20
#   • Medium Accuracy = 91.76% | Val_Accuracy = 75.04% | LossWeight = 0.25
#   • Fine   Accuracy = 32.00% | Val_Accuracy = 26.55% | LossWeight = 0.54
#
# Epoch 25: val_prediction_fine_accuracy improved from 0.26080 to 0.26550, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# 781/781 [==============================] - 89s 115ms/step - loss: 0.1168 - prediction_coarse_accuracy: 0.9412 - prediction_medium_accuracy: 0.9176 - prediction_fine_accuracy: 0.3200 - val_loss: 0.1418 - val_prediction_coarse_accuracy: 0.8488 - val_prediction_medium_accuracy: 0.7504 - val_prediction_fine_accuracy: 0.2655 - lr: 4.6329e-04
# Epoch 26/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1145 - prediction_coarse_accuracy: 0.9424 - prediction_medium_accuracy: 0.9196 - prediction_fine_accuracy: 0.3273
#   • Coarse Accuracy = 94.24% | Val_Accuracy = 84.33% | LossWeight = 0.20
#   • Medium Accuracy = 91.96% | Val_Accuracy = 74.92% | LossWeight = 0.25
#   • Fine   Accuracy = 32.73% | Val_Accuracy = 27.46% | LossWeight = 0.55
#
# Epoch 26: val_prediction_fine_accuracy improved from 0.26550 to 0.27460, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# 781/781 [==============================] - 88s 112ms/step - loss: 0.1145 - prediction_coarse_accuracy: 0.9424 - prediction_medium_accuracy: 0.9196 - prediction_fine_accuracy: 0.3273 - val_loss: 0.1412 - val_prediction_coarse_accuracy: 0.8433 - val_prediction_medium_accuracy: 0.7492 - val_prediction_fine_accuracy: 0.2746 - lr: 4.4013e-04
# Epoch 27/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1127 - prediction_coarse_accuracy: 0.9457 - prediction_medium_accuracy: 0.9247 - prediction_fine_accuracy: 0.3378
#   • Coarse Accuracy = 94.57% | Val_Accuracy = 84.94% | LossWeight = 0.20
#   • Medium Accuracy = 92.47% | Val_Accuracy = 75.26% | LossWeight = 0.25
#   • Fine   Accuracy = 33.78% | Val_Accuracy = 28.31% | LossWeight = 0.56
#
# Epoch 27: val_prediction_fine_accuracy improved from 0.27460 to 0.28310, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# 781/781 [==============================] - 91s 117ms/step - loss: 0.1127 - prediction_coarse_accuracy: 0.9457 - prediction_medium_accuracy: 0.9247 - prediction_fine_accuracy: 0.3378 - val_loss: 0.1396 - val_prediction_coarse_accuracy: 0.8494 - val_prediction_medium_accuracy: 0.7526 - val_prediction_fine_accuracy: 0.2831 - lr: 4.1812e-04
# Epoch 28/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1115 - prediction_coarse_accuracy: 0.9444 - prediction_medium_accuracy: 0.9250 - prediction_fine_accuracy: 0.3468
#   • Coarse Accuracy = 94.44% | Val_Accuracy = 84.75% | LossWeight = 0.20
#   • Medium Accuracy = 92.50% | Val_Accuracy = 75.40% | LossWeight = 0.25
#   • Fine   Accuracy = 34.68% | Val_Accuracy = 30.00% | LossWeight = 0.55
#
# Epoch 28: val_prediction_fine_accuracy improved from 0.28310 to 0.30000, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# 781/781 [==============================] - 80s 103ms/step - loss: 0.1115 - prediction_coarse_accuracy: 0.9444 - prediction_medium_accuracy: 0.9250 - prediction_fine_accuracy: 0.3468 - val_loss: 0.1397 - val_prediction_coarse_accuracy: 0.8475 - val_prediction_medium_accuracy: 0.7540 - val_prediction_fine_accuracy: 0.3000 - lr: 3.9721e-04
# Epoch 29/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1107 - prediction_coarse_accuracy: 0.9451 - prediction_medium_accuracy: 0.9270 - prediction_fine_accuracy: 0.3567
#   • Coarse Accuracy = 94.51% | Val_Accuracy = 84.73% | LossWeight = 0.20
#   • Medium Accuracy = 92.70% | Val_Accuracy = 74.72% | LossWeight = 0.24
#   • Fine   Accuracy = 35.67% | Val_Accuracy = 30.00% | LossWeight = 0.55
#
# Epoch 29: val_prediction_fine_accuracy did not improve from 0.30000
# 781/781 [==============================] - 91s 117ms/step - loss: 0.1107 - prediction_coarse_accuracy: 0.9451 - prediction_medium_accuracy: 0.9270 - prediction_fine_accuracy: 0.3567 - val_loss: 0.1406 - val_prediction_coarse_accuracy: 0.8473 - val_prediction_medium_accuracy: 0.7472 - val_prediction_fine_accuracy: 0.3000 - lr: 3.7735e-04
# Epoch 30/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1093 - prediction_coarse_accuracy: 0.9478 - prediction_medium_accuracy: 0.9299 - prediction_fine_accuracy: 0.3660
#   • Coarse Accuracy = 94.78% | Val_Accuracy = 84.99% | LossWeight = 0.20
#   • Medium Accuracy = 92.99% | Val_Accuracy = 75.92% | LossWeight = 0.24
#   • Fine   Accuracy = 36.60% | Val_Accuracy = 31.02% | LossWeight = 0.56
#
# Epoch 30: val_prediction_fine_accuracy improved from 0.30000 to 0.31020, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# 781/781 [==============================] - 82s 105ms/step - loss: 0.1093 - prediction_coarse_accuracy: 0.9478 - prediction_medium_accuracy: 0.9299 - prediction_fine_accuracy: 0.3660 - val_loss: 0.1365 - val_prediction_coarse_accuracy: 0.8499 - val_prediction_medium_accuracy: 0.7592 - val_prediction_fine_accuracy: 0.3102 - lr: 3.5849e-04
# Epoch 31/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1079 - prediction_coarse_accuracy: 0.9484 - prediction_medium_accuracy: 0.9318 - prediction_fine_accuracy: 0.3757
#   • Coarse Accuracy = 94.84% | Val_Accuracy = 85.19% | LossWeight = 0.20
#   • Medium Accuracy = 93.18% | Val_Accuracy = 75.67% | LossWeight = 0.24
#   • Fine   Accuracy = 37.57% | Val_Accuracy = 31.67% | LossWeight = 0.56
#
# Epoch 31: val_prediction_fine_accuracy improved from 0.31020 to 0.31670, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# 781/781 [==============================] - 79s 101ms/step - loss: 0.1079 - prediction_coarse_accuracy: 0.9484 - prediction_medium_accuracy: 0.9318 - prediction_fine_accuracy: 0.3757 - val_loss: 0.1381 - val_prediction_coarse_accuracy: 0.8519 - val_prediction_medium_accuracy: 0.7567 - val_prediction_fine_accuracy: 0.3167 - lr: 3.4056e-04
# Epoch 32/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1067 - prediction_coarse_accuracy: 0.9496 - prediction_medium_accuracy: 0.9326 - prediction_fine_accuracy: 0.3854
#   • Coarse Accuracy = 94.96% | Val_Accuracy = 85.31% | LossWeight = 0.20
#   • Medium Accuracy = 93.26% | Val_Accuracy = 75.79% | LossWeight = 0.24
#   • Fine   Accuracy = 38.54% | Val_Accuracy = 32.28% | LossWeight = 0.56
#
# Epoch 32: val_prediction_fine_accuracy improved from 0.31670 to 0.32280, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# 781/781 [==============================] - 87s 111ms/step - loss: 0.1067 - prediction_coarse_accuracy: 0.9496 - prediction_medium_accuracy: 0.9326 - prediction_fine_accuracy: 0.3854 - val_loss: 0.1351 - val_prediction_coarse_accuracy: 0.8531 - val_prediction_medium_accuracy: 0.7579 - val_prediction_fine_accuracy: 0.3228 - lr: 3.2353e-04
# Epoch 33/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1059 - prediction_coarse_accuracy: 0.9491 - prediction_medium_accuracy: 0.9339 - prediction_fine_accuracy: 0.3959
#   • Coarse Accuracy = 94.91% | Val_Accuracy = 85.29% | LossWeight = 0.20
#   • Medium Accuracy = 93.39% | Val_Accuracy = 76.17% | LossWeight = 0.24
#   • Fine   Accuracy = 39.59% | Val_Accuracy = 33.05% | LossWeight = 0.56
#
# Epoch 33: val_prediction_fine_accuracy improved from 0.32280 to 0.33050, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# 781/781 [==============================] - 95s 122ms/step - loss: 0.1059 - prediction_coarse_accuracy: 0.9491 - prediction_medium_accuracy: 0.9339 - prediction_fine_accuracy: 0.3959 - val_loss: 0.1335 - val_prediction_coarse_accuracy: 0.8529 - val_prediction_medium_accuracy: 0.7617 - val_prediction_fine_accuracy: 0.3305 - lr: 3.0736e-04
# Epoch 34/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1054 - prediction_coarse_accuracy: 0.9499 - prediction_medium_accuracy: 0.9344 - prediction_fine_accuracy: 0.4019
#   • Coarse Accuracy = 94.99% | Val_Accuracy = 85.33% | LossWeight = 0.20
#   • Medium Accuracy = 93.44% | Val_Accuracy = 76.14% | LossWeight = 0.24
#   • Fine   Accuracy = 40.19% | Val_Accuracy = 33.61% | LossWeight = 0.56
#
# Epoch 34: val_prediction_fine_accuracy improved from 0.33050 to 0.33610, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# 781/781 [==============================] - 96s 123ms/step - loss: 0.1054 - prediction_coarse_accuracy: 0.9499 - prediction_medium_accuracy: 0.9344 - prediction_fine_accuracy: 0.4019 - val_loss: 0.1348 - val_prediction_coarse_accuracy: 0.8533 - val_prediction_medium_accuracy: 0.7614 - val_prediction_fine_accuracy: 0.3361 - lr: 2.9199e-04
# Epoch 35/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1040 - prediction_coarse_accuracy: 0.9508 - prediction_medium_accuracy: 0.9365 - prediction_fine_accuracy: 0.4098
#   • Coarse Accuracy = 95.08% | Val_Accuracy = 85.59% | LossWeight = 0.20
#   • Medium Accuracy = 93.65% | Val_Accuracy = 75.97% | LossWeight = 0.23
#   • Fine   Accuracy = 40.98% | Val_Accuracy = 33.68% | LossWeight = 0.56
#
# Epoch 35: val_prediction_fine_accuracy improved from 0.33610 to 0.33680, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# 781/781 [==============================] - 95s 121ms/step - loss: 0.1040 - prediction_coarse_accuracy: 0.9508 - prediction_medium_accuracy: 0.9365 - prediction_fine_accuracy: 0.4098 - val_loss: 0.1337 - val_prediction_coarse_accuracy: 0.8559 - val_prediction_medium_accuracy: 0.7597 - val_prediction_fine_accuracy: 0.3368 - lr: 2.7739e-04
# Epoch 36/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1049 - prediction_coarse_accuracy: 0.9508 - prediction_medium_accuracy: 0.9353 - prediction_fine_accuracy: 0.4186
#   • Coarse Accuracy = 95.08% | Val_Accuracy = 85.47% | LossWeight = 0.20
#   • Medium Accuracy = 93.53% | Val_Accuracy = 76.16% | LossWeight = 0.24
#   • Fine   Accuracy = 41.86% | Val_Accuracy = 34.57% | LossWeight = 0.56
#
# Epoch 36: val_prediction_fine_accuracy improved from 0.33680 to 0.34570, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# 781/781 [==============================] - 87s 111ms/step - loss: 0.1049 - prediction_coarse_accuracy: 0.9508 - prediction_medium_accuracy: 0.9353 - prediction_fine_accuracy: 0.4186 - val_loss: 0.1336 - val_prediction_coarse_accuracy: 0.8547 - val_prediction_medium_accuracy: 0.7616 - val_prediction_fine_accuracy: 0.3457 - lr: 2.6352e-04
# Epoch 37/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1026 - prediction_coarse_accuracy: 0.9517 - prediction_medium_accuracy: 0.9376 - prediction_fine_accuracy: 0.4286
#   • Coarse Accuracy = 95.17% | Val_Accuracy = 85.77% | LossWeight = 0.20
#   • Medium Accuracy = 93.76% | Val_Accuracy = 76.51% | LossWeight = 0.24
#   • Fine   Accuracy = 42.86% | Val_Accuracy = 35.14% | LossWeight = 0.56
#
# Epoch 37: val_prediction_fine_accuracy improved from 0.34570 to 0.35140, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# 781/781 [==============================] - 78s 100ms/step - loss: 0.1026 - prediction_coarse_accuracy: 0.9517 - prediction_medium_accuracy: 0.9376 - prediction_fine_accuracy: 0.4286 - val_loss: 0.1329 - val_prediction_coarse_accuracy: 0.8577 - val_prediction_medium_accuracy: 0.7651 - val_prediction_fine_accuracy: 0.3514 - lr: 2.5034e-04
# Epoch 38/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1025 - prediction_coarse_accuracy: 0.9506 - prediction_medium_accuracy: 0.9369 - prediction_fine_accuracy: 0.4341
#   • Coarse Accuracy = 95.06% | Val_Accuracy = 86.13% | LossWeight = 0.21
#   • Medium Accuracy = 93.69% | Val_Accuracy = 76.59% | LossWeight = 0.24
#   • Fine   Accuracy = 43.41% | Val_Accuracy = 35.96% | LossWeight = 0.55
#
# Epoch 38: val_prediction_fine_accuracy improved from 0.35140 to 0.35960, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# 781/781 [==============================] - 68s 87ms/step - loss: 0.1025 - prediction_coarse_accuracy: 0.9506 - prediction_medium_accuracy: 0.9369 - prediction_fine_accuracy: 0.4341 - val_loss: 0.1311 - val_prediction_coarse_accuracy: 0.8613 - val_prediction_medium_accuracy: 0.7659 - val_prediction_fine_accuracy: 0.3596 - lr: 2.3783e-04
# Epoch 39/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1020 - prediction_coarse_accuracy: 0.9525 - prediction_medium_accuracy: 0.9389 - prediction_fine_accuracy: 0.4394
#   • Coarse Accuracy = 95.25% | Val_Accuracy = 85.79% | LossWeight = 0.20
#   • Medium Accuracy = 93.89% | Val_Accuracy = 76.38% | LossWeight = 0.24
#   • Fine   Accuracy = 43.94% | Val_Accuracy = 36.13% | LossWeight = 0.56
#
# Epoch 39: val_prediction_fine_accuracy improved from 0.35960 to 0.36130, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# 781/781 [==============================] - 63s 80ms/step - loss: 0.1020 - prediction_coarse_accuracy: 0.9525 - prediction_medium_accuracy: 0.9389 - prediction_fine_accuracy: 0.4394 - val_loss: 0.1316 - val_prediction_coarse_accuracy: 0.8579 - val_prediction_medium_accuracy: 0.7638 - val_prediction_fine_accuracy: 0.3613 - lr: 2.2594e-04
# Epoch 40/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1016 - prediction_coarse_accuracy: 0.9523 - prediction_medium_accuracy: 0.9388 - prediction_fine_accuracy: 0.4406
#   • Coarse Accuracy = 95.23% | Val_Accuracy = 85.77% | LossWeight = 0.20
#   • Medium Accuracy = 93.88% | Val_Accuracy = 76.50% | LossWeight = 0.24
#   • Fine   Accuracy = 44.06% | Val_Accuracy = 36.03% | LossWeight = 0.56
#
# Epoch 40: val_prediction_fine_accuracy did not improve from 0.36130
# 781/781 [==============================] - 62s 79ms/step - loss: 0.1016 - prediction_coarse_accuracy: 0.9523 - prediction_medium_accuracy: 0.9388 - prediction_fine_accuracy: 0.4406 - val_loss: 0.1316 - val_prediction_coarse_accuracy: 0.8577 - val_prediction_medium_accuracy: 0.7650 - val_prediction_fine_accuracy: 0.3603 - lr: 2.1464e-04
# Epoch 41/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1003 - prediction_coarse_accuracy: 0.9548 - prediction_medium_accuracy: 0.9415 - prediction_fine_accuracy: 0.4509
#   • Coarse Accuracy = 95.48% | Val_Accuracy = 86.25% | LossWeight = 0.20
#   • Medium Accuracy = 94.15% | Val_Accuracy = 77.22% | LossWeight = 0.23
#   • Fine   Accuracy = 45.09% | Val_Accuracy = 36.96% | LossWeight = 0.57
#
# Epoch 41: val_prediction_fine_accuracy improved from 0.36130 to 0.36960, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# 781/781 [==============================] - 60s 76ms/step - loss: 0.1003 - prediction_coarse_accuracy: 0.9548 - prediction_medium_accuracy: 0.9415 - prediction_fine_accuracy: 0.4509 - val_loss: 0.1302 - val_prediction_coarse_accuracy: 0.8625 - val_prediction_medium_accuracy: 0.7722 - val_prediction_fine_accuracy: 0.3696 - lr: 2.0391e-04
# Epoch 42/100
# 781/781 [==============================] - ETA: 0s - loss: 0.1005 - prediction_coarse_accuracy: 0.9536 - prediction_medium_accuracy: 0.9404 - prediction_fine_accuracy: 0.4494
#   • Coarse Accuracy = 95.36% | Val_Accuracy = 85.64% | LossWeight = 0.20
#   • Medium Accuracy = 94.04% | Val_Accuracy = 76.87% | LossWeight = 0.23
#   • Fine   Accuracy = 44.94% | Val_Accuracy = 37.35% | LossWeight = 0.56
#
# Epoch 42: val_prediction_fine_accuracy improved from 0.36960 to 0.37350, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# 781/781 [==============================] - 55s 71ms/step - loss: 0.1005 - prediction_coarse_accuracy: 0.9536 - prediction_medium_accuracy: 0.9404 - prediction_fine_accuracy: 0.4494 - val_loss: 0.1305 - val_prediction_coarse_accuracy: 0.8564 - val_prediction_medium_accuracy: 0.7687 - val_prediction_fine_accuracy: 0.3735 - lr: 1.9371e-04
# Epoch 43/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0994 - prediction_coarse_accuracy: 0.9548 - prediction_medium_accuracy: 0.9425 - prediction_fine_accuracy: 0.4547
#   • Coarse Accuracy = 95.48% | Val_Accuracy = 85.83% | LossWeight = 0.20
#   • Medium Accuracy = 94.25% | Val_Accuracy = 76.64% | LossWeight = 0.23
#   • Fine   Accuracy = 45.47% | Val_Accuracy = 37.16% | LossWeight = 0.57
#
# Epoch 43: val_prediction_fine_accuracy did not improve from 0.37350
# 781/781 [==============================] - 54s 69ms/step - loss: 0.0994 - prediction_coarse_accuracy: 0.9548 - prediction_medium_accuracy: 0.9425 - prediction_fine_accuracy: 0.4547 - val_loss: 0.1299 - val_prediction_coarse_accuracy: 0.8583 - val_prediction_medium_accuracy: 0.7664 - val_prediction_fine_accuracy: 0.3716 - lr: 1.8403e-04
# Epoch 44/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0990 - prediction_coarse_accuracy: 0.9545 - prediction_medium_accuracy: 0.9429 - prediction_fine_accuracy: 0.4596
#   • Coarse Accuracy = 95.45% | Val_Accuracy = 85.92% | LossWeight = 0.20
#   • Medium Accuracy = 94.29% | Val_Accuracy = 76.79% | LossWeight = 0.23
#   • Fine   Accuracy = 45.96% | Val_Accuracy = 37.74% | LossWeight = 0.57
#
# Epoch 44: val_prediction_fine_accuracy improved from 0.37350 to 0.37740, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# 781/781 [==============================] - 55s 70ms/step - loss: 0.0990 - prediction_coarse_accuracy: 0.9545 - prediction_medium_accuracy: 0.9429 - prediction_fine_accuracy: 0.4596 - val_loss: 0.1291 - val_prediction_coarse_accuracy: 0.8592 - val_prediction_medium_accuracy: 0.7679 - val_prediction_fine_accuracy: 0.3774 - lr: 1.7482e-04
# Epoch 45/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0993 - prediction_coarse_accuracy: 0.9545 - prediction_medium_accuracy: 0.9415 - prediction_fine_accuracy: 0.4636
#   • Coarse Accuracy = 95.45% | Val_Accuracy = 85.94% | LossWeight = 0.20
#   • Medium Accuracy = 94.15% | Val_Accuracy = 76.66% | LossWeight = 0.24
#   • Fine   Accuracy = 46.36% | Val_Accuracy = 38.03% | LossWeight = 0.56
#
# Epoch 45: val_prediction_fine_accuracy improved from 0.37740 to 0.38030, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# 781/781 [==============================] - 54s 69ms/step - loss: 0.0993 - prediction_coarse_accuracy: 0.9545 - prediction_medium_accuracy: 0.9415 - prediction_fine_accuracy: 0.4636 - val_loss: 0.1298 - val_prediction_coarse_accuracy: 0.8594 - val_prediction_medium_accuracy: 0.7666 - val_prediction_fine_accuracy: 0.3803 - lr: 1.6608e-04
# Epoch 46/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0993 - prediction_coarse_accuracy: 0.9542 - prediction_medium_accuracy: 0.9421 - prediction_fine_accuracy: 0.4667
#   • Coarse Accuracy = 95.42% | Val_Accuracy = 86.07% | LossWeight = 0.21
#   • Medium Accuracy = 94.21% | Val_Accuracy = 76.87% | LossWeight = 0.23
#   • Fine   Accuracy = 46.67% | Val_Accuracy = 38.03% | LossWeight = 0.56
#
# Epoch 46: val_prediction_fine_accuracy did not improve from 0.38030
# 781/781 [==============================] - 54s 70ms/step - loss: 0.0993 - prediction_coarse_accuracy: 0.9542 - prediction_medium_accuracy: 0.9421 - prediction_fine_accuracy: 0.4667 - val_loss: 0.1293 - val_prediction_coarse_accuracy: 0.8607 - val_prediction_medium_accuracy: 0.7687 - val_prediction_fine_accuracy: 0.3803 - lr: 1.5778e-04
# Epoch 47/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0985 - prediction_coarse_accuracy: 0.9547 - prediction_medium_accuracy: 0.9429 - prediction_fine_accuracy: 0.4683
#   • Coarse Accuracy = 95.47% | Val_Accuracy = 85.74% | LossWeight = 0.21
#   • Medium Accuracy = 94.29% | Val_Accuracy = 76.59% | LossWeight = 0.23
#   • Fine   Accuracy = 46.83% | Val_Accuracy = 38.60% | LossWeight = 0.56
#
# Epoch 47: val_prediction_fine_accuracy improved from 0.38030 to 0.38600, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# 781/781 [==============================] - 54s 69ms/step - loss: 0.0985 - prediction_coarse_accuracy: 0.9547 - prediction_medium_accuracy: 0.9429 - prediction_fine_accuracy: 0.4683 - val_loss: 0.1299 - val_prediction_coarse_accuracy: 0.8574 - val_prediction_medium_accuracy: 0.7659 - val_prediction_fine_accuracy: 0.3860 - lr: 1.4989e-04
# Epoch 48/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0987 - prediction_coarse_accuracy: 0.9542 - prediction_medium_accuracy: 0.9420 - prediction_fine_accuracy: 0.4754
#   • Coarse Accuracy = 95.42% | Val_Accuracy = 85.71% | LossWeight = 0.21
#   • Medium Accuracy = 94.20% | Val_Accuracy = 76.54% | LossWeight = 0.24
#   • Fine   Accuracy = 47.54% | Val_Accuracy = 38.62% | LossWeight = 0.56
#
# Epoch 48: val_prediction_fine_accuracy improved from 0.38600 to 0.38620, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# 781/781 [==============================] - 54s 70ms/step - loss: 0.0987 - prediction_coarse_accuracy: 0.9542 - prediction_medium_accuracy: 0.9420 - prediction_fine_accuracy: 0.4754 - val_loss: 0.1300 - val_prediction_coarse_accuracy: 0.8571 - val_prediction_medium_accuracy: 0.7654 - val_prediction_fine_accuracy: 0.3862 - lr: 1.4240e-04
# Epoch 49/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0974 - prediction_coarse_accuracy: 0.9569 - prediction_medium_accuracy: 0.9459 - prediction_fine_accuracy: 0.4810
#   • Coarse Accuracy = 95.69% | Val_Accuracy = 85.91% | LossWeight = 0.20
#   • Medium Accuracy = 94.59% | Val_Accuracy = 77.01% | LossWeight = 0.23
#   • Fine   Accuracy = 48.10% | Val_Accuracy = 39.03% | LossWeight = 0.57
#
# Epoch 49: val_prediction_fine_accuracy improved from 0.38620 to 0.39030, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# 781/781 [==============================] - 54s 70ms/step - loss: 0.0974 - prediction_coarse_accuracy: 0.9569 - prediction_medium_accuracy: 0.9459 - prediction_fine_accuracy: 0.4810 - val_loss: 0.1282 - val_prediction_coarse_accuracy: 0.8591 - val_prediction_medium_accuracy: 0.7701 - val_prediction_fine_accuracy: 0.3903 - lr: 1.3528e-04
# Epoch 50/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0971 - prediction_coarse_accuracy: 0.9575 - prediction_medium_accuracy: 0.9455 - prediction_fine_accuracy: 0.4861
#   • Coarse Accuracy = 95.75% | Val_Accuracy = 85.90% | LossWeight = 0.20
#   • Medium Accuracy = 94.55% | Val_Accuracy = 77.12% | LossWeight = 0.23
#   • Fine   Accuracy = 48.61% | Val_Accuracy = 39.13% | LossWeight = 0.57
#
# Epoch 50: val_prediction_fine_accuracy improved from 0.39030 to 0.39130, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# 781/781 [==============================] - 55s 71ms/step - loss: 0.0971 - prediction_coarse_accuracy: 0.9575 - prediction_medium_accuracy: 0.9455 - prediction_fine_accuracy: 0.4861 - val_loss: 0.1273 - val_prediction_coarse_accuracy: 0.8590 - val_prediction_medium_accuracy: 0.7712 - val_prediction_fine_accuracy: 0.3913 - lr: 1.2851e-04
# Epoch 51/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0956 - prediction_coarse_accuracy: 0.9577 - prediction_medium_accuracy: 0.9464 - prediction_fine_accuracy: 0.4875
#   • Coarse Accuracy = 95.77% | Val_Accuracy = 85.95% | LossWeight = 0.20
#   • Medium Accuracy = 94.64% | Val_Accuracy = 77.16% | LossWeight = 0.23
#   • Fine   Accuracy = 48.75% | Val_Accuracy = 39.35% | LossWeight = 0.57
#
# Epoch 51: val_prediction_fine_accuracy improved from 0.39130 to 0.39350, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# 781/781 [==============================] - 55s 71ms/step - loss: 0.0956 - prediction_coarse_accuracy: 0.9577 - prediction_medium_accuracy: 0.9464 - prediction_fine_accuracy: 0.4875 - val_loss: 0.1271 - val_prediction_coarse_accuracy: 0.8595 - val_prediction_medium_accuracy: 0.7716 - val_prediction_fine_accuracy: 0.3935 - lr: 1.2209e-04
# Epoch 52/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0964 - prediction_coarse_accuracy: 0.9563 - prediction_medium_accuracy: 0.9446 - prediction_fine_accuracy: 0.4906
#   • Coarse Accuracy = 95.63% | Val_Accuracy = 86.28% | LossWeight = 0.21
#   • Medium Accuracy = 94.46% | Val_Accuracy = 76.84% | LossWeight = 0.23
#   • Fine   Accuracy = 49.06% | Val_Accuracy = 39.69% | LossWeight = 0.56
#
# Epoch 52: val_prediction_fine_accuracy improved from 0.39350 to 0.39690, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# 781/781 [==============================] - 54s 70ms/step - loss: 0.0964 - prediction_coarse_accuracy: 0.9563 - prediction_medium_accuracy: 0.9446 - prediction_fine_accuracy: 0.4906 - val_loss: 0.1270 - val_prediction_coarse_accuracy: 0.8628 - val_prediction_medium_accuracy: 0.7684 - val_prediction_fine_accuracy: 0.3969 - lr: 1.1598e-04
# Epoch 53/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0968 - prediction_coarse_accuracy: 0.9567 - prediction_medium_accuracy: 0.9456 - prediction_fine_accuracy: 0.4941
#   • Coarse Accuracy = 95.67% | Val_Accuracy = 86.21% | LossWeight = 0.21
#   • Medium Accuracy = 94.56% | Val_Accuracy = 76.94% | LossWeight = 0.23
#   • Fine   Accuracy = 49.41% | Val_Accuracy = 39.90% | LossWeight = 0.56
#
# Epoch 53: val_prediction_fine_accuracy improved from 0.39690 to 0.39900, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# ...
# Epoch 57/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0957 - prediction_coarse_accuracy: 0.9582 - prediction_medium_accuracy: 0.9478 - prediction_fine_accuracy: 0.5049
#   • Coarse Accuracy = 95.82% | Val_Accuracy = 86.28% | LossWeight = 0.20
#   • Medium Accuracy = 94.78% | Val_Accuracy = 77.11% | LossWeight = 0.23
#   • Fine   Accuracy = 50.49% | Val_Accuracy = 40.49% | LossWeight = 0.57
#
# Epoch 57: val_prediction_fine_accuracy improved from 0.40320 to 0.40490, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# 781/781 [==============================] - 54s 70ms/step - loss: 0.0957 - prediction_coarse_accuracy: 0.9582 - prediction_medium_accuracy: 0.9478 - prediction_fine_accuracy: 0.5049 - val_loss: 0.1261 - val_prediction_coarse_accuracy: 0.8628 - val_prediction_medium_accuracy: 0.7711 - val_prediction_fine_accuracy: 0.4049 - lr: 8.9745e-05
# Epoch 58/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0946 - prediction_coarse_accuracy: 0.9586 - prediction_medium_accuracy: 0.9470 - prediction_fine_accuracy: 0.5111
#   • Coarse Accuracy = 95.86% | Val_Accuracy = 86.55% | LossWeight = 0.20
#   • Medium Accuracy = 94.70% | Val_Accuracy = 77.30% | LossWeight = 0.23
#   • Fine   Accuracy = 51.11% | Val_Accuracy = 40.42% | LossWeight = 0.56
#
# Epoch 58: val_prediction_fine_accuracy did not improve from 0.40490
# 781/781 [==============================] - 53s 68ms/step - loss: 0.0946 - prediction_coarse_accuracy: 0.9586 - prediction_medium_accuracy: 0.9470 - prediction_fine_accuracy: 0.5111 - val_loss: 0.1263 - val_prediction_coarse_accuracy: 0.8655 - val_prediction_medium_accuracy: 0.7730 - val_prediction_fine_accuracy: 0.4042 - lr: 8.5258e-05
# Epoch 59/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0942 - prediction_coarse_accuracy: 0.9589 - prediction_medium_accuracy: 0.9480 - prediction_fine_accuracy: 0.5116
#   • Coarse Accuracy = 95.89% | Val_Accuracy = 86.51% | LossWeight = 0.20
#   • Medium Accuracy = 94.80% | Val_Accuracy = 77.45% | LossWeight = 0.23
#   • Fine   Accuracy = 51.16% | Val_Accuracy = 40.92% | LossWeight = 0.56
#
# Epoch 59: val_prediction_fine_accuracy improved from 0.40490 to 0.40920, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# 781/781 [==============================] - 53s 68ms/step - loss: 0.0942 - prediction_coarse_accuracy: 0.9589 - prediction_medium_accuracy: 0.9480 - prediction_fine_accuracy: 0.5116 - val_loss: 0.1255 - val_prediction_coarse_accuracy: 0.8651 - val_prediction_medium_accuracy: 0.7745 - val_prediction_fine_accuracy: 0.4092 - lr: 8.0995e-05
# Epoch 60/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0947 - prediction_coarse_accuracy: 0.9587 - prediction_medium_accuracy: 0.9476 - prediction_fine_accuracy: 0.5121
#   • Coarse Accuracy = 95.87% | Val_Accuracy = 86.31% | LossWeight = 0.20
#   • Medium Accuracy = 94.76% | Val_Accuracy = 77.59% | LossWeight = 0.23
#   • Fine   Accuracy = 51.21% | Val_Accuracy = 40.88% | LossWeight = 0.56
#
# Epoch 60: val_prediction_fine_accuracy did not improve from 0.40920
# 781/781 [==============================] - 51s 65ms/step - loss: 0.0947 - prediction_coarse_accuracy: 0.9587 - prediction_medium_accuracy: 0.9476 - prediction_fine_accuracy: 0.5121 - val_loss: 0.1253 - val_prediction_coarse_accuracy: 0.8631 - val_prediction_medium_accuracy: 0.7759 - val_prediction_fine_accuracy: 0.4088 - lr: 7.6945e-05
# Epoch 61/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0953 - prediction_coarse_accuracy: 0.9581 - prediction_medium_accuracy: 0.9464 - prediction_fine_accuracy: 0.5134
#   • Coarse Accuracy = 95.81% | Val_Accuracy = 86.35% | LossWeight = 0.21
#   • Medium Accuracy = 94.64% | Val_Accuracy = 77.35% | LossWeight = 0.24
#   • Fine   Accuracy = 51.34% | Val_Accuracy = 41.15% | LossWeight = 0.56
#
# Epoch 61: val_prediction_fine_accuracy improved from 0.40920 to 0.41150, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# 781/781 [==============================] - 51s 65ms/step - loss: 0.0953 - prediction_coarse_accuracy: 0.9581 - prediction_medium_accuracy: 0.9464 - prediction_fine_accuracy: 0.5134 - val_loss: 0.1253 - val_prediction_coarse_accuracy: 0.8635 - val_prediction_medium_accuracy: 0.7735 - val_prediction_fine_accuracy: 0.4115 - lr: 7.3098e-05
# Epoch 62/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0942 - prediction_coarse_accuracy: 0.9578 - prediction_medium_accuracy: 0.9468 - prediction_fine_accuracy: 0.5129
#   • Coarse Accuracy = 95.78% | Val_Accuracy = 86.35% | LossWeight = 0.21
#   • Medium Accuracy = 94.68% | Val_Accuracy = 77.51% | LossWeight = 0.23
#   • Fine   Accuracy = 51.29% | Val_Accuracy = 41.28% | LossWeight = 0.56
#
# Epoch 62: val_prediction_fine_accuracy improved from 0.41150 to 0.41280, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# 781/781 [==============================] - 48s 62ms/step - loss: 0.0942 - prediction_coarse_accuracy: 0.9578 - prediction_medium_accuracy: 0.9468 - prediction_fine_accuracy: 0.5129 - val_loss: 0.1256 - val_prediction_coarse_accuracy: 0.8635 - val_prediction_medium_accuracy: 0.7751 - val_prediction_fine_accuracy: 0.4128 - lr: 6.9443e-05
# Epoch 63/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0949 - prediction_coarse_accuracy: 0.9573 - prediction_medium_accuracy: 0.9466 - prediction_fine_accuracy: 0.5123
#   • Coarse Accuracy = 95.73% | Val_Accuracy = 86.49% | LossWeight = 0.21
#   • Medium Accuracy = 94.66% | Val_Accuracy = 77.43% | LossWeight = 0.23
#   • Fine   Accuracy = 51.23% | Val_Accuracy = 41.38% | LossWeight = 0.56
#
# Epoch 63: val_prediction_fine_accuracy improved from 0.41280 to 0.41380, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# 781/781 [==============================] - 48s 61ms/step - loss: 0.0949 - prediction_coarse_accuracy: 0.9573 - prediction_medium_accuracy: 0.9466 - prediction_fine_accuracy: 0.5123 - val_loss: 0.1254 - val_prediction_coarse_accuracy: 0.8649 - val_prediction_medium_accuracy: 0.7743 - val_prediction_fine_accuracy: 0.4138 - lr: 6.5971e-05
# Epoch 64/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0944 - prediction_coarse_accuracy: 0.9569 - prediction_medium_accuracy: 0.9462 - prediction_fine_accuracy: 0.5178
#   • Coarse Accuracy = 95.69% | Val_Accuracy = 86.66% | LossWeight = 0.21
#   • Medium Accuracy = 94.62% | Val_Accuracy = 77.60% | LossWeight = 0.24
#   • Fine   Accuracy = 51.78% | Val_Accuracy = 41.30% | LossWeight = 0.55
#
# Epoch 64: val_prediction_fine_accuracy did not improve from 0.41380
# 781/781 [==============================] - 94s 121ms/step - loss: 0.0944 - prediction_coarse_accuracy: 0.9569 - prediction_medium_accuracy: 0.9462 - prediction_fine_accuracy: 0.5178 - val_loss: 0.1248 - val_prediction_coarse_accuracy: 0.8666 - val_prediction_medium_accuracy: 0.7760 - val_prediction_fine_accuracy: 0.4130 - lr: 6.2672e-05
# Epoch 65/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0952 - prediction_coarse_accuracy: 0.9573 - prediction_medium_accuracy: 0.9466 - prediction_fine_accuracy: 0.5167
#   • Coarse Accuracy = 95.73% | Val_Accuracy = 86.79% | LossWeight = 0.21
#   • Medium Accuracy = 94.66% | Val_Accuracy = 77.65% | LossWeight = 0.24
#   • Fine   Accuracy = 51.67% | Val_Accuracy = 41.88% | LossWeight = 0.55
#
# Epoch 65: val_prediction_fine_accuracy improved from 0.41380 to 0.41880, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# 781/781 [==============================] - 122s 157ms/step - loss: 0.0952 - prediction_coarse_accuracy: 0.9573 - prediction_medium_accuracy: 0.9466 - prediction_fine_accuracy: 0.5167 - val_loss: 0.1248 - val_prediction_coarse_accuracy: 0.8679 - val_prediction_medium_accuracy: 0.7765 - val_prediction_fine_accuracy: 0.4188 - lr: 5.9539e-05
# Epoch 66/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0948 - prediction_coarse_accuracy: 0.9581 - prediction_medium_accuracy: 0.9474 - prediction_fine_accuracy: 0.5212
#   • Coarse Accuracy = 95.81% | Val_Accuracy = 86.59% | LossWeight = 0.21
#   • Medium Accuracy = 94.74% | Val_Accuracy = 77.56% | LossWeight = 0.24
#   • Fine   Accuracy = 52.12% | Val_Accuracy = 41.89% | LossWeight = 0.56
#
# Epoch 66: val_prediction_fine_accuracy improved from 0.41880 to 0.41890, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# 781/781 [==============================] - 135s 173ms/step - loss: 0.0948 - prediction_coarse_accuracy: 0.9581 - prediction_medium_accuracy: 0.9474 - prediction_fine_accuracy: 0.5212 - val_loss: 0.1248 - val_prediction_coarse_accuracy: 0.8659 - val_prediction_medium_accuracy: 0.7756 - val_prediction_fine_accuracy: 0.4189 - lr: 5.6562e-05
# Epoch 67/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0945 - prediction_coarse_accuracy: 0.9566 - prediction_medium_accuracy: 0.9465 - prediction_fine_accuracy: 0.5240
#   • Coarse Accuracy = 95.66% | Val_Accuracy = 86.60% | LossWeight = 0.21
#   • Medium Accuracy = 94.65% | Val_Accuracy = 77.69% | LossWeight = 0.24
#   • Fine   Accuracy = 52.40% | Val_Accuracy = 41.75% | LossWeight = 0.55
#
# Epoch 67: val_prediction_fine_accuracy did not improve from 0.41890
# 781/781 [==============================] - 136s 174ms/step - loss: 0.0945 - prediction_coarse_accuracy: 0.9566 - prediction_medium_accuracy: 0.9465 - prediction_fine_accuracy: 0.5240 - val_loss: 0.1244 - val_prediction_coarse_accuracy: 0.8660 - val_prediction_medium_accuracy: 0.7769 - val_prediction_fine_accuracy: 0.4175 - lr: 5.3734e-05
# Epoch 68/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0944 - prediction_coarse_accuracy: 0.9581 - prediction_medium_accuracy: 0.9478 - prediction_fine_accuracy: 0.5208
#   • Coarse Accuracy = 95.81% | Val_Accuracy = 86.64% | LossWeight = 0.21
#   • Medium Accuracy = 94.78% | Val_Accuracy = 77.53% | LossWeight = 0.23
#   • Fine   Accuracy = 52.08% | Val_Accuracy = 41.96% | LossWeight = 0.56
#
# Epoch 68: val_prediction_fine_accuracy improved from 0.41890 to 0.41960, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# 781/781 [==============================] - 120s 154ms/step - loss: 0.0944 - prediction_coarse_accuracy: 0.9581 - prediction_medium_accuracy: 0.9478 - prediction_fine_accuracy: 0.5208 - val_loss: 0.1251 - val_prediction_coarse_accuracy: 0.8664 - val_prediction_medium_accuracy: 0.7753 - val_prediction_fine_accuracy: 0.4196 - lr: 5.1047e-05
# Epoch 69/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0945 - prediction_coarse_accuracy: 0.9570 - prediction_medium_accuracy: 0.9466 - prediction_fine_accuracy: 0.5227
#   • Coarse Accuracy = 95.70% | Val_Accuracy = 86.51% | LossWeight = 0.21
#   • Medium Accuracy = 94.66% | Val_Accuracy = 77.70% | LossWeight = 0.24
#   • Fine   Accuracy = 52.27% | Val_Accuracy = 41.86% | LossWeight = 0.55
#
# Epoch 69: val_prediction_fine_accuracy did not improve from 0.41960
# 781/781 [==============================] - 118s 151ms/step - loss: 0.0945 - prediction_coarse_accuracy: 0.9570 - prediction_medium_accuracy: 0.9466 - prediction_fine_accuracy: 0.5227 - val_loss: 0.1243 - val_prediction_coarse_accuracy: 0.8651 - val_prediction_medium_accuracy: 0.7770 - val_prediction_fine_accuracy: 0.4186 - lr: 4.8495e-05
# Epoch 70/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0944 - prediction_coarse_accuracy: 0.9571 - prediction_medium_accuracy: 0.9467 - prediction_fine_accuracy: 0.5246
#   • Coarse Accuracy = 95.71% | Val_Accuracy = 86.58% | LossWeight = 0.21
#   • Medium Accuracy = 94.67% | Val_Accuracy = 77.78% | LossWeight = 0.24
#   • Fine   Accuracy = 52.46% | Val_Accuracy = 41.77% | LossWeight = 0.55
#
# Epoch 70: val_prediction_fine_accuracy did not improve from 0.41960
# 781/781 [==============================] - 140s 179ms/step - loss: 0.0944 - prediction_coarse_accuracy: 0.9571 - prediction_medium_accuracy: 0.9467 - prediction_fine_accuracy: 0.5246 - val_loss: 0.1245 - val_prediction_coarse_accuracy: 0.8658 - val_prediction_medium_accuracy: 0.7778 - val_prediction_fine_accuracy: 0.4177 - lr: 4.6070e-05
# Epoch 71/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0937 - prediction_coarse_accuracy: 0.9594 - prediction_medium_accuracy: 0.9492 - prediction_fine_accuracy: 0.5265
#   • Coarse Accuracy = 95.94% | Val_Accuracy = 86.69% | LossWeight = 0.21
#   • Medium Accuracy = 94.92% | Val_Accuracy = 77.79% | LossWeight = 0.23
#   • Fine   Accuracy = 52.65% | Val_Accuracy = 42.08% | LossWeight = 0.56
#
# Epoch 71: val_prediction_fine_accuracy improved from 0.41960 to 0.42080, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# 781/781 [==============================] - 60s 77ms/step - loss: 0.0937 - prediction_coarse_accuracy: 0.9594 - prediction_medium_accuracy: 0.9492 - prediction_fine_accuracy: 0.5265 - val_loss: 0.1245 - val_prediction_coarse_accuracy: 0.8669 - val_prediction_medium_accuracy: 0.7779 - val_prediction_fine_accuracy: 0.4208 - lr: 4.3766e-05
# Epoch 72/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0937 - prediction_coarse_accuracy: 0.9594 - prediction_medium_accuracy: 0.9480 - prediction_fine_accuracy: 0.5290
#   • Coarse Accuracy = 95.94% | Val_Accuracy = 86.65% | LossWeight = 0.21
#   • Medium Accuracy = 94.80% | Val_Accuracy = 77.70% | LossWeight = 0.24
#   • Fine   Accuracy = 52.90% | Val_Accuracy = 42.11% | LossWeight = 0.56
#
# Epoch 72: val_prediction_fine_accuracy improved from 0.42080 to 0.42110, saving model to ../../logs/MOD_2/4_CIFAR_100/HD_CapsNet/TD_W_C_loss_P16\epoch-best.h5
# 781/781 [==============================] - 48s 61ms/step - loss: 0.0937 - prediction_coarse_accuracy: 0.9594 - prediction_medium_accuracy: 0.9480 - prediction_fine_accuracy: 0.5290 - val_loss: 0.1238 - val_prediction_coarse_accuracy: 0.8665 - val_prediction_medium_accuracy: 0.7770 - val_prediction_fine_accuracy: 0.4211 - lr: 4.1578e-05
# Epoch 73/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0938 - prediction_coarse_accuracy: 0.9583 - prediction_medium_accuracy: 0.9477 - prediction_fine_accuracy: 0.5316
#   • Coarse Accuracy = 95.83% | Val_Accuracy = 86.64% | LossWeight = 0.21
#   • Medium Accuracy = 94.77% | Val_Accuracy = 77.60% | LossWeight = 0.24
#   • Fine   Accuracy = 53.16% | Val_Accuracy = 42.01% | LossWeight = 0.55
#
# Epoch 73: val_prediction_fine_accuracy did not improve from 0.42110
# 781/781 [==============================] - 48s 61ms/step - loss: 0.0938 - prediction_coarse_accuracy: 0.9583 - prediction_medium_accuracy: 0.9477 - prediction_fine_accuracy: 0.5316 - val_loss: 0.1238 - val_prediction_coarse_accuracy: 0.8664 - val_prediction_medium_accuracy: 0.7760 - val_prediction_fine_accuracy: 0.4201 - lr: 3.9499e-05
# Epoch 74/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0943 - prediction_coarse_accuracy: 0.9575 - prediction_medium_accuracy: 0.9469 - prediction_fine_accuracy: 0.5286
#   • Coarse Accuracy = 95.75% | Val_Accuracy = 86.66% | LossWeight = 0.21
#   • Medium Accuracy = 94.69% | Val_Accuracy = 77.71% | LossWeight = 0.24
#   • Fine   Accuracy = 52.86% | Val_Accuracy = 41.98% | LossWeight = 0.55
#
# Epoch 74: val_prediction_fine_accuracy did not improve from 0.42110
# 781/781 [==============================] - 51s 66ms/step - loss: 0.0943 - prediction_coarse_accuracy: 0.9575 - prediction_medium_accuracy: 0.9469 - prediction_fine_accuracy: 0.5286 - val_loss: 0.1246 - val_prediction_coarse_accuracy: 0.8666 - val_prediction_medium_accuracy: 0.7771 - val_prediction_fine_accuracy: 0.4198 - lr: 3.7524e-05
# Epoch 75/100
# 781/781 [==============================] - ETA: 0s - loss: 0.0938 - prediction_coarse_accuracy: 0.9592 - prediction_medium_accuracy: 0.9478 - prediction_fine_accuracy: 0.5338

# %%
try:
    history_dict = history.history

    plotter = tfdocs.plots.HistoryPlotter()
    plotter.plot({"Coarse": history}, metric = "prediction_coarse_accuracy")
    plotter.plot({"Medium": history}, metric = "prediction_medium_accuracy")
    plotter.plot({"Fine": history}, metric = "prediction_fine_accuracy")
    plt.title("Model Accuracy")
    plt.ylim([0,1])
except:
    print('Trained model weights loaded')

# %%
try:
    plotter = tfdocs.plots.HistoryPlotter()
    plotter.plot({"loss": history}, metric = "loss")
    plt.title("Model Loss")
    plt.ylim([0,1])
except:
    print('Trained model weights loaded')

# %% [markdown]
# ## Model Analysis

# %%
final_model = keras.Model(model.inputs[:1], model.output)

lossfn = models.MarginLoss()
final_model.compile(optimizer='adam', 
                    loss={'prediction_fine' : lossfn,
                          'prediction_medium' : lossfn,
                          'prediction_coarse' : lossfn},

                    loss_weights={'prediction_fine' : lossweight['fine_lw'],
                                  'prediction_medium' : lossweight['medium_lw'],
                                  'prediction_coarse' : lossweight['coarse_lw']},

                    metrics={'prediction_fine': 'accuracy',
                             'prediction_medium': 'accuracy',
                             'prediction_coarse': 'accuracy'
                            }
                   )

# %%
model_analysis = models.model_analysis(final_model, dataset)
results = model_analysis.evaluate()
predictions = model_analysis.prediction()

# %%
true_label = [dataset['y_test_coarse'],dataset['y_test_medium'],dataset['y_test_fine']]
pred_label = [predictions[0],predictions[1],predictions[2]]
metrics.lvl_wise_metric(true_label,pred_label)

# %%
h_measurements,consistency,exact_match = metrics.hmeasurements(true_label,
                                       pred_label,
                                       dataset['tree'])
print('\nHierarchical Precision =',h_measurements[0],
      '\nHierarchical Recall =', h_measurements[1],
      '\nHierarchical F1-Score =',h_measurements[2],
      '\nConsistency = ', consistency,
      '\nExact Match = ', exact_match,
     )

# %% [markdown]
# # Training Again

# %%
model_save_dir = str(directory+'/trained_model_2.h5')
try:
    model.load_weights(model_save_dir)
except:
    history = model.fit(training_generator,
                        steps_per_epoch = int(dataset['x_train'].shape[0] / train_params["batch_size"]),
                        epochs = train_params["n_epochs"],
                        validation_data = ([dataset['x_test'],
                                            dataset['y_test_coarse'],dataset['y_test_medium'],dataset['y_test_fine']],
                                           [dataset['y_test_coarse'],dataset['y_test_medium'],dataset['y_test_fine']]),
                        callbacks = [tb,log,change_lw,lr_decay,checkpoint],
                        verbose=1)
    
    model.save_weights(model_save_dir)

# %%
history_dict = history.history

# %%
plotter = tfdocs.plots.HistoryPlotter()
plotter.plot({"Coarse": history}, metric = "prediction_coarse_accuracy")
plotter.plot({"Medium": history}, metric = "prediction_medium_accuracy")
plotter.plot({"Fine": history}, metric = "prediction_fine_accuracy")
plt.title("Model Accuracy")
plt.ylim([0,1])

# %%
plotter = tfdocs.plots.HistoryPlotter()
plotter.plot({"loss": history}, metric = "loss")
plt.title("Model Loss")
plt.ylim([0,1])

# %% [markdown]
# ## Model Analysis

# %%
final_model = keras.Model(model.inputs[:1], model.output)

lossfn = models.MarginLoss()
final_model.compile(optimizer='adam', 
                    loss={'prediction_fine' : lossfn,
                          'prediction_medium' : lossfn,
                          'prediction_coarse' : lossfn},

                    loss_weights={'prediction_fine' : lossweight['fine_lw'],
                                  'prediction_medium' : lossweight['medium_lw'],
                                  'prediction_coarse' : lossweight['coarse_lw']},

                    metrics={'prediction_fine': 'accuracy',
                             'prediction_medium': 'accuracy',
                             'prediction_coarse': 'accuracy'
                            }
                   )

# %%
model_analysis = models.model_analysis(final_model, dataset)
results = model_analysis.evaluate()
predictions = model_analysis.prediction()

# %%
true_label = [dataset['y_test_coarse'],dataset['y_test_medium'],dataset['y_test_fine']]
pred_label = [predictions[0],predictions[1],predictions[2]]
metrics.lvl_wise_metric(true_label,pred_label)

# %%
h_measurements,consistency,exact_match = metrics.hmeasurements(true_label,
                                       pred_label,
                                       dataset['tree'])
print('\nHierarchical Precision =',h_measurements[0],
      '\nHierarchical Recall =', h_measurements[1],
      '\nHierarchical F1-Score =',h_measurements[2],
      '\nConsistency = ', consistency,
      '\nExact Match = ', exact_match,
     )
